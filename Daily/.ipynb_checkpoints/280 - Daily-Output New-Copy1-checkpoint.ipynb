# %% [markdown]
# #### Restart and Run All

# %%
import numpy as np
import os
import pandas as pd
from datetime import date, timedelta
from sqlalchemy import create_engine
from pandas.tseries.offsets import BDay

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

data_path = "../data/"
#data_path = "\\users\\user\\onedrive\\a7\\Data"
csv_path = "\\Users\\User\\iCloudDrive\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"
osd_path = "\\Users\\User\\OneDrive\\Documents\\obsidian-git-sync\\Data\\"

today = date.today()
today
# Out:
# datetime.date(2023, 4, 17)

# %% [markdown]
# ### Today = Last business day

# %%
#today = date(2023, 3, 13)
today
# Out:
# datetime.date(2023, 4, 17)

# %%
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(3)
yesterday = today - num_business_days
yesterday = yesterday.date()
print(f'today: {today}')
print(f'yesterday: {yesterday}')
# Out:
# today: 2023-04-17
# yesterday: 2023-04-12

# %%
cols = 'name fm_date to_date fm_price to_price qty max_price min_price percent status'.split()

format_dict = {
    'fm_price':'{:.2f}','to_price':'{:.2f}','diff':'{:.2f}',
    'max_price':'{:.2f}','min_price':'{:.2f}',
    'volume':'{:,.2f}','beta':'{:,.2f}',
    'pct':'{:,.2f}%','percent':'{:,.2f}%',   
    'fm_date':'{:%Y-%m-%d}','to_date':'{:%Y-%m-%d}',
    'created_at':'{:%Y-%m-%d}','updated_at':'{:%Y-%m-%d}',
    
    'qty':'{:,}','available_qty':'{:,}',
    'cost':'{:.2f}','buy_target':'{:.2f}','sell_target':'{:.2f}',
}

# %% [markdown]
# ### Begin of Tables in the process

# %%
sql = """
SELECT * 
FROM sales 
ORDER BY id DESC LIMIT 1
"""
tmp = pd.read_sql(sql, conlite)
tmp["fm_date"] = pd.to_datetime(tmp["fm_date"])
tmp["to_date"] = pd.to_datetime(tmp["to_date"])
tmp["created_at"] = pd.to_datetime(tmp["created_at"])
tmp["updated_at"] = pd.to_datetime(tmp["updated_at"])
tmp.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_255ba_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >fm_date</th>
#       <th class="col_heading level0 col3" >to_date</th>
#       <th class="col_heading level0 col4" >days</th>
#       <th class="col_heading level0 col5" >fm_price</th>
#       <th class="col_heading level0 col6" >to_price</th>
#       <th class="col_heading level0 col7" >diff</th>
#       <th class="col_heading level0 col8" >pct</th>
#       <th class="col_heading level0 col9" >ttl_spread</th>
#       <th class="col_heading level0 col10" >avg_spread</th>
#       <th class="col_heading level0 col11" >max_price</th>
#       <th class="col_heading level0 col12" >min_price</th>
#       <th class="col_heading level0 col13" >qty</th>
#       <th class="col_heading level0 col14" >created_at</th>
#       <th class="col_heading level0 col15" >updated_at</th>
#       <th class="col_heading level0 col16" >latest_date_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_255ba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_255ba_row0_col0" class="data row0 col0" >1249126</td>
#       <td id="T_255ba_row0_col1" class="data row0 col1" >TMT</td>
#       <td id="T_255ba_row0_col2" class="data row0 col2" >2023-04-10</td>
#       <td id="T_255ba_row0_col3" class="data row0 col3" >2023-04-12</td>
#       <td id="T_255ba_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_255ba_row0_col5" class="data row0 col5" >7.75</td>
#       <td id="T_255ba_row0_col6" class="data row0 col6" >7.85</td>
#       <td id="T_255ba_row0_col7" class="data row0 col7" >0.10</td>
#       <td id="T_255ba_row0_col8" class="data row0 col8" >1.29%</td>
#       <td id="T_255ba_row0_col9" class="data row0 col9" >2</td>
#       <td id="T_255ba_row0_col10" class="data row0 col10" >1</td>
#       <td id="T_255ba_row0_col11" class="data row0 col11" >7.85</td>
#       <td id="T_255ba_row0_col12" class="data row0 col12" >7.60</td>
#       <td id="T_255ba_row0_col13" class="data row0 col13" >361,522</td>
#       <td id="T_255ba_row0_col14" class="data row0 col14" >2023-04-16</td>
#       <td id="T_255ba_row0_col15" class="data row0 col15" >2023-04-16</td>
#       <td id="T_255ba_row0_col16" class="data row0 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
names = tmp["name"]
type(names)
# Out:
# pandas.core.series.Series

# %%
name = names.to_string(index=False)
type(name)
# Out:
# str

# %%
sql = """
SELECT * 
FROM stocks
WHERE name = '%s'
"""
sql = sql % name
print(sql)
tmp = pd.read_sql(sql, conlite)
tmp.style.format(format_dict)
# Out:
# SELECT *
# FROM stocks
# WHERE name = 'TMT'
# <style type="text/css">
# </style>
# <table id="T_dd179_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >max_price</th>
#       <th class="col_heading level0 col3" >min_price</th>
#       <th class="col_heading level0 col4" >status</th>
#       <th class="col_heading level0 col5" >buy_target</th>
#       <th class="col_heading level0 col6" >sell_target</th>
#       <th class="col_heading level0 col7" >volume</th>
#       <th class="col_heading level0 col8" >beta</th>
#       <th class="col_heading level0 col9" >cost</th>
#       <th class="col_heading level0 col10" >qty</th>
#       <th class="col_heading level0 col11" >buy_spread</th>
#       <th class="col_heading level0 col12" >sell_spread</th>
#       <th class="col_heading level0 col13" >available_qty</th>
#       <th class="col_heading level0 col14" >bl</th>
#       <th class="col_heading level0 col15" >sh</th>
#       <th class="col_heading level0 col16" >reason</th>
#       <th class="col_heading level0 col17" >market</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd179_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd179_row0_col0" class="data row0 col0" >645</td>
#       <td id="T_dd179_row0_col1" class="data row0 col1" >TMT</td>
#       <td id="T_dd179_row0_col2" class="data row0 col2" >15.00</td>
#       <td id="T_dd179_row0_col3" class="data row0 col3" >9.70</td>
#       <td id="T_dd179_row0_col4" class="data row0 col4" >S</td>
#       <td id="T_dd179_row0_col5" class="data row0 col5" >7.40</td>
#       <td id="T_dd179_row0_col6" class="data row0 col6" >8.70</td>
#       <td id="T_dd179_row0_col7" class="data row0 col7" >13.30</td>
#       <td id="T_dd179_row0_col8" class="data row0 col8" >1.01</td>
#       <td id="T_dd179_row0_col9" class="data row0 col9" >10.20</td>
#       <td id="T_dd179_row0_col10" class="data row0 col10" >12,000</td>
#       <td id="T_dd179_row0_col11" class="data row0 col11" >-16</td>
#       <td id="T_dd179_row0_col12" class="data row0 col12" >15</td>
#       <td id="T_dd179_row0_col13" class="data row0 col13" >36,000</td>
#       <td id="T_dd179_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_dd179_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_dd179_row0_col16" class="data row0 col16" >RD25pct</td>
#       <td id="T_dd179_row0_col17" class="data row0 col17" >SET</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### End of Tables in the process

# %%
sql = """
SELECT DISTINCT a.name
FROM sales a 
WHERE to_date = '%s'
ORDER BY a.name
"""
sql = sql % yesterday
print(sql)
tmp = pd.read_sql(sql, conlite)
tmp
# Out:
# SELECT DISTINCT a.name
# FROM sales a
# WHERE to_date = '2023-04-12'
# ORDER BY a.name
#       name
# 0    BANPU
# 1      BCH
# 2   GVREIT
# 3      IVL
# 4    JASIF
# 5    JMART
# 6      JMT
# 7      MCS
# 8      ORI
# 9    PTTGC
# 10    SENA
# 11  SINGER
# 12     STA
# 13   TFFIF
# 14     TMT

# %%
sql = """
SELECT a.name,fm_date,to_date,fm_price,to_price,
a.qty,a.max_price,a.min_price,t.status,t.market
FROM sales a 
JOIN stocks t ON a.name = t.name 
WHERE to_date = '%s' AND t.status IN ("B","I", "O", "S") 
ORDER BY t.status, a.name
"""
sql = sql % yesterday
print(sql)
# Out:
# SELECT a.name,fm_date,to_date,fm_price,to_price,
# a.qty,a.max_price,a.min_price,t.status,t.market
# FROM sales a
# JOIN stocks t ON a.name = t.name
# WHERE to_date = '2023-04-12' AND t.status IN ("B","I", "O", "S")
# ORDER BY t.status, a.name

# %% [markdown]
# ### This statement causes program to hang when there is no data

# %%
df = pd.read_sql(sql, conlite)
#df.set_index(["name"], inplace=True)
df['fm_date'] = pd.to_datetime(df['fm_date'])
df['to_date'] = pd.to_datetime(df['to_date'])
df.eval('diff = to_price - fm_price',inplace=True)
df['percent'] = round(df['diff']/df['fm_price']*100,2)
df.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d9519_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >fm_date</th>
#       <th class="col_heading level0 col2" >to_date</th>
#       <th class="col_heading level0 col3" >fm_price</th>
#       <th class="col_heading level0 col4" >to_price</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >max_price</th>
#       <th class="col_heading level0 col7" >min_price</th>
#       <th class="col_heading level0 col8" >status</th>
#       <th class="col_heading level0 col9" >market</th>
#       <th class="col_heading level0 col10" >diff</th>
#       <th class="col_heading level0 col11" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9519_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9519_row0_col0" class="data row0 col0" >IVL</td>
#       <td id="T_d9519_row0_col1" class="data row0 col1" >2023-04-11</td>
#       <td id="T_d9519_row0_col2" class="data row0 col2" >2023-04-12</td>
#       <td id="T_d9519_row0_col3" class="data row0 col3" >34.25</td>
#       <td id="T_d9519_row0_col4" class="data row0 col4" >34.00</td>
#       <td id="T_d9519_row0_col5" class="data row0 col5" >16,141,100</td>
#       <td id="T_d9519_row0_col6" class="data row0 col6" >34.75</td>
#       <td id="T_d9519_row0_col7" class="data row0 col7" >33.25</td>
#       <td id="T_d9519_row0_col8" class="data row0 col8" >B</td>
#       <td id="T_d9519_row0_col9" class="data row0 col9" >SET50</td>
#       <td id="T_d9519_row0_col10" class="data row0 col10" >-0.25</td>
#       <td id="T_d9519_row0_col11" class="data row0 col11" >-0.73%</td>
#     </tr>
#     <tr>
#       <th id="T_d9519_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d9519_row1_col0" class="data row1 col0" >JMART</td>
#       <td id="T_d9519_row1_col1" class="data row1 col1" >2023-04-11</td>
#       <td id="T_d9519_row1_col2" class="data row1 col2" >2023-04-12</td>
#       <td id="T_d9519_row1_col3" class="data row1 col3" >21.70</td>
#       <td id="T_d9519_row1_col4" class="data row1 col4" >21.20</td>
#       <td id="T_d9519_row1_col5" class="data row1 col5" >22,400,967</td>
#       <td id="T_d9519_row1_col6" class="data row1 col6" >22.00</td>
#       <td id="T_d9519_row1_col7" class="data row1 col7" >21.00</td>
#       <td id="T_d9519_row1_col8" class="data row1 col8" >B</td>
#       <td id="T_d9519_row1_col9" class="data row1 col9" >SET50</td>
#       <td id="T_d9519_row1_col10" class="data row1 col10" >-0.50</td>
#       <td id="T_d9519_row1_col11" class="data row1 col11" >-2.30%</td>
#     </tr>
#     <tr>
#       <th id="T_d9519_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d9519_row2_col0" class="data row2 col0" >JMT</td>
#       <td id="T_d9519_row2_col1" class="data row2 col1" >2023-04-11</td>
#       <td id="T_d9519_row2_col2" class="data row2 col2" >2023-04-12</td>
#       <td id="T_d9519_row2_col3" class="data row2 col3" >43.75</td>
#       <td id="T_d9519_row2_col4" class="data row2 col4" >42.00</td>
#       <td id="T_d9519_row2_col5" class="data row2 col5" >11,509,145</td>
#       <td id="T_d9519_row2_col6" class="data row2 col6" >44.00</td>
#       <td id="T_d9519_row2_col7" class="data row2 col7" >41.75</td>
#       <td id="T_d9519_row2_col8" class="data row2 col8" >B</td>
#       <td id="T_d9519_row2_col9" class="data row2 col9" >SET50</td>
#       <td id="T_d9519_row2_col10" class="data row2 col10" >-1.75</td>
#       <td id="T_d9519_row2_col11" class="data row2 col11" >-4.00%</td>
#     </tr>
#     <tr>
#       <th id="T_d9519_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d9519_row3_col0" class="data row3 col0" >SINGER</td>
#       <td id="T_d9519_row3_col1" class="data row3 col1" >2023-04-12</td>
#       <td id="T_d9519_row3_col2" class="data row3 col2" >2023-04-12</td>
#       <td id="T_d9519_row3_col3" class="data row3 col3" >16.90</td>
#       <td id="T_d9519_row3_col4" class="data row3 col4" >16.90</td>
#       <td id="T_d9519_row3_col5" class="data row3 col5" >6,078,823</td>
#       <td id="T_d9519_row3_col6" class="data row3 col6" >17.30</td>
#       <td id="T_d9519_row3_col7" class="data row3 col7" >16.70</td>
#       <td id="T_d9519_row3_col8" class="data row3 col8" >B</td>
#       <td id="T_d9519_row3_col9" class="data row3 col9" >SET100</td>
#       <td id="T_d9519_row3_col10" class="data row3 col10" >0.00</td>
#       <td id="T_d9519_row3_col11" class="data row3 col11" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_d9519_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d9519_row4_col0" class="data row4 col0" >STA</td>
#       <td id="T_d9519_row4_col1" class="data row4 col1" >2023-04-12</td>
#       <td id="T_d9519_row4_col2" class="data row4 col2" >2023-04-12</td>
#       <td id="T_d9519_row4_col3" class="data row4 col3" >22.20</td>
#       <td id="T_d9519_row4_col4" class="data row4 col4" >22.20</td>
#       <td id="T_d9519_row4_col5" class="data row4 col5" >4,353,861</td>
#       <td id="T_d9519_row4_col6" class="data row4 col6" >22.50</td>
#       <td id="T_d9519_row4_col7" class="data row4 col7" >22.00</td>
#       <td id="T_d9519_row4_col8" class="data row4 col8" >B</td>
#       <td id="T_d9519_row4_col9" class="data row4 col9" >SET100</td>
#       <td id="T_d9519_row4_col10" class="data row4 col10" >0.00</td>
#       <td id="T_d9519_row4_col11" class="data row4 col11" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_d9519_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d9519_row5_col0" class="data row5 col0" >BANPU</td>
#       <td id="T_d9519_row5_col1" class="data row5 col1" >2023-04-12</td>
#       <td id="T_d9519_row5_col2" class="data row5 col2" >2023-04-12</td>
#       <td id="T_d9519_row5_col3" class="data row5 col3" >9.95</td>
#       <td id="T_d9519_row5_col4" class="data row5 col4" >9.95</td>
#       <td id="T_d9519_row5_col5" class="data row5 col5" >181,279,431</td>
#       <td id="T_d9519_row5_col6" class="data row5 col6" >10.10</td>
#       <td id="T_d9519_row5_col7" class="data row5 col7" >9.80</td>
#       <td id="T_d9519_row5_col8" class="data row5 col8" >I</td>
#       <td id="T_d9519_row5_col9" class="data row5 col9" >SET50</td>
#       <td id="T_d9519_row5_col10" class="data row5 col10" >0.00</td>
#       <td id="T_d9519_row5_col11" class="data row5 col11" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_d9519_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d9519_row6_col0" class="data row6 col0" >BCH</td>
#       <td id="T_d9519_row6_col1" class="data row6 col1" >2023-04-04</td>
#       <td id="T_d9519_row6_col2" class="data row6 col2" >2023-04-12</td>
#       <td id="T_d9519_row6_col3" class="data row6 col3" >20.60</td>
#       <td id="T_d9519_row6_col4" class="data row6 col4" >21.30</td>
#       <td id="T_d9519_row6_col5" class="data row6 col5" >49,364,956</td>
#       <td id="T_d9519_row6_col6" class="data row6 col6" >21.60</td>
#       <td id="T_d9519_row6_col7" class="data row6 col7" >20.30</td>
#       <td id="T_d9519_row6_col8" class="data row6 col8" >I</td>
#       <td id="T_d9519_row6_col9" class="data row6 col9" >SET100</td>
#       <td id="T_d9519_row6_col10" class="data row6 col10" >0.70</td>
#       <td id="T_d9519_row6_col11" class="data row6 col11" >3.40%</td>
#     </tr>
#     <tr>
#       <th id="T_d9519_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d9519_row7_col0" class="data row7 col0" >GVREIT</td>
#       <td id="T_d9519_row7_col1" class="data row7 col1" >2023-04-11</td>
#       <td id="T_d9519_row7_col2" class="data row7 col2" >2023-04-12</td>
#       <td id="T_d9519_row7_col3" class="data row7 col3" >9.45</td>
#       <td id="T_d9519_row7_col4" class="data row7 col4" >9.45</td>
#       <td id="T_d9519_row7_col5" class="data row7 col5" >156,803</td>
#       <td id="T_d9519_row7_col6" class="data row7 col6" >9.50</td>
#       <td id="T_d9519_row7_col7" class="data row7 col7" >9.35</td>
#       <td id="T_d9519_row7_col8" class="data row7 col8" >I</td>
#       <td id="T_

# %%
df.shape
# Out:
# (15, 12)

# %% [markdown]
# ### IF the above count not equal number of orders, there must be something incorrect

# %% [markdown]
# ### Create daily-sales from sales

# %%
df[cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_00518_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >fm_date</th>
#       <th class="col_heading level0 col2" >to_date</th>
#       <th class="col_heading level0 col3" >fm_price</th>
#       <th class="col_heading level0 col4" >to_price</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >max_price</th>
#       <th class="col_heading level0 col7" >min_price</th>
#       <th class="col_heading level0 col8" >percent</th>
#       <th class="col_heading level0 col9" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00518_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00518_row0_col0" class="data row0 col0" >IVL</td>
#       <td id="T_00518_row0_col1" class="data row0 col1" >2023-04-11</td>
#       <td id="T_00518_row0_col2" class="data row0 col2" >2023-04-12</td>
#       <td id="T_00518_row0_col3" class="data row0 col3" >34.25</td>
#       <td id="T_00518_row0_col4" class="data row0 col4" >34.00</td>
#       <td id="T_00518_row0_col5" class="data row0 col5" >16,141,100</td>
#       <td id="T_00518_row0_col6" class="data row0 col6" >34.75</td>
#       <td id="T_00518_row0_col7" class="data row0 col7" >33.25</td>
#       <td id="T_00518_row0_col8" class="data row0 col8" >-0.73%</td>
#       <td id="T_00518_row0_col9" class="data row0 col9" >B</td>
#     </tr>
#     <tr>
#       <th id="T_00518_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_00518_row1_col0" class="data row1 col0" >JMART</td>
#       <td id="T_00518_row1_col1" class="data row1 col1" >2023-04-11</td>
#       <td id="T_00518_row1_col2" class="data row1 col2" >2023-04-12</td>
#       <td id="T_00518_row1_col3" class="data row1 col3" >21.70</td>
#       <td id="T_00518_row1_col4" class="data row1 col4" >21.20</td>
#       <td id="T_00518_row1_col5" class="data row1 col5" >22,400,967</td>
#       <td id="T_00518_row1_col6" class="data row1 col6" >22.00</td>
#       <td id="T_00518_row1_col7" class="data row1 col7" >21.00</td>
#       <td id="T_00518_row1_col8" class="data row1 col8" >-2.30%</td>
#       <td id="T_00518_row1_col9" class="data row1 col9" >B</td>
#     </tr>
#     <tr>
#       <th id="T_00518_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_00518_row2_col0" class="data row2 col0" >JMT</td>
#       <td id="T_00518_row2_col1" class="data row2 col1" >2023-04-11</td>
#       <td id="T_00518_row2_col2" class="data row2 col2" >2023-04-12</td>
#       <td id="T_00518_row2_col3" class="data row2 col3" >43.75</td>
#       <td id="T_00518_row2_col4" class="data row2 col4" >42.00</td>
#       <td id="T_00518_row2_col5" class="data row2 col5" >11,509,145</td>
#       <td id="T_00518_row2_col6" class="data row2 col6" >44.00</td>
#       <td id="T_00518_row2_col7" class="data row2 col7" >41.75</td>
#       <td id="T_00518_row2_col8" class="data row2 col8" >-4.00%</td>
#       <td id="T_00518_row2_col9" class="data row2 col9" >B</td>
#     </tr>
#     <tr>
#       <th id="T_00518_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_00518_row3_col0" class="data row3 col0" >SINGER</td>
#       <td id="T_00518_row3_col1" class="data row3 col1" >2023-04-12</td>
#       <td id="T_00518_row3_col2" class="data row3 col2" >2023-04-12</td>
#       <td id="T_00518_row3_col3" class="data row3 col3" >16.90</td>
#       <td id="T_00518_row3_col4" class="data row3 col4" >16.90</td>
#       <td id="T_00518_row3_col5" class="data row3 col5" >6,078,823</td>
#       <td id="T_00518_row3_col6" class="data row3 col6" >17.30</td>
#       <td id="T_00518_row3_col7" class="data row3 col7" >16.70</td>
#       <td id="T_00518_row3_col8" class="data row3 col8" >0.00%</td>
#       <td id="T_00518_row3_col9" class="data row3 col9" >B</td>
#     </tr>
#     <tr>
#       <th id="T_00518_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_00518_row4_col0" class="data row4 col0" >STA</td>
#       <td id="T_00518_row4_col1" class="data row4 col1" >2023-04-12</td>
#       <td id="T_00518_row4_col2" class="data row4 col2" >2023-04-12</td>
#       <td id="T_00518_row4_col3" class="data row4 col3" >22.20</td>
#       <td id="T_00518_row4_col4" class="data row4 col4" >22.20</td>
#       <td id="T_00518_row4_col5" class="data row4 col5" >4,353,861</td>
#       <td id="T_00518_row4_col6" class="data row4 col6" >22.50</td>
#       <td id="T_00518_row4_col7" class="data row4 col7" >22.00</td>
#       <td id="T_00518_row4_col8" class="data row4 col8" >0.00%</td>
#       <td id="T_00518_row4_col9" class="data row4 col9" >B</td>
#     </tr>
#     <tr>
#       <th id="T_00518_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_00518_row5_col0" class="data row5 col0" >BANPU</td>
#       <td id="T_00518_row5_col1" class="data row5 col1" >2023-04-12</td>
#       <td id="T_00518_row5_col2" class="data row5 col2" >2023-04-12</td>
#       <td id="T_00518_row5_col3" class="data row5 col3" >9.95</td>
#       <td id="T_00518_row5_col4" class="data row5 col4" >9.95</td>
#       <td id="T_00518_row5_col5" class="data row5 col5" >181,279,431</td>
#       <td id="T_00518_row5_col6" class="data row5 col6" >10.10</td>
#       <td id="T_00518_row5_col7" class="data row5 col7" >9.80</td>
#       <td id="T_00518_row5_col8" class="data row5 col8" >0.00%</td>
#       <td id="T_00518_row5_col9" class="data row5 col9" >I</td>
#     </tr>
#     <tr>
#       <th id="T_00518_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_00518_row6_col0" class="data row6 col0" >BCH</td>
#       <td id="T_00518_row6_col1" class="data row6 col1" >2023-04-04</td>
#       <td id="T_00518_row6_col2" class="data row6 col2" >2023-04-12</td>
#       <td id="T_00518_row6_col3" class="data row6 col3" >20.60</td>
#       <td id="T_00518_row6_col4" class="data row6 col4" >21.30</td>
#       <td id="T_00518_row6_col5" class="data row6 col5" >49,364,956</td>
#       <td id="T_00518_row6_col6" class="data row6 col6" >21.60</td>
#       <td id="T_00518_row6_col7" class="data row6 col7" >20.30</td>
#       <td id="T_00518_row6_col8" class="data row6 col8" >3.40%</td>
#       <td id="T_00518_row6_col9" class="data row6 col9" >I</td>
#     </tr>
#     <tr>
#       <th id="T_00518_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_00518_row7_col0" class="data row7 col0" >GVREIT</td>
#       <td id="T_00518_row7_col1" class="data row7 col1" >2023-04-11</td>
#       <td id="T_00518_row7_col2" class="data row7 col2" >2023-04-12</td>
#       <td id="T_00518_row7_col3" class="data row7 col3" >9.45</td>
#       <td id="T_00518_row7_col4" class="data row7 col4" >9.45</td>
#       <td id="T_00518_row7_col5" class="data row7 col5" >156,803</td>
#       <td id="T_00518_row7_col6" class="data row7 col6" >9.50</td>
#       <td id="T_00518_row7_col7" class="data row7 col7" >9.35</td>
#       <td id="T_00518_row7_col8" class="data row7 col8" >0.00%</td>
#       <td id="T_00518_row7_col9" class="data row7 col9" >I</td>
#     </tr>
#     <tr>
#       <th id="T_00518_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_00518_row8_col0" class="data row8 col0" >ORI</td>
#       <td id="T_00518_row8_col1" class="data row8 col1" >2023-04-07</td>
#       <td id="T_00518_row8_col2" class="data row8 col2" >2023-04-12</td>
#       <td id="T_00518_row8_col3" class="data row8 col3" >11.90</td>
#       <td id="T_00518_row8_col4" class="data row8 col4" >12.10</td>
#       <td id="T_00518_row8_col5" class="data row8 col5" >29,712,437</td>
#       <td id="T_00518_row8_col6" class="data row8 col6" >12.20</td>
#       <td id="T_00518_row8_col7" class="data row8 col7" >11.50</td>
#       <td id="T_00518_row8_col8" class="data row8 col8" >1.68%</td>
#       <td id="T_00518_row8_col9" class="data row8 col9" >I</td>
#     </tr>
#     <tr>
#       <th id="T_00518_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_00518_row9_col0" class="data row9 col0" >SENA</td>
#       <td id="T_00518_row9_col1" class="data row9 col1" >2023-04-10</td>
#       <td id="T_0051

# %%
file_name = "daily-sales.csv"
data_file = data_path + file_name
output_file = csv_path + file_name
one_file = one_path + file_name
osd_file = osd_path + file_name

df[cols].sort_values(['status','percent'],ascending=[True,True]).to_csv(output_file, header=True, index=False)
df[cols].sort_values(['status','percent'],ascending=[True,True]).to_csv(data_file, header=True, index=False)
df[cols].sort_values(['status','percent'],ascending=[True,True]).to_csv(one_file, header=True, index=False)
df[cols].sort_values(['status','percent'],ascending=[True,True]).to_csv(osd_file, header=True, index=False)

# %%
df[cols].shape
# Out:
# (15, 10)

# %%
sales = df[cols]
sales
# Out:
#       name    fm_date    to_date  fm_price  to_price        qty  max_price  \
# 0      IVL 2023-04-11 2023-04-12     34.25     34.00   16141100      34.75
# 1    JMART 2023-04-11 2023-04-12     21.70     21.20   22400967      22.00
# 2      JMT 2023-04-11 2023-04-12     43.75     42.00   11509145      44.00
# 3   SINGER 2023-04-12 2023-04-12     16.90     16.90    6078823      17.30
# 4      STA 2023-04-12 2023-04-12     22.20     22.20    4353861      22.50
# 5    BANPU 2023-04-12 2023-04-12      9.95      9.95  181279431      10.10
# 6      BCH 2023-04-04 2023-04-12     20.60     21.30   49364956      21.60
# 7   GVREIT 2023-04-11 2023-04-12      9.45      9.45     156803       9.50
# 8      ORI 2023-04-07 2023-04-12     11.90     12.10   29712437      12.20
# 9     SENA 2023-04-10 2023-04-12      3.48      3.50    1346579       3.50
# 10   TFFIF 2023-04-11 2023-04-12      7.65      7.70    1210724       7.70
# 11   JASIF 2023-04-11 2023-04-12      7.05      7.10   15132458       7.10
# 12     MCS 2023-04-10 2023-04-12      8.90      9.15    1380934       9.20
# 13   PTTGC 2023-04-11 2023-04-12     44.25     43.75   25655708      45.00
# 14     TMT 2023-04-10 2023-04-12      7.75      7.85     361522       7.85
#
#     min_price  percent status
# 0       33.25    -0.73      B
# 1       21.00    -2.30      B
# 2       41.75    -4.00      B
# 3       16.70     0.00      B
# 4       22.00     0.00      B
# 5        9.80     0.00      I
# 6       20.30     3.40      I
# 7        9.35     0.00      I
# 8       11.50     1.68      I
# 9        3.40     0.57      I
# 10       7.60     0.65      O
# 11       7.00     0.71      S
# 12       8.80     2.81      S
# 13      43.25    -1.13      S
# 14       7.60     1.29      S

# %%
file_name = "Price-Today.csv"
input_file = data_path + file_name
prices = pd.read_csv(input_file)
prices
# Out:
#        name        date   price  change   %change    open    high     low  \
# 0       ACE  2023-04-17    2.30    0.06  2.678571    2.26    2.30    2.26
# 1    ADVANC  2023-04-17  213.00    2.00  0.947867  213.00  215.00  211.00
# 2    AEONTS  2023-04-17  189.00   -1.00 -0.526316  190.00  191.50  185.50
# 3        AH  2023-04-17   32.75    1.00  3.149606   32.00   32.75   32.00
# 4       AIE  2023-04-17    2.00    0.00  0.000000    2.00    2.06    2.00
# ..      ...         ...     ...     ...       ...     ...     ...     ...
# 187   WHAIR  2023-04-17    7.50   -0.05 -0.662252    7.50    7.55    7.50
# 188   WHART  2023-04-17   11.20   -0.10 -0.884956   11.30   11.30   11.10
# 189   WHAUP  2023-04-17    4.04    0.06  1.507538    4.00    4.04    3.96
# 190    WICE  2023-04-17    9.95    0.10  1.015228    9.90   10.10    9.80
# 191    WORK  2023-04-17   17.00   -0.20 -1.162791   17.30   17.30   17.00
#
#        volume      value(m)
# 0    18612764   42389.08216
# 1     4653621  991192.94420
# 2      651388  123061.96300
# 3     3092500  100508.39600
# 4      253904     513.24439
# ..        ...           ...
# 187    210522    1579.28500
# 188    984527   11029.49290
# 189   5636277   22558.34142
# 190    924106    9190.33195
# 191     54085     925.08810
#
# [192 rows x 10 columns]

# %%
df_merge = pd.merge(sales,prices,on='name', how='inner')
df_merge
# Out:
#       name    fm_date    to_date  fm_price  to_price        qty  max_price  \
# 0      IVL 2023-04-11 2023-04-12     34.25     34.00   16141100      34.75
# 1    JMART 2023-04-11 2023-04-12     21.70     21.20   22400967      22.00
# 2      JMT 2023-04-11 2023-04-12     43.75     42.00   11509145      44.00
# 3   SINGER 2023-04-12 2023-04-12     16.90     16.90    6078823      17.30
# 4      STA 2023-04-12 2023-04-12     22.20     22.20    4353861      22.50
# 5    BANPU 2023-04-12 2023-04-12      9.95      9.95  181279431      10.10
# 6      BCH 2023-04-04 2023-04-12     20.60     21.30   49364956      21.60
# 7   GVREIT 2023-04-11 2023-04-12      9.45      9.45     156803       9.50
# 8      ORI 2023-04-07 2023-04-12     11.90     12.10   29712437      12.20
# 9     SENA 2023-04-10 2023-04-12      3.48      3.50    1346579       3.50
# 10   TFFIF 2023-04-11 2023-04-12      7.65      7.70    1210724       7.70
# 11   JASIF 2023-04-11 2023-04-12      7.05      7.10   15132458       7.10
# 12     MCS 2023-04-10 2023-04-12      8.90      9.15    1380934       9.20
# 13   PTTGC 2023-04-11 2023-04-12     44.25     43.75   25655708      45.00
# 14     TMT 2023-04-10 2023-04-12      7.75      7.85     361522       7.85
#
#     min_price  percent status        date  price  change   %change   open  \
# 0       33.25    -0.73      B  2023-04-17  34.00    0.00  0.000000  34.25
# 1       21.00    -2.30      B  2023-04-17  21.90    0.70  3.301887  21.30
# 2       41.75    -4.00      B  2023-04-17  43.50    1.50  3.571429  42.00
# 3       16.70     0.00      B  2023-04-17  17.40    0.50  2.958580  16.90
# 4       22.00     0.00      B  2023-04-17  22.70    0.50  2.252252  22.40
# 5        9.80     0.00      I  2023-04-17   9.80   -0.15 -1.507538   9.90
# 6       20.30     3.40      I  2023-04-17  21.60    0.30  1.408451  21.60
# 7        9.35     0.00      I  2023-04-17   9.30   -0.15 -1.587302   9.45
# 8       11.50     1.68      I  2023-04-17  12.20    0.10  0.826446  12.20
# 9        3.40     0.57      I  2023-04-17   3.52    0.02  0.571429   3.50
# 10       7.60     0.65      O  2023-04-17   7.70    0.00  0.000000   7.70
# 11       7.00     0.71      S  2023-04-17   7.05   -0.05 -0.704225   7.05
# 12       8.80     2.81      S  2023-04-17   9.25    0.10  1.092896   9.20
# 13      43.25    -1.13      S  2023-04-17  43.50   -0.25 -0.571429  43.75
# 14       7.60     1.29      S  2023-04-17   7.65   -0.20 -2.547771   7.65
#
#      high    low     volume      value(m)
# 0   34.50  33.75    6001454  2.044404e+05
# 1   22.00  21.10   13348630  2.892056e+05
# 2   44.00  41.75    9790729  4.218119e+05
# 3   17.40  16.80    7908445  1.360474e+05
# 4   22.90  22.20    3912672  8.845764e+04
# 5    9.95   9.80  122929972  1.211762e+06
# 6   21.90  21.50   20349134  4.418213e+05
# 7    9.45   9.20     128190  1.192855e+03
# 8   12.20  12.00    4017461  4.873229e+04
# 9    3.52   3.50     577716  2.023135e+03
# 10   7.75   7.65     333535  2.568953e+03
# 11   7.15   7.00   11722880  8.297653e+04
# 12   9.30   9.20     198507  1.830761e+03
# 13  44.00  43.00   14490139  6.283571e+05
# 14   7.65   7.55     371507  2.825469e+03

# %%
colu = 'name fm_date to_date fm_price to_price qty max_price min_price percent status \
price change volume date'.split()
colu
# Out:
# ['name',
#  'fm_date',
#  'to_date',
#  'fm_price',
#  'to_price',
#  'qty',
#  'max_price',
#  'min_price',
#  'percent',
#  'status',
#  'price',
#  'change',
#  'volume',
#  'date']

# %%
df_merge[colu]
# Out:
#       name    fm_date    to_date  fm_price  to_price        qty  max_price  \
# 0      IVL 2023-04-11 2023-04-12     34.25     34.00   16141100      34.75
# 1    JMART 2023-04-11 2023-04-12     21.70     21.20   22400967      22.00
# 2      JMT 2023-04-11 2023-04-12     43.75     42.00   11509145      44.00
# 3   SINGER 2023-04-12 2023-04-12     16.90     16.90    6078823      17.30
# 4      STA 2023-04-12 2023-04-12     22.20     22.20    4353861      22.50
# 5    BANPU 2023-04-12 2023-04-12      9.95      9.95  181279431      10.10
# 6      BCH 2023-04-04 2023-04-12     20.60     21.30   49364956      21.60
# 7   GVREIT 2023-04-11 2023-04-12      9.45      9.45     156803       9.50
# 8      ORI 2023-04-07 2023-04-12     11.90     12.10   29712437      12.20
# 9     SENA 2023-04-10 2023-04-12      3.48      3.50    1346579       3.50
# 10   TFFIF 2023-04-11 2023-04-12      7.65      7.70    1210724       7.70
# 11   JASIF 2023-04-11 2023-04-12      7.05      7.10   15132458       7.10
# 12     MCS 2023-04-10 2023-04-12      8.90      9.15    1380934       9.20
# 13   PTTGC 2023-04-11 2023-04-12     44.25     43.75   25655708      45.00
# 14     TMT 2023-04-10 2023-04-12      7.75      7.85     361522       7.85
#
#     min_price  percent status  price  change     volume        date
# 0       33.25    -0.73      B  34.00    0.00    6001454  2023-04-17
# 1       21.00    -2.30      B  21.90    0.70   13348630  2023-04-17
# 2       41.75    -4.00      B  43.50    1.50    9790729  2023-04-17
# 3       16.70     0.00      B  17.40    0.50    7908445  2023-04-17
# 4       22.00     0.00      B  22.70    0.50    3912672  2023-04-17
# 5        9.80     0.00      I   9.80   -0.15  122929972  2023-04-17
# 6       20.30     3.40      I  21.60    0.30   20349134  2023-04-17
# 7        9.35     0.00      I   9.30   -0.15     128190  2023-04-17
# 8       11.50     1.68      I  12.20    0.10    4017461  2023-04-17
# 9        3.40     0.57      I   3.52    0.02     577716  2023-04-17
# 10       7.60     0.65      O   7.70    0.00     333535  2023-04-17
# 11       7.00     0.71      S   7.05   -0.05   11722880  2023-04-17
# 12       8.80     2.81      S   9.25    0.10     198507  2023-04-17
# 13      43.25    -1.13      S  43.50   -0.25   14490139  2023-04-17
# 14       7.60     1.29      S   7.65   -0.20     371507  2023-04-17

# %%
df_merge[colu].shape
# Out:
# (15, 14)

# %%
df_merge.shape
# Out:
# (15, 19)

# %%
file_name = "daily-sales-prices.csv"
data_file = data_path + file_name
output_file = csv_path + file_name
one_file = one_path + file_name
osd_file = osd_path + file_name

df_merge[colu].sort_values(['name'],ascending=[True]).to_csv(output_file, header=True, index=False)
df_merge[colu].sort_values(['name'],ascending=[True]).to_csv(data_file, header=True, index=False)
df_merge[colu].sort_values(['name'],ascending=[True]).to_csv(one_file, header=True, index=False)
df_merge[colu].sort_values(['name'],ascending=[True]).to_csv(osd_file, header=True, index=False)

# %%
### Call ruby ruby\daily-out-new.rb

# %%
# %pwd
# Out:
# 'C:\\Users\\User\\OneDrive\\A7\\Daily'

# %%
os.chdir("C:\\users\\user\\onedrive\\a7")
# %pwd
# Out:
# 'C:\\users\\user\\onedrive\\a7'

# %%
# !ruby ruby\\daily-out-new.rb
# Out:
# Name      From Date    To Date   From     To     Pct      Shares    Max    Min S Action
# ---------------------------------------------------------------------------------------
# BANPU    2023-04-12 2023-04-17   9.95   9.80  -1.51% 181,279,431  10.10   9.80 I Update
# BCH      2023-04-04 2023-04-17  20.60  21.60   4.85%  49,364,956  21.60  20.30 I Update
# GVREIT   2023-04-11 2023-04-17   9.45   9.30  -1.59%     156,803   9.50   9.30 I Update
# IVL      2023-04-11 2023-04-17  34.25  34.00  -0.73%  16,141,100  34.75  33.25 B Update
# JASIF    2023-04-17 2023-04-17   7.10   7.05   -0.7%  15,132,458   7.10   7.00 S Insert
# JMART    2023-04-17 2023-04-17  21.20  21.90    3.3%  22,400,967  22.00  21.00 B Insert
# JMT      2023-04-17 2023-04-17  42.00  43.50   3.57%  11,509,145  44.00  41.75 B Insert
# MCS      2023-04-10 2023-04-17   8.90   9.25   3.93%   1,380,934   9.25   8.80 S Update
# ORI      2023-04-07 2023-04-17  11.90  12.20   2.52%  29,712,437  12.20  11.50 I Update
# PTTGC    2023-04-11 2023-04-17  44.25  43.50  -1.69%  25,655,708  45.00  43.25 S Update
# SENA     2023-04-10 2023-04-17   3.48   3.52   1.15%   1,346,579   3.52   3.40 I Update
# SINGER   2023-04-12 2023-04-17  16.90  17.40   2.96%   6,078,823  17.40  16.70 B Update
# STA      2023-04-12 2023-04-17  22.20  22.70   2.25%   4,353,861  22.70  22.00 B Update
# TFFIF    2023-04-11 2023-04-17   7.65   7.70   0.65%   1,210,724   7.70   7.60 O Update
# TMT      2023-04-17 2023-04-17   7.85   7.65  -2.55%     361,522   7.85   7.60 S Insert
# =======================================================================================

# %%
os.chdir("C:\\users\\user\\onedrive\\a7\\Daily")
# %pwd
# Out:
# 'C:\\users\\user\\onedrive\\a7\\Daily'

# %% [markdown]
# ### cd\ruby\port_lite
# ### rails runner db/ins_sales.rb
