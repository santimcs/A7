# %% [markdown]
# ##### SQLite port_lite database: stocks table
# ##### PostgreSQL portpg database: stocks table
# ##### MySQL stock database: setindex, price, buy tables
# ##### output csv: 5-day_average, extreme

# %%
import calendar
import pandas as pd
from datetime import date, timedelta
from sqlalchemy import create_engine
from pandas.tseries.offsets import BDay

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development")
conpg = engine.connect()

engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

pd.set_option("display.max_rows", None)

today = date.today()
today
# Out:
# datetime.date(2022, 12, 30)

# %% [markdown]
# ### Yesterday is last business day

# %%
#today = today - timedelta(days=1)
num_business_days = BDay(1)
yesterday = today - num_business_days
yesterday = yesterday.date()
today, yesterday
# Out:
# (datetime.date(2022, 12, 30), datetime.date(2022, 12, 29))

# %%
sql = '''
SELECT * FROM setindex WHERE setindex IS Null'''
df = pd.read_sql(sql, const)
df

setindex = pd.read_sql(sql, const)
setindex
# Out:
# Empty DataFrame
# Columns: [date, setindex]
# Index: []

# %%
setindex = 1668.66

sqlUpd = """UPDATE setindex
SET setindex = %s WHERE setindex IS Null"""
sqlUpd = sqlUpd % setindex
print(sqlUpd)
# Out:
# UPDATE setindex
# SET setindex = 1668.66 WHERE setindex IS Null

# %%
#setindex = 1648.44
sqlUpd = """
UPDATE setindex
SET setindex = %s WHERE date = '%s'"""
sqlUpd = sqlUpd % (setindex, today)
print(sqlUpd)
# Out:
# UPDATE setindex
# SET setindex = 1668.66 WHERE date = '2022-12-30'

# %%
rp = const.execute(sqlUpd)
rp.rowcount
# Out:
# 1

# %% [markdown]
# ### Restart and run all cells

# %% [markdown]
# ### Begin of Tables in the process

# %%
cols = "name market price_x maxp max_price qty".split()
colt = 'name pct price_x price_y status diff'.split()
colu = "name prc_pct tdy_price avg_price qty_pct tdy_qty avg_qty".split()
colv = "name market price_x minp min_price qty".split()

# %%
format_dict = {
    'setindex':'{:,.2f}',
    
    'qty':'{:,}',    
    'price':'{:.2f}','maxp':'{:.2f}','minp':'{:.2f}','opnp':'{:.2f}',  
    'date':'{:%Y-%m-%d}',
    
    'price_x':'{:.2f}','price_y':'{:.2f}','diff':'{:.2f}', 
    'tdy_price':'{:.2f}','avg_price':'{:.2f}',
    'tdy_qty':'{:,}','avg_qty':'{:,}',
    'prc_pct':'{:,.2f}%','qty_pct':'{:,.2f}%','pct':'{:,.2f}%',
    'qty_x':'{:,}','qty_y':'{:,}',    
    
    'price':'{:.2f}','max_price':'{:.2f}','min_price':'{:.2f}',                
    'pe':'{:.2f}','pbv':'{:.2f}',
    'paid_up':'{:,.2f}','market_cap':'{:,.2f}',   
    'daily_volume':'{:,.2f}','beta':'{:,.2f}', 
    'created_at':'{:%Y-%m-%d}','updated_at':'{:%Y-%m-%d}',    
    'start_date':'{:%Y-%m-%d}','end_date':'{:%Y-%m-%d}',    
              }

# %%
sql = """
SELECT * 
FROM price 
WHERE date = '%s'
ORDER BY name
"""
sql = sql % today
print(sql)

prices = pd.read_sql(sql, const)
prices.tail().style.format(format_dict)
# Out:
# SELECT *
# FROM price
# WHERE date = '2022-12-30'
# ORDER BY name
# <style type="text/css">
# </style>
# <table id="T_4278b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >minp</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >opnp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4278b_level0_row0" class="row_heading level0 row0" >228</th>
#       <td id="T_4278b_row0_col0" class="data row0 col0" >WHAIR</td>
#       <td id="T_4278b_row0_col1" class="data row0 col1" >2022-12-30</td>
#       <td id="T_4278b_row0_col2" class="data row0 col2" >7.45</td>
#       <td id="T_4278b_row0_col3" class="data row0 col3" >7.55</td>
#       <td id="T_4278b_row0_col4" class="data row0 col4" >7.40</td>
#       <td id="T_4278b_row0_col5" class="data row0 col5" >905,123</td>
#       <td id="T_4278b_row0_col6" class="data row0 col6" >7.55</td>
#     </tr>
#     <tr>
#       <th id="T_4278b_level0_row1" class="row_heading level0 row1" >229</th>
#       <td id="T_4278b_row1_col0" class="data row1 col0" >WHART</td>
#       <td id="T_4278b_row1_col1" class="data row1 col1" >2022-12-30</td>
#       <td id="T_4278b_row1_col2" class="data row1 col2" >10.70</td>
#       <td id="T_4278b_row1_col3" class="data row1 col3" >10.70</td>
#       <td id="T_4278b_row1_col4" class="data row1 col4" >10.60</td>
#       <td id="T_4278b_row1_col5" class="data row1 col5" >1,040,854</td>
#       <td id="T_4278b_row1_col6" class="data row1 col6" >10.60</td>
#     </tr>
#     <tr>
#       <th id="T_4278b_level0_row2" class="row_heading level0 row2" >230</th>
#       <td id="T_4278b_row2_col0" class="data row2 col0" >WHAUP</td>
#       <td id="T_4278b_row2_col1" class="data row2 col1" >2022-12-30</td>
#       <td id="T_4278b_row2_col2" class="data row2 col2" >4.10</td>
#       <td id="T_4278b_row2_col3" class="data row2 col3" >4.14</td>
#       <td id="T_4278b_row2_col4" class="data row2 col4" >4.10</td>
#       <td id="T_4278b_row2_col5" class="data row2 col5" >2,890,342</td>
#       <td id="T_4278b_row2_col6" class="data row2 col6" >4.12</td>
#     </tr>
#     <tr>
#       <th id="T_4278b_level0_row3" class="row_heading level0 row3" >231</th>
#       <td id="T_4278b_row3_col0" class="data row3 col0" >WICE</td>
#       <td id="T_4278b_row3_col1" class="data row3 col1" >2022-12-30</td>
#       <td id="T_4278b_row3_col2" class="data row3 col2" >10.30</td>
#       <td id="T_4278b_row3_col3" class="data row3 col3" >10.50</td>
#       <td id="T_4278b_row3_col4" class="data row3 col4" >10.20</td>
#       <td id="T_4278b_row3_col5" class="data row3 col5" >3,933,305</td>
#       <td id="T_4278b_row3_col6" class="data row3 col6" >10.30</td>
#     </tr>
#     <tr>
#       <th id="T_4278b_level0_row4" class="row_heading level0 row4" >232</th>
#       <td id="T_4278b_row4_col0" class="data row4 col0" >WORK</td>
#       <td id="T_4278b_row4_col1" class="data row4 col1" >2022-12-30</td>
#       <td id="T_4278b_row4_col2" class="data row4 col2" >18.20</td>
#       <td id="T_4278b_row4_col3" class="data row4 col3" >18.30</td>
#       <td id="T_4278b_row4_col4" class="data row4 col4" >18.20</td>
#       <td id="T_4278b_row4_col5" class="data row4 col5" >88,331</td>
#       <td id="T_4278b_row4_col6" class="data row4 col6" >18.30</td>
#     </tr>
#   </tbody>
# </table>

# %%
sql = """
SELECT * 
FROM stocks
ORDER BY name
"""
stocks = pd.read_sql(sql, conpg)
stocks['created_at'] = pd.to_datetime(stocks['created_at'])
stocks['updated_at'] = pd.to_datetime(stocks['updated_at'])
stocks.head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_002cc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >market</th>
#       <th class="col_heading level0 col3" >price</th>
#       <th class="col_heading level0 col4" >max_price</th>
#       <th class="col_heading level0 col5" >min_price</th>
#       <th class="col_heading level0 col6" >pe</th>
#       <th class="col_heading level0 col7" >pbv</th>
#       <th class="col_heading level0 col8" >paid_up</th>
#       <th class="col_heading level0 col9" >market_cap</th>
#       <th class="col_heading level0 col10" >daily_volume</th>
#       <th class="col_heading level0 col11" >beta</th>
#       <th class="col_heading level0 col12" >ticker_id</th>
#       <th class="col_heading level0 col13" >created_at</th>
#       <th class="col_heading level0 col14" >updated_at</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_002cc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T
>0.92</td>
#     </tr>
#     <tr>
#       <th id="T_b5422_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b5422_row1_col0" class="data row1 col0" >ADVANC</td>
#       <td id="T_b5422_row1_col1" class="data row1 col1" >2022-12-30</td>
#       <td id="T_b5422_row1_col2" class="data row1 col2" >195.00</td>
#       <td id="T_b5422_row1_col3" class="data row1 col3" >197.00</td>
#       <td id="T_b5422_row1_col4" class="data row1 col4" >194.50</td>
#       <td id="T_b5422_row1_col5" class="data row1 col5" >6,036,469</td>
#       <td id="T_b5422_row1_col6" class="data row1 col6" >196.00</td>
#       <td id="T_b5422_row1_col7" class="data row1 col7" >SET50 / SETHD / SETTHSI    </td>
#       <td id="T_b5422_row1_col8" class="data row1 col8" >196.00</td>
#       <td id="T_b5422_row1_col9" class="data row1 col9" >242.00</td>
#       <td id="T_b5422_row1_col10" class="data row1 col10" >181.50</td>
#       <td id="T_b5422_row1_col11" class="data row1 col11" >22.85</td>
#       <td id="T_b5422_row1_col12" class="data row1 col12" >7.47</td>
#       <td id="T_b5422_row1_col13" class="data row1 col13" >1,291.59</td>
#       <td id="T_b5422_row1_col14" class="data row1 col14" >0.77</td>
#     </tr>
#     <tr>
#       <th id="T_b5422_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b5422_row2_col0" class="data row2 col0" >AEONTS</td>
#       <td id="T_b5422_row2_col1" class="data row2 col1" >2022-12-30</td>
#       <td id="T_b5422_row2_col2" class="data row2 col2" >182.00</td>
#       <td id="T_b5422_row2_col3" class="data row2 col3" >183.50</td>
#       <td id="T_b5422_row2_col4" class="data row2 col4" >181.50</td>
#       <td id="T_b5422_row2_col5" class="data row2 col5" >407,749</td>
#       <td id="T_b5422_row2_col6" class="data row2 col6" >183.00</td>
#       <td id="T_b5422_row2_col7" class="data row2 col7" >SET100    </td>
#       <td id="T_b5422_row2_col8" class="data row2 col8" >182.00</td>
#       <td id="T_b5422_row2_col9" class="data row2 col9" >209.00</td>
#       <td id="T_b5422_row2_col10" class="data row2 col10" >152.00</td>
#       <td id="T_b5422_row2_col11" class="data row2 col11" >12.15</td>
#       <td id="T_b5422_row2_col12" class="data row2 col12" >2.11</td>
#       <td id="T_b5422_row2_col13" class="data row2 col13" >67.24</td>
#       <td id="T_b5422_row2_col14" class="data row2 col14" >1.09</td>
#     </tr>
#     <tr>
#       <th id="T_b5422_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b5422_row3_col0" class="data row3 col0" >AH</td>
#       <td id="T_b5422_row3_col1" class="data row3 col1" >2022-12-30</td>
#       <td id="T_b5422_row3_col2" class="data row3 col2" >29.75</td>
#       <td id="T_b5422_row3_col3" class="data row3 col3" >30.25</td>
#       <td id="T_b5422_row3_col4" class="data row3 col4" >29.75</td>
#       <td id="T_b5422_row3_col5" class="data row3 col5" >1,513,797</td>
#       <td id="T_b5422_row3_col6" class="data row3 col6" >30.25</td>
#       <td id="T_b5422_row3_col7" class="data row3 col7" >sSET / SETTHSI    </td>
#       <td id="T_b5422_row3_col8" class="data row3 col8" >29.75</td>
#       <td id="T_b5422_row3_col9" class="data row3 col9" >35.75</td>
#       <td id="T_b5422_row3_col10" class="data row3 col10" >19.40</td>
#       <td id="T_b5422_row3_col11" class="data row3 col11" >6.85</td>
#       <td id="T_b5422_row3_col12" class="data row3 col12" >1.11</td>
#       <td id="T_b5422_row3_col13" class="data row3 col13" >65.92</td>
#       <td id="T_b5422_row3_col14" class="data row3 col14" >1.42</td>
#     </tr>
#     <tr>
#       <th id="T_b5422_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b5422_row4_col0" class="data row4 col0" >AIE</td>
#       <td id="T_b5422_row4_col1" class="data row4 col1" >2022-12-30</td>
#       <td id="T_b5422_row4_col2" class="data row4 col2" >2.84</td>
#       <td id="T_b5422_row4_col3" class="data row4 col3" >2.92</td>
#       <td id="T_b5422_row4_col4" class="data row4 col4" >2.70</td>
#       <td id="T_b5422_row4_col5" class="data row4 col5" >6,479,562</td>
#       <td id="T_b5422_row4_col6" class="data row4 col6" >2.72</td>
#       <td id="T_b5422_row4_col7" class="data row4 col7" >sSET    </td>
#       <td id="T_b5422_row4_col8" class="data row4 col8" >2.72</td>
#       <td id="T_b5422_row4_col9" class="data row4 col9" >5.10</td>
#       <td id="T_b5422_row4_col10" class="data row4 col10" >2.56</td>
#       <td id="T_b5422_row4_col11" class="data row4 col11" >20.41</td>
#       <td id="T_b5422_row4_col12" class="data row4 col12" >1.76</td>
#       <td id="T_b5422_row4_col13" class="data row4 col13" >25.71</td>
#       <td id="T_b5422_row4_col14" class="data row4 col14" >1.25</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 52 Weeks High

# %%
Yearly_High = (df_merge.maxp > df_merge.max_price) & (df_merge.qty > 100000)
Final_High = df_merge[Yearly_High]
Final_High[cols].sort_values(by=["name"], ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_20d1a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >market</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >max_price</th>
#       <th class="col_heading level0 col5" >qty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20d1a_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_20d1a_row0_col0" class="data row0 col0" >AOT</td>
#       <td id="T_20d1a_row0_col1" class="data row0 col1" >SET50 / SETTHSI / SETWB    </td>
#       <td id="T_20d1a_row0_col2" class="data row0 col2" >75.00</td>
#       <td id="T_20d1a_row0_col3" class="data row0 col3" >76.50</td>
#       <td id="T_20d1a_row0_col4" class="data row0 col4" >76.25</td>
#       <td id="T_20d1a_row0_col5" class="data row0 col5" >38,724,794</td>
#     </tr>
#     <tr>
#       <th id="T_20d1a_level0_row1" class="row_heading level0 row1" >30</th>
#       <td id="T_20d1a_row1_col0" class="data row1 col0" >BEM</td>
#       <td id="T_20d1a_row1_col1" class="data row1 col1" >SET50 / SETTHSI / SETWB    </td>
#       <td id="T_20d1a_row1_col2" class="data row1 col2" >9.80</td>
#       <td id="T_20d1a_row1_col3" class="data row1 col3" >9.85</td>
#       <td id="T_20d1a_row1_col4" class="data row1 col4" >9.80</td>
#       <td id="T_20d1a_row1_col5" class="data row1 col5" >70,097,096</td>
#     </tr>
#     <tr>
#       <th id="T_20d1a_level0_row2" class="row_heading level0 row2" >57</th>
#       <td id="T_20d1a_row2_col0" class="data row2 col0" >DELTA</td>
#       <td id="T_20d1a_row2_col1" class="data row2 col1" >SET    </td>
#       <td id="T_20d1a_row2_col2" class="data row2 col2" >830.00</td>
#       <td id="T_20d1a_row2_col3" class="data row2 col3" >876.00</td>
#       <td id="T_20d1a_row2_col4" class="data row2 col4" >796.00</td>
#       <td id="T_20d1a_row2_col5" class="data row2 col5" >23,557,640</td>
#     </tr>
#   </tbody>
# </table>

# %%
'New high today: ' + str(df_merge[Yearly_High].shape[0]) + ' stocks'
# Out:
# 'New high today: 3 stocks'

# %% [markdown]
# ### High or Low by Markets

# %%
set50H = Final_High["market"].str.contains("SET50")
Final_High[set50H].sort_values(by=["name"],ascending=["True"]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_57c37_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >minp</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >opnp</th>
#       <th class="col_heading level0 col7" >market</th>
#       <th class="col_heading level0 col8" >price_y</th>
#       <th class="col_heading level0 col9" >max_price</th>
#       <th class="col_heading level0 col10" >min_price</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >daily_volume</th>
#       <th class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57c37_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_57c37_row0_col0" class="data row0 col0" >AOT</td>
#       <td id="T_57c37_row0_col1" class="data row0 col1" >2022-12-30</td>
#       <td id="T_57c37_row0_col2" class="data row0 col2" >75.00</td>
#       <td id="T_57c37_row0_col3" class="data row0 col3" >76.50</td>
#       <td id="T_57c37_row0_col4" class="data row0 col4" >75.00</td>
#       <td id="T_57c37_row0_col5" class="data row0 col5" >38,724,794</td>
#       <td id="T_57c37_row0_col6" class="data row0 col6" >76.00</td>
#       <td id="T_57c37_row0_col7" class="data row0 col7" >SET50 / SETTHSI / SETWB    </td>
#       <td id="T_57c37_row0_col8" class="data row0 col8" >76.25</td>
#       <td id="T_57c37_row0_col9" class="data row0 col9" >76.25</td>
#       <td id="T_57c37_row0_col10" class="data row0 col10" >59.75</td>
#       <td id="T_57c37_row0_col11" class="data row0 col11" >999.99</td>
#       <td id="T_57c37_row0_col12" class="data row0 col12" >10.75</td>
#       <td id="T_57c37_row0_col13" class="data row0 col13" >1,728.09</td>
#       <td id="T_57c37_row0_col14" class="data row0 col14" >0.76</td>
#     </tr>
#     <tr>
#       <th id="T_57c37_level0_row1" class="row_heading level0 row1" >30</th>
#       <td id="T_57c37_row1_col0" class="data row1 col0" >BEM</td>
#       <td id="T_57c37_row1_col1" class="data row1 col1" >2022-12-30</td>
#       <td id="T_57c37_row1_col2" class="data row1 col2" >9.80</td>
#       <td id="T_57c37_row1_col3" class="data row1 col3" >9.85</td>
#       <td id="T_57c37_row1_col4" class="data row1 col4" >9.60</td>
#       <td id="T_57c37_row1_col5" class="data row1 col5" >70,097,096</td>
#       <td id="T_57c37_row1_col6" class="data row1 col6" >9.70</td>
#       <td id="T_57c37_row1_col7" class="data row1 col7" >SET50 / SETTHSI / SETWB    </td>
#       <td id="T_57c37_row1_col8" class="data row1 col8" >9.70</td>
#       <td id="T_57c37_row1_col9" class="data row1 col9" >9.80</td>
#       <td id="T_57c37_row1_col10" class="data row1 col10" >7.90</td>
#       <td id="T_57c37_row1_col11" class="data row1 col11" >66.52</td>
#       <td id="T_57c37_row1_col12" class="data row1 col12" >3.93</td>
#       <td id="T_57c37_row1_col13" class="data row1 col13" >397.46</td>
#       <td id="T_57c37_row1_col14" class="data row1 col14" >0.74</td>
#     </tr>
#   </tbody>
# </table>

# %%
set100H = Final_High["market"].str.contains("SET100")
Final_High[set100H].sort_values(by=["name"],ascending=["True"]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9e8b1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >minp</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >opnp</th>
#       <th class="col_heading level0 col7" >market</th>
#       <th class="col_heading level0 col8" >price_y</th>
#       <th class="col_heading level0 col9" >max_price</th>
#       <th class="col_heading level0 col10" >min_price</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >daily_volume</th>
#       <th class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
setsmallH = Final_High["market"].str.contains("sSET")
Final_High[setsmallH].sort_values(by=["name"],ascending=["True"]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e3b73_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >minp</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >opnp</th>
#       <th class="col_heading level0 col7" >market</th>
#       <th class="col_heading level0 col8" >price_y</th>
#       <th class="col_heading level0 col9" >max_price</th>
#       <th class="col_heading level0 col10" >min_price</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >daily_volume</th>
#       <th class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
maiH = Final_High["market"].str.contains("mai")
Final_High[maiH].sort_values(by=["name"],ascending=["True"]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7b7cf_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >minp</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >opnp</th>
#       <th class="col_heading level0 col7" >market</th>
#       <th class="col_heading level0 col8" >price_y</th>
#       <th class="col_heading level0 col9" >max_price</th>
#       <th class="col_heading level0 col10" >min_price</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >daily_volume</th>
#       <th class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# ### 52 Weeks Low

# %%
Yearly_Low = (df_merge.minp < df_merge.min_price) & (df_merge.qty > 100000)
Final_Low = df_merge[Yearly_Low]
Final_Low[colv].sort_values(by=["name"], ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3d6b9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >market</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >minp</th>
#       <th class="col_heading level0 col4" >min_price</th>
#       <th class="col_heading level0 col5" >qty</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
'New low today: ' + str(df_merge[Yearly_Low].shape[0]) + ' stocks'
# Out:
# 'New low today: 0 stocks'

# %% [markdown]
# ### New High or Low by Markets

# %%
set50L = Final_Low["market"].str.contains("SET50")
Final_Low[set50L].sort_values(by=["name"],ascending=["True"]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_005f6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >minp</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >opnp</th>
#       <th class="col_heading level0 col7" >market</th>
#       <th class="col_heading level0 col8" >price_y</th>
#       <th class="col_heading level0 col9" >max_price</th>
#       <th class="col_heading level0 col10" >min_price</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >daily_volume</th>
#       <th class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
set100L = Final_Low["market"].str.contains("SET100")
Final_Low[set100L].sort_values(by=["name"],ascending=["True"]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_f9534_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >minp</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >opnp</th>
#       <th class="col_heading level0 col7" >market</th>
#       <th class="col_heading level0 col8" >price_y</th>
#       <th class="col_heading level0 col9" >max_price</th>
#       <th class="col_heading level0 col10" >min_price</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >daily_volume</th>
#       <th class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
setsmallL = Final_Low["market"].str.contains("sSET")
Final_Low[setsmallL].sort_values(by=["name"],ascending=["True"]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4e7d8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >minp</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >opnp</th>
#       <th class="col_heading level0 col7" >market</th>
#       <th class="col_heading level0 col8" >price_y</th>
#       <th class="col_heading level0 col9" >max_price</th>
#       <th class="col_heading level0 col10" >min_price</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >daily_volume</th>
#       <th class="col_heading level0 col14" >beta</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# ### Break 5-day Average Volume

# %%
sql = """
SELECT name, qty, price, date As today
FROM price 
WHERE date = '%s'
ORDER BY name
"""
sql = sql % today
print(sql)

today_vol = pd.read_sql(sql, const)
today_vol.head().style.format(format_dict)
# Out:
# SELECT name, qty, price, date As today
# FROM price
# WHERE date = '2022-12-30'
# ORDER BY name
# <style type="text/css">
# </style>
# <table id="T_94240_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >qty</th>
#       <th class="col_heading level0 col2" >price</th>
#       <th class="col_heading level0 col3" >today</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94240_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_94240_row0_col0" class="data row0 col0" >ACE</td>
#       <td id="T_94240_row0_col1" class="data row0 col1" >40,885,244</td>
#       <td id="T_94240_row0_col2" class="data row0 col2" >2.70</td>
#       <td id="T_94240_row0_col3" class="data row0 col3" >2022-12-30</td>
#     </tr>
#     <tr>
#       <th id="T_94240_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_94240_row1_col0" class="data row1 col0" >ADVANC</td>
#       <td id="T_94240_row1_col1" class="data row1 col1" >6,036,469</td>
#       <td id="T_94240_row1_col2" class="data row1 col2" >195.00</td>
#       <td id="T_94240_row1_col3" class="data row1 col3" >2022-12-30</td>
#     </tr>
#     <tr>
#       <th id="T_94240_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_94240_row2_col0" class="data row2 col0" >AEONTS</td>
#       <td id="T_94240_row2_col1" class="data row2 col1" >407,749</td>
#       <td id="T_94240_row2_col2" class="data row2 col2" >182.00</td>
#       <td id="T_94240_row2_col3" class="data row2 col3" >2022-12-30</td>
#     </tr>
#     <tr>
#       <th id="T_94240_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_94240_row3_col0" class="data row3 col0" >AH</td>
#       <td id="T_94240_row3_col1" class="data row3 col1" >1,513,797</td>
#       <td id="T_94240_row3_col2" class="data row3 col2" >29.75</td>
#       <td id="T_94240_row3_col3" class="data row3 col3" >2022-12-30</td>
#     </tr>
#     <tr>
#       <th id="T_94240_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_94240_row4_col0" class="data row4 col0" >AIE</td>
#       <td id="T_94240_row4_col1" class="data row4 col1" >6,479,562</td>
#       <td id="T_94240_row4_col2" class="data row4 col2" >2.84</td>
#       <td id="T_94240_row4_col3" class="data row4 col3" >2022-12-30</td>
#     </tr>
#   </tbody>
# </table>

# %%
# specify the number of business days
num_days = 1
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(num_days)
end_date = today - num_business_days
end_date = end_date.date()
end_date
# Out:
# datetime.date(2022, 12, 29)

# %%
# create a new column 'start_date' by subtracting the specified number of business days from the 'end_date'
today_vol['end_date'] = today_vol['today'] - num_business_days
today_vol.head()
# Out:
#      name       qty   price       today   end_date
# 0     ACE  40885244    2.70  2022-12-30 2022-12-29
# 1  ADVANC   6036469  195.00  2022-12-30 2022-12-29
# 2  AEONTS    407749  182.00  2022-12-30 2022-12-29
# 3      AH   1513797   29.75  2022-12-30 2022-12-29
# 4     AIE   6479562    2.84  2022-12-30 2022-12-29

# %%
# specify the number of business days
num_days = 4
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(num_days)
num_business_days
start_date = yesterday - num_business_days
start_date = start_date.date()
start_date
# Out:
# datetime.date(2022, 12, 23)

# %%
# create a new column 'start_date' by subtracting the specified number of business days from the 'end_date'
today_vol['start_date'] = today_vol['end_date'] - num_business_days
today_vol.head()
# Out:
#      name       qty   price       today   end_date start_date
# 0     ACE  40885244    2.70  2022-12-30 2022-12-29 2022-12-23
# 1  ADVANC   6036469  195.00  2022-12-30 2022-12-29 2022-12-23
# 2  AEONTS    407749  182.00  2022-12-30 2022-12-29 2022-12-23
# 3      AH   1513797   29.75  2022-12-30 2022-12-29 2022-12-23
# 4     AIE   6479562    2.84  2022-12-30 2022-12-29 2022-12-23

# %%
sql = """
SELECT * 
FROM price 
WHERE date BETWEEN '%s' AND '%s'
"""
sql = sql % (start_date, end_date)
print(sql)

five_day_vol = pd.read_sql(sql, const)
five_day_vol.sort_values(by=['name'],ascending=[True]).head().style.format(format_dict)
# Out:
# SELECT *
# FROM price
# WHERE date BETWEEN '2022-12-23' AND '2022-12-29'
# <style type="text/css">
# </style>
# <table id="T_0b793_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >price</th>
#       <th class="col_heading level0 col3" >maxp</th>
#       <th class="col_heading level0 col4" >minp</th>
#       <th class="col_heading level0 col5" >qty</th>
#       <th class="col_heading level0 col6" >opnp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b793_level0_row0" class="row_heading level0 row0" >1164</th>
#       <td id="T_0b793_row0_col0" class="data row0 col0" >ACE</td>
#       <td id="T_0b793_row0_col1" class="data row0 col1" >2022-12-23</td>
#       <td id="T_0b793_row0_col2" class="data row0 col2" >2.56</td>
#       <td id="T_0b793_row0_col3" class="data row0 col3" >2.58</td>
#       <td id="T_0b793_row0_col4" class="data row0 col4" >2.54</td>
#       <td id="T_0b793_row0_col5" class="data row0 col5" >13,693,466</td>
#       <td id="T_0b793_row0_col6" class="data row0 col6" >2.56</td>
#     </tr>
#     <tr>
#       <th id="T_0b793_level0_row1" class="row_heading level0 row1" >465</th>
#       <td id="T_0b793_row1_col0" class="data row1 col0" >ACE</td>
#       <td id="T_0b793_row1_col1" class="data row1 col1" >2022-12-28</td>
#       <td id="T_0b793_row1_col2" class="data row1 col2" >2.62</td>
#       <td id="T_0b793_row1_col3" class="data row1 col3" >2.62</td>
#       <td id="T_0b793_row1_col4" class="data row1 col4" >2.60</td>
#       <td id="T_0b793_row1_col5" class="data row1 col5" >13,103,523</td>
#       <td id="T_0b793_row1_col6" class="data row1 col6" >2.60</td>
#     </tr>
#     <tr>
#       <th id="T_0b793_level0_row2" class="row_heading level0 row2" >698</th>
#       <td id="T_0b793_row2_col0" class="data row2 col0" >ACE</td>
#       <td id="T_0b793_row2_col1" class="data row2 col1" >2022-12-27</td>
#       <td id="T_0b793_row2_col2" class="data row2 col2" >2.60</td>
#       <td id="T_0b793_row2_col3" class="data row2 col3" >2.64</td>
#       <td id="T_0b793_row2_col4" class="data row2 col4" >2.58</td>
#       <td id="T_0b793_row2_col5" class="data row2 col5" >16,711,748</td>
#       <td id="T_0b793_row2_col6" class="data row2 col6" >2.58</td>
#     </tr>
#     <tr>
#       <th id="T_0b793_level0_row3" class="row_heading level0 row3" >232</th>
#       <td id="T_0b793_row3_col0" class="data row3 col0" >ACE</td>
#       <td id="T_0b793_row3_col1" class="data row3 col1" >2022-12-29</td>
#       <td id="T_0b793_row3_col2" class="data row3 col2" >2.66</td>
#       <td id="T_0b793_row3_col3" class="data row3 col3" >2.66</td>
#       <td id="T_0b793_row3_col4" class="data row3 col4" >2.62</td>
#       <td id="T_0b793_row3_col5" class="data row3 col5" >7,753,382</td>
#       <td id="T_0b793_row3_col6" class="data row3 col6" >2.62</td>
#     </tr>
#     <tr>
#       <th id="T_0b793_level0_row4" class="row_heading level0 row4" >931</th>
#       <td id="T_0b793_row4_col0" class="data row4 col0" >ACE</td>
#       <td id="T_0b793_row4_col1" class="data row4 col1" >2022-12-26</td>
#       <td id="T_0b793_row4_col2" class="data row4 col2" >2.58</td>
#       <td id="T_0b793_row4_col3" class="data row4 col3" >2.60</td>
#       <td id="T_0b793_row4_col4" class="data row4 col4" >2.58</td>
#       <td id="T_0b793_row4_col5" class="data row4 col5" >9,327,316</td>
#       <td id="T_0b793_row4_col6" class="data row4 col6" >2.58</td>
#     </tr>
#   </tbody>
# </table>

# %%
five_day_mean = five_day_vol.groupby(by=["name"])[["qty","price"]].mean()
five_day_mean.reset_index(inplace=True)
five_day_mean.columns
# Out:
# Index(['name', 'qty', 'price'], dtype='object')

# %%
df_merge2 = pd.merge(today_vol, five_day_mean, on=["name"], how="inner")
df_merge2.columns
# Out:
# Index(['name', 'qty_x', 'price_x', 'today', 'end_date', 'start_date', 'qty_y',
#        'price_y'],
#       dtype='object')

# %%
df_merge2["qty_y"] = df_merge2.qty_y.astype("int64")
df_merge2.head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e91f3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >qty_x</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >today</th>
#       <th class="col_heading level0 col4" >end_date</th>
#       <th class="col_heading level0 col5" >start_date</th>
#       <th class="col_heading level0 col6" >qty_y</th>
#       <th class="col_heading level0 col7" >price_y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e91f3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e91f3_row0_col0" class="data row0 col0" >ACE</td>
#       <td id="T
_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >date</th>
#       <th class="col_heading level0 col2" >volbuy</th>
#       <th class="col_heading level0 col3" >price</th>
#       <th class="col_heading level0 col4" >dividend</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3f0a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3f0a_row0_col0" class="data row0 col0" >STA</td>
#       <td id="T_e3f0a_row0_col1" class="data row0 col1" >2021-06-15</td>
#       <td id="T_e3f0a_row0_col2" class="data row0 col2" >15000</td>
#       <td id="T_e3f0a_row0_col3" class="data row0 col3" >36.50</td>
#       <td id="T_e3f0a_row0_col4" class="data row0 col4" >1.650000</td>
#     </tr>
#     <tr>
#       <th id="T_e3f0a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e3f0a_row1_col0" class="data row1 col0" >JMART</td>
#       <td id="T_e3f0a_row1_col1" class="data row1 col1" >2022-12-20</td>
#       <td id="T_e3f0a_row1_col2" class="data row1 col2" >3000</td>
#       <td id="T_e3f0a_row1_col3" class="data row1 col3" >40.00</td>
#       <td id="T_e3f0a_row1_col4" class="data row1 col4" >1.460000</td>
#     </tr>
#     <tr>
#       <th id="T_e3f0a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e3f0a_row2_col0" class="data row2 col0" >KCE</td>
#       <td id="T_e3f0a_row2_col1" class="data row2 col1" >2021-10-07</td>
#       <td id="T_e3f0a_row2_col2" class="data row2 col2" >14000</td>
#       <td id="T_e3f0a_row2_col3" class="data row2 col3" >72.75</td>
#       <td id="T_e3f0a_row2_col4" class="data row2 col4" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e3f0a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e3f0a_row3_col0" class="data row3 col0" >MCS</td>
#       <td id="T_e3f0a_row3_col1" class="data row3 col1" >2016-09-20</td>
#       <td id="T_e3f0a_row3_col2" class="data row3 col2" >75000</td>
#       <td id="T_e3f0a_row3_col3" class="data row3 col3" >15.40</td>
#       <td id="T_e3f0a_row3_col4" class="data row3 col4" >0.500000</td>
#     </tr>
#     <tr>
#       <th id="T_e3f0a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e3f0a_row4_col0" class="data row4 col0" >DIF</td>
#       <td id="T_e3f0a_row4_col1" class="data row4 col1" >2020-08-01</td>
#       <td id="T_e3f0a_row4_col2" class="data row4 col2" >40000</td>
#       <td id="T_e3f0a_row4_col3" class="data row4 col3" >14.70</td>
#       <td id="T_e3f0a_row4_col4" class="data row4 col4" >1.041000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_merge3 = pd.merge(break_five_day_mean, buys, on=["name"], how="inner")
df_merge3["qty_pct"] = round((df_merge3.qty_x - df_merge3.qty_y) / abs(df_merge3.qty_y) * 100,2)
df_merge3["prc_pct"] = round((df_merge3.price_x - df_merge3.price_y) / abs(df_merge3.price_y) * 100,2)
df_merge3.rename(columns={'price_x':'tdy_price','price_y':'avg_price',
                          'qty_x':'tdy_qty','qty_y':'avg_qty'},inplace=True)
df_merge3[colu].sort_values(["prc_pct"], ascending=False
).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fd825_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >prc_pct</th>
#       <th class="col_heading level0 col2" >tdy_price</th>
#       <th class="col_heading level0 col3" >avg_price</th>
#       <th class="col_heading level0 col4" >qty_pct</th>
#       <th class="col_heading level0 col5" >tdy_qty</th>
#       <th class="col_heading level0 col6" >avg_qty</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd825_level0_row0" class="row_heading level0 row0" >14</th>
#       <td id="T_fd825_row0_col0" class="data row0 col0" >SYNEX</td>
#       <td id="T_fd825_row0_col1" class="data row0 col1" >3.40%</td>
#       <td id="T_fd825_row0_col2" class="data row0 col2" >16.40</td>
#       <td id="T_fd825_row0_col3" class="data row0 col3" >15.86</td>
#       <td id="T_fd825_row0_col4" class="data row0 col4" >307.96%</td>
#       <td id="T_fd825_row0_col5" class="data row0 col5" >4,934,430</td>
#       <td id="T_fd825_row0_col6" class="data row0 col6" >1,209,524</td>
#     </tr>
#     <tr>
#       <th id="T_fd825_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_fd825_row1_col0" class="data row1 col0" >IVL</td>
#       <td id="T_fd825_row1_col1" class="data row1 col1" >1.24%</td>
#       <td id="T_fd825_row1_col2" class="data row1 col2" >40.75</td>
#       <td id="T_fd825_row1_col3" class="data row1 col3" >40.25</td>
#       <td id="T_fd825_row1_col4" class="data row1 col4" >39.32%</td>
#       <td id="T_fd825_row1_col5" class="data row1 col5" >13,313,221</td>
#       <td id="T_fd825_row1_col6" class="data row1 col6" >9,555,637</td>
#     </tr>
#     <tr>
#       <th id="T_fd825_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_fd825_row2_col0" class="data row2 col0" >MAKRO</td>
#       <td id="T_fd825_row2_col1" class="data row2 col1" >1.14%</td>
#       <td id="T_fd825_row2_col2" class="data row2 col2" >40.00</td>
#       <td id="T_fd825_row2_col3" class="data row2 col3" >39.55</td>
#       <td id="T_fd825_row2_col4" class="data row2 col4" >45.47%</td>
#       <td id="T_fd825_row2_col5" class="data row2 col5" >10,449,620</td>
#       <td id="T_fd825_row2_col6" class="data row2 col6" >7,183,249</td>
#     </tr>
#     <tr>
#       <th id="T_fd825_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_fd825_row3_col0" class="data row3 col0" >BCH</td>
#       <td id="T_fd825_row3_col1" class="data row3 col1" >0.99%</td>
#       <td id="T_fd825_row3_col2" class="data row3 col2" >20.50</td>
#       <td id="T_fd825_row3_col3" class="data row3 col3" >20.30</td>
#       <td id="T_fd825_row3_col4" class="data row3 col4" >202.98%</td>
#       <td id="T_fd825_row3_col5" class="data row3 col5" >25,899,919</td>
#       <td id="T_fd825_row3_col6" class="data row3 col6" >8,548,496</td>
#     </tr>
#     <tr>
#       <th id="T_fd825_level0_row4" class="row_heading level0 row4" >7</th>
#       <td id="T_fd825_row4_col0" class="data row4 col0" >JMART</td>
#       <td id="T_fd825_row4_col1" class="data row4 col1" >0.99%</td>
#       <td id="T_fd825_row4_col2" class="data row4 col2" >40.75</td>
#       <td id="T_fd825_row4_col3" class="data row4 col3" >40.35</td>
#       <td id="T_fd825_row4_col4" class="data row4 col4" >17.22%</td>
#       <td id="T_fd825_row4_col5" class="data row4 col5" >6,010,236</td>
#       <td id="T_fd825_row4_col6" class="data row4 col6" >5,127,406</td>
#     </tr>
#     <tr>
#       <th id="T_fd825_level0_row5" class="row_heading level0 row5" >12</th>
#       <td id="T_fd825_row5_col0" class="data row5 col0" >SCC</td>
#       <td id="T_fd825_row5_col1" class="data row5 col1" >0.94%</td>
#       <td id="T_fd825_row5_col2" class="data row5 col2" >342.00</td>
#       <td id="T_fd825_row5_col3" class="data row5 col3" >338.80</td>
#       <td id="T_fd825_row5_col4" class="data row5 col4" >61.89%</td>
#       <td id="T_fd825_row5_col5" class="data row5 col5" >2,037,787</td>
#       <td id="T_fd825_row5_col6" class="data row5 col6" >1,258,714</td>
#     </tr>
#     <tr>
#       <th id="T_fd825_level0_row6" class="row_heading level0 row6" >0</th>
#       <td id="T_fd825_row6_col0" class="data row6 col0" >ASP</td>
#       <td id="T_fd825_row6_col1" class="data row6 col1" >0.68%</td>
#       <td id="T_fd825_row6_col2" class="data row6 col2" >2.98</td>
#       <td id="T_fd825_row6_col3" class="data row6 col3" >2.96</td>
#       <td id="T_fd825_row6_col4" class="data row6 col4" >11.49%</td>
#       <td id="T_fd825_row6_col5" class="data row6 col5" >1,971,614</td>
#       <td id="T_fd825_row6_col6" class="data row6 col6" >1,768,357</td>
#     </tr>
#     <tr>
#       <th id="T_fd825_level0_row7" class="row_heading level0 row7" >2</th>
#       <td id="T_fd825_row7_col0" class="data row7 col0" >DCC</td>
#       <td id="T_fd825_row7_col1" class="data row7 col1" >0.57%</td>
#       <td id="T_fd825_row7_col2" class="data row7 col2" >2.82</td>
#       <td id="T_fd825_row7_col3" class="data row7 col3" >2.80</td>
#       <td id="T_fd825_row7_col4" class="data row7 col4" >77.35%</td>
#       <td id="T_fd825_row7_col5" class="data row7 col5" >6,955,178</td>
#       <td id="T_fd825_row7_col6" class="data row7 col6" >3,921,731</td>
#     </tr>
#     <tr>
#       <th id="T_fd825_level0_row8" class="row_heading level0 row8" >13</th>
#       <td id="T_fd825_row8_col0" class="data row8 col0" >SENA</td>
#       <td id="T_fd825_row8_col1" class="data row8 col1" >0.41%</td>
#       <td id="T_fd825_row8_col2" class="data row8 col2" >3.94</td>
#       <td id="T_fd825_row8_col3" class="data row8 col3" >3.92</td>
#       <td id="T_fd825_row8_col4" class="data row8 col4" >33.33%</td>
#       <td id="T_fd825_row8_col5" class="data row8 col5" >1,103,705</td>
#       <td id="T_fd825_row8_col6" class="data row8 col6" >827,772</td>
#     </tr>
#     <tr>
#       <th id="T_fd825_level0_row9" class="row_heading level0 row9" >6</th>
#       <td id="T_fd825_row9_col0" class="data row9 col0" >JASIF</td>
#       <td id="T_fd825_row9_col1" class="data row9 col1" >0.37%</td>
#       <td id="T_fd825_row9_col2" class="data row9 col2" >8.05</td>
#       <td id="T_fd825_row9_col3" class="data row9 col3" >8.02</td>
#       <td id="T_fd825_row9_col4" class="data row9 col4" >67.33%</td>
#       <td id="T_fd825_row9_col5" class="data row9 col5" >4,872,314</td>
#       <td id="T_fd825_row9_col6" class="data row9 col6" >2,911,834</td>
#     </tr>
#     <tr>
#       <th id="T_fd825_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_fd825_row10_col0" class="data row10 col0" >RCL</td>
#       <td id="T_fd825_row10_col1" class="data row10 col1" >0.33%</td>
#       <td id="T_fd825_row10_col2" class="data row10 col2" >30.75</td>
#       <td id="T_fd825_row10_col3" class="data row10 col3" >30.65</td>
#       <td id="T_fd825_row10_col4" class="data row10 col4" >39.84%</td>
#       <td id="T_fd825_row10_col5" class="data row10 col5" >2,948,494</td>
#       <td id="T_fd825_row10_col6" class="data row10 col6" >2,108,485</td>
#     </tr>
#     <tr>
#       <th id="T_fd825_level0_row11" class="row_heading level0 row11" >8</th>
#       <td id="T_fd825_row11_col0" class="data row11 col0" >KCE</td>
#       <td id="T_fd825_row11_col1" class="data row11 col1" >0.22%</td>
#       <td id="T_fd825_row11_col2" class="data row11 col2" >46.50</td>
#       <td id="T_fd825_row11_col3" class="data row11 col3" >46.40</td>
#       <td id="T_fd825_row11_col4" class="data row11 col4" >156.37%</td>
#       <td id="T_fd825_row11_col5" class="data row11 col5" >22,449,277</td>
#       <td id="T_fd825_row11_col6" class="data row11 col6" >8,756,571</td>
#     </tr>
#     <tr>
#       <th id="T_fd825_level0_row12" class="row_heading level0 row12" >10</th>
#       <td id="T_fd825_row12_col0" class="data row12 col0" >MCS</td>
#       <td id="T_fd825_row12_col1" class="data row12 col1" >0.22%</td>
#       <td id="T_fd825_row12_col2" class="data row12 col2" >8.95</td>
#       <td id="T_fd825_row12_col3" class="data row12 col3" >8.93</td>
#       <td id="T_fd825_row12_col4" class="data row12 col4" >9.23%</td>
#       <td id="T_fd825_row12_col5" class="data row12 col5"

# %%
file_name = '5-day-average.csv'
data_file = data_path + file_name
output_file = csv_path + file_name
box_file = box_path + file_name
one_file = one_path + file_name

df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(data_file, index=False)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(output_file, index=False)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(box_file, index=False)
df_merge3[colu].sort_values(["prc_pct"], ascending=False).to_csv(one_file, index=False)

# %% [markdown]
# ### Extreme price discrepancy

# %%
sql = '''
SELECT name, status
FROM stocks'''
stocks = pd.read_sql(sql, conlite)
stocks.head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_57ba4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57ba4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_57ba4_row0_col0" class="data row0 col0" >MCS</td>
#       <td id="T_57ba4_row0_col1" class="data row0 col1" >U</td>
#     </tr>
#     <tr>
#       <th id="T_57ba4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_57ba4_row1_col0" class="data row1 col0" >PTTGC</td>
#       <td id="T_57ba4_row1_col1" class="data row1 col1" >U</td>
#     </tr>
#     <tr>
#       <th id="T_57ba4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_57ba4_row2_col0" class="data row2 col0" >JASIF</td>
#       <td id="T_57ba4_row2_col1" class="data row2 col1" >I</td>
#     </tr>
#     <tr>
#       <th id="T_57ba4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_57ba4_row3_col0" class="data row3 col0" >DIF</td>
#       <td id="T_57ba4_row3_col1" class="data row3 col1" >U</td>
#     </tr>
#     <tr>
#       <th id="T_57ba4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_57ba4_row4_col0" class="data row4 col0" >WHAIR</td>
#       <td id="T_57ba4_row4_col1" class="data row4 col1" >T</td>
#     </tr>
#   </tbody>
# </table>

# %%
names = stocks["name"].values.tolist()
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'MCS', 'PTTGC', 'JASIF', 'DIF', 'WHAIR', 'STA', 'SCC', 'NER', 'SYNEX', 'BCH', 'KCE', 'TMT', 'RCL', 'WHART', 'ASP', 'SCCC', 'MAKRO', 'SENA', 'ORI', 'DCC', 'ASK', 'BH', 'IVL', 'BANPU', 'TTB', 'PTTEP', 'CKP', 'GVREIT', 'CPNREIT', 'JMART', 'JMT', 'SAPPE', 'SPALI', 'SVI', 'TFFIF', 'SCB', 'AIT', 'BBL', 'BEM', 'BPP', 'CPALL', 'CPN', 'EA', 'GFPT', 'HMPRO', 'ICHI', 'III', 'KKP', 'KTB', 'LH', 'PSH', 'QH', 'SC', 'TFG', 'COM7', 'CPF', 'BDMS', 'CK', 'MEGA', 'SIRI', 'AH', 'SINGER'"

# %%
type(in_p)
# Out:
# str

# %%
sql = """
SELECT name, price 
FROM price 
WHERE date = '%s' AND name IN (%s) 
ORDER BY name"""
sql = sql % (today, in_p)
print(sql)

tdy_prices = pd.read_sql(sql, const)
str(tdy_prices.shape[0]) + ' stocks'
# Out:
# SELECT name, price
# FROM price
# WHERE date = '2022-12-30' AND name IN ('MCS', 'PTTGC', 'JASIF', 'DIF', 'WHAIR', 'STA', 'SCC', 'NER', 'SYNEX', 'BCH', 'KCE', 'TMT', 'RCL', 'WHART', 'ASP', 'SCCC', 'MAKRO', 'SENA', 'ORI', 'DCC', 'ASK', 'BH', 'IVL', 'BANPU', 'TTB', 'PTTEP', 'CKP', 'GVREIT', 'CPNREIT', 'JMART', 'JMT', 'SAPPE', 'SPALI', 'SVI', 'TFFIF', 'SCB', 'AIT', 'BBL', 'BEM', 'BPP', 'CPALL', 'CPN', 'EA', 'GFPT', 'HMPRO', 'ICHI', 'III', 'KKP', 'KTB', 'LH', 'PSH', 'QH', 'SC', 'TFG', 'COM7', 'CPF', 'BDMS', 'CK', 'MEGA', 'SIRI', 'AH', 'SINGER')
# ORDER BY name
# '62 stocks'

# %%
sql = """
SELECT name, price 
FROM price 
WHERE date = '%s' AND name IN (%s) 
ORDER BY name"""
sql = sql % (yesterday, in_p)
print(sql)

ytd_prices = pd.read_sql(sql, const)
str(ytd_prices.shape[0]) + ' stocks'
# Out:
# SELECT name, price
# FROM price
# WHERE date = '2022-12-29' AND name IN ('MCS', 'PTTGC', 'JASIF', 'DIF', 'WHAIR', 'STA', 'SCC', 'NER', 'SYNEX', 'BCH', 'KCE', 'TMT', 'RCL', 'WHART', 'ASP', 'SCCC', 'MAKRO', 'SENA', 'ORI', 'DCC', 'ASK', 'BH', 'IVL', 'BANPU', 'TTB', 'PTTEP', 'CKP', 'GVREIT', 'CPNREIT', 'JMART', 'JMT', 'SAPPE', 'SPALI', 'SVI', 'TFFIF', 'SCB', 'AIT', 'BBL', 'BEM', 'BPP', 'CPALL', 'CPN', 'EA', 'GFPT', 'HMPRO', 'ICHI', 'III', 'KKP', 'KTB', 'LH', 'PSH', 'QH', 'SC', 'TFG', 'COM7', 'CPF', 'BDMS', 'CK', 'MEGA', 'SIRI', 'AH', 'SINGER')
# ORDER BY name
# '62 stocks'

# %%
compare1 = pd.merge(tdy_prices,ytd_prices,on='name',how='inner')
compare1.head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6aa2d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price_x</th>
#       <th class="col_heading level0 col2" >price_y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6aa2d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6aa2d_row0_col0" class="data row0 col0" >AH</td>
#       <td id="T_6aa2d_row0_col1" class="data row0 col1" >29.75</td>
#       <td id="T_6aa2d_row0_col2" class="data row0 col2" >29.75</td>
#     </tr>
#     <tr>
#       <th id="T_6aa2d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6aa2d_row1_col0" class="data row1 col0" >AIT</td>
#       <td id="T_6aa2d_row1_col1" class="data row1 col1" >6.80</td>
#       <td id="T_6aa2d_row1_col2" class="data row1 col2" >6.50</td>
#     </tr>
#     <tr>
#       <th id="T_6aa2d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6aa2d_row2_col0" class="data row2 col0" >ASK</td>
#       <td id="T_6aa2d_row2_col1" class="data row2 col1" >35.50</td>
#       <td id="T_6aa2d_row2_col2" class="data row2 col2" >35.50</td>
#     </tr>
#     <tr>
#       <th id="T_6aa2d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6aa2d_row3_col0" class="data row3 col0" >ASP</td>
#       <td id="T_6aa2d_row3_col1" class="data row3 col1" >2.98</td>
#       <td id="T_6aa2d_row3_col2" class="data row3 col2" >2.96</td>
#     </tr>
#     <tr>
#       <th id="T_6aa2d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6aa2d_row4_col0" class="data row4 col0" >BANPU</td>
#       <td id="T_6aa2d_row4_col1" class="data row4 col1" >13.70</td>
#       <td id="T_6aa2d_row4_col2" class="data row4 col2" >13.70</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare2 = pd.merge(compare1,stocks,on='name',how='inner')
compare2.head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e776c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >price_x</th>
#       <th class="col_heading level0 col2" >price_y</th>
#       <th class="col_heading level0 col3" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e776c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e776c_row0_col0" class="data row0 col0" >AH</td>
#       <td id="T_e776c_row0_col1" class="data row0 col1" >29.75</td>
#       <td id="T_e776c_row0_col2" class="data row0 col2" >29.75</td>
#       <td id="T_e776c_row0_col3" class="data row0 col3" >O</td>
#     </tr>
#     <tr>
#       <th id="T_e776c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e776c_row1_col0" class="data row1 col0" >AIT</td>
#       <td id="T_e776c_row1_col1" class="data row1 col1" >6.80</td>
#       <td id="T_e776c_row1_col2" class="data row1 col2" >6.50</td>
#       <td id="T_e776c_row1_col3" class="data row1 col3" >X</td>
#     </tr>
#     <tr>
#       <th id="T_e776c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e776c_row2_col0" class="data row2 col0" >ASK</td>
#       <td id="T_e776c_row2_col1" class="data row2 col1" >35.50</td>
#       <td id="T_e776c_row2_col2" class="data row2 col2" >35.50</td>
#       <td id="T_e776c_row2_col3" class="data row2 col3" >X</td>
#     </tr>
#     <tr>
#       <th id="T_e776c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e776c_row3_col0" class="data row3 col0" >ASP</td>
#       <td id="T_e776c_row3_col1" class="data row3 col1" >2.98</td>
#       <td id="T_e776c_row3_col2" class="data row3 col2" >2.96</td>
#       <td id="T_e776c_row3_col3" class="data row3 col3" >S</td>
#     </tr>
#     <tr>
#       <th id="T_e776c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e776c_row4_col0" class="data row4 col0" >BANPU</td>
#       <td id="T_e776c_row4_col1" class="data row4 col1" >13.70</td>
#       <td id="T_e776c_row4_col2" class="data row4 col2" >13.70</td>
#       <td id="T_e776c_row4_col3" class="data row4 col3" >O</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare2['diff'] = round((compare2.price_x - compare2.price_y),2)
compare2['pct'] = round(compare2['diff'] / compare2['price_y'] * 100,2)
compare2[colt].sort_values(['pct'],ascending=[False]).head().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_cea48_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >pct</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >price_y</th>
#       <th class="col_heading level0 col4" >status</th>
#       <th class="col_heading level0 col5" >diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cea48_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_cea48_row0_col0" class="data row0 col0" >AIT</td>
#       <td id="T_cea48_row0_col1" class="data row0 col1" >4.62%</td>
#       <td id="T_cea48_row0_col2" class="data row0 col2" >6.80</td>
#       <td id="T_cea48_row0_col3" class="data row0 col3" >6.50</td>
#       <td id="T_cea48_row0_col4" class="data row0 col4" >X</td>
#       <td id="T_cea48_row0_col5" class="data row0 col5" >0.30</td>
#     </tr>
#     <tr>
#       <th id="T_cea48_level0_row1" class="row_heading level0 row1" >55</th>
#       <td id="T_cea48_row1_col0" class="data row1 col0" >SYNEX</td>
#       <td id="T_cea48_row1_col1" class="data row1 col1" >3.14%</td>
#       <td id="T_cea48_row1_col2" class="data row1 col2" >16.40</td>
#       <td id="T_cea48_row1_col3" class="data row1 col3" >15.90</td>
#       <td id="T_cea48_row1_col4" class="data row1 col4" >I</td>
#       <td id="T_cea48_row1_col5" class="data row1 col5" >0.50</td>
#     </tr>
#     <tr>
#       <th id="T_cea48_level0_row2" class="row_heading level0 row2" >13</th>
#       <td id="T_cea48_row2_col0" class="data row2 col0" >COM7</td>
#       <td id="T_cea48_row2_col1" class="data row2 col1" >2.26%</td>
#       <td id="T_cea48_row2_col2" class="data row2 col2" >34.00</td>
#       <td id="T_cea48_row2_col3" class="data row2 col3" >33.25</td>
#       <td id="T_cea48_row2_col4" class="data row2 col4" >X</td>
#       <td id="T_cea48_row2_col5" class="data row2 col5" >0.75</td>
#     </tr>
#     <tr>
#       <th id="T_cea48_level0_row3" class="row_heading level0 row3" >59</th>
#       <td id="T_cea48_row3_col0" class="data row3 col0" >TTB</td>
#       <td id="T_cea48_row3_col1" class="data row3 col1" >1.44%</td>
#       <td id="T_cea48_row3_col2" class="data row3 col2" >1.41</td>
#       <td id="T_cea48_row3_col3" class="data row3 col3" >1.39</td>
#       <td id="T_cea48_row3_col4" class="data row3 col4" >X</td>
#       <td id="T_cea48_row3_col5" class="data row3 col5" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_cea48_level0_row4" class="row_heading level0 row4" >34</th>
#       <td id="T_cea48_row4_col0" class="data row4 col0" >MAKRO</td>
#       <td id="T_cea48_row4_col1" class="data row4 col1" >1.27%</td>
#       <td id="T_cea48_row4_col2" class="data row4 col2" >40.00</td>
#       <td id="T_cea48_row4_col3" class="data row4 col3" >39.50</td>
#       <td id="T_cea48_row4_col4" class="data row4 col4" >I</td>
#       <td id="T_cea48_row4_col5" class="data row4 col5" >0.50</td>
#     </tr>
#   </tbody>
# </table>

# %%
criteria = 3
mask = abs(compare2.pct) >= criteria
extremes = compare2[mask].sort_values(['status','pct'],ascending=[True,False])
extremes[colt].sort_values(['status','pct'],ascending=[True,False]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8b25c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >pct</th>
#       <th class="col_heading level0 col2" >price_x</th>
#       <th class="col_heading level0 col3" >price_y</th>
#       <th class="col_heading level0 col4" >status</th>
#       <th class="col_heading level0 col5" >diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b25c_level0_row0" class="row_heading level0 row0" >55</th>
#       <td id="T_8b25c_row0_col0" class="data row0 col0" >SYNEX</td>
#       <td id="T_8b25c_row0_col1" class="data row0 col1" >3.14%</td>
#       <td id="T_8b25c_row0_col2" class="data row0 col2" >16.40</td>
#       <td id="T_8b25c_row0_col3" class="data row0 col3" >15.90</td>
#       <td id="T_8b25c_row0_col4" class="data row0 col4" >I</td>
#       <td id="T_8b25c_row0_col5" class="data row0 col5" >0.50</td>
#     </tr>
#     <tr>
#       <th id="T_8b25c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8b25c_row1_col0" class="data row1 col0" >AIT</td>
#       <td id="T_8b25c_row1_col1" class="data row1 col1" >4.62%</td>
#       <td id="T_8b25c_row1_col2" class="data row1 col2" >6.80</td>
#       <td id="T_8b25c_row1_col3" class="data row1 col3" >6.50</td>
#       <td id="T_8b25c_row1_col4" class="data row1 col4" >X</td>
#       <td id="T_8b25c_row1_col5" class="data row1 col5" >0.30</td>
#     </tr>
#   </tbody>
# </table>

# %%
file_name = 'extremes.csv'
data_file = data_path + file_name
output_file = csv_path + file_name
box_file = box_path + file_name
one_file = one_path + file_name

extremes[colt].sort_values(['status','pct'],ascending=[True,False]).to_csv(data_file, index=False)
extremes[colt].sort_values(['status','pct'],ascending=[True,False]).to_csv(output_file, index=False)
extremes[colt].sort_values(['status','pct'],ascending=[True,False]).to_csv(box_file, index=False)
extremes[colt].sort_values(['status','pct'],ascending=[True,False]).to_csv(one_file, index=False)
