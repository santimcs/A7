# %% [markdown]
# #### SQLite port_lite database: sales, stocks table
# #### csv files: daily-watch-list, daily-sales, monitors, stocks-all

# %% [markdown]
# ### Restart and Run All Cells

# %%
import numpy as np
import pandas as pd
from datetime import date, timedelta
from sqlalchemy import create_engine
from pandas.tseries.offsets import BDay

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"

today = date.today()
today
# Out:
# datetime.date(2023, 1, 2)

# %% [markdown]
# ### Yesterday = Last business day

# %%
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(1)
yesterday = today - num_business_days
yesterday = yesterday.date()
print(f'today: {today}')
print(f'yesterday: {yesterday}')
# Out:
# today: 2023-01-02
# yesterday: 2022-12-30

# %%
cols = 'fm_date to_date fm_price to_price qty max_price min_price percent status'.split()

format_dict = {
    'fm_price':'{:.2f}','to_price':'{:.2f}','diff':'{:.2f}',
    'max_price':'{:.2f}','min_price':'{:.2f}',
    'volume':'{:,.2f}','beta':'{:,.2f}',
    'pct':'{:,.2f}%','percent':'{:,.2f}%',   
    'fm_date':'{:%Y-%m-%d}','to_date':'{:%Y-%m-%d}',
    'created_at':'{:%Y-%m-%d}','updated_at':'{:%Y-%m-%d}',
    
    'qty':'{:,}','available_qty':'{:,}',
    'cost':'{:.2f}','buy_target':'{:.2f}','sell_target':'{:.2f}',
}

# %% [markdown]
# ### Begin of Tables in the process

# %%
sql = """
SELECT * 
FROM sales 
ORDER BY id DESC LIMIT 1
"""
tmp = pd.read_sql(sql, conlite)
tmp["fm_date"] = pd.to_datetime(tmp["fm_date"])
tmp["to_date"] = pd.to_datetime(tmp["to_date"])
tmp["created_at"] = pd.to_datetime(tmp["created_at"])
tmp["updated_at"] = pd.to_datetime(tmp["updated_at"])
tmp.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d04ba_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >fm_date</th>
#       <th class="col_heading level0 col3" >to_date</th>
#       <th class="col_heading level0 col4" >days</th>
#       <th class="col_heading level0 col5" >fm_price</th>
#       <th class="col_heading level0 col6" >to_price</th>
#       <th class="col_heading level0 col7" >diff</th>
#       <th class="col_heading level0 col8" >pct</th>
#       <th class="col_heading level0 col9" >ttl_spread</th>
#       <th class="col_heading level0 col10" >avg_spread</th>
#       <th class="col_heading level0 col11" >max_price</th>
#       <th class="col_heading level0 col12" >min_price</th>
#       <th class="col_heading level0 col13" >qty</th>
#       <th class="col_heading level0 col14" >created_at</th>
#       <th class="col_heading level0 col15" >updated_at</th>
#       <th class="col_heading level0 col16" >latest_date_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d04ba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d04ba_row0_col0" class="data row0 col0" >1201996</td>
#       <td id="T_d04ba_row0_col1" class="data row0 col1" >TOP</td>
#       <td id="T_d04ba_row0_col2" class="data row0 col2" >2022-12-29</td>
#       <td id="T_d04ba_row0_col3" class="data row0 col3" >2022-12-30</td>
#       <td id="T_d04ba_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_d04ba_row0_col5" class="data row0 col5" >56.50</td>
#       <td id="T_d04ba_row0_col6" class="data row0 col6" >56.25</td>
#       <td id="T_d04ba_row0_col7" class="data row0 col7" >-0.25</td>
#       <td id="T_d04ba_row0_col8" class="data row0 col8" >-0.44%</td>
#       <td id="T_d04ba_row0_col9" class="data row0 col9" >-1</td>
#       <td id="T_d04ba_row0_col10" class="data row0 col10" >-1</td>
#       <td id="T_d04ba_row0_col11" class="data row0 col11" >56.75</td>
#       <td id="T_d04ba_row0_col12" class="data row0 col12" >56.25</td>
#       <td id="T_d04ba_row0_col13" class="data row0 col13" >5,708,042</td>
#       <td id="T_d04ba_row0_col14" class="data row0 col14" >2023-01-02</td>
#       <td id="T_d04ba_row0_col15" class="data row0 col15" >2023-01-02</td>
#       <td id="T_d04ba_row0_col16" class="data row0 col16" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
names = tmp["name"]
type(names)
# Out:
# pandas.core.series.Series

# %%
name = names.to_string(index=False)
type(name)
# Out:
# str

# %%
sql = """
SELECT * 
FROM stocks
WHERE name = '%s'
"""
sql = sql % name
print(sql)
tmp = pd.read_sql(sql, conlite)
tmp.style.format(format_dict)
# Out:
# SELECT *
# FROM stocks
# WHERE name = 'TOP'
# <style type="text/css">
# </style>
# <table id="T_0d6c2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >max_price</th>
#       <th class="col_heading level0 col3" >min_price</th>
#       <th class="col_heading level0 col4" >status</th>
#       <th class="col_heading level0 col5" >buy_target</th>
#       <th class="col_heading level0 col6" >sell_target</th>
#       <th class="col_heading level0 col7" >volume</th>
#       <th class="col_heading level0 col8" >beta</th>
#       <th class="col_heading level0 col9" >cost</th>
#       <th class="col_heading level0 col10" >qty</th>
#       <th class="col_heading level0 col11" >buy_spread</th>
#       <th class="col_heading level0 col12" >sell_spread</th>
#       <th class="col_heading level0 col13" >available_qty</th>
#       <th class="col_heading level0 col14" >bl</th>
#       <th class="col_heading level0 col15" >sh</th>
#       <th class="col_heading level0 col16" >reason</th>
#       <th class="col_heading level0 col17" >market</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d6c2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d6c2_row0_col0" class="data row0 col0" >9778</td>
#       <td id="T_0d6c2_row0_col1" class="data row0 col1" >TOP</td>
#       <td id="T_0d6c2_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_0d6c2_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_0d6c2_row0_col4" class="data row0 col4" >O</td>
#       <td id="T_0d6c2_row0_col5" class="data row0 col5" >55.00</td>
#       <td id="T_0d6c2_row0_col6" class="data row0 col6" >0.00</td>
#       <td id="T_0d6c2_row0_col7" class="data row0 col7" >0.00</td>
#       <td id="T_0d6c2_row0_col8" class="data row0 col8" >0.00</td>
#       <td id="T_0d6c2_row0_col9" class="data row0 col9" >0.00</td>
#       <td id="T_0d6c2_row0_col10" class="data row0 col10" >2,100</td>
#       <td id="T_0d6c2_row0_col11" class="data row0 col11" >-4</td>
#       <td id="T_0d6c2_row0_col12" class="data row0 col12" >4</td>
#       <td id="T_0d6c2_row0_col13" class="data row0 col13" >0</td>
#       <td id="T_0d6c2_row0_col14" class="data row0 col14" >0</td>
#       <td id="T_0d6c2_row0_col15" class="data row0 col15" >0</td>
#       <td id="T_0d6c2_row0_col16" class="data row0 col16" >XXX</td>
#       <td id="T_0d6c2_row0_col17" class="data row0 col17" >SET50</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### End of Tables in the process

# %%
sql = """
SELECT a.name,fm_date,to_date,fm_price,to_price,
a.qty,a.max_price,a.min_price,t.status,t.market
FROM sales a 
JOIN stocks t ON a.name = t.name 
WHERE to_date = '%s' AND t.status IN ("B","I", "O", "S") 
ORDER BY t.status, a.name
"""
sql = sql % yesterday
print(sql)
# Out:
# SELECT a.name,fm_date,to_date,fm_price,to_price,
# a.qty,a.max_price,a.min_price,t.status,t.market
# FROM sales a
# JOIN stocks t ON a.name = t.name
# WHERE to_date = '2022-12-30' AND t.status IN ("B","I", "O", "S")
# ORDER BY t.status, a.name

# %%
df = pd.read_sql(sql, conlite)
df.set_index(["name"], inplace=True)
df['fm_date'] = pd.to_datetime(df['fm_date'])
df['to_date'] = pd.to_datetime(df['to_date'])
df['diff'] = (df['to_price'] - df['fm_price'])
df['percent'] = round(df['diff']/df['fm_price']*100,2)
df.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_47759_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >fm_date</th>
#       <th class="col_heading level0 col1" >to_date</th>
#       <th class="col_heading level0 col2" >fm_price</th>
#       <th class="col_heading level0 col3" >to_price</th>
#       <th class="col_heading level0 col4" >qty</th>
#       <th class="col_heading level0 col5" >max_price</th>
#       <th class="col_heading level0 col6" >min_price</th>
#       <th class="col_heading level0 col7" >status</th>
#       <th class="col_heading level0 col8" >market</th>
#       <th class="col_heading level0 col9" >diff</th>
#       <th class="col_heading level0 col10" >percent</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47759_level0_row0" class="row_heading level0 row0" >TFFIF</th>
#       <td id="T_47759_row0_col0" class="data row0 col0" >2022-12-23</td>
#       <td id="T_47759_row0_col1" class="data row0 col1" >2022-12-30</td>
#       <td id="T_47759_row0_col2" class="data row0 col2" >7.80</td>
#       <td id="T_47759_row0_col3" class="data row0 col3" >7.65</td>
#       <td id="T_47759_row0_col4" class="data row0 col4" >418,765</td>
#       <td id="T_47759_row0_col5" class="data row0 col5" >7.80</td>
#       <td id="T_47759_row0_col6" class="data row0 col6" >7.60</td>
#       <td id="T_47759_row0_col7" class="data row0 col7" >B</td>
#       <td id="T_47759_row0_col8" class="data row0 col8" >SET</td>
#       <td id="T_47759_row0_col9" class="data row0 col9" >-0.15</td>
#       <td id="T_47759_row0_col10" class="data row0 col10" >-1.92%</td>
#     </tr>
#     <tr>
#       <th id="T_47759_level0_row1" class="row_heading level0 row1" >GFPT</th>
#       <td id="T_47759_row1_col0" class="data row1 col0" >2022-12-29</td>
#       <td id="T_47759_row1_col1" class="data row1 col1" >2022-12-30</td>
#       <td id="T_47759_row1_col2" class="data row1 col2" >12.90</td>
#       <td id="T_47759_row1_col3" class="data row1 col3" >12.80</td>
#       <td id="T_47759_row1_col4" class="data row1 col4" >2,201,202</td>
#       <td id="T_47759_row1_col5" class="data row1 col5" >13.00</td>
#       <td id="T_47759_row1_col6" class="data row1 col6" >12.80</td>
#       <td id="T_47759_row1_col7" class="data row1 col7" >I</td>
#       <td id="T_47759_row1_col8" class="data row1 col8" >SET</td>
#       <td id="T_47759_row1_col9" class="data row1 col9" >-0.10</td>
#       <td id="T_47759_row1_col10" class="data row1 col10" >-0.78%</td>
#     </tr>
#     <tr>
#       <th id="T_47759_level0_row2" class="row_heading level0 row2" >JASIF</th>
#       <td id="T_47759_row2_col0" class="data row2 col0" >2022-12-28</td>
#       <td id="T_47759_row2_col1" class="data row2 col1" >2022-12-30</td>
#       <td id="T_47759_row2_col2" class="data row2 col2" >8.00</td>
#       <td id="T_47759_row2_col3" class="data row2 col3" >8.05</td>
#       <td id="T_47759_row2_col4" class="data row2 col4" >7,987,879</td>
#       <td id="T_47759_row2_col5" class="data row2 col5" >8.10</td>
#       <td id="T_47759_row2_col6" class="data row2 col6" >8.00</td>
#       <td id="T_47759_row2_col7" class="data row2 col7" >I</td>
#       <td id="T_47759_row2_col8" class="data row2 col8" >SET</td>
#       <td id="T_47759_row2_col9" class="data row2 col9" >0.05</td>
#       <td id="T_47759_row2_col10" class="data row2 col10" >0.63%</td>
#     </tr>
#     <tr>
#       <th id="T_47759_level0_row3" class="row_heading level0 row3" >JMART</th>
#       <td id="T_47759_row3_col0" class="data row3 col0" >2022-12-29</td>
#       <td id="T_47759_row3_col1" class="data row3 col1" >2022-12-30</td>
#       <td id="T_47759_row3_col2" class="data row3 col2" >41.50</td>
#       <td id="T_47759_row3_col3" class="data row3 col3" >40.75</td>
#       <td id="T_47759_row3_col4" class="data row3 col4" >6,010,236</td>
#       <td id="T_47759_row3_col5" class="data row3 col5" >41.75</td>
#       <td id="T_47759_row3_col6" class="data row3 col6" >40.75</td>
#       <td id="T_47759_row3_col7" class="data row3 col7" >I</td>
#       <td id="T_47759_row3_col8" class="data row3 col8" >SET50</td>
#       <td id="T_47759_row3_col9" class="data row3 col9" >-0.75</td>
#       <td id="T_47759_row3_col10" class="data row3 col10" >-1.81%</td>
#     </tr>
#     <tr>
#       <th id="T_47759_level0_row4" class="row_heading level0 row4" >MAKRO</th>
#       <td id="T_47759_row4_col0" class="data row4 col0" >2022-12-28</td>
#       <td id="T_47759_row4_col1" class="data row4 col1" >2022-12-30</td>
#       <td id="T_47759_row4_col2" class="data row4 col2" >39.25</td>
#       <td id="T_47759_row4_col3" class="data row4 col3" >40.00</td>
#       <td id="T_47759_row4_col4" class="data row4 col4" >12,442,168</td>
#       <td id="T_47759_row4_col5" class="data row4 col5" >40.25</td>
#       <td id="T_47759_row4_col6" class="data row4 col6" >39.25</td>
#       <td id="T_47759_row4_col7" class="data row4 col7" >I</td>
#       <td id="T_47759_row4_col8" class="data row4 col8" >SET</td>
#       <td id="T_47759_row4_col9" class="data row4 col9" >0.75</td>
#       <td id="T_47759_row4_col10" class="data row4 col10" >1.91%</td>
#     </tr>
#     <tr>
#       <th id="T_47759_level0_row5" class="row_heading level0 row5" >RCL</th>
#       <td id="T_47759_row5_col0" class="data row5 col0" >2022-12-28</td>
#       <td id="T_47759_row5_col1" class="data row5 col1" >2022-12-30</td>
#       <td id="T_47759_row5_col2" class="data row5 col2" >31.00</td>
#       <td id="T_47759_row5_col3" class="data row5 col3" >30.75</td>
#       <td id="T_47759_row5_col4" class="data row5 col4" >2,948,494</td>
#       <td id="T_47759_row5_col5" class="data row5 col5" >31.50</td>
#       <td id="T_47759_row5_col6" class="data row5 col6" >30.75</td>
#       <td id="T_47759_row5_col7" class="data row5 col7" >I</td>
#       <td id="T_47759_row5_col8" class="data row5 col8" >SET100</td>
#       <td id="T_47759_row5_col9" class="data row5 col9" >-0.25</td>
#       <td id="T_47759_row5_col10" class="data row5 col10" >-0.81%</td>
#     </tr>
#     <tr>
#       <th id="T_47759_level0_row6" class="row_heading level0 row6" >SCC</th>
#       <td id="T_47759_row6_col0" class="data row6 col0" >2022-12-29</td>
#       <td id="T_47759_row6_col1" class="data row6 col1" >2022-12-30</td>
#       <td id="T_47759_row6_col2" class="data row6 col2" >344.00</td>
#       <td id="T_47759_row6_col3" class="data row6 col3" >342.00</td>
#       <td id="T_47759_row6_col4" class="data row6 col4" >2,037,787</td>
#       <td id="T_47759_row6_col5" class="data row6 col5" >344.00</td>
#       <td id="T_47759_row6_col6" class="data row6 col6" >341.00</td>
#       <td id="T_47759_row6_col7" class="data row6 col7" >I</td>
#       <td id="T_47759_row6_col8" class="data row6 col8" >SET50</td>
#       <td id="T_47759_row6_col9" class="data row6 col9" >-2.00</td>
#       <td id="T_47759_row6_col10" class="data row6 col10" >-0.58%</td>
#     </tr>
#     <tr>
#       <th id="T_47759_level0_row7" class="row_heading level0 row7" >STA</th>
#       <td id="T_47759_row7_col0" class="data row7 col0" >2022-12-29</td>
#       <td id="T_47759_row7_col1" class="data row7 col1" >2022-12-30</td>
#       <td id="T_47759_row7_col2" class="data row7 col2" >21.20</td>
#       <td id="T_47759_row7_col3" class="data row7 col3" >21.10</td>
#       <td id="T_47759_row7_col4" class="data row7 col4" >6,986,609</td>
#       <td id="T_47759_row7_col5" class="data row7 col5" >21.60</td>
#       <td id="T_47759_row7_col6" class="data row7 col6" >20.80</td>
#       <td id="T_47759_row7_col7" class="data row7 col7" >I</td>
#       <td id="T_47759_row7_col8" class="data row7 col8" >SET100</td>
#       <

# %% [markdown]
# ### Price change up or down more than 3%

# %%
# For each row in the DataFrame, generate a series of dates between the start and end dates
df['dates'] = df.apply(lambda x: pd.date_range(x['fm_date'], x['to_date']), axis=1)

# For each row in the DataFrame, select only the business days (Monday through Friday) from the series of dates
df['business_days'] = df['dates'].apply(lambda x: x[x.isin(pd.date_range(x.min(), x.max(), freq='B'))])

# For each row in the DataFrame, count the number of business days between the start and end dates
df['bdays'] = df['business_days'].apply(lambda x: len(x))

# %%
colt =  'percent status fm_price to_price market \
fm_date bdays max_price min_price'.split()
watch_list = df.loc[abs(df.percent) >= 3,colt]
watch_list.sort_values(by="percent",ascending=False).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b1733_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >percent</th>
#       <th class="col_heading level0 col1" >status</th>
#       <th class="col_heading level0 col2" >fm_price</th>
#       <th class="col_heading level0 col3" >to_price</th>
#       <th class="col_heading level0 col4" >market</th>
#       <th class="col_heading level0 col5" >fm_date</th>
#       <th class="col_heading level0 col6" >bdays</th>
#       <th class="col_heading level0 col7" >max_price</th>
#       <th class="col_heading level0 col8" >min_price</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1733_level0_row0" class="row_heading level0 row0" >PTT</th>
#       <td id="T_b1733_row0_col0" class="data row0 col0" >7.26%</td>
#       <td id="T_b1733_row0_col1" class="data row0 col1" >O</td>
#       <td id="T_b1733_row0_col2" class="data row0 col2" >31.00</td>
#       <td id="T_b1733_row0_col3" class="data row0 col3" >33.25</td>
#       <td id="T_b1733_row0_col4" class="data row0 col4" >SET50</td>
#       <td id="T_b1733_row0_col5" class="data row0 col5" >2022-12-21</td>
#       <td id="T_b1733_row0_col6" class="data row0 col6" >8</td>
#       <td id="T_b1733_row0_col7" class="data row0 col7" >33.50</td>
#       <td id="T_b1733_row0_col8" class="data row0 col8" >31.00</td>
#     </tr>
#     <tr>
#       <th id="T_b1733_level0_row1" class="row_heading level0 row1" >SYNEX</th>
#       <td id="T_b1733_row1_col0" class="data row1 col0" >3.14%</td>
#       <td id="T_b1733_row1_col1" class="data row1 col1" >I</td>
#       <td id="T_b1733_row1_col2" class="data row1 col2" >15.90</td>
#       <td id="T_b1733_row1_col3" class="data row1 col3" >16.40</td>
#       <td id="T_b1733_row1_col4" class="data row1 col4" >SET100</td>
#       <td id="T_b1733_row1_col5" class="data row1 col5" >2022-12-28</td>
#       <td id="T_b1733_row1_col6" class="data row1 col6" >3</td>
#       <td id="T_b1733_row1_col7" class="data row1 col7" >16.60</td>
#       <td id="T_b1733_row1_col8" class="data row1 col8" >16.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
file_name = "daily-watch-list.csv"
data_file = data_path + file_name
output_file = csv_path + file_name
box_file = box_path + file_name
one_file = one_path + file_name

watch_list.sort_values(['percent'],ascending=[False]).to_csv(output_file)
watch_list.sort_values(['percent'],ascending=[False]).to_csv(data_file)
watch_list.sort_values(['percent'],ascending=[False]).to_csv(box_file)
watch_list.sort_values(['percent'],ascending=[False]).to_csv(one_file)

# %% [markdown]
# ### Create daily-sales from sales

# %%
df[cols].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e338f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >fm_date</th>
#       <th class="col_heading level0 col1" >to_date</th>
#       <th class="col_heading level0 col2" >fm_price</th>
#       <th class="col_heading level0 col3" >to_price</th>
#       <th class="col_heading level0 col4" >qty</th>
#       <th class="col_heading level0 col5" >max_price</th>
#       <th class="col_heading level0 col6" >min_price</th>
#       <th class="col_heading level0 col7" >percent</th>
#       <th class="col_heading level0 col8" >status</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e338f_level0_row0" class="row_heading level0 row0" >TFFIF</th>
#       <td id="T_e338f_row0_col0" class="data row0 col0" >2022-12-23</td>
#       <td id="T_e338f_row0_col1" class="data row0 col1" >2022-12-30</td>
#       <td id="T_e338f_row0_col2" class="data row0 col2" >7.80</td>
#       <td id="T_e338f_row0_col3" class="data row0 col3" >7.65</td>
#       <td id="T_e338f_row0_col4" class="data row0 col4" >418,765</td>
#       <td id="T_e338f_row0_col5" class="data row0 col5" >7.80</td>
#       <td id="T_e338f_row0_col6" class="data row0 col6" >7.60</td>
#       <td id="T_e338f_row0_col7" class="data row0 col7" >-1.92%</td>
#       <td id="T_e338f_row0_col8" class="data row0 col8" >B</td>
#     </tr>
#     <tr>
#       <th id="T_e338f_level0_row1" class="row_heading level0 row1" >GFPT</th>
#       <td id="T_e338f_row1_col0" class="data row1 col0" >2022-12-29</td>
#       <td id="T_e338f_row1_col1" class="data row1 col1" >2022-12-30</td>
#       <td id="T_e338f_row1_col2" class="data row1 col2" >12.90</td>
#       <td id="T_e338f_row1_col3" class="data row1 col3" >12.80</td>
#       <td id="T_e338f_row1_col4" class="data row1 col4" >2,201,202</td>
#       <td id="T_e338f_row1_col5" class="data row1 col5" >13.00</td>
#       <td id="T_e338f_row1_col6" class="data row1 col6" >12.80</td>
#       <td id="T_e338f_row1_col7" class="data row1 col7" >-0.78%</td>
#       <td id="T_e338f_row1_col8" class="data row1 col8" >I</td>
#     </tr>
#     <tr>
#       <th id="T_e338f_level0_row2" class="row_heading level0 row2" >JASIF</th>
#       <td id="T_e338f_row2_col0" class="data row2 col0" >2022-12-28</td>
#       <td id="T_e338f_row2_col1" class="data row2 col1" >2022-12-30</td>
#       <td id="T_e338f_row2_col2" class="data row2 col2" >8.00</td>
#       <td id="T_e338f_row2_col3" class="data row2 col3" >8.05</td>
#       <td id="T_e338f_row2_col4" class="data row2 col4" >7,987,879</td>
#       <td id="T_e338f_row2_col5" class="data row2 col5" >8.10</td>
#       <td id="T_e338f_row2_col6" class="data row2 col6" >8.00</td>
#       <td id="T_e338f_row2_col7" class="data row2 col7" >0.63%</td>
#       <td id="T_e338f_row2_col8" class="data row2 col8" >I</td>
#     </tr>
#     <tr>
#       <th id="T_e338f_level0_row3" class="row_heading level0 row3" >JMART</th>
#       <td id="T_e338f_row3_col0" class="data row3 col0" >2022-12-29</td>
#       <td id="T_e338f_row3_col1" class="data row3 col1" >2022-12-30</td>
#       <td id="T_e338f_row3_col2" class="data row3 col2" >41.50</td>
#       <td id="T_e338f_row3_col3" class="data row3 col3" >40.75</td>
#       <td id="T_e338f_row3_col4" class="data row3 col4" >6,010,236</td>
#       <td id="T_e338f_row3_col5" class="data row3 col5" >41.75</td>
#       <td id="T_e338f_row3_col6" class="data row3 col6" >40.75</td>
#       <td id="T_e338f_row3_col7" class="data row3 col7" >-1.81%</td>
#       <td id="T_e338f_row3_col8" class="data row3 col8" >I</td>
#     </tr>
#     <tr>
#       <th id="T_e338f_level0_row4" class="row_heading level0 row4" >MAKRO</th>
#       <td id="T_e338f_row4_col0" class="data row4 col0" >2022-12-28</td>
#       <td id="T_e338f_row4_col1" class="data row4 col1" >2022-12-30</td>
#       <td id="T_e338f_row4_col2" class="data row4 col2" >39.25</td>
#       <td id="T_e338f_row4_col3" class="data row4 col3" >40.00</td>
#       <td id="T_e338f_row4_col4" class="data row4 col4" >12,442,168</td>
#       <td id="T_e338f_row4_col5" class="data row4 col5" >40.25</td>
#       <td id="T_e338f_row4_col6" class="data row4 col6" >39.25</td>
#       <td id="T_e338f_row4_col7" class="data row4 col7" >1.91%</td>
#       <td id="T_e338f_row4_col8" class="data row4 col8" >I</td>
#     </tr>
#     <tr>
#       <th id="T_e338f_level0_row5" class="row_heading level0 row5" >RCL</th>
#       <td id="T_e338f_row5_col0" class="data row5 col0" >2022-12-28</td>
#       <td id="T_e338f_row5_col1" class="data row5 col1" >2022-12-30</td>
#       <td id="T_e338f_row5_col2" class="data row5 col2" >31.00</td>
#       <td id="T_e338f_row5_col3" class="data row5 col3" >30.75</td>
#       <td id="T_e338f_row5_col4" class="data row5 col4" >2,948,494</td>
#       <td id="T_e338f_row5_col5" class="data row5 col5" >31.50</td>
#       <td id="T_e338f_row5_col6" class="data row5 col6" >30.75</td>
#       <td id="T_e338f_row5_col7" class="data row5 col7" >-0.81%</td>
#       <td id="T_e338f_row5_col8" class="data row5 col8" >I</td>
#     </tr>
#     <tr>
#       <th id="T_e338f_level0_row6" class="row_heading level0 row6" >SCC</th>
#       <td id="T_e338f_row6_col0" class="data row6 col0" >2022-12-29</td>
#       <td id="T_e338f_row6_col1" class="data row6 col1" >2022-12-30</td>
#       <td id="T_e338f_row6_col2" class="data row6 col2" >344.00</td>
#       <td id="T_e338f_row6_col3" class="data row6 col3" >342.00</td>
#       <td id="T_e338f_row6_col4" class="data row6 col4" >2,037,787</td>
#       <td id="T_e338f_row6_col5" class="data row6 col5" >344.00</td>
#       <td id="T_e338f_row6_col6" class="data row6 col6" >341.00</td>
#       <td id="T_e338f_row6_col7" class="data row6 col7" >-0.58%</td>
#       <td id="T_e338f_row6_col8" class="data row6 col8" >I</td>
#     </tr>
#     <tr>
#       <th id="T_e338f_level0_row7" class="row_heading level0 row7" >STA</th>
#       <td id="T_e338f_row7_col0" class="data row7 col0" >2022-12-29</td>
#       <td id="T_e338f_row7_col1" class="data row7 col1" >2022-12-30</td>
#       <td id="T_e338f_row7_col2" class="data row7 col2" >21.20</td>
#       <td id="T_e338f_row7_col3" class="data row7 col3" >21.10</td>
#       <td id="T_e338f_row7_col4" class="data row7 col4" >6,986,609</td>
#       <td id="T_e338f_row7_col5" class="data row7 col5" >21.60</td>
#       <td id="T_e338f_row7_col6" class="data row7 col6" >20.80</td>
#       <td id="T_e338f_row7_col7" class="data row7 col7" >-0.47%</td>
#       <td id="T_e338f_row7_col8" class="data row7 col8" >I</td>
#     </tr>
#     <tr>
#       <th id="T_e338f_level0_row8" class="row_heading level0 row8" >SYNEX</th>
#       <td id="T_e338f_row8_col0" class="data row8 col0" >2022-12-28</td>
#       <td id="T_e338f_row8_col1" class="data row8 col1" >2022-12-30</td>
#       <td id="T_e338f_row8_col2" class="data row8 col2" >15.90</td>
#       <td id="T_e338f_row8_col3" class="data row8 col3" >16.40</td>
#       <td id="T_e338f_row8_col4" class="data row8 col4" >5,696,313</td>
#       <td id="T_e338f_row8_col5" class="data row8 col5" >16.60</td>
#       <td id="T_e338f_row8_col6" class="data row8 col6" >16.00</td>
#       <td id="T_e338f_row8_col7" class="data row8 col7" >3.14%</td>
#       <td id="T_e338f_row8_col8" class="data row8 col8" >I</td>
#     </tr>
#     <tr>
#       <th id="T_e338f_level0_row9" class="row_heading level0 row9" >AP</th>
#       <td id="T_e338f_row9_col0" class="data row9 col0" >2022-12-29</td>
#       <td id="T_e338f_row9_col1" class="data row9 col1" >2022-12-30</td>
#       <td id="T_e338f_row9_col2" class="data row9 col2" >11.70</td>
#       <td id="T_e338f_row9_col3" class="data row9 col3" >11.60</td>
#       <td id="T_e338f_row9_col4" class="data row9 col4" >17,2

# %%
file_name = "daily-sales.csv"
data_file = data_path + file_name
output_file = csv_path + file_name
box_file = box_path + file_name
one_file = one_path + file_name

df[cols].sort_values(['status','percent'],ascending=[True,True]).to_csv(output_file,header=None)
df[cols].sort_values(['status','percent'],ascending=[True,True]).to_csv(data_file,header=None)
df[cols].sort_values(['status','percent'],ascending=[True,True]).to_csv(box_file)
df[cols].sort_values(['status','percent'],ascending=[True,True]).to_csv(one_file)

# %% [markdown]
# ### Create monitors from orders

# %%
sql = """
SELECT name, trade 
FROM orders 
ORDER BY name
"""
monitors = pd.read_sql(sql, conlite)
monitors.set_index(["name"], inplace=True)
monitors.sample(5)
# Out:
#       trade
# name
# MAKRO     S
# BANPU     B
# TFFIF     B
# PTT       B
# GFPT      S

# %%
sql = """
SELECT trade, COUNT(*) AS 'no. of stocks'
FROM orders 
GROUP BY trade
"""
df_tmp = pd.read_sql(sql, conlite)
df_tmp
# Out:
#   trade  no. of stocks
# 0     B             10
# 1     S             10

# %% [markdown]
# ### output_file = iCloud Drive on PC

# %%
file_name = "monitors.csv"
data_file = data_path + file_name
output_file = csv_path + file_name
box_file = box_path + file_name
one_file = one_path + file_name

monitors.to_csv(data_file, header=None)
monitors.to_csv(box_file)
monitors.to_csv(output_file)
monitors.to_csv(one_file)

# %% [markdown]
# ### End of daily process

# %%
sql = """
SELECT trade, COUNT(*) AS 'no. of stocks'
FROM orders 
GROUP BY trade
"""
df_tmp = pd.read_sql(sql, conlite)
df_tmp
# Out:
#   trade  no. of stocks
# 0     B             10
# 1     S             10

# %%
sql = """
SELECT name, status, market
FROM stocks 
ORDER BY status, name
"""
stocks = pd.read_sql(sql, conlite)
stocks.set_index(["name"], inplace=True)
stocks
# Out:
#        status  market
# name
# TFFIF       B     SET
# GFPT        I     SET
# JASIF       I     SET
# JMART       I   SET50
# MAKRO       I     SET
# ...       ...     ...
# SINGER      X  SET100
# SIRI        X     SET
# SPALI       X  SET100
# SVI         X     SET
# TTB         X   SET50
#
# [66 rows x 2 columns]

# %%
file_name = "stocks-all.csv"
data_file = data_path + file_name
output_file = csv_path + file_name
box_file = box_path + file_name
one_file = one_path + file_name

stocks.to_csv(data_file, header=None)
stocks.to_csv(output_file)
stocks.to_csv(box_file)
stocks.to_csv(one_file)

# %%
sql = """
SELECT name, trade 
FROM orders 
WHERE trade IN ("B")
ORDER BY name
"""
buy_candidates = pd.read_sql(sql, conlite)
buy_candidates.set_index(["name"], inplace=True)
buy_candidates
# Out:
#       trade
# name
# AP        B
# BANPU     B
# BCP       B
# CKP       B
# CPF       B
# PTT       B
# SCB       B
# TFFIF     B
# TFG       B
# TOP       B

# %%
buy_candidates.shape[0]
# Out:
# 10

# %%
sql = """
SELECT name, trade 
FROM orders 
WHERE trade IN ("S")
ORDER BY name
"""
sell_candidates = pd.read_sql(sql, conlite)
sell_candidates.set_index(["name"], inplace=True)
sell_candidates
# Out:
#       trade
# name
# ASP       S
# GFPT      S
# JASIF     S
# JMART     S
# MAKRO     S
# RCL       S
# SCC       S
# STA       S
# SYNEX     S
# TMT       S

# %%
sell_candidates.shape[0]
# Out:
# 10
