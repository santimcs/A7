# %% [markdown]
# ### Restart and Run All Cells

# %%
import glob
import os
import pandas as pd
from datetime import date, timedelta
from pandas.tseries.offsets import *
from sqlalchemy import create_engine

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()
engine = create_engine('mysql+pymysql://root:@localhost:3306/portfolio_development')
conpf = engine.connect()

format_dict = {'qty':'{:,}',
              'sell_price':'{:,.2f}','buy_price':'{:,.2f}','diff':'{:,.2f}',
              'sell_amt':'{:,.2f}','buy_amt':'{:,.2f}','gross':'{:,.2f}','amount':'{:,.2f}',
              'pct':'{:,.2f}','net':'{:,.2f}'}

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"
osd_path = "\\Users\\User\\OneDrive\\Documents\\obsidian-git-sync\\Data\\"
dts_path = "/Users/User/Downloads/Datasets/"

# Directory to be monitored
directory = '/Users/User/Downloads'
# Dictionary of file categories and their extensions
categories = {
    'Images': ['jpeg', 'jpg', 'png'],
    'PDFs': ['pdf'],
    'Datasets': ['csv', 'xlsx', 'xls', 'json'],
    'Videos': ['mp4','m4a'],
    'Zips': ['zip'],
    'EXEs': ['exe', 'msi'],
    'Pythons': ['ipynb'],
}
pd.options.display.max_rows = 11
pd.options.display.float_format = '{:.2f}'.format
year = 2023
month = 8
today = date.today()
yesterday = today - timedelta(days=1)
today, yesterday
# Out:
# (datetime.date(2023, 8, 24), datetime.date(2023, 8, 23))

# %%
num_business_days = BDay(2)
yesterday = today - num_business_days
print(f'today: {today}')
yesterday = yesterday.date()
print(f'yesterday: {yesterday}')
# Out:
# today: 2023-08-24
# yesterday: 2023-08-22

# %% [markdown]
# ## Must rerun whenever there is change in orders

# %%
sql = """
SELECT trade, name, qty, price AS target, active, reason, market, xdate 
FROM orders
ORDER BY trade, name"""
orders = pd.read_sql(sql, conlite)
orders.shape
# Out:
# (48, 8)

# %%
file_name = "Price-Today.csv"
input_file = data_path + file_name
input_file
# Out:
# '../data/Price-Today.csv'

# %%
prices = pd.read_csv(input_file)
prices.shape
# Out:
# (190, 10)

# %%
df_merge  = pd.merge(orders, prices, on = 'name', how='inner')
df_merge.shape
# Out:
# (48, 17)

# %%
df_merge['spd'] = 0

# %%
colo = ['trade', 'name', 'spd', 'reason', 'market', 'qty', 'target', 'price', 'change', '%change',
        'active', 'xdate']
df_merge[colo].shape
# Out:
# (48, 12)

# %%
file_name = "Price-for-Order.csv"
output_file = data_path + file_name
osd_file = osd_path + file_name

df_merge[colo].to_csv(output_file, header=True, index=False)
df_merge[colo].to_csv(osd_file, header=True, index=False)

# %% [markdown]
# ### call ruby ruby\order-log-new.rb

# %%
# %pwd
# Out:
# 'C:\\Users\\User\\OneDrive\\A7\\Daily'

# %%
os.chdir("C:\\users\\user\\onedrive\\a7")
# %pwd
# Out:
# 'C:\\users\\user\\onedrive\\a7'

# %%
# !ruby ruby\\order-log-new.rb
# Out:
# trade,name,spd,reason,market,qty,target,current,change,%change,active,xdate
# B,AH,-13,RD15pct,SET,600,31.0,34.25,0.25,0.735294,0,2023-08-29
# B,AWC,-23,RD25pct,SET50,4000,3.66,4.12,0.06,1.477833,0,2022-12-22
# B,BBL,-24,XXX,SET50,400,155.0,167.0,-3.0,-1.764706,0,2023-09-08
# B,BEM,-24,XXX,SET50,2500,7.8,9.0,-0.05,-0.552486,0,2022-12-22
# B,BH,-11,10S,SET50,100,250.0,261.0,2.0,0.772201,0,2022-12-22
# B,CK,-11,XXX,SET100,1000,22.1,23.2,-0.1,-0.429185,0,2022-12-22
# B,CPN,-19,10S,SET50,300,64.5,69.25,1.0,1.465201,0,2022-12-22
# B,DELTA,-62,XXX,SET50,200,90.0,111.0,8.0,7.76699,0,2022-12-22
# B,DIF,-11,RD40pct,SET,3000,8.65,9.2,0.05,0.546448,1,2023-08-15
# B,GVREIT,-6,RD20pct,SET,6000,7.0,7.3,0.0,0.0,2,2023-08-28
# B,HANA,-18,10S,SET100,400,59.0,63.5,0.75,1.195219,0,2022-12-22
# B,ICHI,-24,XXX,SET,1500,14.3,16.7,0.6,3.726708,0,2022-12-22
# B,III,-13,10S,SET,2000,10.8,12.1,0.2,1.680672,0,2022-12-22
# B,IVL,-4,RD30pct,SET50,800,27.5,28.5,-0.5,-1.724138,2,2023-08-28
# B,JASIF,-8,RD35pct,SET,4000,6.5,6.9,0.1,1.470588,1,2023-08-21
# B,JMART,-22,RD45pct,SET50,3000,18.9,21.1,-0.2,-0.938967,1,2023-08-24
# B,JMT,-24,RD30pct,SET50,1800,39.75,45.75,0.0,0.0,0,2023-08-24
# B,KTB,-4,10S,SET50,1000,18.8,19.2,-0.8,-4.0,1,2023-04-20
# B,M,-10,10S,SET,500,46.0,48.5,-0.75,-1.522843,0,2022-12-22
# B,MCS,-2,RD60pct,SET,4000,6.0,6.1,0.0,0.0,1,2023-03-17
# B,NER,-8,RD40pct,SET,3000,4.44,4.6,0.04,0.877193,2,2023-08-25
# B,ORI,-16,RD15pct,SET100,2000,9.5,10.6,0.1,0.952381,0,2023-08-28
# B,PSH,-12,10S,SET,2000,12.2,13.4,0.1,0.75188,0,2023-03-10
# B,PTTEP,-47,XXX,SET50,200,134.5,158.0,0.0,0.0,0,2023-08-15
# B,PTTGC,-9,RD4,SET50,600,34.5,36.75,0.75,2.083333,1,2023-02-27
# B,QH,-10,10S,SET100,10000,2.1,2.3,0.02,0.877193,0,2023-08-23
# B,SAPPE,-22,10S,SET,300,89.0,94.5,1.25,1.340483,0,2022-12-22
# B,SC,-10,10S,SET,5000,4.1,4.3,0.0,0.0,0,2023-04-29
# B,SENA,-14,RD45pct,SET,7000,2.56,2.84,0.02,0.70922,0,2023-08-28
# B,SINGER,-13,RD60pct,SET100,3000,9.5,10.3,-0.4,-3.738318,0,2023-08-03
# B,SIRI,-12,10S,SET,10000,1.9,2.04,0.05,2.512563,0,2022-12-22
# B,STA,-8,RD70pct,SET100,2500,12.7,13.5,0.2,1.503759,1,2023-08-24
# B,SYNEX,-27,RD65pct,SET,2000,10.0,12.7,0.2,1.6,0,2023-08-25
# B,TFFIF,-3,DOS,SET,10000,7.35,7.5,0.05,0.671141,1,2023-08-31
# B,TMT,-13,RD40pct,SET,3000,6.3,6.95,-0.25,-3.472222,0,2023-08-24
# B,TOA,-21,10S,SET,1000,24.0,27.75,0.0,0.0,0,2022-12-22
# B,TTB,-8,XXX,SET50,15000,1.64,1.72,-0.08,-4.444444,1,2022-12-22
# S,AIMIRT,2,DOS,SET,10000,11.1,10.9,0.0,0.0,1,2023-08-23
# S,ASK,22,COS,SET,4500,31.25,25.75,0.75,3.0,0,2023-02-28
# S,ASP,42,COS,SET,30000,3.82,2.98,0.02,0.675676,0,2023-08-28
# S,BCH,21,COS,SET100,3000,21.4,19.3,0.1,0.520833,0,2023-08-31
# S,CPNREIT,23,XXX,SET,5000,13.2,10.9,0.0,0.0,0,2023-08-23
# S,KCE,44,COS,SET100,1000,61.75,50.75,3.25,6.842105,0,2023-08-21
# S,PTG,16,5pct,SET100,3600,12.1,10.5,-0.1,-0.943396,0,2022-12-22
# S,RCL,58,XXX,SET100,3000,30.5,21.4,-0.2,-0.925926,0,2023-08-24
# S,SCC,68,XXX,SET50,300,385.0,317.0,3.0,0.955414,0,2023-08-09
# S,WHAIR,17,DOS,SET,10000,7.75,6.9,0.15,2.222222,1,2023-08-18
# S,WHART,1,DOS,SET,10000,10.6,10.5,0.0,0.0,2,2023-08-21

# %%
os.chdir("C:\\users\\user\\onedrive\\a7\\daily")
# %pwd
# Out:
# 'C:\\users\\user\\onedrive\\a7\\daily'

# %%
file_name   = 'orders-log.csv'
input_file = data_path + file_name

df = pd.read_csv(input_file, sep=',', index_col=None)
df['amount'] = df['qty'] * df['target']
df.query('spd >= -3 and spd <= 3')
# Out:
#    trade    name  spd   reason market    qty  target  current  change  \
# 19     B     MCS   -2  RD60pct    SET   4000    6.00     6.10    0.00
# 33     B   TFFIF   -3      DOS    SET  10000    7.35     7.50    0.05
# 37     S  AIMIRT    2      DOS    SET  10000   11.10    10.90    0.00
# 47     S   WHART    1      DOS    SET  10000   10.60    10.50    0.00
#
#     %change  active       xdate    amount
# 19     0.00       1  2023-03-17  24000.00
# 33     0.67       1  2023-08-31  73500.00
# 37     0.00       1  2023-08-23 111000.00
# 47     0.00       2  2023-08-21 106000.00

# %%
df.query('active == 2')
# Out:
#    trade    name  spd   reason market    qty  target  current  change  \
# 9      B  GVREIT   -6  RD20pct    SET   6000    7.00     7.30    0.00
# 13     B     IVL   -4  RD30pct  SET50    800   27.50    28.50   -0.50
# 20     B     NER   -8  RD40pct    SET   3000    4.44     4.60    0.04
# 47     S   WHART    1      DOS    SET  10000   10.60    10.50    0.00
#
#     %change  active       xdate    amount
# 9      0.00       2  2023-08-28  42000.00
# 13    -1.72       2  2023-08-28  22000.00
# 20     0.88       2  2023-08-25  13320.00
# 47     0.00       2  2023-08-21 106000.00

# %%
df.query('active == 1')
# Out:
#    trade    name  spd   reason  market    qty  target  current  change  \
# 8      B     DIF  -11  RD40pct     SET   3000    8.65     9.20    0.05
# 14     B   JASIF   -8  RD35pct     SET   4000    6.50     6.90    0.10
# 15     B   JMART  -22  RD45pct   SET50   3000   18.90    21.10   -0.20
# 17     B     KTB   -4      10S   SET50   1000   18.80    19.20   -0.80
# 19     B     MCS   -2  RD60pct     SET   4000    6.00     6.10    0.00
# 24     B   PTTGC   -9      RD4   SET50    600   34.50    36.75    0.75
# 31     B     STA   -8  RD70pct  SET100   2500   12.70    13.50    0.20
# 33     B   TFFIF   -3      DOS     SET  10000    7.35     7.50    0.05
# 36     B     TTB   -8      XXX   SET50  15000    1.64     1.72   -0.08
# 37     S  AIMIRT    2      DOS     SET  10000   11.10    10.90    0.00
# 46     S   WHAIR   17      DOS     SET  10000    7.75     6.90    0.15
#
#     %change  active       xdate    amount
# 8      0.55       1  2023-08-15  25950.00
# 14     1.47       1  2023-08-21  26000.00
# 15    -0.94       1  2023-08-24  56700.00
# 17    -4.00       1  2023-04-20  18800.00
# 19     0.00       1  2023-03-17  24000.00
# 24     2.08       1  2023-02-27  20700.00
# 31     1.50       1  2023-08-24  31750.00
# 33     0.67       1  2023-08-31  73500.00
# 36    -4.44       1  2022-12-22  24600.00
# 37     0.00       1  2023-08-23 111000.00
# 46     2.22       1  2023-08-18  77500.00

# %%
pd.options.display.max_rows = 35
df.query('active == 0')
# Out:
#    trade     name  spd   reason  market    qty  target  current  change  \
# 0      B       AH  -13  RD15pct     SET    600   31.00    34.25    0.25
# 1      B      AWC  -23  RD25pct   SET50   4000    3.66     4.12    0.06
# 2      B      BBL  -24      XXX   SET50    400  155.00   167.00   -3.00
# 3      B      BEM  -24      XXX   SET50   2500    7.80     9.00   -0.05
# 4      B       BH  -11      10S   SET50    100  250.00   261.00    2.00
# 5      B       CK  -11      XXX  SET100   1000   22.10    23.20   -0.10
# 6      B      CPN  -19      10S   SET50    300   64.50    69.25    1.00
# 7      B    DELTA  -62      XXX   SET50    200   90.00   111.00    8.00
# 10     B     HANA  -18      10S  SET100    400   59.00    63.50    0.75
# 11     B     ICHI  -24      XXX     SET   1500   14.30    16.70    0.60
# 12     B      III  -13      10S     SET   2000   10.80    12.10    0.20
# 16     B      JMT  -24  RD30pct   SET50   1800   39.75    45.75    0.00
# 18     B        M  -10      10S     SET    500   46.00    48.50   -0.75
# 21     B      ORI  -16  RD15pct  SET100   2000    9.50    10.60    0.10
# 22     B      PSH  -12      10S     SET   2000   12.20    13.40    0.10
# 23     B    PTTEP  -47      XXX   SET50    200  134.50   158.00    0.00
# 25     B       QH  -10      10S  SET100  10000    2.10     2.30    0.02
# 26     B    SAPPE  -22      10S     SET    300   89.00    94.50    1.25
# 27     B       SC  -10      10S     SET   5000    4.10     4.30    0.00
# 28     B     SENA  -14  RD45pct     SET   7000    2.56     2.84    0.02
# 29     B   SINGER  -13  RD60pct  SET100   3000    9.50    10.30   -0.40
# 30     B     SIRI  -12      10S     SET  10000    1.90     2.04    0.05
# 32     B    SYNEX  -27  RD65pct     SET   2000   10.00    12.70    0.20
# 34     B      TMT  -13  RD40pct     SET   3000    6.30     6.95   -0.25
# 35     B      TOA  -21      10S     SET   1000   24.00    27.75    0.00
# 38     S      ASK   22      COS     SET   4500   31.25    25.75    0.75
# 39     S      ASP   42      COS     SET  30000    3.82     2.98    0.02
# 40     S      BCH   21      COS  SET100   3000   21.40    19.30    0.10
# 41     S  CPNREIT   23      XXX     SET   5000   13.20    10.90    0.00
# 42     S      KCE   44      COS  SET100   1000   61.75    50.75    3.25
# 43     S      PTG   16     5pct  SET100   3600   12.10    10.50   -0.10
# 44     S      RCL   58      XXX  SET100   3000   30.50    21.40   -0.20
# 45     S      SCC   68      XXX   SET50    300  385.00   317.00    3.00
#
#     %change  active       xdate    amount
# 0      0.74       0  2023-08-29  18600.00
# 1      1.48       0  2022-12-22  14640.00
# 2     -1.76       0  2023-09-08  62000.00
# 3     -0.55       0  2022-12-22  19500.00
# 4      0.77       0  2022-12-22  25000.00
# 5     -0.43       0  2022-12-22  22100.00
# 6      1.47       0  2022-12-22  19350.00
# 7      7.77       0  2022-12-22  18000.00
# 10     1.20       0  2022-12-22  23600.00
# 11     3.73       0  2022-12-22  21450.00
# 12     1.68       0  2022-12-22  21600.00
# 16     0.00       0  2023-08-24  71550.00
# 18    -1.52       0  2022-12-22  23000.00
# 21     0.95       0  2023-08-28  19000.00
# 22     0.75       0  2023-03-10  24400.00
# 23     0.00       0  2023-08-15  26900.00
# 25     0.88       0  2023-08-23  21000.00
# 26     1.34       0  2022-12-22  26700.00
# 27     0.00       0  2023-04-29  20500.00
# 28     0.71       0  2023-08-28  17920.00
# 29    -3.74       0  2023-08-03  28500.00
# 30     2.51       0  2022-12-22  19000.00
# 32     1.60       0  2023-08-25  20000.00
# 34    -3.47       0  2023-08-24  18900.00
# 35     0.00       0  2022-12-22  24000.00
# 38     3.00       0  2023-02-28 140625.00
# 39     0.68       0  2023-08-28 114600.00
# 40     0.52       0  2023-08-31  64200.00
# 41     0.00       0  2023-08-23  66000.00
# 42     6.84       0  2023-08-21  61750.00
# 43    -0.94       0  2022-12-22  43560.00
# 44    -0.93       0  2023-08-24  91500.00
# 45     0.96       0  2023-08-09 115500.00

# %%
df.query('spd <= -40 and trade == "B"')
# Out:
#    trade   name  spd reason market  qty  target  current  change  %change  \
# 7      B  DELTA  -62    XXX  SET50  200   90.00   111.00    8.00     7.77
# 23     B  PTTEP  -47    XXX  SET50  200  134.50   158.00    0.00     0.00
#
#     active       xdate   amount
# 7        0  2022-12-22 18000.00
# 23       0  2023-08-15 26900.00

# %%
df.query('trade == "B" & spd > 0')
# Out:
# Empty DataFrame
# Columns: [trade, name, spd, reason, market, qty, target, current, change, %change, active, xdate, amount]
# Index: []

# %%
colx = ['trade', 'name', 'spd', 'reason', 'market', 'qty', 'target', 'current', 'change', '%change',
        'active', 'xdate']

file_name = "orders-log.csv"
output_file = data_path + file_name
osd_file = osd_path + file_name

df[colx].to_csv(output_file, header=True, index=False)
df[colx].to_csv(osd_file, header=True, index=False)

# %% [markdown]
# ### Convert column name to make it valid for df.query

# %%
df['percent'] = df['%change']

# %%
df.query('percent < -2')
# Out:
#    trade    name  spd   reason  market    qty  target  current  change  \
# 17     B     KTB   -4      10S   SET50   1000   18.80    19.20   -0.80
# 29     B  SINGER  -13  RD60pct  SET100   3000    9.50    10.30   -0.40
# 34     B     TMT  -13  RD40pct     SET   3000    6.30     6.95   -0.25
# 36     B     TTB   -8      XXX   SET50  15000    1.64     1.72   -0.08
#
#     %change  active       xdate   amount  percent
# 17    -4.00       1  2023-04-20 18800.00    -4.00
# 29    -3.74       0  2023-08-03 28500.00    -3.74
# 34    -3.47       0  2023-08-24 18900.00    -3.47
# 36    -4.44       1  2022-12-22 24600.00    -4.44

# %%
df.query('percent >= 2.00')
# Out:
#    trade   name  spd reason  market    qty  target  current  change  %change  \
# 7      B  DELTA  -62    XXX   SET50    200   90.00   111.00    8.00     7.77
# 11     B   ICHI  -24    XXX     SET   1500   14.30    16.70    0.60     3.73
# 24     B  PTTGC   -9    RD4   SET50    600   34.50    36.75    0.75     2.08
# 30     B   SIRI  -12    10S     SET  10000    1.90     2.04    0.05     2.51
# 38     S    ASK   22    COS     SET   4500   31.25    25.75    0.75     3.00
# 42     S    KCE   44    COS  SET100   1000   61.75    50.75    3.25     6.84
# 46     S  WHAIR   17    DOS     SET  10000    7.75     6.90    0.15     2.22
#
#     active       xdate    amount  percent
# 7        0  2022-12-22  18000.00     7.77
# 11       0  2022-12-22  21450.00     3.73
# 24       1  2023-02-27  20700.00     2.08
# 30       0  2022-12-22  19000.00     2.51
# 38       0  2023-02-28 140625.00     3.00
# 42       0  2023-08-21  61750.00     6.84
# 46       1  2023-08-18  77500.00     2.22

# %%
df.loc[df.trade == 'B'].sort_values('spd',ascending=False)
# Out:
#    trade    name  spd   reason market    qty  target  current  change  \
# 19     B     MCS   -2  RD60pct    SET   4000    6.00     6.10    0.00
# 33     B   TFFIF   -3      DOS    SET  10000    7.35     7.50    0.05
# 13     B     IVL   -4  RD30pct  SET50    800   27.50    28.50   -0.50
# 17     B     KTB   -4      10S  SET50   1000   18.80    19.20   -0.80
# 9      B  GVREIT   -6  RD20pct    SET   6000    7.00     7.30    0.00
# ..   ...     ...  ...      ...    ...    ...     ...      ...     ...
# 3      B     BEM  -24      XXX  SET50   2500    7.80     9.00   -0.05
# 2      B     BBL  -24      XXX  SET50    400  155.00   167.00   -3.00
# 32     B   SYNEX  -27  RD65pct    SET   2000   10.00    12.70    0.20
# 23     B   PTTEP  -47      XXX  SET50    200  134.50   158.00    0.00
# 7      B   DELTA  -62      XXX  SET50    200   90.00   111.00    8.00
#
#     %change  active       xdate   amount  percent
# 19     0.00       1  2023-03-17 24000.00     0.00
# 33     0.67       1  2023-08-31 73500.00     0.67
# 13    -1.72       2  2023-08-28 22000.00    -1.72
# 17    -4.00       1  2023-04-20 18800.00    -4.00
# 9      0.00       2  2023-08-28 42000.00     0.00
# ..      ...     ...         ...      ...      ...
# 3     -0.55       0  2022-12-22 19500.00    -0.55
# 2     -1.76       0  2023-09-08 62000.00    -1.76
# 32     1.60       0  2023-08-25 20000.00     1.60
# 23     0.00       0  2023-08-15 26900.00     0.00
# 7      7.77       0  2022-12-22 18000.00     7.77
#
# [37 rows x 14 columns]

# %% [markdown]
# ### Sell recently purchased stocks if profitable

# %%
pd.set_option('display.max_rows', 40)
sql = """SELECT name, qty, price AS cost, date 
FROM buys B 
JOIN stocks S 
ON stock_id = S.id 
WHERE status = 'Active'
ORDER BY name, date"""
buys = pd.read_sql(sql, conpf)
buys.shape
# Out:
# (107, 4)

# %%
colu = 'name date_x qty cost price difa %change %profit'.split()
buys_price = pd.merge(buys, prices, on='name', how='inner')
buys_price['diff'] = buys_price['price'] - buys_price['cost']
buys_price['difa'] = buys_price['diff'] * buys_price['qty']
buys_price['%profit'] = round(buys_price['difa'] / (buys_price['qty'] * buys_price['cost']) * 100,2)

# %%
laggards = buys_price.loc[buys_price.cost > buys_price.price,colu]
laggards.shape
# Out:
# (104, 8)

# %%
watch_list = buys_price.loc[buys_price.cost <= buys_price.price,colu]
watch_list.sort_values('name',ascending='False')
# Out:
#        name      date_x    qty  cost  price   difa  %change  %profit
# 22   GVREIT  2023-08-18   3000  7.30   7.30   0.00     0.00     0.00
# 94    TFFIF  2023-07-25  10000  7.45   7.50 500.00     0.67     0.67
# 106   WHART  2022-05-17  10000 10.50  10.50   0.00     0.00     0.00

# %% [markdown]
# ### Profit per Day

# %%
sql = '''
SELECT name, YEAR(sells.date) AS sell_year, MONTH(sells.date) AS sell_month, 
       sells.price AS sell_price, buys.price AS buy_price, (sells.price - buys.price) AS diff, 
       qty, (sells.price * qty) AS sell_amt, (buys.price * qty) AS buy_amt, 
       (sells.price - buys.price) * qty AS gross, 
       ROUND((sells.price - buys.price)/buys.price*100,2) AS pct, days
FROM sells JOIN buys ON sells.buy_id = buys.id
JOIN stocks ON buys.stock_id = stocks.id
WHERE YEAR(sells.date) = %s AND MONTH(sells.date) = %s
ORDER BY sells.date DESC, name'''
sql = sql % (year, month)
sells_df = pd.read_sql(sql, conpf)
print(sql)
# Out:
# SELECT name, YEAR(sells.date) AS sell_year, MONTH(sells.date) AS sell_month,
#        sells.price AS sell_price, buys.price AS buy_price, (sells.price - buys.price) AS diff,
#        qty, (sells.price * qty) AS sell_amt, (buys.price * qty) AS buy_amt,
#        (sells.price - buys.price) * qty AS gross,
#        ROUND((sells.price - buys.price)/buys.price*100,2) AS pct, days
# FROM sells JOIN buys ON sells.buy_id = buys.id
# JOIN stocks ON buys.stock_id = stocks.id
# WHERE YEAR(sells.date) = 2023 AND MONTH(sells.date) = 8
# ORDER BY sells.date DESC, name

# %%
sells_df.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8d2e7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >sell_year</th>
#       <th class="col_heading level0 col2" >sell_month</th>
#       <th class="col_heading level0 col3" >sell_price</th>
#       <th class="col_heading level0 col4" >buy_price</th>
#       <th class="col_heading level0 col5" >diff</th>
#       <th class="col_heading level0 col6" >qty</th>
#       <th class="col_heading level0 col7" >sell_amt</th>
#       <th class="col_heading level0 col8" >buy_amt</th>
#       <th class="col_heading level0 col9" >gross</th>
#       <th class="col_heading level0 col10" >pct</th>
#       <th class="col_heading level0 col11" >days</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8d2e7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8d2e7_row0_col0" class="data row0 col0" >JMART</td>
#       <td id="T_8d2e7_row0_col1" class="data row0 col1" >2023</td>
#       <td id="T_8d2e7_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_8d2e7_row0_col3" class="data row0 col3" >20.60</td>
#       <td id="T_8d2e7_row0_col4" class="data row0 col4" >19.60</td>
#       <td id="T_8d2e7_row0_col5" class="data row0 col5" >1.00</td>
#       <td id="T_8d2e7_row0_col6" class="data row0 col6" >1,200</td>
#       <td id="T_8d2e7_row0_col7" class="data row0 col7" >24,720.00</td>
#       <td id="T_8d2e7_row0_col8" class="data row0 col8" >23,520.00</td>
#       <td id="T_8d2e7_row0_col9" class="data row0 col9" >1,200.00</td>
#       <td id="T_8d2e7_row0_col10" class="data row0 col10" >5.10</td>
#       <td id="T_8d2e7_row0_col11" class="data row0 col11" >126</td>
#     </tr>
#     <tr>
#       <th id="T_8d2e7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8d2e7_row1_col0" class="data row1 col0" >ICHI</td>
#       <td id="T_8d2e7_row1_col1" class="data row1 col1" >2023</td>
#       <td id="T_8d2e7_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_8d2e7_row1_col3" class="data row1 col3" >15.90</td>
#       <td id="T_8d2e7_row1_col4" class="data row1 col4" >14.30</td>
#       <td id="T_8d2e7_row1_col5" class="data row1 col5" >1.60</td>
#       <td id="T_8d2e7_row1_col6" class="data row1 col6" >1,400</td>
#       <td id="T_8d2e7_row1_col7" class="data row1 col7" >22,260.00</td>
#       <td id="T_8d2e7_row1_col8" class="data row1 col8" >20,020.00</td>
#       <td id="T_8d2e7_row1_col9" class="data row1 col9" >2,240.00</td>
#       <td id="T_8d2e7_row1_col10" class="data row1 col10" >11.19</td>
#       <td id="T_8d2e7_row1_col11" class="data row1 col11" >59</td>
#     </tr>
#     <tr>
#       <th id="T_8d2e7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8d2e7_row2_col0" class="data row2 col0" >TTB</td>
#       <td id="T_8d2e7_row2_col1" class="data row2 col1" >2023</td>
#       <td id="T_8d2e7_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_8d2e7_row2_col3" class="data row2 col3" >1.76</td>
#       <td id="T_8d2e7_row2_col4" class="data row2 col4" >1.64</td>
#       <td id="T_8d2e7_row2_col5" class="data row2 col5" >0.12</td>
#       <td id="T_8d2e7_row2_col6" class="data row2 col6" >15,000</td>
#       <td id="T_8d2e7_row2_col7" class="data row2 col7" >26,400.00</td>
#       <td id="T_8d2e7_row2_col8" class="data row2 col8" >24,600.00</td>
#       <td id="T_8d2e7_row2_col9" class="data row2 col9" >1,800.00</td>
#       <td id="T_8d2e7_row2_col10" class="data row2 col10" >7.32</td>
#       <td id="T_8d2e7_row2_col11" class="data row2 col11" >26</td>
#     </tr>
#     <tr>
#       <th id="T_8d2e7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8d2e7_row3_col0" class="data row3 col0" >JMART</td>
#       <td id="T_8d2e7_row3_col1" class="data row3 col1" >2023</td>
#       <td id="T_8d2e7_row3_col2" class="data row3 col2" >8</td>
#       <td id="T_8d2e7_row3_col3" class="data row3 col3" >18.30</td>
#       <td id="T_8d2e7_row3_col4" class="data row3 col4" >17.00</td>
#       <td id="T_8d2e7_row3_col5" class="data row3 col5" >1.30</td>
#       <td id="T_8d2e7_row3_col6" class="data row3 col6" >3,600</td>
#       <td id="T_8d2e7_row3_col7" class="data row3 col7" >65,880.00</td>
#       <td id="T_8d2e7_row3_col8" class="data row3 col8" >61,200.00</td>
#       <td id="T_8d2e7_row3_col9" class="data row3 col9" >4,680.00</td>
#       <td id="T_8d2e7_row3_col10" class="data row3 col10" >7.65</td>
#       <td id="T_8d2e7_row3_col11" class="data row3 col11" >41</td>
#     </tr>
#     <tr>
#       <th id="T_8d2e7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8d2e7_row4_col0" class="data row4 col0" >JMT</td>
#       <td id="T_8d2e7_row4_col1" class="data row4 col1" >2023</td>
#       <td id="T_8d2e7_row4_col2" class="data row4 col2" >8</td>
#       <td id="T_8d2e7_row4_col3" class="data row4 col3" >43.50</td>
#       <td id="T_8d2e7_row4_col4" class="data row4 col4" >39.75</td>
#       <td id="T_8d2e7_row4_col5" class="data row4 col5" >3.75</td>
#       <td id="T_8d2e7_row4_col6" class="data row4 col6" >1,800</td>
#       <td id="T_8d2e7_row4_col7" class="data row4 col7" >78,300.00</td>
#       <td id="T_8d2e7_row4_col8" class="data row4 col8" >71,550.00</td>
#       <td id="T_8d2e7_row4_col9" class="data row4 col9" >6,750.00</td>
#       <td id="T_8d2e7_row4_col10" class="data row4 col10" >9.43</td>
#       <td id="T_8d2e7_row4_col11" class="data row4 col11" >57</td>
#     </tr>
#   </tbody>
# </table>

# %%
file_name = "monthly-sales.csv"
output_file = data_path + file_name
osd_file = osd_path + file_name

sells_df.to_csv(output_file, header=True, index=False)
sells_df.to_csv(osd_file, header=True, index=False)

# %%
sells_df['profit_per_day'] = (sells_df['gross'] / sells_df['buy_amt']) / sells_df['days'] * 100
sells_df.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4ba14_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >sell_year</th>
#       <th class="col_heading level0 col2" >sell_month</th>
#       <th class="col_heading level0 col3" >sell_price</th>
#       <th class="col_heading level0 col4" >buy_price</th>
#       <th class="col_heading level0 col5" >diff</th>
#       <th class="col_heading level0 col6" >qty</th>
#       <th class="col_heading level0 col7" >sell_amt</th>
#       <th class="col_heading level0 col8" >buy_amt</th>
#       <th class="col_heading level0 col9" >gross</th>
#       <th class="col_heading level0 col10" >pct</th>
#       <th class="col_heading level0 col11" >days</th>
#       <th class="col_heading level0 col12" >profit_per_day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ba14_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4ba14_row0_col0" class="data row0 col0" >JMART</td>
#       <td id="T_4ba14_row0_col1" class="data row0 col1" >2023</td>
#       <td id="T_4ba14_row0_col2" class="data row0 col2" >8</td>
#       <td id="T_4ba14_row0_col3" class="data row0 col3" >20.60</td>
#       <td id="T_4ba14_row0_col4" class="data row0 col4" >19.60</td>
#       <td id="T_4ba14_row0_col5" class="data row0 col5" >1.00</td>
#       <td id="T_4ba14_row0_col6" class="data row0 col6" >1,200</td>
#       <td id="T_4ba14_row0_col7" class="data row0 col7" >24,720.00</td>
#       <td id="T_4ba14_row0_col8" class="data row0 col8" >23,520.00</td>
#       <td id="T_4ba14_row0_col9" class="data row0 col9" >1,200.00</td>
#       <td id="T_4ba14_row0_col10" class="data row0 col10" >5.10</td>
#       <td id="T_4ba14_row0_col11" class="data row0 col11" >126</td>
#       <td id="T_4ba14_row0_col12" class="data row0 col12" >0.040492</td>
#     </tr>
#     <tr>
#       <th id="T_4ba14_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4ba14_row1_col0" class="data row1 col0" >ICHI</td>
#       <td id="T_4ba14_row1_col1" class="data row1 col1" >2023</td>
#       <td id="T_4ba14_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_4ba14_row1_col3" class="data row1 col3" >15.90</td>
#       <td id="T_4ba14_row1_col4" class="data row1 col4" >14.30</td>
#       <td id="T_4ba14_row1_col5" class="data row1 col5" >1.60</td>
#       <td id="T_4ba14_row1_col6" class="data row1 col6" >1,400</td>
#       <td id="T_4ba14_row1_col7" class="data row1 col7" >22,260.00</td>
#       <td id="T_4ba14_row1_col8" class="data row1 col8" >20,020.00</td>
#       <td id="T_4ba14_row1_col9" class="data row1 col9" >2,240.00</td>
#       <td id="T_4ba14_row1_col10" class="data row1 col10" >11.19</td>
#       <td id="T_4ba14_row1_col11" class="data row1 col11" >59</td>
#       <td id="T_4ba14_row1_col12" class="data row1 col12" >0.189641</td>
#     </tr>
#     <tr>
#       <th id="T_4ba14_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4ba14_row2_col0" class="data row2 col0" >TTB</td>
#       <td id="T_4ba14_row2_col1" class="data row2 col1" >2023</td>
#       <td id="T_4ba14_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_4ba14_row2_col3" class="data row2 col3" >1.76</td>
#       <td id="T_4ba14_row2_col4" class="data row2 col4" >1.64</td>
#       <td id="T_4ba14_row2_col5" class="data row2 col5" >0.12</td>
#       <td id="T_4ba14_row2_col6" class="data row2 col6" >15,000</td>
#       <td id="T_4ba14_row2_col7" class="data row2 col7" >26,400.00</td>
#       <td id="T_4ba14_row2_col8" class="data row2 col8" >24,600.00</td>
#       <td id="T_4ba14_row2_col9" class="data row2 col9" >1,800.00</td>
#       <td id="T_4ba14_row2_col10" class="data row2 col10" >7.32</td>
#       <td id="T_4ba14_row2_col11" class="data row2 col11" >26</td>
#       <td id="T_4ba14_row2_col12" class="data row2 col12" >0.281426</td>
#     </tr>
#     <tr>
#       <th id="T_4ba14_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4ba14_row3_col0" class="data row3 col0" >JMART</td>
#       <td id="T_4ba14_row3_col1" class="data row3 col1" >2023</td>
#       <td id="T_4ba14_row3_col2" class="data row3 col2" >8</td>
#       <td id="T_4ba14_row3_col3" class="data row3 col3" >18.30</td>
#       <td id="T_4ba14_row3_col4" class="data row3 col4" >17.00</td>
#       <td id="T_4ba14_row3_col5" class="data row3 col5" >1.30</td>
#       <td id="T_4ba14_row3_col6" class="data row3 col6" >3,600</td>
#       <td id="T_4ba14_row3_col7" class="data row3 col7" >65,880.00</td>
#       <td id="T_4ba14_row3_col8" class="data row3 col8" >61,200.00</td>
#       <td id="T_4ba14_row3_col9" class="data row3 col9" >4,680.00</td>
#       <td id="T_4ba14_row3_col10" class="data row3 col10" >7.65</td>
#       <td id="T_4ba14_row3_col11" class="data row3 col11" >41</td>
#       <td id="T_4ba14_row3_col12" class="data row3 col12" >0.186514</td>
#     </tr>
#     <tr>
#       <th id="T_4ba14_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4ba14_row4_col0" class="data row4 col0" >JMT</td>
#       <td id="T_4ba14_row4_col1" class="data row4 col1" >2023</td>
#       <td id="T_4ba14_row4_col2" class="data row4 col2" >8</td>
#       <td id="T_4ba14_row4_col3" class="data row4 col3" >43.50</td>
#       <td id="T_4ba14_row4_col4" class="data row4 col4" >39.75</td>
#       <td id="T_4ba14_row4_col5" class="data row4 col5" >3.75</td>
#       <td id="T_4ba14_row4_col6" class="data row4 col6" >1,800</td>
#       <td id="T_4ba14_row4_col7" class="data row4 col7" >78,300.00</td>
#       <td id="T_4ba14_row4_col8" class="data row4 col8" >71,550.00</td>
#       <td id="T_4ba14_row4_col9" class="data row4 col9" >6,750.00</td>
#       <td id="T_4ba14_row4_col10" class="data row4 col10" >9.43</td>
#       <td id="T_4ba14_row4_col11" class="data row4 col11" >57</td>
#       <td id="T_4ba14_row4_col12" class="data row4 col12" >0.165508</td>
#     </tr>
#   </tbody>
# </table>

# %%
average_profit_percent = sells_df['profit_per_day'].mean()
print(f"Average Profit Percent: {average_profit_percent:.2f}%")
# Out:
# Average Profit Percent: 0.17%
