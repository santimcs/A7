# %% [markdown]
# ### Restart and Run All Cells

# %%
import pandas as pd
import numpy as np
import sidetable
from datetime import date, timedelta
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:@localhost:3306/portfolio_development')
conpf = engine.connect()

engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

engine = create_engine("sqlite:///c:\\ruby\\portmy\\db\\development.sqlite3")
conmy = engine.connect()

engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

format_dict = {'qty':'{:,}','volbuy':'{:,}',
               'dividend':'฿{:.2f}','price':'฿{:.2f}','target':'฿{:.2f}','unit_cost':'฿{:.2f}',
               'grs_profit':'฿{:,.2f}','net_profit':'฿{:,.2f}','sell_price':'฿{:.2f}',
               'buy_price':'฿{:.2f}','max':'฿{:.2f}','min':'฿{:.2f}',
               'pct':'{:.2f}%','percent':'{:.2f}%','cumulative_percent':'{:.2f}%' 
               'pe':'{:.2f}','pbv':'{:.2f}','volume':'{:,.2f}','beta':'{:.2f}','diff':'฿{:.2f}',             
               'sell_amt':'฿{:,.2f}','buy_amt':'฿{:,.2f}',
               'cost_amt':'฿{:,.2f}'},'cumultive_cost_amt':'฿{:,.2f}'}
float_formatter = "฿{:,.2f}"

pd.set_option('display.max_rows', None)
year = 2022
year
# Out:
#   File "C:\Users\User\AppData\Local\Temp/ipykernel_30164/81578760.py", line 26
#     'pe':'{:.2f}','pbv':'{:.2f}','volume':'{:,.2f}','beta':'{:.2f}','diff':'฿{:.2f}',
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Record selection for sold stocks in year 2022

# %%
sql = """
SELECT stocks.name, buys.date AS buy_date, sells.date AS sell_date,
sells.price AS sell_price, buys.price AS buy_price, 
(sells.price - buys.price) AS diff, qty, 
(sells.price * qty) AS sell_amt, (buys.price * qty) AS buy_amt,
(sells.price - buys.price) * qty AS gross, 
ROUND((sells.price - buys.price)/buys.price*100,2) AS pct, profit, categories.name AS market
FROM sells JOIN buys ON sells.buy_id = buys.id
JOIN stocks ON buys.stock_id = stocks.id
JOIN categories ON stocks.category_id = categories.id
WHERE YEAR(sells.date) = %s
ORDER BY sells.date DESC, stocks.name"""
#AND kind = 'DTD'
sql = sql % year
print(sql)
sells_df = pd.read_sql(sql, conpf)
sells_df.sample(5).style.format(format_dict)
# Out:
# SELECT stocks.name, buys.date AS buy_date, sells.date AS sell_date,
# sells.price AS sell_price, buys.price AS buy_price,
# (sells.price - buys.price) AS diff, qty,
# (sells.price * qty) AS sell_amt, (buys.price * qty) AS buy_amt,
# (sells.price - buys.price) * qty AS gross,
# ROUND((sells.price - buys.price)/buys.price*100,2) AS pct, profit, categories.name AS market
# FROM sells JOIN buys ON sells.buy_id = buys.id
# JOIN stocks ON buys.stock_id = stocks.id
# JOIN categories ON stocks.category_id = categories.id
# WHERE YEAR(sells.date) = 2022
# ORDER BY sells.date DESC, stocks.name
# <style type="text/css">
# </style>
# <table id="T_e9090_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >buy_date</th>
#       <th class="col_heading level0 col2" >sell_date</th>
#       <th class="col_heading level0 col3" >sell_price</th>
#       <th class="col_heading level0 col4" >buy_price</th>
#       <th class="col_heading level0 col5" >diff</th>
#       <th class="col_heading level0 col6" >qty</th>
#       <th class="col_heading level0 col7" >sell_amt</th>
#       <th class="col_heading level0 col8" >buy_amt</th>
#       <th class="col_heading level0 col9" >gross</th>
#       <th class="col_heading level0 col10" >pct</th>
#       <th class="col_heading level0 col11" >profit</th>
#       <th class="col_heading level0 col12" >market</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9090_level0_row0" class="row_heading level0 row0" >89</th>
#       <td id="T_e9090_row0_col0" class="data row0 col0" >TOP</td>
#       <td id="T_e9090_row0_col1" class="data row0 col1" >2021-11-26</td>
#       <td id="T_e9090_row0_col2" class="data row0 col2" >2022-01-31</td>
#       <td id="T_e9090_row0_col3" class="data row0 col3" >฿53.25</td>
#       <td id="T_e9090_row0_col4" class="data row0 col4" >฿50.50</td>
#       <td id="T_e9090_row0_col5" class="data row0 col5" >฿2.75</td>
#       <td id="T_e9090_row0_col6" class="data row0 col6" >2,000</td>
#       <td id="T_e9090_row0_col7" class="data row0 col7" >฿106,500.00</td>
#       <td id="T_e9090_row0_col8" class="data row0 col8" >฿101,000.00</td>
#       <td id="T_e9090_row0_col9" class="data row0 col9" >5500.000000</td>
#       <td id="T_e9090_row0_col10" class="data row0 col10" >5.45%</td>
#       <td id="T_e9090_row0_col11" class="data row0 col11" >5040.410000</td>
#       <td id="T_e9090_row0_col12" class="data row0 col12" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_e9090_level0_row1" class="row_heading level0 row1" >63</th>
#       <td id="T_e9090_row1_col0" class="data row1 col0" >TYCN</td>
#       <td id="T_e9090_row1_col1" class="data row1 col1" >2021-11-05</td>
#       <td id="T_e9090_row1_col2" class="data row1 col2" >2022-03-01</td>
#       <td id="T_e9090_row1_col3" class="data row1 col3" >฿3.50</td>
#       <td id="T_e9090_row1_col4" class="data row1 col4" >฿3.80</td>
#       <td id="T_e9090_row1_col5" class="data row1 col5" >฿-0.30</td>
#       <td id="T_e9090_row1_col6" class="data row1 col6" >40,000</td>
#       <td id="T_e9090_row1_col7" class="data row1 col7" >฿140,000.00</td>
#       <td id="T_e9090_row1_col8" class="data row1 col8" >฿152,000.00</td>
#       <td id="T_e9090_row1_col9" class="data row1 col9" >-12000.000000</td>
#       <td id="T_e9090_row1_col10" class="data row1 col10" >-7.89%</td>
#       <td id="T_e9090_row1_col11" class="data row1 col11" >-12646.750000</td>
#       <td id="T_e9090_row1_col12" class="data row1 col12" >SET</td>
#     </tr>
#     <tr>
#       <th id="T_e9090_level0_row2" class="row_heading level0 row2" >36</th>
#       <td id="T_e9090_row2_col0" class="data row2 col0" >IP</td>
#       <td id="T_e9090_row2_col1" class="data row2 col1" >2021-11-10</td>
#       <td id="T_e9090_row2_col2" class="data row2 col2" >2022-05-30</td>
#       <td id="T_e9090_row2_col3" class="data row2 col3" >฿20.30</td>
#       <td id="T_e9090_row2_col4" class="data row2 col4" >฿20.20</td>
#       <td id="T_e9090_row2_col5" class="data row2 col5" >฿0.10</td>
#       <td id="T_e9090_row2_col6" class="data row2 col6" >7,500</td>
#       <td id="T_e9090_row2_col7" class="data row2 col7" >฿152,250.00</td>
#       <td id="T_e9090_row2_col8" class="data row2 col8" >฿151,500.00</td>
#       <td id="T_e9090_row2_col9" class="data row2 col9" >750.000000</td>
#       <td id="T_e9090_row2_col10" class="data row2 col10" >0.50%</td>
#       <td id="T_e9090_row2_col11" class="data row2 col11" >77.220000</td>
#       <td id="T_e9090_row2_col12" class="data row2 col12" >MAI</td>
#     </tr>
#     <tr>
#       <th id="T_e9090_level0_row3" class="row_heading level0 row3" >39</th>
#       <td id="T_e9090_row3_col0" class="data row3 col0" >RJH</td>
#       <td id="T_e9090_row3_col1" class="data row3 col1" >2021-11-09</td>
#       <td id="T_e9090_row3_col2" class="data row3 col2" >2022-05-23</td>
#       <td id="T_e9090_row3_col3" class="data row3 col3" >฿34.00</td>
#       <td id="T_e9090_row3_col4" class="data row3 col4" >฿33.00</td>
#       <td id="T_e9090_row3_col5" class="data row3 col5" >฿1.00</td>
#       <td id="T_e9090_row3_col6" class="data row3 col6" >4,500</td>
#       <td id="T_e9090_row3_col7" class="data row3 col7" >฿153,000.00</td>
#       <td id="T_e9090_row3_col8" class="data row3 col8" >฿148,500.00</td>
#       <td id="T_e9090_row3_col9" class="data row3 col9" >4500.000000</td>
#       <td id="T_e9090_row3_col10" class="data row3 col10" >3.03%</td>
#       <td id="T_e9090_row3_col11" class="data row3 col11" >3832.200000</td>
#       <td id="T_e9090_row3_col12" class="data row3 col12" >SET</td>
#     </tr>
#     <tr>
#       <th id="T_e9090_level0_row4" class="row_heading level0 row4" >76</th>
#       <td id="T_e9090_row4_col0" class="data row4 col0" >TSTH</td>
#       <td id="T_e9090_row4_col1" class="data row4 col1" >2021-11-30</td>
#       <td id="T_e9090_row4_col2" class="data row4 col2" >2022-02-17</td>
#       <td id="T_e9090_row4_col3" class="data row4 col3" >฿1.43</td>
#       <td id="T_e9090_row4_col4" class="data row4 col4" >฿1.50</td>
#       <td id="T_e9090_row4_col5" class="data row4 col5" >฿-0.07</td>
#       <td id="T_e9090_row4_col6" class="data row4 col6" >10,300</td>
#       <td id="T_e9090_row4_col7" class="data row4 col7" >฿14,729.00</td>
#       <td id="T_e9090_row4_col8" class="data row4 col8" >฿15,450.00</td>
#       <td id="T_e9090_row4_col9" class="data row4 col9" >-721.000000</td>
#       <td id="T_e9090_row4_col10" class="data row4 col10" >-4.67%</td>
#       <td id="T_e9090_row4_col11" class="data row4 col11" >-787.840000</td>
#       <td id="T_e9090_row4_col12" class="data row4 col12" >SET</td>
#     </tr>
#   </tbody>
# </table>

# %%
sells_df.dtypes
# Out:
# name           object
# buy_date       object
# sell_date      object
# sell_price    float64
# buy_price     float64
# diff          float64
# qty             int64
# sell_amt      float64
# buy_amt       float64
# gross         float64
# pct           float64
# profit        float64
# market         object
# dtype: object

# %%
sells_df['buy_date'] = pd.to_datetime(sells_df['buy_date'])
sells_df['sell_date'] = pd.to_datetime(sells_df['sell_date'])
sells_df.dtypes
# Out:
# name                  object
# buy_date      datetime64[ns]
# sell_date     datetime64[ns]
# sell_price           float64
# buy_price            float64
# diff                 float64
# qty                    int64
# sell_amt             float64
# buy_amt              float64
# gross                float64
# pct                  float64
# profit               float64
# market                object
# dtype: object

# %%
sells_df.rename(columns={'gross':'grs_profit','profit':'net_profit'},inplace=True)
sells_df.dtypes
# Out:
# name                  object
# buy_date      datetime64[ns]
# sell_date     datetime64[ns]
# sell_price           float64
# buy_price            float64
# diff                 float64
# qty                    int64
# sell_amt             float64
# buy_amt              float64
# grs_profit           float64
# pct                  float64
# net_profit           float64
# market                object
# dtype: object

# %%
sells_df.groupby(['market'])[['grs_profit','net_profit']].sum().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9a2de_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >grs_profit</th>
#       <th class="col_heading level0 col1" >net_profit</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >market</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a2de_level0_row0" class="row_heading level0 row0" >MAI</th>
#       <td id="T_9a2de_row0_col0" class="data row0 col0" >฿55,450.00</td>
#       <td id="T_9a2de_row0_col1" class="data row0 col1" >฿53,023.25</td>
#     </tr>
#     <tr>
#       <th id="T_9a2de_level0_row1" class="row_heading level0 row1" >SET</th>
#       <td id="T_9a2de_row1_col0" class="data row1 col0" >฿-102,055.00</td>
#       <td id="T_9a2de_row1_col1" class="data row1 col1" >฿-119,790.97</td>
#     </tr>
#     <tr>
#       <th id="T_9a2de_level0_row2" class="row_heading level0 row2" >SET100</th>
#       <td id="T_9a2de_row2_col0" class="data row2 col0" >฿-8,825.00</td>
#       <td id="T_9a2de_row2_col1" class="data row2 col1" >฿-16,041.08</td>
#     </tr>
#     <tr>
#       <th id="T_9a2de_level0_row3" class="row_heading level0 row3" >SET50</th>
#       <td id="T_9a2de_row3_col0" class="data row3 col0" >฿-94,262.00</td>
#       <td id="T_9a2de_row3_col1" class="data row3 col1" >฿-118,604.57</td>
#     </tr>
#   </tbody>
# </table>

# %%
sells_df.stb.freq(["market"])
# Out:
#    market  count    percent  cumulative_count  cumulative_percent
# 0   SET50     44  40.366972                44           40.366972
# 1     SET     35  32.110092                79           72.477064
# 2  SET100     21  19.266055               100           91.743119
# 3     MAI      9   8.256881               109          100.000000

# %% [markdown]
# ### Begin of Special Process

# %%
colt = 'name sell_amt buy_amt grs_profit net_profit'.split()
mask_100 = sells_df.market == 'SET100'
sells_df[mask_100][colt].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3e727_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >sell_amt</th>
#       <th class="col_heading level0 col2" >buy_amt</th>
#       <th class="col_heading level0 col3" >grs_profit</th>
#       <th class="col_heading level0 col4" >net_profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e727_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3e727_row0_col0" class="data row0 col0" >SYNEX</td>
#       <td id="T_3e727_row0_col1" class="data row0 col1" >฿49,500.00</td>
#       <td id="T_3e727_row0_col2" class="data row0 col2" >฿51,000.00</td>
#       <td id="T_3e727_row0_col3" class="data row0 col3" >฿-1,500.00</td>
#       <td id="T_3e727_row0_col4" class="data row0 col4" >฿-1,722.60</td>
#     </tr>
#     <tr>
#       <th id="T_3e727_level0_row1" class="row_heading level0 row1" >4</th>
#       <td id="T_3e727_row1_col0" class="data row1 col0" >DOHOME</td>
#       <td id="T_3e727_row1_col1" class="data row1 col1" >฿35,040.00</td>
#       <td id="T_3e727_row1_col2" class="data row1 col2" >฿48,600.00</td>
#       <td id="T_3e727_row1_col3" class="data row1 col3" >฿-13,560.00</td>
#       <td id="T_3e727_row1_col4" class="data row1 col4" >฿-13,745.25</td>
#     </tr>
#     <tr>
#       <th id="T_3e727_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_3e727_row2_col0" class="data row2 col0" >SINGER</td>
#       <td id="T_3e727_row2_col1" class="data row2 col1" >฿108,000.00</td>
#       <td id="T_3e727_row2_col2" class="data row2 col2" >฿100,800.00</td>
#       <td id="T_3e727_row2_col3" class="data row2 col3" >฿7,200.00</td>
#       <td id="T_3e727_row2_col4" class="data row2 col4" >฿6,737.52</td>
#     </tr>
#     <tr>
#       <th id="T_3e727_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_3e727_row3_col0" class="data row3 col0" >DOHOME</td>
#       <td id="T_3e727_row3_col1" class="data row3 col1" >฿34,080.00</td>
#       <td id="T_3e727_row3_col2" class="data row3 col2" >฿48,600.00</td>
#       <td id="T_3e727_row3_col3" class="data row3 col3" >฿-14,520.00</td>
#       <td id="T_3e727_row3_col4" class="data row3 col4" >฿-14,703.13</td>
#     </tr>
#     <tr>
#       <th id="T_3e727_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_3e727_row4_col0" class="data row4 col0" >DOHOME</td>
#       <td id="T_3e727_row4_col1" class="data row4 col1" >฿32,880.00</td>
#       <td id="T_3e727_row4_col2" class="data row4 col2" >฿48,600.00</td>
#       <td id="T_3e727_row4_col3" class="data row4 col3" >฿-15,720.00</td>
#       <td id="T_3e727_row4_col4" class="data row4 col4" >฿-15,900.46</td>
#     </tr>
#     <tr>
#       <th id="T_3e727_level0_row5" class="row_heading level0 row5" >11</th>
#       <td id="T_3e727_row5_col0" class="data row5 col0" >SYNEX</td>
#       <td id="T_3e727_row5_col1" class="data row5 col1" >฿48,300.00</td>
#       <td id="T_3e727_row5_col2" class="data row5 col2" >฿73,500.00</td>
#       <td id="T_3e727_row5_col3" class="data row5 col3" >฿-25,200.00</td>
#       <td id="T_3e727_row5_col4" class="data row5 col4" >฿-25,469.78</td>
#     </tr>
#     <tr>
#       <th id="T_3e727_level0_row6" class="row_heading level0 row6" >15</th>
#       <td id="T_3e727_row6_col0" class="data row6 col0" >BCH</td>
#       <td id="T_3e727_row6_col1" class="data row6 col1" >฿55,200.00</td>
#       <td id="T_3e727_row6_col2" class="data row6 col2" >฿61,500.00</td>
#       <td id="T_3e727_row6_col3" class="data row6 col3" >฿-6,300.00</td>
#       <td id="T_3e727_row6_col4" class="data row6 col4" >฿-6,558.48</td>
#     </tr>
#     <tr>
#       <th id="T_3e727_level0_row7" class="row_heading level0 row7" >18</th>
#       <td id="T_3e727_row7_col0" class="data row7 col0" >BANPU</td>
#       <td id="T_3e727_row7_col1" class="data row7 col1" >฿108,750.00</td>
#       <td id="T_3e727_row7_col2" class="data row7 col2" >฿105,000.00</td>
#       <td id="T_3e727_row7_col3" class="data row7 col3" >฿3,750.00</td>
#       <td id="T_3e727_row7_col4" class="data row7 col4" >฿3,276.57</td>
#     </tr>
#     <tr>
#       <th id="T_3e727_level0_row8" class="row_heading level0 row8" >21</th>
#       <td id="T_3e727_row8_col0" class="data row8 col0" >BCH</td>
#       <td id="T_3e727_row8_col1" class="data row8 col1" >฿57,000.00</td>
#       <td id="T_3e727_row8_col2" class="data row8 col2" >฿55,500.00</td>
#       <td id="T_3e727_row8_col3" class="data row8 col3" >฿1,500.00</td>
#       <td id="T_3e727_row8_col4" class="data row8 col4" >฿1,250.82</td>
#     </tr>
#     <tr>
#       <th id="T_3e727_level0_row9" class="row_heading level0 row9" >45</th>
#       <td id="T_3e727_row9_col0" class="data row9 col0" >SPALI</td>
#       <td id="T_3e727_row9_col1" class="data row9 col1" >฿127,200.00</td>
#       <td id="T_3e727_row9_col2" class="data row9 col2" >฿132,000.00</td>
#       <td id="T_3e727_row9_col3" class="data row9 col3" >฿-4,800.00</td>
#       <td id="T_3e727_row9_col4" class="data row9 col4" >฿-5,374.10</td>
#     </tr>
#     <tr>
#       <th id="T_3e727_level0_row10" class="row_heading level0 row10" >46</th>
#       <td id="T_3e727_row10_col0" class="data row10 col0" >DOHOME</td>
#       <td id="T_3e727_row10_col1" class="data row10 col1" >฿46,560.00</td>
#       <td id="T_3e727_row10_col2" class="data row10 col2" >฿48,600.00</td>
#       <td id="T_3e727_row10_col3" class="data row10 col3" >฿-2,040.00</td>
#       <td id="T_3e727_row10_col4" class="data row10 col4" >฿-2,250.77</td>
#     </tr>
#     <tr>
#       <th id="T_3e727_level0_row11" class="row_heading level0 row11" >48</th>
#       <td id="T_3e727_row11_col0" class="data row11 col0" >SPALI</td>
#       <td id="T_3e727_row11_col1" class="data row11 col1" >฿66,300.00</td>
#       <td id="T_3e727_row11_col2" class="data row11 col2" >฿66,000.00</td>
#       <td id="T_3e727_row11_col3" class="data row11 col3" >฿300.00</td>
#       <td id="T_3e727_row11_col4" class="data row11 col4" >฿6.97</td>
#     </tr>
#     <tr>
#       <th id="T_3e727_level0_row12" class="row_heading level0 row12" >52</th>
#       <td id="T_3e727_row12_col0" class="data row12 col0" >DOHOME</td>
#       <td id="T_3e727_row12_col1" class="data row12 col1" >฿53,760.00</td>
#       <td id="T_3e727_row12_col2" class="data row12 col2" >฿51,120.00</td>
#       <td id="T_3e727_row12_col3" class="data row12 col3" >฿2,640.00</td>
#       <td id="T_3e727_row12_col4" class="data row12 col4" >฿2,407.70</td>
#     </tr>
#     <tr>
#       <th id="T_3e727_level0_row13" class="row_heading level0 row13" >57</th>
#       <td id="T_3e727_row13_col0" class="data row13 col0" >SINGER</td>
#       <td id="T_3e727_row13_col1" class="data row13 col1" >฿79,125.00</td>
#       <td id="T_3e727_row13_col2" class="data row13 col2" >฿63,375.00</td>
#       <td id="T_3e727_row13_col3" class="data row13 col3" >฿15,750.00</td>
#       <td id="T_3e727_row13_col4" class="data row13 col4" >฿15,434.37</td>
#     </tr>
#     <tr>
#       <th id="T_3e727_level0_row14" class="row_heading level0 row14" >58</th>
#       <td id="T_3e727_row14_col0" class="data row14 col0" >SINGER</td>
#       <td id="T_3e727_row14_col1" class="data row14 col1" >฿76,125.00</td>
#       <td id="T_3e727_row14_col2" class="data row14 col2" >฿63,375.00</td>
#       <td id="T_3e727_row14_col3" class="data row14 col3" >฿12,750.00</td>
#       <td id="T_3e727_row14_col4" class="data row14 col4" >฿12,441.02</td>
#     </tr>
#     <tr>
#       <th id="T_3e727_level0_row15" class="row_heading level0 row15" >59</th>
#       <td id="T_3e727_row15_col0" class="data row15 col0" >DOHOME</td>
#       <td id="T_3e727_row15_col1" class="data row15 col1" >฿108,000.00</td>
#       <td id="T_3e727_row15_col2" class="data row15 col2" >฿97,200.00</td>
#       <td id="T_3e727_row15_col3" class="data row15 col3" >฿10,800.00</td>
#       <td id="T_3e727_row15_col4" class="data row15 col4" >฿10,345.51</td>
#     </tr>
#     <tr>
#       <th id="T_3e727_level0_row16" class="row_heading level0 row16" >60</th>
#       <td id="T_3e727_row16_col0" class="data row16 col0" >SINGER</td>
#       <td id="T_3e727_row16_col1" class="data row16 col1"

# %%
data_path = "../data/"
file_name = 'tmp-file-for-problem-solving.csv'
data_file = data_path + file_name

# %%
sells_df[mask_100][colt].to_csv(data_file, index=False)

# %%
sells_df[mask_100][['grs_profit','net_profit']].sum()
# Out:
# grs_profit    -8825.00
# net_profit   -16041.08
# dtype: float64

# %% [markdown]
# ### End of Special Process

# %% [markdown]
# ### Total profit amount

# %%
ttl_prf = sells_df.grs_profit.sum()
net_prf = sells_df.net_profit.sum()
ttl_prf,round(net_prf,2)
# Out:
# (-149692.0, -201413.37)

# %%
array = pd.Series([ttl_prf,net_prf])
array = array.map('฿{:,.2f}'.format)
for value in array:
    print(f"The value is: {value}")
# Out:
# The value is: ฿-149,692.00
# The value is: ฿-201,413.37

# %% [markdown]
# ### Input the above figures to Excel

# %%
sold_grp = sells_df.groupby(['name','market'])
sold_stocks = sold_grp[['sell_amt','buy_amt','qty','grs_profit','net_profit']].sum()
sold_stocks.sort_values(['name'],ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d90ed_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >sell_amt</th>
#       <th class="col_heading level0 col1" >buy_amt</th>
#       <th class="col_heading level0 col2" >qty</th>
#       <th class="col_heading level0 col3" >grs_profit</th>
#       <th class="col_heading level0 col4" >net_profit</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="index_name level1" >market</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d90ed_level0_row0" class="row_heading level0 row0" >AIMIRT</th>
#       <th id="T_d90ed_level1_row0" class="row_heading level1 row0" >SET</th>
#       <td id="T_d90ed_row0_col0" class="data row0 col0" >฿127,000.00</td>
#       <td id="T_d90ed_row0_col1" class="data row0 col1" >฿130,000.00</td>
#       <td id="T_d90ed_row0_col2" class="data row0 col2" >10,000</td>
#       <td id="T_d90ed_row0_col3" class="data row0 col3" >฿-3,000.00</td>
#       <td id="T_d90ed_row0_col4" class="data row0 col4" >฿-3,569.23</td>
#     </tr>
#     <tr>
#       <th id="T_d90ed_level0_row1" class="row_heading level0 row1" >BANPU</th>
#       <th id="T_d90ed_level1_row1" class="row_heading level1 row1" >SET100</th>
#       <td id="T_d90ed_row1_col0" class="data row1 col0" >฿108,750.00</td>
#       <td id="T_d90ed_row1_col1" class="data row1 col1" >฿105,000.00</td>
#       <td id="T_d90ed_row1_col2" class="data row1 col2" >7,500</td>
#       <td id="T_d90ed_row1_col3" class="data row1 col3" >฿3,750.00</td>
#       <td id="T_d90ed_row1_col4" class="data row1 col4" >฿3,276.57</td>
#     </tr>
#     <tr>
#       <th id="T_d90ed_level0_row2" class="row_heading level0 row2" >BCH</th>
#       <th id="T_d90ed_level1_row2" class="row_heading level1 row2" >SET100</th>
#       <td id="T_d90ed_row2_col0" class="data row2 col0" >฿112,200.00</td>
#       <td id="T_d90ed_row2_col1" class="data row2 col1" >฿117,000.00</td>
#       <td id="T_d90ed_row2_col2" class="data row2 col2" >6,000</td>
#       <td id="T_d90ed_row2_col3" class="data row2 col3" >฿-4,800.00</td>
#       <td id="T_d90ed_row2_col4" class="data row2 col4" >฿-5,307.66</td>
#     </tr>
#     <tr>
#       <th id="T_d90ed_level0_row3" class="row_heading level0 row3" >BDMS</th>
#       <th id="T_d90ed_level1_row3" class="row_heading level1 row3" >SET50</th>
#       <td id="T_d90ed_row3_col0" class="data row3 col0" >฿111,600.00</td>
#       <td id="T_d90ed_row3_col1" class="data row3 col1" >฿117,000.00</td>
#       <td id="T_d90ed_row3_col2" class="data row3 col2" >4,500</td>
#       <td id="T_d90ed_row3_col3" class="data row3 col3" >฿-5,400.00</td>
#       <td id="T_d90ed_row3_col4" class="data row3 col4" >฿-5,906.32</td>
#     </tr>
#     <tr>
#       <th id="T_d90ed_level0_row4" class="row_heading level0 row4" >BGRIM</th>
#       <th id="T_d90ed_level1_row4" class="row_heading level1 row4" >SET50</th>
#       <td id="T_d90ed_row4_col0" class="data row4 col0" >฿297,000.00</td>
#       <td id="T_d90ed_row4_col1" class="data row4 col1" >฿360,000.00</td>
#       <td id="T_d90ed_row4_col2" class="data row4 col2" >9,000</td>
#       <td id="T_d90ed_row4_col3" class="data row4 col3" >฿-63,000.00</td>
#       <td id="T_d90ed_row4_col4" class="data row4 col4" >฿-64,455.19</td>
#     </tr>
#     <tr>
#       <th id="T_d90ed_level0_row5" class="row_heading level0 row5" >BH</th>
#       <th id="T_d90ed_level1_row5" class="row_heading level1 row5" >SET50</th>
#       <td id="T_d90ed_row5_col0" class="data row5 col0" >฿110,000.00</td>
#       <td id="T_d90ed_row5_col1" class="data row5 col1" >฿105,000.00</td>
#       <td id="T_d90ed_row5_col2" class="data row5 col2" >500</td>
#       <td id="T_d90ed_row5_col3" class="data row5 col3" >฿5,000.00</td>
#       <td id="T_d90ed_row5_col4" class="data row5 col4" >฿4,523.80</td>
#     </tr>
#     <tr>
#       <th id="T_d90ed_level0_row6" class="row_heading level0 row6" >CKP</th>
#       <th id="T_d90ed_level1_row6" class="row_heading level1 row6" >SET100</th>
#       <td id="T_d90ed_row6_col0" class="data row6 col0" >฿157,000.00</td>
#       <td id="T_d90ed_row6_col1" class="data row6 col1" >฿150,000.00</td>
#       <td id="T_d90ed_row6_col2" class="data row6 col2" >30,000</td>
#       <td id="T_d90ed_row6_col3" class="data row6 col3" >฿7,000.00</td>
#       <td id="T_d90ed_row6_col4" class="data row6 col4" >฿6,320.02</td>
#     </tr>
#     <tr>
#       <th id="T_d90ed_level0_row7" class="row_heading level0 row7" >CPNCG</th>
#       <th id="T_d90ed_level1_row7" class="row_heading level1 row7" >SET</th>
#       <td id="T_d90ed_row7_col0" class="data row7 col0" >฿242,000.00</td>
#       <td id="T_d90ed_row7_col1" class="data row7 col1" >฿248,000.00</td>
#       <td id="T_d90ed_row7_col2" class="data row7 col2" >20,000</td>
#       <td id="T_d90ed_row7_col3" class="data row7 col3" >฿-6,000.00</td>
#       <td id="T_d90ed_row7_col4" class="data row7 col4" >฿-7,085.31</td>
#     </tr>
#     <tr>
#       <th id="T_d90ed_level0_row8" class="row_heading level0 row8" >DCC</th>
#       <th id="T_d90ed_level1_row8" class="row_heading level1 row8" >SET</th>
#       <td id="T_d90ed_row8_col0" class="data row8 col0" >฿120,000.00</td>
#       <td id="T_d90ed_row8_col1" class="data row8 col1" >฿116,000.00</td>
#       <td id="T_d90ed_row8_col2" class="data row8 col2" >40,000</td>
#       <td id="T_d90ed_row8_col3" class="data row8 col3" >฿4,000.00</td>
#       <td id="T_d90ed_row8_col4" class="data row8 col4" >฿3,477.28</td>
#     </tr>
#     <tr>
#       <th id="T_d90ed_level0_row9" class="row_heading level0 row9" >DIF</th>
#       <th id="T_d90ed_level1_row9" class="row_heading level1 row9" >SET</th>
#       <td id="T_d90ed_row9_col0" class="data row9 col0" >฿278,000.00</td>
#       <td id="T_d90ed_row9_col1" class="data row9 col1" >฿294,000.00</td>
#       <td id="T_d90ed_row9_col2" class="data row9 col2" >20,000</td>
#       <td id="T_d90ed_row9_col3" class="data row9 col3" >฿-16,000.00</td>
#       <td id="T_d90ed_row9_col4" class="data row9 col4" >฿-17,266.92</td>
#     </tr>
#     <tr>
#       <th id="T_d90ed_level0_row10" class="row_heading level0 row10" >DOHOME</th>
#       <th id="T_d90ed_level1_row10" class="row_heading level1 row10" >SET100</th>
#       <td id="T_d90ed_row10_col0" class="data row10 col0" >฿310,320.00</td>
#       <td id="T_d90ed_row10_col1" class="data row10 col1" >฿342,720.00</td>
#       <td id="T_d90ed_row10_col2" class="data row10 col2" >16,800</td>
#       <td id="T_d90ed_row10_col3" class="data row10 col3" >฿-32,400.00</td>
#       <td id="T_d90ed_row10_col4" class="data row10 col4" >฿-33,846.40</td>
#     </tr>
#     <tr>
#       <th id="T_d90ed_level0_row11" class="row_heading level0 row11" >EPG</th>
#       <th id="T_d90ed_level1_row11" class="row_heading level1 row11" >SET</th>
#       <td id="T_d90ed_row11_col0" class="data row11 col0" >฿271,800.00</td>
#       <td id="T_d90ed_row11_col1" class="data row11 col1" >฿284,000.00</td>
#       <td id="T_d90ed_row11_col2" class="data row11 col2" >26,000</td>
#       <td id="T_d90ed_row11_col3" class="data row11 col3" >฿-12,200.00</td>
#       <td id="T_d90ed_row11_col4" class="data row11 col4" >฿-13,431.04</td>
#     </tr>
#     <tr>
#       <th id="T_d90ed_level0_row12" class="row_heading level0 row12" >GLOBAL</th>
#       <th id="T_d90ed_level1_row12" class="row_heading level1 row12" >SET50</th>
#       <td id="T_d90ed_row12_col0" class="data row12 col0" >฿482,400.00</td>
#       <td id="T_d90ed_row12_col1" class="data row12 col1" >฿456,600.00</td>
#       <td id="T_d90ed_row12_col2" class="data row12 col2" >24,000</td>
#       <td id="T_d90ed_row12_col3" class="data row12 col3" >฿25,800.00</td>
#       <td id="T_d90ed_row12_col4" class="data row12 col4" >฿23,720.19</td>
#     </tr>
#     <tr>
#       <th id="T_d90ed_level0_row13" class="row_heading level0 row13" >IMH</th>
#       <th id="T_d90ed_level1_row13" class="row_heading level1 row13" >MAI</th>

# %%
sold_stocks['sell_price'] = sold_stocks['sell_amt'] / sold_stocks['qty']
sold_stocks['buy_price'] = sold_stocks['buy_amt'] / sold_stocks['qty']
sold_stocks['diff'] = sold_stocks['sell_price'] - sold_stocks['buy_price']
cols = 'sell_amt buy_amt grs_profit net_profit qty sell_price buy_price diff'.split()
sold_stocks[cols].sort_values(['name'],ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d34d9_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >sell_amt</th>
#       <th class="col_heading level0 col1" >buy_amt</th>
#       <th class="col_heading level0 col2" >grs_profit</th>
#       <th class="col_heading level0 col3" >net_profit</th>
#       <th class="col_heading level0 col4" >qty</th>
#       <th class="col_heading level0 col5" >sell_price</th>
#       <th class="col_heading level0 col6" >buy_price</th>
#       <th class="col_heading level0 col7" >diff</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="index_name level1" >market</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d34d9_level0_row0" class="row_heading level0 row0" >AIMIRT</th>
#       <th id="T_d34d9_level1_row0" class="row_heading level1 row0" >SET</th>
#       <td id="T_d34d9_row0_col0" class="data row0 col0" >฿127,000.00</td>
#       <td id="T_d34d9_row0_col1" class="data row0 col1" >฿130,000.00</td>
#       <td id="T_d34d9_row0_col2" class="data row0 col2" >฿-3,000.00</td>
#       <td id="T_d34d9_row0_col3" class="data row0 col3" >฿-3,569.23</td>
#       <td id="T_d34d9_row0_col4" class="data row0 col4" >10,000</td>
#       <td id="T_d34d9_row0_col5" class="data row0 col5" >฿12.70</td>
#       <td id="T_d34d9_row0_col6" class="data row0 col6" >฿13.00</td>
#       <td id="T_d34d9_row0_col7" class="data row0 col7" >฿-0.30</td>
#     </tr>
#     <tr>
#       <th id="T_d34d9_level0_row1" class="row_heading level0 row1" >BANPU</th>
#       <th id="T_d34d9_level1_row1" class="row_heading level1 row1" >SET100</th>
#       <td id="T_d34d9_row1_col0" class="data row1 col0" >฿108,750.00</td>
#       <td id="T_d34d9_row1_col1" class="data row1 col1" >฿105,000.00</td>
#       <td id="T_d34d9_row1_col2" class="data row1 col2" >฿3,750.00</td>
#       <td id="T_d34d9_row1_col3" class="data row1 col3" >฿3,276.57</td>
#       <td id="T_d34d9_row1_col4" class="data row1 col4" >7,500</td>
#       <td id="T_d34d9_row1_col5" class="data row1 col5" >฿14.50</td>
#       <td id="T_d34d9_row1_col6" class="data row1 col6" >฿14.00</td>
#       <td id="T_d34d9_row1_col7" class="data row1 col7" >฿0.50</td>
#     </tr>
#     <tr>
#       <th id="T_d34d9_level0_row2" class="row_heading level0 row2" >BCH</th>
#       <th id="T_d34d9_level1_row2" class="row_heading level1 row2" >SET100</th>
#       <td id="T_d34d9_row2_col0" class="data row2 col0" >฿112,200.00</td>
#       <td id="T_d34d9_row2_col1" class="data row2 col1" >฿117,000.00</td>
#       <td id="T_d34d9_row2_col2" class="data row2 col2" >฿-4,800.00</td>
#       <td id="T_d34d9_row2_col3" class="data row2 col3" >฿-5,307.66</td>
#       <td id="T_d34d9_row2_col4" class="data row2 col4" >6,000</td>
#       <td id="T_d34d9_row2_col5" class="data row2 col5" >฿18.70</td>
#       <td id="T_d34d9_row2_col6" class="data row2 col6" >฿19.50</td>
#       <td id="T_d34d9_row2_col7" class="data row2 col7" >฿-0.80</td>
#     </tr>
#     <tr>
#       <th id="T_d34d9_level0_row3" class="row_heading level0 row3" >BDMS</th>
#       <th id="T_d34d9_level1_row3" class="row_heading level1 row3" >SET50</th>
#       <td id="T_d34d9_row3_col0" class="data row3 col0" >฿111,600.00</td>
#       <td id="T_d34d9_row3_col1" class="data row3 col1" >฿117,000.00</td>
#       <td id="T_d34d9_row3_col2" class="data row3 col2" >฿-5,400.00</td>
#       <td id="T_d34d9_row3_col3" class="data row3 col3" >฿-5,906.32</td>
#       <td id="T_d34d9_row3_col4" class="data row3 col4" >4,500</td>
#       <td id="T_d34d9_row3_col5" class="data row3 col5" >฿24.80</td>
#       <td id="T_d34d9_row3_col6" class="data row3 col6" >฿26.00</td>
#       <td id="T_d34d9_row3_col7" class="data row3 col7" >฿-1.20</td>
#     </tr>
#     <tr>
#       <th id="T_d34d9_level0_row4" class="row_heading level0 row4" >BGRIM</th>
#       <th id="T_d34d9_level1_row4" class="row_heading level1 row4" >SET50</th>
#       <td id="T_d34d9_row4_col0" class="data row4 col0" >฿297,000.00</td>
#       <td id="T_d34d9_row4_col1" class="data row4 col1" >฿360,000.00</td>
#       <td id="T_d34d9_row4_col2" class="data row4 col2" >฿-63,000.00</td>
#       <td id="T_d34d9_row4_col3" class="data row4 col3" >฿-64,455.19</td>
#       <td id="T_d34d9_row4_col4" class="data row4 col4" >9,000</td>
#       <td id="T_d34d9_row4_col5" class="data row4 col5" >฿33.00</td>
#       <td id="T_d34d9_row4_col6" class="data row4 col6" >฿40.00</td>
#       <td id="T_d34d9_row4_col7" class="data row4 col7" >฿-7.00</td>
#     </tr>
#     <tr>
#       <th id="T_d34d9_level0_row5" class="row_heading level0 row5" >BH</th>
#       <th id="T_d34d9_level1_row5" class="row_heading level1 row5" >SET50</th>
#       <td id="T_d34d9_row5_col0" class="data row5 col0" >฿110,000.00</td>
#       <td id="T_d34d9_row5_col1" class="data row5 col1" >฿105,000.00</td>
#       <td id="T_d34d9_row5_col2" class="data row5 col2" >฿5,000.00</td>
#       <td id="T_d34d9_row5_col3" class="data row5 col3" >฿4,523.80</td>
#       <td id="T_d34d9_row5_col4" class="data row5 col4" >500</td>
#       <td id="T_d34d9_row5_col5" class="data row5 col5" >฿220.00</td>
#       <td id="T_d34d9_row5_col6" class="data row5 col6" >฿210.00</td>
#       <td id="T_d34d9_row5_col7" class="data row5 col7" >฿10.00</td>
#     </tr>
#     <tr>
#       <th id="T_d34d9_level0_row6" class="row_heading level0 row6" >CKP</th>
#       <th id="T_d34d9_level1_row6" class="row_heading level1 row6" >SET100</th>
#       <td id="T_d34d9_row6_col0" class="data row6 col0" >฿157,000.00</td>
#       <td id="T_d34d9_row6_col1" class="data row6 col1" >฿150,000.00</td>
#       <td id="T_d34d9_row6_col2" class="data row6 col2" >฿7,000.00</td>
#       <td id="T_d34d9_row6_col3" class="data row6 col3" >฿6,320.02</td>
#       <td id="T_d34d9_row6_col4" class="data row6 col4" >30,000</td>
#       <td id="T_d34d9_row6_col5" class="data row6 col5" >฿5.23</td>
#       <td id="T_d34d9_row6_col6" class="data row6 col6" >฿5.00</td>
#       <td id="T_d34d9_row6_col7" class="data row6 col7" >฿0.23</td>
#     </tr>
#     <tr>
#       <th id="T_d34d9_level0_row7" class="row_heading level0 row7" >CPNCG</th>
#       <th id="T_d34d9_level1_row7" class="row_heading level1 row7" >SET</th>
#       <td id="T_d34d9_row7_col0" class="data row7 col0" >฿242,000.00</td>
#       <td id="T_d34d9_row7_col1" class="data row7 col1" >฿248,000.00</td>
#       <td id="T_d34d9_row7_col2" class="data row7 col2" >฿-6,000.00</td>
#       <td id="T_d34d9_row7_col3" class="data row7 col3" >฿-7,085.31</td>
#       <td id="T_d34d9_row7_col4" class="data row7 col4" >20,000</td>
#       <td id="T_d34d9_row7_col5" class="data row7 col5" >฿12.10</td>
#       <td id="T_d34d9_row7_col6" class="data row7 col6" >฿12.40</td>
#       <td id="T_d34d9_row7_col7" class="data row7 col7" >฿-0.30</td>
#     </tr>
#     <tr>
#       <th id="T_d34d9_level0_row8" class="row_heading level0 row8" >DCC</th>
#       <th id="T_d34d9_level1_row8" class="row_heading level1 row8" >SET</th>
#       <td id="T_d34d9_row8_col0" class="data row8 col0" >฿120,000.00</td>
#       <td id="T_d34d9_row8_col1" class="data row8 col1" >฿116,000.00</td>
#       <td id="T_d34d9_row8_col2" class="data row8 col2" >฿4,000.00</td>
#       <td id="T_d34d9_row8_col3" class="data row8 col3" >฿3,477.28</td>
#       <td id="T_d34d9_row8_col4" class="data row8 col4" >40,000</td>
#       <td id="T_d34d9_row8_col5" class="data row8 col5" >฿3.00</td>
#       <td id="T_d34d9_row8_col6" class="data row8 col6" >฿2.90</td>
#       <td id="T_d34d9_row8_col7" class="data row8 col7" >฿0.10</td>
#     </tr>
#     <tr>
#       <th id="T_d34d9_level0_row9" class="row_heading level0 row9" >DIF</th>
#       <th id="T_d34d9_level1_row9" class="row_heading level1 row9" >SET</th>
#       <td id="T_d34d9_row9_col0" class="data row9 col0

# %%
sql = '''
SELECT name, max_price AS max, min_price AS min, pe, pbv, daily_volume AS volume, beta, market
FROM stocks
'''
stocks = pd.read_sql(sql, conmy)
stocks.shape[0]
# Out:
# 253

# %%
filters = [
   (stocks.market.str.contains('SET50')),
   (stocks.market.str.contains('SET100'))]
values = ['SET50','SET100']
stocks["mrkt"] = np.select(filters, values, default='SET')

stocks["mrkt"].value_counts()
# Out:
# SET       153
# SET50      50
# SET100     50
# Name: mrkt, dtype: int64

# %%
stocks.stb.freq(["mrkt"]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a53b8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mrkt</th>
#       <th class="col_heading level0 col1" >count</th>
#       <th class="col_heading level0 col2" >percent</th>
#       <th class="col_heading level0 col3" >cumulative_count</th>
#       <th class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a53b8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a53b8_row0_col0" class="data row0 col0" >SET</td>
#       <td id="T_a53b8_row0_col1" class="data row0 col1" >153</td>
#       <td id="T_a53b8_row0_col2" class="data row0 col2" >60.474308</td>
#       <td id="T_a53b8_row0_col3" class="data row0 col3" >153</td>
#       <td id="T_a53b8_row0_col4" class="data row0 col4" >60.474308</td>
#     </tr>
#     <tr>
#       <th id="T_a53b8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a53b8_row1_col0" class="data row1 col0" >SET50</td>
#       <td id="T_a53b8_row1_col1" class="data row1 col1" >50</td>
#       <td id="T_a53b8_row1_col2" class="data row1 col2" >19.762846</td>
#       <td id="T_a53b8_row1_col3" class="data row1 col3" >203</td>
#       <td id="T_a53b8_row1_col4" class="data row1 col4" >80.237154</td>
#     </tr>
#     <tr>
#       <th id="T_a53b8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a53b8_row2_col0" class="data row2 col0" >SET100</td>
#       <td id="T_a53b8_row2_col1" class="data row2 col1" >50</td>
#       <td id="T_a53b8_row2_col2" class="data row2 col2" >19.762846</td>
#       <td id="T_a53b8_row2_col3" class="data row2 col3" >253</td>
#       <td id="T_a53b8_row2_col4" class="data row2 col4" >100.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_merge = pd.merge(sold_stocks, stocks, on='name', how='inner')
#df_merge.set_index('name', inplace=True)
df_merge.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a7725_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >sell_amt</th>
#       <th class="col_heading level0 col2" >buy_amt</th>
#       <th class="col_heading level0 col3" >qty</th>
#       <th class="col_heading level0 col4" >grs_profit</th>
#       <th class="col_heading level0 col5" >net_profit</th>
#       <th class="col_heading level0 col6" >sell_price</th>
#       <th class="col_heading level0 col7" >buy_price</th>
#       <th class="col_heading level0 col8" >diff</th>
#       <th class="col_heading level0 col9" >max</th>
#       <th class="col_heading level0 col10" >min</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >volume</th>
#       <th class="col_heading level0 col14" >beta</th>
#       <th class="col_heading level0 col15" >market</th>
#       <th class="col_heading level0 col16" >mrkt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7725_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a7725_row0_col0" class="data row0 col0" >AIMIRT</td>
#       <td id="T_a7725_row0_col1" class="data row0 col1" >฿127,000.00</td>
#       <td id="T_a7725_row0_col2" class="data row0 col2" >฿130,000.00</td>
#       <td id="T_a7725_row0_col3" class="data row0 col3" >10,000</td>
#       <td id="T_a7725_row0_col4" class="data row0 col4" >฿-3,000.00</td>
#       <td id="T_a7725_row0_col5" class="data row0 col5" >฿-3,569.23</td>
#       <td id="T_a7725_row0_col6" class="data row0 col6" >฿12.70</td>
#       <td id="T_a7725_row0_col7" class="data row0 col7" >฿13.00</td>
#       <td id="T_a7725_row0_col8" class="data row0 col8" >฿-0.30</td>
#       <td id="T_a7725_row0_col9" class="data row0 col9" >฿13.30</td>
#       <td id="T_a7725_row0_col10" class="data row0 col10" >฿11.70</td>
#       <td id="T_a7725_row0_col11" class="data row0 col11" >999.99</td>
#       <td id="T_a7725_row0_col12" class="data row0 col12" >0.98</td>
#       <td id="T_a7725_row0_col13" class="data row0 col13" >2.62</td>
#       <td id="T_a7725_row0_col14" class="data row0 col14" >0.11</td>
#       <td id="T_a7725_row0_col15" class="data row0 col15" >SET    </td>
#       <td id="T_a7725_row0_col16" class="data row0 col16" >SET</td>
#     </tr>
#     <tr>
#       <th id="T_a7725_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a7725_row1_col0" class="data row1 col0" >BANPU</td>
#       <td id="T_a7725_row1_col1" class="data row1 col1" >฿108,750.00</td>
#       <td id="T_a7725_row1_col2" class="data row1 col2" >฿105,000.00</td>
#       <td id="T_a7725_row1_col3" class="data row1 col3" >7,500</td>
#       <td id="T_a7725_row1_col4" class="data row1 col4" >฿3,750.00</td>
#       <td id="T_a7725_row1_col5" class="data row1 col5" >฿3,276.57</td>
#       <td id="T_a7725_row1_col6" class="data row1 col6" >฿14.50</td>
#       <td id="T_a7725_row1_col7" class="data row1 col7" >฿14.00</td>
#       <td id="T_a7725_row1_col8" class="data row1 col8" >฿0.50</td>
#       <td id="T_a7725_row1_col9" class="data row1 col9" >฿15.00</td>
#       <td id="T_a7725_row1_col10" class="data row1 col10" >฿10.50</td>
#       <td id="T_a7725_row1_col11" class="data row1 col11" >2.62</td>
#       <td id="T_a7725_row1_col12" class="data row1 col12" >1.04</td>
#       <td id="T_a7725_row1_col13" class="data row1 col13" >1,587.48</td>
#       <td id="T_a7725_row1_col14" class="data row1 col14" >0.76</td>
#       <td id="T_a7725_row1_col15" class="data row1 col15" >SET50 / SETCLMV / SETTHSI    </td>
#       <td id="T_a7725_row1_col16" class="data row1 col16" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_a7725_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a7725_row2_col0" class="data row2 col0" >BCH</td>
#       <td id="T_a7725_row2_col1" class="data row2 col1" >฿112,200.00</td>
#       <td id="T_a7725_row2_col2" class="data row2 col2" >฿117,000.00</td>
#       <td id="T_a7725_row2_col3" class="data row2 col3" >6,000</td>
#       <td id="T_a7725_row2_col4" class="data row2 col4" >฿-4,800.00</td>
#       <td id="T_a7725_row2_col5" class="data row2 col5" >฿-5,307.66</td>
#       <td id="T_a7725_row2_col6" class="data row2 col6" >฿18.70</td>
#       <td id="T_a7725_row2_col7" class="data row2 col7" >฿19.50</td>
#       <td id="T_a7725_row2_col8" class="data row2 col8" >฿-0.80</td>
#       <td id="T_a7725_row2_col9" class="data row2 col9" >฿23.10</td>
#       <td id="T_a7725_row2_col10" class="data row2 col10" >฿16.80</td>
#       <td id="T_a7725_row2_col11" class="data row2 col11" >9.74</td>
#       <td id="T_a7725_row2_col12" class="data row2 col12" >4.19</td>
#       <td id="T_a7725_row2_col13" class="data row2 col13" >376.16</td>
#       <td id="T_a7725_row2_col14" class="data row2 col14" >0.24</td>
#       <td id="T_a7725_row2_col15" class="data row2 col15" >SET100 / SETCLMV / SETHD / SETWB    </td>
#       <td id="T_a7725_row2_col16" class="data row2 col16" >SET100</td>
#     </tr>
#     <tr>
#       <th id="T_a7725_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a7725_row3_col0" class="data row3 col0" >BDMS</td>
#       <td id="T_a7725_row3_col1" class="data row3 col1" >฿111,600.00</td>
#       <td id="T_a7725_row3_col2" class="data row3 col2" >฿117,000.00</td>
#       <td id="T_a7725_row3_col3" class="data row3 col3" >4,500</td>
#       <td id="T_a7725_row3_col4" class="data row3 col4" >฿-5,400.00</td>
#       <td id="T_a7725_row3_col5" class="data row3 col5" >฿-5,906.32</td>
#       <td id="T_a7725_row3_col6" class="data row3 col6" >฿24.80</td>
#       <td id="T_a7725_row3_col7" class="data row3 col7" >฿26.00</td>
#       <td id="T_a7725_row3_col8" class="data row3 col8" >฿-1.20</td>
#       <td id="T_a7725_row3_col9" class="data row3 col9" >฿32.00</td>
#       <td id="T_a7725_row3_col10" class="data row3 col10" >฿21.50</td>
#       <td id="T_a7725_row3_col11" class="data row3 col11" >38.00</td>
#       <td id="T_a7725_row3_col12" class="data row3 col12" >5.36</td>
#       <td id="T_a7725_row3_col13" class="data row3 col13" >1,320.35</td>
#       <td id="T_a7725_row3_col14" class="data row3 col14" >0.42</td>
#       <td id="T_a7725_row3_col15" class="data row3 col15" >SET50 / SETCLMV / SETTHSI / SETWB    </td>
#       <td id="T_a7725_row3_col16" class="data row3 col16" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_a7725_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a7725_row4_col0" class="data row4 col0" >BGRIM</td>
#       <td id="T_a7725_row4_col1" class="data row4 col1" >฿297,000.00</td>
#       <td id="T_a7725_row4_col2" class="data row4 col2" >฿360,000.00</td>
#       <td id="T_a7725_row4_col3" class="data row4 col3" >9,000</td>
#       <td id="T_a7725_row4_col4" class="data row4 col4" >฿-63,000.00</td>
#       <td id="T_a7725_row4_col5" class="data row4 col5" >฿-64,455.19</td>
#       <td id="T_a7725_row4_col6" class="data row4 col6" >฿33.00</td>
#       <td id="T_a7725_row4_col7" class="data row4 col7" >฿40.00</td>
#       <td id="T_a7725_row4_col8" class="data row4 col8" >฿-7.00</td>
#       <td id="T_a7725_row4_col9" class="data row4 col9" >฿41.00</td>
#       <td id="T_a7725_row4_col10" class="data row4 col10" >฿29.75</td>
#       <td id="T_a7725_row4_col11" class="data row4 col11" >999.99</td>
#       <td id="T_a7725_row4_col12" class="data row4 col12" >3.29</td>
#       <td id="T_a7725_row4_col13" class="data row4 col13" >439.82</td>
#       <td id="T_a7725_row4_col14" class="data row4 col14" >1.31</td>
#       <td id="T_a7725_row4_col15" class="data row4 col15" >SET50 / SETCLMV / SETTHSI    </td>
#       <td id="T_a7725_row4_col16" class="data row4 col16" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_a7725_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a7725_row5_col0" class="data row5 col0" >BH</td>
#       <td id="T_a7725_row5_col1" class="data row5 col1" >฿110,000.00</td>
#       <td id="T_a7725_row5_col2" class="data row5 col2" >฿105,000.00</td>
#       <td id="T_a7725_row5_col3" class="data row5 col3"

# %%
df_merge.groupby(['mrkt'])[['grs_profit','net_profit']].sum().style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c6185_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >grs_profit</th>
#       <th class="col_heading level0 col1" >net_profit</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >mrkt</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6185_level0_row0" class="row_heading level0 row0" >SET</th>
#       <td id="T_c6185_row0_col0" class="data row0 col0" >฿-46,405.00</td>
#       <td id="T_c6185_row0_col1" class="data row0 col1" >฿-64,645.64</td>
#     </tr>
#     <tr>
#       <th id="T_c6185_level0_row1" class="row_heading level0 row1" >SET100</th>
#       <td id="T_c6185_row1_col0" class="data row1 col0" >฿-115,300.00</td>
#       <td id="T_c6185_row1_col1" class="data row1 col1" >฿-126,645.09</td>
#     </tr>
#     <tr>
#       <th id="T_c6185_level0_row2" class="row_heading level0 row2" >SET50</th>
#       <td id="T_c6185_row2_col0" class="data row2 col0" >฿12,013.00</td>
#       <td id="T_c6185_row2_col1" class="data row2 col1" >฿-10,122.64</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_merge.dtypes
# Out:
# name           object
# sell_amt      float64
# buy_amt       float64
# qty             int64
# grs_profit    float64
# net_profit    float64
# sell_price    float64
# buy_price     float64
# diff          float64
# max           float64
# min           float64
# pe            float64
# pbv           float64
# volume        float64
# beta          float64
# market         object
# mrkt           object
# dtype: object

# %%
set50 = df_merge.market.str.contains('SET50') 
flt_set50 = df_merge[set50]
flt_set50.sort_values(['name'],ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_88a33_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >sell_amt</th>
#       <th class="col_heading level0 col2" >buy_amt</th>
#       <th class="col_heading level0 col3" >qty</th>
#       <th class="col_heading level0 col4" >grs_profit</th>
#       <th class="col_heading level0 col5" >net_profit</th>
#       <th class="col_heading level0 col6" >sell_price</th>
#       <th class="col_heading level0 col7" >buy_price</th>
#       <th class="col_heading level0 col8" >diff</th>
#       <th class="col_heading level0 col9" >max</th>
#       <th class="col_heading level0 col10" >min</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >volume</th>
#       <th class="col_heading level0 col14" >beta</th>
#       <th class="col_heading level0 col15" >market</th>
#       <th class="col_heading level0 col16" >mrkt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88a33_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_88a33_row0_col0" class="data row0 col0" >BANPU</td>
#       <td id="T_88a33_row0_col1" class="data row0 col1" >฿108,750.00</td>
#       <td id="T_88a33_row0_col2" class="data row0 col2" >฿105,000.00</td>
#       <td id="T_88a33_row0_col3" class="data row0 col3" >7,500</td>
#       <td id="T_88a33_row0_col4" class="data row0 col4" >฿3,750.00</td>
#       <td id="T_88a33_row0_col5" class="data row0 col5" >฿3,276.57</td>
#       <td id="T_88a33_row0_col6" class="data row0 col6" >฿14.50</td>
#       <td id="T_88a33_row0_col7" class="data row0 col7" >฿14.00</td>
#       <td id="T_88a33_row0_col8" class="data row0 col8" >฿0.50</td>
#       <td id="T_88a33_row0_col9" class="data row0 col9" >฿15.00</td>
#       <td id="T_88a33_row0_col10" class="data row0 col10" >฿10.50</td>
#       <td id="T_88a33_row0_col11" class="data row0 col11" >2.62</td>
#       <td id="T_88a33_row0_col12" class="data row0 col12" >1.04</td>
#       <td id="T_88a33_row0_col13" class="data row0 col13" >1,587.48</td>
#       <td id="T_88a33_row0_col14" class="data row0 col14" >0.76</td>
#       <td id="T_88a33_row0_col15" class="data row0 col15" >SET50 / SETCLMV / SETTHSI    </td>
#       <td id="T_88a33_row0_col16" class="data row0 col16" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_88a33_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_88a33_row1_col0" class="data row1 col0" >BDMS</td>
#       <td id="T_88a33_row1_col1" class="data row1 col1" >฿111,600.00</td>
#       <td id="T_88a33_row1_col2" class="data row1 col2" >฿117,000.00</td>
#       <td id="T_88a33_row1_col3" class="data row1 col3" >4,500</td>
#       <td id="T_88a33_row1_col4" class="data row1 col4" >฿-5,400.00</td>
#       <td id="T_88a33_row1_col5" class="data row1 col5" >฿-5,906.32</td>
#       <td id="T_88a33_row1_col6" class="data row1 col6" >฿24.80</td>
#       <td id="T_88a33_row1_col7" class="data row1 col7" >฿26.00</td>
#       <td id="T_88a33_row1_col8" class="data row1 col8" >฿-1.20</td>
#       <td id="T_88a33_row1_col9" class="data row1 col9" >฿32.00</td>
#       <td id="T_88a33_row1_col10" class="data row1 col10" >฿21.50</td>
#       <td id="T_88a33_row1_col11" class="data row1 col11" >38.00</td>
#       <td id="T_88a33_row1_col12" class="data row1 col12" >5.36</td>
#       <td id="T_88a33_row1_col13" class="data row1 col13" >1,320.35</td>
#       <td id="T_88a33_row1_col14" class="data row1 col14" >0.42</td>
#       <td id="T_88a33_row1_col15" class="data row1 col15" >SET50 / SETCLMV / SETTHSI / SETWB    </td>
#       <td id="T_88a33_row1_col16" class="data row1 col16" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_88a33_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_88a33_row2_col0" class="data row2 col0" >BGRIM</td>
#       <td id="T_88a33_row2_col1" class="data row2 col1" >฿297,000.00</td>
#       <td id="T_88a33_row2_col2" class="data row2 col2" >฿360,000.00</td>
#       <td id="T_88a33_row2_col3" class="data row2 col3" >9,000</td>
#       <td id="T_88a33_row2_col4" class="data row2 col4" >฿-63,000.00</td>
#       <td id="T_88a33_row2_col5" class="data row2 col5" >฿-64,455.19</td>
#       <td id="T_88a33_row2_col6" class="data row2 col6" >฿33.00</td>
#       <td id="T_88a33_row2_col7" class="data row2 col7" >฿40.00</td>
#       <td id="T_88a33_row2_col8" class="data row2 col8" >฿-7.00</td>
#       <td id="T_88a33_row2_col9" class="data row2 col9" >฿41.00</td>
#       <td id="T_88a33_row2_col10" class="data row2 col10" >฿29.75</td>
#       <td id="T_88a33_row2_col11" class="data row2 col11" >999.99</td>
#       <td id="T_88a33_row2_col12" class="data row2 col12" >3.29</td>
#       <td id="T_88a33_row2_col13" class="data row2 col13" >439.82</td>
#       <td id="T_88a33_row2_col14" class="data row2 col14" >1.31</td>
#       <td id="T_88a33_row2_col15" class="data row2 col15" >SET50 / SETCLMV / SETTHSI    </td>
#       <td id="T_88a33_row2_col16" class="data row2 col16" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_88a33_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_88a33_row3_col0" class="data row3 col0" >BH</td>
#       <td id="T_88a33_row3_col1" class="data row3 col1" >฿110,000.00</td>
#       <td id="T_88a33_row3_col2" class="data row3 col2" >฿105,000.00</td>
#       <td id="T_88a33_row3_col3" class="data row3 col3" >500</td>
#       <td id="T_88a33_row3_col4" class="data row3 col4" >฿5,000.00</td>
#       <td id="T_88a33_row3_col5" class="data row3 col5" >฿4,523.80</td>
#       <td id="T_88a33_row3_col6" class="data row3 col6" >฿220.00</td>
#       <td id="T_88a33_row3_col7" class="data row3 col7" >฿210.00</td>
#       <td id="T_88a33_row3_col8" class="data row3 col8" >฿10.00</td>
#       <td id="T_88a33_row3_col9" class="data row3 col9" >฿241.00</td>
#       <td id="T_88a33_row3_col10" class="data row3 col10" >฿132.50</td>
#       <td id="T_88a33_row3_col11" class="data row3 col11" >42.13</td>
#       <td id="T_88a33_row3_col12" class="data row3 col12" >9.33</td>
#       <td id="T_88a33_row3_col13" class="data row3 col13" >904.71</td>
#       <td id="T_88a33_row3_col14" class="data row3 col14" >0.50</td>
#       <td id="T_88a33_row3_col15" class="data row3 col15" >SET50 / SETCLMV / SETWB    </td>
#       <td id="T_88a33_row3_col16" class="data row3 col16" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_88a33_level0_row4" class="row_heading level0 row4" >12</th>
#       <td id="T_88a33_row4_col0" class="data row4 col0" >GLOBAL</td>
#       <td id="T_88a33_row4_col1" class="data row4 col1" >฿482,400.00</td>
#       <td id="T_88a33_row4_col2" class="data row4 col2" >฿456,600.00</td>
#       <td id="T_88a33_row4_col3" class="data row4 col3" >24,000</td>
#       <td id="T_88a33_row4_col4" class="data row4 col4" >฿25,800.00</td>
#       <td id="T_88a33_row4_col5" class="data row4 col5" >฿23,720.19</td>
#       <td id="T_88a33_row4_col6" class="data row4 col6" >฿20.10</td>
#       <td id="T_88a33_row4_col7" class="data row4 col7" >฿19.02</td>
#       <td id="T_88a33_row4_col8" class="data row4 col8" >฿1.08</td>
#       <td id="T_88a33_row4_col9" class="data row4 col9" >฿23.70</td>
#       <td id="T_88a33_row4_col10" class="data row4 col10" >฿16.80</td>
#       <td id="T_88a33_row4_col11" class="data row4 col11" >29.02</td>
#       <td id="T_88a33_row4_col12" class="data row4 col12" >5.04</td>
#       <td id="T_88a33_row4_col13" class="data row4 col13" >231.75</td>
#       <td id="T_88a33_row4_col14" class="data row4 col14" >1.06</td>
#       <td id="T_88a33_row4_col15" class="data row4 col15" >SET50 / SETCLMV / SETTHSI / SETWB    </td>
#       <td id="T_88a33_row4_col16" class="data row4 col16" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_88a33_level0_row5" class="row_heading level0 row5" >15</th>
#       <td id="T_88a33_row5_col0" class="data row5 col0" >IVL</td>
#       <td id="T_88a33_row5_col1" class="data row5 col1" >฿1,129,350.00</td>
#       <td id="T_88a33_row5_col2" class="data row5 col2" >฿1,047,000.00</td>
#       <td id="T_88a33_row5_

# %%
prf_set50 = flt_set50.grs_profit.sum()
net_set50 = flt_set50.net_profit.sum()
prf_set50,net_set50
# Out:
# (12013.0, -10122.64)

# %%
array = pd.Series([prf_set50,net_set50])
array = array.map('฿{:,.2f}'.format)
for value in array:
    print(f"The value is: {value}")
# Out:
# The value is: ฿12,013.00
# The value is: ฿-10,122.64

# %%
set100 = df_merge.market.str.contains('SET100') 
flt_set100 = df_merge[set100]
flt_set100.sort_values(['name'],ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a7652_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >sell_amt</th>
#       <th class="col_heading level0 col2" >buy_amt</th>
#       <th class="col_heading level0 col3" >qty</th>
#       <th class="col_heading level0 col4" >grs_profit</th>
#       <th class="col_heading level0 col5" >net_profit</th>
#       <th class="col_heading level0 col6" >sell_price</th>
#       <th class="col_heading level0 col7" >buy_price</th>
#       <th class="col_heading level0 col8" >diff</th>
#       <th class="col_heading level0 col9" >max</th>
#       <th class="col_heading level0 col10" >min</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >volume</th>
#       <th class="col_heading level0 col14" >beta</th>
#       <th class="col_heading level0 col15" >market</th>
#       <th class="col_heading level0 col16" >mrkt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7652_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_a7652_row0_col0" class="data row0 col0" >BCH</td>
#       <td id="T_a7652_row0_col1" class="data row0 col1" >฿112,200.00</td>
#       <td id="T_a7652_row0_col2" class="data row0 col2" >฿117,000.00</td>
#       <td id="T_a7652_row0_col3" class="data row0 col3" >6,000</td>
#       <td id="T_a7652_row0_col4" class="data row0 col4" >฿-4,800.00</td>
#       <td id="T_a7652_row0_col5" class="data row0 col5" >฿-5,307.66</td>
#       <td id="T_a7652_row0_col6" class="data row0 col6" >฿18.70</td>
#       <td id="T_a7652_row0_col7" class="data row0 col7" >฿19.50</td>
#       <td id="T_a7652_row0_col8" class="data row0 col8" >฿-0.80</td>
#       <td id="T_a7652_row0_col9" class="data row0 col9" >฿23.10</td>
#       <td id="T_a7652_row0_col10" class="data row0 col10" >฿16.80</td>
#       <td id="T_a7652_row0_col11" class="data row0 col11" >9.74</td>
#       <td id="T_a7652_row0_col12" class="data row0 col12" >4.19</td>
#       <td id="T_a7652_row0_col13" class="data row0 col13" >376.16</td>
#       <td id="T_a7652_row0_col14" class="data row0 col14" >0.24</td>
#       <td id="T_a7652_row0_col15" class="data row0 col15" >SET100 / SETCLMV / SETHD / SETWB    </td>
#       <td id="T_a7652_row0_col16" class="data row0 col16" >SET100</td>
#     </tr>
#     <tr>
#       <th id="T_a7652_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_a7652_row1_col0" class="data row1 col0" >CKP</td>
#       <td id="T_a7652_row1_col1" class="data row1 col1" >฿157,000.00</td>
#       <td id="T_a7652_row1_col2" class="data row1 col2" >฿150,000.00</td>
#       <td id="T_a7652_row1_col3" class="data row1 col3" >30,000</td>
#       <td id="T_a7652_row1_col4" class="data row1 col4" >฿7,000.00</td>
#       <td id="T_a7652_row1_col5" class="data row1 col5" >฿6,320.02</td>
#       <td id="T_a7652_row1_col6" class="data row1 col6" >฿5.23</td>
#       <td id="T_a7652_row1_col7" class="data row1 col7" >฿5.00</td>
#       <td id="T_a7652_row1_col8" class="data row1 col8" >฿0.23</td>
#       <td id="T_a7652_row1_col9" class="data row1 col9" >฿5.90</td>
#       <td id="T_a7652_row1_col10" class="data row1 col10" >฿4.52</td>
#       <td id="T_a7652_row1_col11" class="data row1 col11" >14.91</td>
#       <td id="T_a7652_row1_col12" class="data row1 col12" >1.45</td>
#       <td id="T_a7652_row1_col13" class="data row1 col13" >82.32</td>
#       <td id="T_a7652_row1_col14" class="data row1 col14" >1.06</td>
#       <td id="T_a7652_row1_col15" class="data row1 col15" >SET100 / SETCLMV / SETTHSI    </td>
#       <td id="T_a7652_row1_col16" class="data row1 col16" >SET100</td>
#     </tr>
#     <tr>
#       <th id="T_a7652_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_a7652_row2_col0" class="data row2 col0" >DOHOME</td>
#       <td id="T_a7652_row2_col1" class="data row2 col1" >฿310,320.00</td>
#       <td id="T_a7652_row2_col2" class="data row2 col2" >฿342,720.00</td>
#       <td id="T_a7652_row2_col3" class="data row2 col3" >16,800</td>
#       <td id="T_a7652_row2_col4" class="data row2 col4" >฿-32,400.00</td>
#       <td id="T_a7652_row2_col5" class="data row2 col5" >฿-33,846.40</td>
#       <td id="T_a7652_row2_col6" class="data row2 col6" >฿18.47</td>
#       <td id="T_a7652_row2_col7" class="data row2 col7" >฿20.40</td>
#       <td id="T_a7652_row2_col8" class="data row2 col8" >฿-1.93</td>
#       <td id="T_a7652_row2_col9" class="data row2 col9" >฿23.30</td>
#       <td id="T_a7652_row2_col10" class="data row2 col10" >฿12.20</td>
#       <td id="T_a7652_row2_col11" class="data row2 col11" >37.14</td>
#       <td id="T_a7652_row2_col12" class="data row2 col12" >3.69</td>
#       <td id="T_a7652_row2_col13" class="data row2 col13" >176.99</td>
#       <td id="T_a7652_row2_col14" class="data row2 col14" >1.34</td>
#       <td id="T_a7652_row2_col15" class="data row2 col15" >SET100 / SETWB    </td>
#       <td id="T_a7652_row2_col16" class="data row2 col16" >SET100</td>
#     </tr>
#     <tr>
#       <th id="T_a7652_level0_row3" class="row_heading level0 row3" >11</th>
#       <td id="T_a7652_row3_col0" class="data row3 col0" >EPG</td>
#       <td id="T_a7652_row3_col1" class="data row3 col1" >฿271,800.00</td>
#       <td id="T_a7652_row3_col2" class="data row3 col2" >฿284,000.00</td>
#       <td id="T_a7652_row3_col3" class="data row3 col3" >26,000</td>
#       <td id="T_a7652_row3_col4" class="data row3 col4" >฿-12,200.00</td>
#       <td id="T_a7652_row3_col5" class="data row3 col5" >฿-13,431.04</td>
#       <td id="T_a7652_row3_col6" class="data row3 col6" >฿10.45</td>
#       <td id="T_a7652_row3_col7" class="data row3 col7" >฿10.92</td>
#       <td id="T_a7652_row3_col8" class="data row3 col8" >฿-0.47</td>
#       <td id="T_a7652_row3_col9" class="data row3 col9" >฿12.60</td>
#       <td id="T_a7652_row3_col10" class="data row3 col10" >฿8.60</td>
#       <td id="T_a7652_row3_col11" class="data row3 col11" >20.52</td>
#       <td id="T_a7652_row3_col12" class="data row3 col12" >2.32</td>
#       <td id="T_a7652_row3_col13" class="data row3 col13" >76.00</td>
#       <td id="T_a7652_row3_col14" class="data row3 col14" >1.24</td>
#       <td id="T_a7652_row3_col15" class="data row3 col15" >SET100 / SETTHSI    </td>
#       <td id="T_a7652_row3_col16" class="data row3 col16" >SET100</td>
#     </tr>
#     <tr>
#       <th id="T_a7652_level0_row4" class="row_heading level0 row4" >21</th>
#       <td id="T_a7652_row4_col0" class="data row4 col0" >MEGA</td>
#       <td id="T_a7652_row4_col1" class="data row4 col1" >฿259,500.00</td>
#       <td id="T_a7652_row4_col2" class="data row4 col2" >฿258,000.00</td>
#       <td id="T_a7652_row4_col3" class="data row4 col3" >6,000</td>
#       <td id="T_a7652_row4_col4" class="data row4 col4" >฿1,500.00</td>
#       <td id="T_a7652_row4_col5" class="data row4 col5" >฿353.79</td>
#       <td id="T_a7652_row4_col6" class="data row4 col6" >฿43.25</td>
#       <td id="T_a7652_row4_col7" class="data row4 col7" >฿43.00</td>
#       <td id="T_a7652_row4_col8" class="data row4 col8" >฿0.25</td>
#       <td id="T_a7652_row4_col9" class="data row4 col9" >฿55.25</td>
#       <td id="T_a7652_row4_col10" class="data row4 col10" >฿40.25</td>
#       <td id="T_a7652_row4_col11" class="data row4 col11" >17.43</td>
#       <td id="T_a7652_row4_col12" class="data row4 col12" >4.78</td>
#       <td id="T_a7652_row4_col13" class="data row4 col13" >163.93</td>
#       <td id="T_a7652_row4_col14" class="data row4 col14" >1.08</td>
#       <td id="T_a7652_row4_col15" class="data row4 col15" >SET100 / SETCLMV / SETWB    </td>
#       <td id="T_a7652_row4_col16" class="data row4 col16" >SET100</td>
#     </tr>
#     <tr>
#       <th id="T_a7652_level0_row5" class="row_heading level0 row5" >27</th>
#       <td id="T_a7652_row5_col0" class="data row5 col0" >RATCH</td>
#       <td id="T_a7652_row5_col1" class="data row5 col1" >฿372,500.00</td>
#       <td id="T_a7652_row5_col2" class="data row5 col2" >฿411,750.00</td>
#       <td id="T_a7652_row5_col3" class="data row5 col3" >9,000</

# %%
prf_set100 = flt_set100.grs_profit.sum()
net_set100 = flt_set100.net_profit.sum()
prf_set100,net_set100
# Out:
# (-115300.0, -126645.08999999998)

# %%
array = pd.Series([prf_set100,net_set100])
array = array.map('฿{:,.2f}'.format)
for value in array:
    print(f"The value is: {value}")
# Out:
# The value is: ฿-115,300.00
# The value is: ฿-126,645.09

# %%
flt_set = df_merge[~(set100 | set50)]
flt_set.sort_values(['name'],ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_eac44_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >sell_amt</th>
#       <th class="col_heading level0 col2" >buy_amt</th>
#       <th class="col_heading level0 col3" >qty</th>
#       <th class="col_heading level0 col4" >grs_profit</th>
#       <th class="col_heading level0 col5" >net_profit</th>
#       <th class="col_heading level0 col6" >sell_price</th>
#       <th class="col_heading level0 col7" >buy_price</th>
#       <th class="col_heading level0 col8" >diff</th>
#       <th class="col_heading level0 col9" >max</th>
#       <th class="col_heading level0 col10" >min</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >volume</th>
#       <th class="col_heading level0 col14" >beta</th>
#       <th class="col_heading level0 col15" >market</th>
#       <th class="col_heading level0 col16" >mrkt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eac44_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eac44_row0_col0" class="data row0 col0" >AIMIRT</td>
#       <td id="T_eac44_row0_col1" class="data row0 col1" >฿127,000.00</td>
#       <td id="T_eac44_row0_col2" class="data row0 col2" >฿130,000.00</td>
#       <td id="T_eac44_row0_col3" class="data row0 col3" >10,000</td>
#       <td id="T_eac44_row0_col4" class="data row0 col4" >฿-3,000.00</td>
#       <td id="T_eac44_row0_col5" class="data row0 col5" >฿-3,569.23</td>
#       <td id="T_eac44_row0_col6" class="data row0 col6" >฿12.70</td>
#       <td id="T_eac44_row0_col7" class="data row0 col7" >฿13.00</td>
#       <td id="T_eac44_row0_col8" class="data row0 col8" >฿-0.30</td>
#       <td id="T_eac44_row0_col9" class="data row0 col9" >฿13.30</td>
#       <td id="T_eac44_row0_col10" class="data row0 col10" >฿11.70</td>
#       <td id="T_eac44_row0_col11" class="data row0 col11" >999.99</td>
#       <td id="T_eac44_row0_col12" class="data row0 col12" >0.98</td>
#       <td id="T_eac44_row0_col13" class="data row0 col13" >2.62</td>
#       <td id="T_eac44_row0_col14" class="data row0 col14" >0.11</td>
#       <td id="T_eac44_row0_col15" class="data row0 col15" >SET    </td>
#       <td id="T_eac44_row0_col16" class="data row0 col16" >SET</td>
#     </tr>
#     <tr>
#       <th id="T_eac44_level0_row1" class="row_heading level0 row1" >7</th>
#       <td id="T_eac44_row1_col0" class="data row1 col0" >CPNCG</td>
#       <td id="T_eac44_row1_col1" class="data row1 col1" >฿242,000.00</td>
#       <td id="T_eac44_row1_col2" class="data row1 col2" >฿248,000.00</td>
#       <td id="T_eac44_row1_col3" class="data row1 col3" >20,000</td>
#       <td id="T_eac44_row1_col4" class="data row1 col4" >฿-6,000.00</td>
#       <td id="T_eac44_row1_col5" class="data row1 col5" >฿-7,085.31</td>
#       <td id="T_eac44_row1_col6" class="data row1 col6" >฿12.10</td>
#       <td id="T_eac44_row1_col7" class="data row1 col7" >฿12.40</td>
#       <td id="T_eac44_row1_col8" class="data row1 col8" >฿-0.30</td>
#       <td id="T_eac44_row1_col9" class="data row1 col9" >฿12.70</td>
#       <td id="T_eac44_row1_col10" class="data row1 col10" >฿10.40</td>
#       <td id="T_eac44_row1_col11" class="data row1 col11" >999.99</td>
#       <td id="T_eac44_row1_col12" class="data row1 col12" >1.01</td>
#       <td id="T_eac44_row1_col13" class="data row1 col13" >2.50</td>
#       <td id="T_eac44_row1_col14" class="data row1 col14" >0.37</td>
#       <td id="T_eac44_row1_col15" class="data row1 col15" >SET    </td>
#       <td id="T_eac44_row1_col16" class="data row1 col16" >SET</td>
#     </tr>
#     <tr>
#       <th id="T_eac44_level0_row2" class="row_heading level0 row2" >8</th>
#       <td id="T_eac44_row2_col0" class="data row2 col0" >DCC</td>
#       <td id="T_eac44_row2_col1" class="data row2 col1" >฿120,000.00</td>
#       <td id="T_eac44_row2_col2" class="data row2 col2" >฿116,000.00</td>
#       <td id="T_eac44_row2_col3" class="data row2 col3" >40,000</td>
#       <td id="T_eac44_row2_col4" class="data row2 col4" >฿4,000.00</td>
#       <td id="T_eac44_row2_col5" class="data row2 col5" >฿3,477.28</td>
#       <td id="T_eac44_row2_col6" class="data row2 col6" >฿3.00</td>
#       <td id="T_eac44_row2_col7" class="data row2 col7" >฿2.90</td>
#       <td id="T_eac44_row2_col8" class="data row2 col8" >฿0.10</td>
#       <td id="T_eac44_row2_col9" class="data row2 col9" >฿3.18</td>
#       <td id="T_eac44_row2_col10" class="data row2 col10" >฿2.58</td>
#       <td id="T_eac44_row2_col11" class="data row2 col11" >15.35</td>
#       <td id="T_eac44_row2_col12" class="data row2 col12" >4.40</td>
#       <td id="T_eac44_row2_col13" class="data row2 col13" >35.29</td>
#       <td id="T_eac44_row2_col14" class="data row2 col14" >0.59</td>
#       <td id="T_eac44_row2_col15" class="data row2 col15" >SET    </td>
#       <td id="T_eac44_row2_col16" class="data row2 col16" >SET</td>
#     </tr>
#     <tr>
#       <th id="T_eac44_level0_row3" class="row_heading level0 row3" >9</th>
#       <td id="T_eac44_row3_col0" class="data row3 col0" >DIF</td>
#       <td id="T_eac44_row3_col1" class="data row3 col1" >฿278,000.00</td>
#       <td id="T_eac44_row3_col2" class="data row3 col2" >฿294,000.00</td>
#       <td id="T_eac44_row3_col3" class="data row3 col3" >20,000</td>
#       <td id="T_eac44_row3_col4" class="data row3 col4" >฿-16,000.00</td>
#       <td id="T_eac44_row3_col5" class="data row3 col5" >฿-17,266.92</td>
#       <td id="T_eac44_row3_col6" class="data row3 col6" >฿13.90</td>
#       <td id="T_eac44_row3_col7" class="data row3 col7" >฿14.70</td>
#       <td id="T_eac44_row3_col8" class="data row3 col8" >฿-0.80</td>
#       <td id="T_eac44_row3_col9" class="data row3 col9" >฿14.50</td>
#       <td id="T_eac44_row3_col10" class="data row3 col10" >฿13.00</td>
#       <td id="T_eac44_row3_col11" class="data row3 col11" >999.99</td>
#       <td id="T_eac44_row3_col12" class="data row3 col12" >0.79</td>
#       <td id="T_eac44_row3_col13" class="data row3 col13" >180.59</td>
#       <td id="T_eac44_row3_col14" class="data row3 col14" >0.28</td>
#       <td id="T_eac44_row3_col15" class="data row3 col15" >SET    </td>
#       <td id="T_eac44_row3_col16" class="data row3 col16" >SET</td>
#     </tr>
#     <tr>
#       <th id="T_eac44_level0_row4" class="row_heading level0 row4" >13</th>
#       <td id="T_eac44_row4_col0" class="data row4 col0" >IMH</td>
#       <td id="T_eac44_row4_col1" class="data row4 col1" >฿357,300.00</td>
#       <td id="T_eac44_row4_col2" class="data row4 col2" >฿308,000.00</td>
#       <td id="T_eac44_row4_col3" class="data row4 col3" >19,000</td>
#       <td id="T_eac44_row4_col4" class="data row4 col4" >฿49,300.00</td>
#       <td id="T_eac44_row4_col5" class="data row4 col5" >฿47,826.43</td>
#       <td id="T_eac44_row4_col6" class="data row4 col6" >฿18.81</td>
#       <td id="T_eac44_row4_col7" class="data row4 col7" >฿16.21</td>
#       <td id="T_eac44_row4_col8" class="data row4 col8" >฿2.59</td>
#       <td id="T_eac44_row4_col9" class="data row4 col9" >฿23.30</td>
#       <td id="T_eac44_row4_col10" class="data row4 col10" >฿10.80</td>
#       <td id="T_eac44_row4_col11" class="data row4 col11" >7.51</td>
#       <td id="T_eac44_row4_col12" class="data row4 col12" >3.08</td>
#       <td id="T_eac44_row4_col13" class="data row4 col13" >39.90</td>
#       <td id="T_eac44_row4_col14" class="data row4 col14" >0.46</td>
#       <td id="T_eac44_row4_col15" class="data row4 col15" >mai    </td>
#       <td id="T_eac44_row4_col16" class="data row4 col16" >SET</td>
#     </tr>
#     <tr>
#       <th id="T_eac44_level0_row5" class="row_heading level0 row5" >14</th>
#       <td id="T_eac44_row5_col0" class="data row5 col0" >IP</td>
#       <td id="T_eac44_row5_col1" class="data row5 col1" >฿218,250.00</td>
#       <td id="T_eac44_row5_col2" class="data row5 col2" >฿212,100.00</td>
#       <td id="T_eac44_row5_col3" class="data row5 col3" >10,500</td>
#       <td id="T_eac44_row5_col4" class="data row5 col4" >฿6,150.00</td>
#       <td id="T_eac44_row5_col5" cl

# %%
prf_set = flt_set.grs_profit.sum()
net_set = flt_set.net_profit.sum()
prf_set,net_set
# Out:
# (-46405.0, -64645.64000000001)

# %%
array = pd.Series([prf_set,net_set])
array = array.map('฿{:,.2f}'.format)
for value in array:
    print(f"The value is: {value}")
# Out:
# The value is: ฿-46,405.00
# The value is: ฿-64,645.64

# %% [markdown]
# ### Input to Excel

# %%
pct_set50 = round(prf_set50 / ttl_prf * 100,2)
pct_set100 = round(prf_set100 / ttl_prf * 100,2)
pct_set  = round(prf_set  / ttl_prf * 100,2)
pct_set50, pct_set100, pct_set
# Out:
# (-8.03, 77.02, 31.0)

# %% [markdown]
# ### Start of Balance process

# %%
sql = '''
SELECT name, volbuy, price, volbuy * price AS cost_amt
FROM buy
WHERE active = 1 
ORDER BY name
'''
#AND period IN ("3","4")
total_buy = pd.read_sql(sql, const)
total_buy['volbuy'] = total_buy['volbuy'].astype(int)
total_buy.sample(5).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2ef03_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >volbuy</th>
#       <th class="col_heading level0 col2" >price</th>
#       <th class="col_heading level0 col3" >cost_amt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ef03_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_2ef03_row0_col0" class="data row0 col0" >KCE</td>
#       <td id="T_2ef03_row0_col1" class="data row0 col1" >14,000</td>
#       <td id="T_2ef03_row0_col2" class="data row0 col2" >฿72.75</td>
#       <td id="T_2ef03_row0_col3" class="data row0 col3" >฿1,018,500.00</td>
#     </tr>
#     <tr>
#       <th id="T_2ef03_level0_row1" class="row_heading level0 row1" >14</th>
#       <td id="T_2ef03_row1_col0" class="data row1 col0" >ORI</td>
#       <td id="T_2ef03_row1_col1" class="data row1 col1" >45,000</td>
#       <td id="T_2ef03_row1_col2" class="data row1 col2" >฿11.00</td>
#       <td id="T_2ef03_row1_col3" class="data row1 col3" >฿495,000.00</td>
#     </tr>
#     <tr>
#       <th id="T_2ef03_level0_row2" class="row_heading level0 row2" >13</th>
#       <td id="T_2ef03_row2_col0" class="data row2 col0" >NER</td>
#       <td id="T_2ef03_row2_col1" class="data row2 col1" >27,000</td>
#       <td id="T_2ef03_row2_col2" class="data row2 col2" >฿7.45</td>
#       <td id="T_2ef03_row2_col3" class="data row2 col3" >฿201,150.00</td>
#     </tr>
#     <tr>
#       <th id="T_2ef03_level0_row3" class="row_heading level0 row3" >23</th>
#       <td id="T_2ef03_row3_col0" class="data row3 col0" >TMT</td>
#       <td id="T_2ef03_row3_col1" class="data row3 col1" >36,000</td>
#       <td id="T_2ef03_row3_col2" class="data row3 col2" >฿10.20</td>
#       <td id="T_2ef03_row3_col3" class="data row3 col3" >฿367,200.00</td>
#     </tr>
#     <tr>
#       <th id="T_2ef03_level0_row4" class="row_heading level0 row4" >18</th>
#       <td id="T_2ef03_row4_col0" class="data row4 col0" >SCCC</td>
#       <td id="T_2ef03_row4_col1" class="data row4 col1" >1,200</td>
#       <td id="T_2ef03_row4_col2" class="data row4 col2" >฿171.00</td>
#       <td id="T_2ef03_row4_col3" class="data row4 col3" >฿205,200.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
total_stocks = pd.merge(total_buy, stocks, on='name', how='inner')
total_stocks.sample(5).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a1ee8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >volbuy</th>
#       <th class="col_heading level0 col2" >price</th>
#       <th class="col_heading level0 col3" >cost_amt</th>
#       <th class="col_heading level0 col4" >max</th>
#       <th class="col_heading level0 col5" >min</th>
#       <th class="col_heading level0 col6" >pe</th>
#       <th class="col_heading level0 col7" >pbv</th>
#       <th class="col_heading level0 col8" >volume</th>
#       <th class="col_heading level0 col9" >beta</th>
#       <th class="col_heading level0 col10" >market</th>
#       <th class="col_heading level0 col11" >mrkt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1ee8_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_a1ee8_row0_col0" class="data row0 col0" >BCH</td>
#       <td id="T_a1ee8_row0_col1" class="data row0 col1" >15,000</td>
#       <td id="T_a1ee8_row0_col2" class="data row0 col2" >฿21.46</td>
#       <td id="T_a1ee8_row0_col3" class="data row0 col3" >฿321,900.00</td>
#       <td id="T_a1ee8_row0_col4" class="data row0 col4" >฿23.10</td>
#       <td id="T_a1ee8_row0_col5" class="data row0 col5" >฿16.80</td>
#       <td id="T_a1ee8_row0_col6" class="data row0 col6" >9.74</td>
#       <td id="T_a1ee8_row0_col7" class="data row0 col7" >4.19</td>
#       <td id="T_a1ee8_row0_col8" class="data row0 col8" >376.16</td>
#       <td id="T_a1ee8_row0_col9" class="data row0 col9" >0.24</td>
#       <td id="T_a1ee8_row0_col10" class="data row0 col10" >SET100 / SETCLMV / SETHD / SETWB    </td>
#       <td id="T_a1ee8_row0_col11" class="data row0 col11" >SET100</td>
#     </tr>
#     <tr>
#       <th id="T_a1ee8_level0_row1" class="row_heading level0 row1" >24</th>
#       <td id="T_a1ee8_row1_col0" class="data row1 col0" >WHAIR</td>
#       <td id="T_a1ee8_row1_col1" class="data row1 col1" >40,000</td>
#       <td id="T_a1ee8_row1_col2" class="data row1 col2" >฿8.95</td>
#       <td id="T_a1ee8_row1_col3" class="data row1 col3" >฿358,000.00</td>
#       <td id="T_a1ee8_row1_col4" class="data row1 col4" >฿9.06</td>
#       <td id="T_a1ee8_row1_col5" class="data row1 col5" >฿7.02</td>
#       <td id="T_a1ee8_row1_col6" class="data row1 col6" >999.99</td>
#       <td id="T_a1ee8_row1_col7" class="data row1 col7" >0.81</td>
#       <td id="T_a1ee8_row1_col8" class="data row1 col8" >3.77</td>
#       <td id="T_a1ee8_row1_col9" class="data row1 col9" >0.26</td>
#       <td id="T_a1ee8_row1_col10" class="data row1 col10" >SET    </td>
#       <td id="T_a1ee8_row1_col11" class="data row1 col11" >SET</td>
#     </tr>
#     <tr>
#       <th id="T_a1ee8_level0_row2" class="row_heading level0 row2" >11</th>
#       <td id="T_a1ee8_row2_col0" class="data row2 col0" >MAKRO</td>
#       <td id="T_a1ee8_row2_col1" class="data row2 col1" >7,500</td>
#       <td id="T_a1ee8_row2_col2" class="data row2 col2" >฿40.40</td>
#       <td id="T_a1ee8_row2_col3" class="data row2 col3" >฿303,000.00</td>
#       <td id="T_a1ee8_row2_col4" class="data row2 col4" >฿43.75</td>
#       <td id="T_a1ee8_row2_col5" class="data row2 col5" >฿32.00</td>
#       <td id="T_a1ee8_row2_col6" class="data row2 col6" >29.56</td>
#       <td id="T_a1ee8_row2_col7" class="data row2 col7" >1.47</td>
#       <td id="T_a1ee8_row2_col8" class="data row2 col8" >445.45</td>
#       <td id="T_a1ee8_row2_col9" class="data row2 col9" >1.16</td>
#       <td id="T_a1ee8_row2_col10" class="data row2 col10" >SET    </td>
#       <td id="T_a1ee8_row2_col11" class="data row2 col11" >SET</td>
#     </tr>
#     <tr>
#       <th id="T_a1ee8_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_a1ee8_row3_col0" class="data row3 col0" >GFPT</td>
#       <td id="T_a1ee8_row3_col1" class="data row3 col1" >7,500</td>
#       <td id="T_a1ee8_row3_col2" class="data row3 col2" >฿12.50</td>
#       <td id="T_a1ee8_row3_col3" class="data row3 col3" >฿93,750.00</td>
#       <td id="T_a1ee8_row3_col4" class="data row3 col4" >฿18.70</td>
#       <td id="T_a1ee8_row3_col5" class="data row3 col5" >฿11.80</td>
#       <td id="T_a1ee8_row3_col6" class="data row3 col6" >9.74</td>
#       <td id="T_a1ee8_row3_col7" class="data row3 col7" >1.00</td>
#       <td id="T_a1ee8_row3_col8" class="data row3 col8" >100.41</td>
#       <td id="T_a1ee8_row3_col9" class="data row3 col9" >0.59</td>
#       <td id="T_a1ee8_row3_col10" class="data row3 col10" >sSET / SETTHSI / SETWB    </td>
#       <td id="T_a1ee8_row3_col11" class="data row3 col11" >SET</td>
#     </tr>
#     <tr>
#       <th id="T_a1ee8_level0_row4" class="row_heading level0 row4" >14</th>
#       <td id="T_a1ee8_row4_col0" class="data row4 col0" >ORI</td>
#       <td id="T_a1ee8_row4_col1" class="data row4 col1" >45,000</td>
#       <td id="T_a1ee8_row4_col2" class="data row4 col2" >฿11.00</td>
#       <td id="T_a1ee8_row4_col3" class="data row4 col3" >฿495,000.00</td>
#       <td id="T_a1ee8_row4_col4" class="data row4 col4" >฿12.70</td>
#       <td id="T_a1ee8_row4_col5" class="data row4 col5" >฿9.20</td>
#       <td id="T_a1ee8_row4_col6" class="data row4 col6" >8.37</td>
#       <td id="T_a1ee8_row4_col7" class="data row4 col7" >1.82</td>
#       <td id="T_a1ee8_row4_col8" class="data row4 col8" >79.97</td>
#       <td id="T_a1ee8_row4_col9" class="data row4 col9" >1.57</td>
#       <td id="T_a1ee8_row4_col10" class="data row4 col10" >SET100 / SETHD / SETTHSI    </td>
#       <td id="T_a1ee8_row4_col11" class="data row4 col11" >SET100</td>
#     </tr>
#   </tbody>
# </table>

# %%
total_stocks.stb.freq(['mrkt'], value='cost_amt').style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_40ed6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >mrkt</th>
#       <th class="col_heading level0 col1" >cost_amt</th>
#       <th class="col_heading level0 col2" >percent</th>
#       <th class="col_heading level0 col3" >cumulative_cost_amt</th>
#       <th class="col_heading level0 col4" >cumulative_percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40ed6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40ed6_row0_col0" class="data row0 col0" >SET</td>
#       <td id="T_40ed6_row0_col1" class="data row0 col1" >฿6,315,300.00</td>
#       <td id="T_40ed6_row0_col2" class="data row0 col2" >56.875380</td>
#       <td id="T_40ed6_row0_col3" class="data row0 col3" >6315300.000000</td>
#       <td id="T_40ed6_row0_col4" class="data row0 col4" >56.875380</td>
#     </tr>
#     <tr>
#       <th id="T_40ed6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_40ed6_row1_col0" class="data row1 col0" >SET100</td>
#       <td id="T_40ed6_row1_col1" class="data row1 col1" >฿2,750,100.00</td>
#       <td id="T_40ed6_row1_col2" class="data row1 col2" >24.767308</td>
#       <td id="T_40ed6_row1_col3" class="data row1 col3" >9065400.000000</td>
#       <td id="T_40ed6_row1_col4" class="data row1 col4" >81.642688</td>
#     </tr>
#     <tr>
#       <th id="T_40ed6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_40ed6_row2_col0" class="data row2 col0" >SET50</td>
#       <td id="T_40ed6_row2_col1" class="data row2 col1" >฿2,038,350.00</td>
#       <td id="T_40ed6_row2_col2" class="data row2 col2" >18.357312</td>
#       <td id="T_40ed6_row2_col3" class="data row2 col3" >11103750.000000</td>
#       <td id="T_40ed6_row2_col4" class="data row2 col4" >100.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Total balance amount

# %%
ttl_stk_amt = total_stocks.cost_amt.sum()
float_formatter.format(ttl_stk_amt)
# Out:
# '฿11,103,750.00'

# %%
total_stocks['volbuy'] = total_stocks['volbuy'].astype(int)
set50 = total_stocks.market.str.contains('SET50') 
port_set50 = total_stocks[set50]
port_set50.sample(5).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6c343_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >volbuy</th>
#       <th class="col_heading level0 col2" >price</th>
#       <th class="col_heading level0 col3" >cost_amt</th>
#       <th class="col_heading level0 col4" >max</th>
#       <th class="col_heading level0 col5" >min</th>
#       <th class="col_heading level0 col6" >pe</th>
#       <th class="col_heading level0 col7" >pbv</th>
#       <th class="col_heading level0 col8" >volume</th>
#       <th class="col_heading level0 col9" >beta</th>
#       <th class="col_heading level0 col10" >market</th>
#       <th class="col_heading level0 col11" >mrkt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c343_level0_row0" class="row_heading level0 row0" >17</th>
#       <td id="T_6c343_row0_col0" class="data row0 col0" >SCC</td>
#       <td id="T_6c343_row0_col1" class="data row0 col1" >600</td>
#       <td id="T_6c343_row0_col2" class="data row0 col2" >฿405.00</td>
#       <td id="T_6c343_row0_col3" class="data row0 col3" >฿243,000.00</td>
#       <td id="T_6c343_row0_col4" class="data row0 col4" >฿402.00</td>
#       <td id="T_6c343_row0_col5" class="data row0 col5" >฿307.00</td>
#       <td id="T_6c343_row0_col6" class="data row0 col6" >13.90</td>
#       <td id="T_6c343_row0_col7" class="data row0 col7" >1.04</td>
#       <td id="T_6c343_row0_col8" class="data row0 col8" >1,019.09</td>
#       <td id="T_6c343_row0_col9" class="data row0 col9" >0.74</td>
#       <td id="T_6c343_row0_col10" class="data row0 col10" >SET50 / SETCLMV / SETHD / SETTHSI    </td>
#       <td id="T_6c343_row0_col11" class="data row0 col11" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_6c343_level0_row1" class="row_heading level0 row1" >15</th>
#       <td id="T_6c343_row1_col0" class="data row1 col0" >PTTGC</td>
#       <td id="T_6c343_row1_col1" class="data row1 col1" >9,000</td>
#       <td id="T_6c343_row1_col2" class="data row1 col2" >฿61.25</td>
#       <td id="T_6c343_row1_col3" class="data row1 col3" >฿551,250.00</td>
#       <td id="T_6c343_row1_col4" class="data row1 col4" >฿61.50</td>
#       <td id="T_6c343_row1_col5" class="data row1 col5" >฿39.75</td>
#       <td id="T_6c343_row1_col6" class="data row1 col6" >999.99</td>
#       <td id="T_6c343_row1_col7" class="data row1 col7" >0.73</td>
#       <td id="T_6c343_row1_col8" class="data row1 col8" >747.16</td>
#       <td id="T_6c343_row1_col9" class="data row1 col9" >1.13</td>
#       <td id="T_6c343_row1_col10" class="data row1 col10" >SET50 / SETCLMV / SETTHSI    </td>
#       <td id="T_6c343_row1_col11" class="data row1 col11" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_6c343_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_6c343_row2_col0" class="data row2 col0" >JMART</td>
#       <td id="T_6c343_row2_col1" class="data row2 col1" >3,000</td>
#       <td id="T_6c343_row2_col2" class="data row2 col2" >฿40.00</td>
#       <td id="T_6c343_row2_col3" class="data row2 col3" >฿120,000.00</td>
#       <td id="T_6c343_row2_col4" class="data row2 col4" >฿64.00</td>
#       <td id="T_6c343_row2_col5" class="data row2 col5" >฿39.00</td>
#       <td id="T_6c343_row2_col6" class="data row2 col6" >19.98</td>
#       <td id="T_6c343_row2_col7" class="data row2 col7" >3.46</td>
#       <td id="T_6c343_row2_col8" class="data row2 col8" >425.41</td>
#       <td id="T_6c343_row2_col9" class="data row2 col9" >2.03</td>
#       <td id="T_6c343_row2_col10" class="data row2 col10" >SET50    </td>
#       <td id="T_6c343_row2_col11" class="data row2 col11" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_6c343_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_6c343_row3_col0" class="data row3 col0" >IVL</td>
#       <td id="T_6c343_row3_col1" class="data row3 col1" >2,400</td>
#       <td id="T_6c343_row3_col2" class="data row3 col2" >฿44.00</td>
#       <td id="T_6c343_row3_col3" class="data row3 col3" >฿105,600.00</td>
#       <td id="T_6c343_row3_col4" class="data row3 col4" >฿52.75</td>
#       <td id="T_6c343_row3_col5" class="data row3 col5" >฿38.00</td>
#       <td id="T_6c343_row3_col6" class="data row3 col6" >4.78</td>
#       <td id="T_6c343_row3_col7" class="data row3 col7" >1.08</td>
#       <td id="T_6c343_row3_col8" class="data row3 col8" >878.32</td>
#       <td id="T_6c343_row3_col9" class="data row3 col9" >1.13</td>
#       <td id="T_6c343_row3_col10" class="data row3 col10" >SET50 / SETTHSI    </td>
#       <td id="T_6c343_row3_col11" class="data row3 col11" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_6c343_level0_row4" class="row_heading level0 row4" >10</th>
#       <td id="T_6c343_row4_col0" class="data row4 col0" >KCE</td>
#       <td id="T_6c343_row4_col1" class="data row4 col1" >14,000</td>
#       <td id="T_6c343_row4_col2" class="data row4 col2" >฿72.75</td>
#       <td id="T_6c343_row4_col3" class="data row4 col3" >฿1,018,500.00</td>
#       <td id="T_6c343_row4_col4" class="data row4 col4" >฿89.25</td>
#       <td id="T_6c343_row4_col5" class="data row4 col5" >฿39.75</td>
#       <td id="T_6c343_row4_col6" class="data row4 col6" >21.83</td>
#       <td id="T_6c343_row4_col7" class="data row4 col7" >4.27</td>
#       <td id="T_6c343_row4_col8" class="data row4 col8" >825.26</td>
#       <td id="T_6c343_row4_col9" class="data row4 col9" >1.78</td>
#       <td id="T_6c343_row4_col10" class="data row4 col10" >SET50    </td>
#       <td id="T_6c343_row4_col11" class="data row4 col11" >SET50</td>
#     </tr>
#   </tbody>
# </table>

# %%
amt_set50 = port_set50.cost_amt.sum()
float_formatter.format(amt_set50)
# Out:
# '฿2,038,350.00'

# %%
set100 = total_stocks.market.str.contains('SET100') 
port_set100 = total_stocks[set100]
port_set100.sort_values(['name'],ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ce126_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >volbuy</th>
#       <th class="col_heading level0 col2" >price</th>
#       <th class="col_heading level0 col3" >cost_amt</th>
#       <th class="col_heading level0 col4" >max</th>
#       <th class="col_heading level0 col5" >min</th>
#       <th class="col_heading level0 col6" >pe</th>
#       <th class="col_heading level0 col7" >pbv</th>
#       <th class="col_heading level0 col8" >volume</th>
#       <th class="col_heading level0 col9" >beta</th>
#       <th class="col_heading level0 col10" >market</th>
#       <th class="col_heading level0 col11" >mrkt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce126_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_ce126_row0_col0" class="data row0 col0" >BCH</td>
#       <td id="T_ce126_row0_col1" class="data row0 col1" >15,000</td>
#       <td id="T_ce126_row0_col2" class="data row0 col2" >฿21.46</td>
#       <td id="T_ce126_row0_col3" class="data row0 col3" >฿321,900.00</td>
#       <td id="T_ce126_row0_col4" class="data row0 col4" >฿23.10</td>
#       <td id="T_ce126_row0_col5" class="data row0 col5" >฿16.80</td>
#       <td id="T_ce126_row0_col6" class="data row0 col6" >9.74</td>
#       <td id="T_ce126_row0_col7" class="data row0 col7" >4.19</td>
#       <td id="T_ce126_row0_col8" class="data row0 col8" >376.16</td>
#       <td id="T_ce126_row0_col9" class="data row0 col9" >0.24</td>
#       <td id="T_ce126_row0_col10" class="data row0 col10" >SET100 / SETCLMV / SETHD / SETWB    </td>
#       <td id="T_ce126_row0_col11" class="data row0 col11" >SET100</td>
#     </tr>
#     <tr>
#       <th id="T_ce126_level0_row1" class="row_heading level0 row1" >14</th>
#       <td id="T_ce126_row1_col0" class="data row1 col0" >ORI</td>
#       <td id="T_ce126_row1_col1" class="data row1 col1" >45,000</td>
#       <td id="T_ce126_row1_col2" class="data row1 col2" >฿11.00</td>
#       <td id="T_ce126_row1_col3" class="data row1 col3" >฿495,000.00</td>
#       <td id="T_ce126_row1_col4" class="data row1 col4" >฿12.70</td>
#       <td id="T_ce126_row1_col5" class="data row1 col5" >฿9.20</td>
#       <td id="T_ce126_row1_col6" class="data row1 col6" >8.37</td>
#       <td id="T_ce126_row1_col7" class="data row1 col7" >1.82</td>
#       <td id="T_ce126_row1_col8" class="data row1 col8" >79.97</td>
#       <td id="T_ce126_row1_col9" class="data row1 col9" >1.57</td>
#       <td id="T_ce126_row1_col10" class="data row1 col10" >SET100 / SETHD / SETTHSI    </td>
#       <td id="T_ce126_row1_col11" class="data row1 col11" >SET100</td>
#     </tr>
#     <tr>
#       <th id="T_ce126_level0_row2" class="row_heading level0 row2" >16</th>
#       <td id="T_ce126_row2_col0" class="data row2 col0" >RCL</td>
#       <td id="T_ce126_row2_col1" class="data row2 col1" >24,000</td>
#       <td id="T_ce126_row2_col2" class="data row2 col2" >฿39.80</td>
#       <td id="T_ce126_row2_col3" class="data row2 col3" >฿955,200.00</td>
#       <td id="T_ce126_row2_col4" class="data row2 col4" >฿54.25</td>
#       <td id="T_ce126_row2_col5" class="data row2 col5" >฿26.25</td>
#       <td id="T_ce126_row2_col6" class="data row2 col6" >0.85</td>
#       <td id="T_ce126_row2_col7" class="data row2 col7" >0.52</td>
#       <td id="T_ce126_row2_col8" class="data row2 col8" >256.29</td>
#       <td id="T_ce126_row2_col9" class="data row2 col9" >1.80</td>
#       <td id="T_ce126_row2_col10" class="data row2 col10" >SET100 / SETCLMV / SETWB    </td>
#       <td id="T_ce126_row2_col11" class="data row2 col11" >SET100</td>
#     </tr>
#     <tr>
#       <th id="T_ce126_level0_row3" class="row_heading level0 row3" >20</th>
#       <td id="T_ce126_row3_col0" class="data row3 col0" >STA</td>
#       <td id="T_ce126_row3_col1" class="data row3 col1" >15,000</td>
#       <td id="T_ce126_row3_col2" class="data row3 col2" >฿36.50</td>
#       <td id="T_ce126_row3_col3" class="data row3 col3" >฿547,500.00</td>
#       <td id="T_ce126_row3_col4" class="data row3 col4" >฿32.50</td>
#       <td id="T_ce126_row3_col5" class="data row3 col5" >฿17.70</td>
#       <td id="T_ce126_row3_col6" class="data row3 col6" >5.98</td>
#       <td id="T_ce126_row3_col7" class="data row3 col7" >0.64</td>
#       <td id="T_ce126_row3_col8" class="data row3 col8" >161.40</td>
#       <td id="T_ce126_row3_col9" class="data row3 col9" >1.24</td>
#       <td id="T_ce126_row3_col10" class="data row3 col10" >SET100 / SETTHSI / SETWB    </td>
#       <td id="T_ce126_row3_col11" class="data row3 col11" >SET100</td>
#     </tr>
#     <tr>
#       <th id="T_ce126_level0_row4" class="row_heading level0 row4" >21</th>
#       <td id="T_ce126_row4_col0" class="data row4 col0" >SYNEX</td>
#       <td id="T_ce126_row4_col1" class="data row4 col1" >15,000</td>
#       <td id="T_ce126_row4_col2" class="data row4 col2" >฿28.70</td>
#       <td id="T_ce126_row4_col3" class="data row4 col3" >฿430,500.00</td>
#       <td id="T_ce126_row4_col4" class="data row4 col4" >฿37.00</td>
#       <td id="T_ce126_row4_col5" class="data row4 col5" >฿14.50</td>
#       <td id="T_ce126_row4_col6" class="data row4 col6" >15.45</td>
#       <td id="T_ce126_row4_col7" class="data row4 col7" >3.56</td>
#       <td id="T_ce126_row4_col8" class="data row4 col8" >67.82</td>
#       <td id="T_ce126_row4_col9" class="data row4 col9" >2.03</td>
#       <td id="T_ce126_row4_col10" class="data row4 col10" >SET100 / SETTHSI    </td>
#       <td id="T_ce126_row4_col11" class="data row4 col11" >SET100</td>
#     </tr>
#   </tbody>
# </table>

# %%
amt_set100 = port_set100.cost_amt.sum()
float_formatter.format(amt_set100)
# Out:
# '฿2,750,100.00'

# %%
port_set = total_stocks[~(set100 | set50)]
port_set.sample(5).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ce7d0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >volbuy</th>
#       <th class="col_heading level0 col2" >price</th>
#       <th class="col_heading level0 col3" >cost_amt</th>
#       <th class="col_heading level0 col4" >max</th>
#       <th class="col_heading level0 col5" >min</th>
#       <th class="col_heading level0 col6" >pe</th>
#       <th class="col_heading level0 col7" >pbv</th>
#       <th class="col_heading level0 col8" >volume</th>
#       <th class="col_heading level0 col9" >beta</th>
#       <th class="col_heading level0 col10" >market</th>
#       <th class="col_heading level0 col11" >mrkt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce7d0_level0_row0" class="row_heading level0 row0" >11</th>
#       <td id="T_ce7d0_row0_col0" class="data row0 col0" >MAKRO</td>
#       <td id="T_ce7d0_row0_col1" class="data row0 col1" >7,500</td>
#       <td id="T_ce7d0_row0_col2" class="data row0 col2" >฿40.40</td>
#       <td id="T_ce7d0_row0_col3" class="data row0 col3" >฿303,000.00</td>
#       <td id="T_ce7d0_row0_col4" class="data row0 col4" >฿43.75</td>
#       <td id="T_ce7d0_row0_col5" class="data row0 col5" >฿32.00</td>
#       <td id="T_ce7d0_row0_col6" class="data row0 col6" >29.56</td>
#       <td id="T_ce7d0_row0_col7" class="data row0 col7" >1.47</td>
#       <td id="T_ce7d0_row0_col8" class="data row0 col8" >445.45</td>
#       <td id="T_ce7d0_row0_col9" class="data row0 col9" >1.16</td>
#       <td id="T_ce7d0_row0_col10" class="data row0 col10" >SET    </td>
#       <td id="T_ce7d0_row0_col11" class="data row0 col11" >SET</td>
#     </tr>
#     <tr>
#       <th id="T_ce7d0_level0_row1" class="row_heading level0 row1" >12</th>
#       <td id="T_ce7d0_row1_col0" class="data row1 col0" >MCS</td>
#       <td id="T_ce7d0_row1_col1" class="data row1 col1" >75,000</td>
#       <td id="T_ce7d0_row1_col2" class="data row1 col2" >฿15.40</td>
#       <td id="T_ce7d0_row1_col3" class="data row1 col3" >฿1,155,000.00</td>
#       <td id="T_ce7d0_row1_col4" class="data row1 col4" >฿15.20</td>
#       <td id="T_ce7d0_row1_col5" class="data row1 col5" >฿8.50</td>
#       <td id="T_ce7d0_row1_col6" class="data row1 col6" >8.95</td>
#       <td id="T_ce7d0_row1_col7" class="data row1 col7" >1.09</td>
#       <td id="T_ce7d0_row1_col8" class="data row1 col8" >22.20</td>
#       <td id="T_ce7d0_row1_col9" class="data row1 col9" >0.48</td>
#       <td id="T_ce7d0_row1_col10" class="data row1 col10" >sSET    </td>
#       <td id="T_ce7d0_row1_col11" class="data row1 col11" >SET</td>
#     </tr>
#     <tr>
#       <th id="T_ce7d0_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_ce7d0_row2_col0" class="data row2 col0" >GFPT</td>
#       <td id="T_ce7d0_row2_col1" class="data row2 col1" >7,500</td>
#       <td id="T_ce7d0_row2_col2" class="data row2 col2" >฿12.50</td>
#       <td id="T_ce7d0_row2_col3" class="data row2 col3" >฿93,750.00</td>
#       <td id="T_ce7d0_row2_col4" class="data row2 col4" >฿18.70</td>
#       <td id="T_ce7d0_row2_col5" class="data row2 col5" >฿11.80</td>
#       <td id="T_ce7d0_row2_col6" class="data row2 col6" >9.74</td>
#       <td id="T_ce7d0_row2_col7" class="data row2 col7" >1.00</td>
#       <td id="T_ce7d0_row2_col8" class="data row2 col8" >100.41</td>
#       <td id="T_ce7d0_row2_col9" class="data row2 col9" >0.59</td>
#       <td id="T_ce7d0_row2_col10" class="data row2 col10" >sSET / SETTHSI / SETWB    </td>
#       <td id="T_ce7d0_row2_col11" class="data row2 col11" >SET</td>
#     </tr>
#     <tr>
#       <th id="T_ce7d0_level0_row3" class="row_heading level0 row3" >19</th>
#       <td id="T_ce7d0_row3_col0" class="data row3 col0" >SENA</td>
#       <td id="T_ce7d0_row3_col1" class="data row3 col1" >105,000</td>
#       <td id="T_ce7d0_row3_col2" class="data row3 col2" >฿4.48</td>
#       <td id="T_ce7d0_row3_col3" class="data row3 col3" >฿470,400.00</td>
#       <td id="T_ce7d0_row3_col4" class="data row3 col4" >฿5.50</td>
#       <td id="T_ce7d0_row3_col5" class="data row3 col5" >฿3.76</td>
#       <td id="T_ce7d0_row3_col6" class="data row3 col6" >4.24</td>
#       <td id="T_ce7d0_row3_col7" class="data row3 col7" >0.71</td>
#       <td id="T_ce7d0_row3_col8" class="data row3 col8" >14.83</td>
#       <td id="T_ce7d0_row3_col9" class="data row3 col9" >0.97</td>
#       <td id="T_ce7d0_row3_col10" class="data row3 col10" >sSET    </td>
#       <td id="T_ce7d0_row3_col11" class="data row3 col11" >SET</td>
#     </tr>
#     <tr>
#       <th id="T_ce7d0_level0_row4" class="row_heading level0 row4" >18</th>
#       <td id="T_ce7d0_row4_col0" class="data row4 col0" >SCCC</td>
#       <td id="T_ce7d0_row4_col1" class="data row4 col1" >1,200</td>
#       <td id="T_ce7d0_row4_col2" class="data row4 col2" >฿171.00</td>
#       <td id="T_ce7d0_row4_col3" class="data row4 col3" >฿205,200.00</td>
#       <td id="T_ce7d0_row4_col4" class="data row4 col4" >฿175.50</td>
#       <td id="T_ce7d0_row4_col5" class="data row4 col5" >฿144.50</td>
#       <td id="T_ce7d0_row4_col6" class="data row4 col6" >11.97</td>
#       <td id="T_ce7d0_row4_col7" class="data row4 col7" >1.26</td>
#       <td id="T_ce7d0_row4_col8" class="data row4 col8" >29.52</td>
#       <td id="T_ce7d0_row4_col9" class="data row4 col9" >0.44</td>
#       <td id="T_ce7d0_row4_col10" class="data row4 col10" >SETCLMV / SETTHSI    </td>
#       <td id="T_ce7d0_row4_col11" class="data row4 col11" >SET</td>
#     </tr>
#   </tbody>
# </table>

# %%
amt_set = port_set.cost_amt.sum()
float_formatter.format(amt_set)
# Out:
# '฿6,315,300.00'

# %%
pct_set50 = round(amt_set50 / ttl_stk_amt * 100,2)
pct_set100 = round(amt_set100 / ttl_stk_amt * 100,2)
pct_set  = round(amt_set  / ttl_stk_amt * 100,2)
pct_set50, pct_set100, pct_set
# Out:
# (18.36, 24.77, 56.88)

# %% [markdown]
# ### For interested reviews

# %%
sold_stocks.loc[
    sold_stocks.net_profit > 20_000
].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d2566_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >sell_amt</th>
#       <th class="col_heading level0 col1" >buy_amt</th>
#       <th class="col_heading level0 col2" >qty</th>
#       <th class="col_heading level0 col3" >grs_profit</th>
#       <th class="col_heading level0 col4" >net_profit</th>
#       <th class="col_heading level0 col5" >sell_price</th>
#       <th class="col_heading level0 col6" >buy_price</th>
#       <th class="col_heading level0 col7" >diff</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="index_name level1" >market</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2566_level0_row0" class="row_heading level0 row0" >GLOBAL</th>
#       <th id="T_d2566_level1_row0" class="row_heading level1 row0" >SET50</th>
#       <td id="T_d2566_row0_col0" class="data row0 col0" >฿482,400.00</td>
#       <td id="T_d2566_row0_col1" class="data row0 col1" >฿456,600.00</td>
#       <td id="T_d2566_row0_col2" class="data row0 col2" >24,000</td>
#       <td id="T_d2566_row0_col3" class="data row0 col3" >฿25,800.00</td>
#       <td id="T_d2566_row0_col4" class="data row0 col4" >฿23,720.19</td>
#       <td id="T_d2566_row0_col5" class="data row0 col5" >฿20.10</td>
#       <td id="T_d2566_row0_col6" class="data row0 col6" >฿19.02</td>
#       <td id="T_d2566_row0_col7" class="data row0 col7" >฿1.08</td>
#     </tr>
#     <tr>
#       <th id="T_d2566_level0_row1" class="row_heading level0 row1" >IMH</th>
#       <th id="T_d2566_level1_row1" class="row_heading level1 row1" >MAI</th>
#       <td id="T_d2566_row1_col0" class="data row1 col0" >฿357,300.00</td>
#       <td id="T_d2566_row1_col1" class="data row1 col1" >฿308,000.00</td>
#       <td id="T_d2566_row1_col2" class="data row1 col2" >19,000</td>
#       <td id="T_d2566_row1_col3" class="data row1 col3" >฿49,300.00</td>
#       <td id="T_d2566_row1_col4" class="data row1 col4" >฿47,826.43</td>
#       <td id="T_d2566_row1_col5" class="data row1 col5" >฿18.81</td>
#       <td id="T_d2566_row1_col6" class="data row1 col6" >฿16.21</td>
#       <td id="T_d2566_row1_col7" class="data row1 col7" >฿2.59</td>
#     </tr>
#     <tr>
#       <th id="T_d2566_level0_row2" class="row_heading level0 row2" >IVL</th>
#       <th id="T_d2566_level1_row2" class="row_heading level1 row2" >SET50</th>
#       <td id="T_d2566_row2_col0" class="data row2 col0" >฿1,129,350.00</td>
#       <td id="T_d2566_row2_col1" class="data row2 col1" >฿1,047,000.00</td>
#       <td id="T_d2566_row2_col2" class="data row2 col2" >24,000</td>
#       <td id="T_d2566_row2_col3" class="data row2 col3" >฿82,350.00</td>
#       <td id="T_d2566_row2_col4" class="data row2 col4" >฿77,529.62</td>
#       <td id="T_d2566_row2_col5" class="data row2 col5" >฿47.06</td>
#       <td id="T_d2566_row2_col6" class="data row2 col6" >฿43.62</td>
#       <td id="T_d2566_row2_col7" class="data row2 col7" >฿3.43</td>
#     </tr>
#     <tr>
#       <th id="T_d2566_level0_row3" class="row_heading level0 row3" >SINGER</th>
#       <th id="T_d2566_level1_row3" class="row_heading level1 row3" >SET100</th>
#       <td id="T_d2566_row3_col0" class="data row3 col0" >฿336,000.00</td>
#       <td id="T_d2566_row3_col1" class="data row3 col1" >฿290,925.00</td>
#       <td id="T_d2566_row3_col2" class="data row3 col2" >8,100</td>
#       <td id="T_d2566_row3_col3" class="data row3 col3" >฿45,075.00</td>
#       <td id="T_d2566_row3_col4" class="data row3 col4" >฿43,686.41</td>
#       <td id="T_d2566_row3_col5" class="data row3 col5" >฿41.48</td>
#       <td id="T_d2566_row3_col6" class="data row3 col6" >฿35.92</td>
#       <td id="T_d2566_row3_col7" class="data row3 col7" >฿5.56</td>
#     </tr>
#     <tr>
#       <th id="T_d2566_level0_row4" class="row_heading level0 row4" >TOP</th>
#       <th id="T_d2566_level1_row4" class="row_heading level1 row4" >SET50</th>
#       <td id="T_d2566_row4_col0" class="data row4 col0" >฿680,500.00</td>
#       <td id="T_d2566_row4_col1" class="data row4 col1" >฿648,000.00</td>
#       <td id="T_d2566_row4_col2" class="data row4 col2" >12,000</td>
#       <td id="T_d2566_row4_col3" class="data row4 col3" >฿32,500.00</td>
#       <td id="T_d2566_row4_col4" class="data row4 col4" >฿29,557.48</td>
#       <td id="T_d2566_row4_col5" class="data row4 col5" >฿56.71</td>
#       <td id="T_d2566_row4_col6" class="data row4 col6" >฿54.00</td>
#       <td id="T_d2566_row4_col7" class="data row4 col7" >฿2.71</td>
#     </tr>
#   </tbody>
# </table>

# %%
sold_stocks.nlargest(5, 'net_profit')[['grs_profit','net_profit']].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1f9e0_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >grs_profit</th>
#       <th class="col_heading level0 col1" >net_profit</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="index_name level1" >market</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f9e0_level0_row0" class="row_heading level0 row0" >IVL</th>
#       <th id="T_1f9e0_level1_row0" class="row_heading level1 row0" >SET50</th>
#       <td id="T_1f9e0_row0_col0" class="data row0 col0" >฿82,350.00</td>
#       <td id="T_1f9e0_row0_col1" class="data row0 col1" >฿77,529.62</td>
#     </tr>
#     <tr>
#       <th id="T_1f9e0_level0_row1" class="row_heading level0 row1" >IMH</th>
#       <th id="T_1f9e0_level1_row1" class="row_heading level1 row1" >MAI</th>
#       <td id="T_1f9e0_row1_col0" class="data row1 col0" >฿49,300.00</td>
#       <td id="T_1f9e0_row1_col1" class="data row1 col1" >฿47,826.43</td>
#     </tr>
#     <tr>
#       <th id="T_1f9e0_level0_row2" class="row_heading level0 row2" >SINGER</th>
#       <th id="T_1f9e0_level1_row2" class="row_heading level1 row2" >SET100</th>
#       <td id="T_1f9e0_row2_col0" class="data row2 col0" >฿45,075.00</td>
#       <td id="T_1f9e0_row2_col1" class="data row2 col1" >฿43,686.41</td>
#     </tr>
#     <tr>
#       <th id="T_1f9e0_level0_row3" class="row_heading level0 row3" >TOP</th>
#       <th id="T_1f9e0_level1_row3" class="row_heading level1 row3" >SET50</th>
#       <td id="T_1f9e0_row3_col0" class="data row3 col0" >฿32,500.00</td>
#       <td id="T_1f9e0_row3_col1" class="data row3 col1" >฿29,557.48</td>
#     </tr>
#     <tr>
#       <th id="T_1f9e0_level0_row4" class="row_heading level0 row4" >GLOBAL</th>
#       <th id="T_1f9e0_level1_row4" class="row_heading level1 row4" >SET50</th>
#       <td id="T_1f9e0_row4_col0" class="data row4 col0" >฿25,800.00</td>
#       <td id="T_1f9e0_row4_col1" class="data row4 col1" >฿23,720.19</td>
#     </tr>
#   </tbody>
# </table>

# %%
sold_stocks.nsmallest(5, 'net_profit')[['grs_profit','net_profit']].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_88d33_">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >grs_profit</th>
#       <th class="col_heading level0 col1" >net_profit</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="index_name level1" >market</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88d33_level0_row0" class="row_heading level0 row0" >NOBLE</th>
#       <th id="T_88d33_level1_row0" class="row_heading level1 row0" >SET</th>
#       <td id="T_88d33_row0_col0" class="data row0 col0" >฿-63,000.00</td>
#       <td id="T_88d33_row0_col1" class="data row0 col1" >฿-64,814.00</td>
#     </tr>
#     <tr>
#       <th id="T_88d33_level0_row1" class="row_heading level0 row1" >BGRIM</th>
#       <th id="T_88d33_level1_row1" class="row_heading level1 row1" >SET50</th>
#       <td id="T_88d33_row1_col0" class="data row1 col0" >฿-63,000.00</td>
#       <td id="T_88d33_row1_col1" class="data row1 col1" >฿-64,455.19</td>
#     </tr>
#     <tr>
#       <th id="T_88d33_level0_row2" class="row_heading level0 row2" >STA</th>
#       <th id="T_88d33_level1_row2" class="row_heading level1 row2" >SET50</th>
#       <td id="T_88d33_row2_col0" class="data row2 col0" >฿-63,275.00</td>
#       <td id="T_88d33_row2_col1" class="data row2 col1" >฿-64,218.29</td>
#     </tr>
#     <tr>
#       <th id="T_88d33_level0_row3" class="row_heading level0 row3" >RATCH</th>
#       <th id="T_88d33_level1_row3" class="row_heading level1 row3" >SET50</th>
#       <td id="T_88d33_row3_col0" class="data row3 col0" >฿-39,250.00</td>
#       <td id="T_88d33_row3_col1" class="data row3 col1" >฿-40,987.07</td>
#     </tr>
#     <tr>
#       <th id="T_88d33_level0_row4" class="row_heading level0 row4" >DOHOME</th>
#       <th id="T_88d33_level1_row4" class="row_heading level1 row4" >SET100</th>
#       <td id="T_88d33_row4_col0" class="data row4 col0" >฿-32,400.00</td>
#       <td id="T_88d33_row4_col1" class="data row4 col1" >฿-33,846.40</td>
#     </tr>
#   </tbody>
# </table>
