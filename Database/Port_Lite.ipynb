# %%
import calendar
import numpy as np
import os
import pandas as pd

from datetime import date, timedelta
from sqlalchemy import create_engine
from pandas.tseries.offsets import BDay

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

engine = create_engine("sqlite:///c:\\ruby\\portmy\\db\\development.sqlite3")
conmy = engine.connect()

engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"

format_dict = {
    'qty':'{:,}','price':'{:.2f}','amount':'{:,.2f}'
}
cols = 'trade name qty price active'.split()

today = date.today()
yesterday = today - timedelta(days=1)
today, yesterday
# Out:
# (datetime.date(2023, 8, 21), datetime.date(2023, 8, 20))

# %% [markdown]
# ### Yesterday must be last business day

# %%
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(1)
yesterday = today - num_business_days
yesterday = yesterday.date()
print(f'today: {today}')
print(f'yesterday: {yesterday}')
# Out:
# today: 2023-08-21
# yesterday: 2023-08-18

# %%
format_dict = {
    'qty':'{:,}',
    'fm_price':'{:.2f}','to_price':'{:.2f}','diff':'{:.2f}',
    'max_price':'{:.2f}','min_price':'{:.2f}',
    'volume':'{:,.2f}','beta':'{:,.2f}',
    'pct':'{:,.2f}%',  
    'fm_date':'{:%Y-%m-%d}','to_date':'{:%Y-%m-%d}',    
    'created_at':'{:%Y-%m-%d}','updated_at':'{:%Y-%m-%d}',
}

# %% [markdown]
# ### Problem solving process

# %%
sql = """
SELECT *
FROM stocks
LIMIT 1"""
stock = pd.read_sql(sql, conlite)
stock.dtypes
# Out:
# id                 int64
# name              object
# max_price        float64
# min_price        float64
# status            object
# buy_target         int64
# sell_target      float64
# volume           float64
# beta             float64
# cost             float64
# qty                int64
# buy_spread         int64
# sell_spread        int64
# available_qty      int64
# bl                 int64
# sh                 int64
# reason            object
# market            object
# dtype: object

# %%
sql = """
SELECT *
FROM stocks
ORDER BY name"""
stocks = pd.read_sql(sql, conlite)
stocks.head()
# Out:
#    id    name  max_price  min_price status  buy_target  sell_target  volume  \
# 0   0      AH        0.0        0.0      B       31.00        37.25     0.0
# 1   1  AIMIRT        0.0        0.0      I        0.00        11.30     0.0
# 2   2     ASK        0.0        0.0      I        0.00         0.00     0.0
# 3   3     ASP        0.0        0.0      I        0.00         0.00     0.0
# 4   4     AWC        0.0        0.0      B        3.66         0.00     0.0
#
#    beta   cost    qty  buy_spread  sell_spread  available_qty  bl  sh  \
# 0   0.0  37.00    600          -4            4           1200   0   0
# 1   0.0  11.00  10000          -4            4          10000   0   0
# 2   0.0  31.00      0          -4            4           4500   0   0
# 3   0.0   3.80      0          -4            4          30000   0   0
# 4   0.0   4.96   4000          -4            4           9000   0   0
#
#     reason market
# 0  RD15pct    SET
# 1      XXX    SET
# 2      XXX    SET
# 3      XXX    SET
# 4  RD25pct  SET50

# %%
sql = """
SELECT *
FROM orders
ORDER BY name"""
orders = pd.read_sql(sql, conlite)
orders.head()
# Out:
#    id trade    name    qty  price  active   reason market       xdate
# 0   1     B      AH    600  31.00       0  RD15pct    SET  2023-08-29
# 1  35     S  AIMIRT  10000  11.30       2      XXX    SET  2023-08-23
# 2  36     S     ASK      0   0.00       0      XXX    SET  2023-02-28
# 3  37     S     ASP      0   0.00       0      XXX    SET  2023-08-28
# 4   2     B     AWC   4000   3.66       0  RD25pct  SET50  2022-12-22

# %% [markdown]
# ### Matching check with profits in portmy database with 2023-q2 data

# %%
sql = '''
SELECT *
FROM stocks
ORDER BY market, name'''
stocks = pd.read_sql(sql, conlite)
stocks.shape
# Out:
# (48, 18)

# %%
sql = '''
SELECT *
FROM profits
ORDER BY name'''
profits = pd.read_sql(sql, conmy)
profits.shape
# Out:
# (21, 23)

# %%
df_merge = pd.merge(stocks, profits, on='name', how='outer', indicator=True)
df_merge.shape
# Out:
# (48, 41)

# %%
names = df_merge[df_merge._merge == 'right_only']['name']
names
# Out:
# Series([], Name: name, dtype: object)

# %%
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# ''

# %%
sql = """
SELECT Null AS id, name, market, max_price, min_price, daily_volume AS volume, beta 
FROM stocks
WHERE name IN (%s)"""
sql = sql % in_p
my_stocks = pd.read_sql(sql, conmy)
my_stocks
# Out:
# Empty DataFrame
# Columns: [id, name, market, max_price, min_price, volume, beta]
# Index: []

# %%
my_stocks.dtypes
# Out:
# id           object
# name         object
# market       object
# max_price    object
# min_price    object
# volume       object
# beta         object
# dtype: object

# %%
my_stocks['status'] = 'O'
my_stocks['buy_target'] = 0.00
my_stocks['sell_target'] = 0.00
my_stocks['cost'] = 0.00
my_stocks['qty'] = 0
my_stocks['buy_spread'] = -4
my_stocks['sell_spread'] = 4
my_stocks['available_qty'] = 0
my_stocks['bl'] = 0
my_stocks['sh'] = 0
my_stocks['reason'] = 'XXX'
my_stocks
# Out:
#      id   name                                 market  max_price  min_price  \
# 0  None    BCT                                SET          68.50      44.75
# 1  None    CRC  SET50 / SETCLMV / SETTHSI / SETWB          41.75      31.50
# 2  None    KSL                     sSET / SETCLMV           4.40       3.22
# 3  None  OISHI                                SET          50.50      41.25
#
#    volume  beta status  buy_target  sell_target  cost  qty  buy_spread  \
# 0    1.40  0.50      O         0.0          0.0   0.0    0          -4
# 1  483.40  1.43      O         0.0          0.0   0.0    0          -4
# 2   37.54  1.02      O         0.0          0.0   0.0    0          -4
# 3    0.94  0.60      O         0.0          0.0   0.0    0          -4
#
#    sell_spread  available_qty  bl  sh reason
# 0            4              0   0   0    XXX
# 1            4              0   0   0    XXX
# 2            4              0   0   0    XXX
# 3            4              0   0   0    XXX

# %%
rearrange_col = 'id name max_price min_price status buy_target sell_target volume beta cost qty buy_spread sell_spread available_qty bl sh reason market'.split()
rearrange_col
# Out:
# ['id',
#  'name',
#  'max_price',
#  'min_price',
#  'status',
#  'buy_target',
#  'sell_target',
#  'volume',
#  'beta',
#  'cost',
#  'qty',
#  'buy_spread',
#  'sell_spread',
#  'available_qty',
#  'bl',
#  'sh',
#  'reason',
#  'market']

# %%
my_stocks = my_stocks[rearrange_col]
my_stocks
# Out:
#      id   name  max_price  min_price status  buy_target  sell_target  volume  \
# 0  None    BCT      68.50      44.75      O         0.0          0.0    1.40
# 1  None    CRC      41.75      31.50      O         0.0          0.0  483.40
# 2  None    KSL       4.40       3.22      O         0.0          0.0   37.54
# 3  None  OISHI      50.50      41.25      O         0.0          0.0    0.94
#
#    beta  cost  qty  buy_spread  sell_spread  available_qty  bl  sh reason  \
# 0  0.50   0.0    0          -4            4              0   0   0    XXX
# 1  1.43   0.0    0          -4            4              0   0   0    XXX
# 2  1.02   0.0    0          -4            4              0   0   0    XXX
# 3  0.60   0.0    0          -4            4              0   0   0    XXX
#
#                                   market
# 0                                SET
# 1  SET50 / SETCLMV / SETTHSI / SETWB
# 2                     sSET / SETCLMV
# 3                                SET

# %%
rcds = my_stocks.values.tolist()
len(rcds)
# Out:
# 4

# %%
for rcd in rcds:
    print(rcd)
# Out:
# [None, 'BCT', 68.5, 44.75, 'O', 0.0, 0.0, 1.4, 0.5, 0.0, 0, -4, 4, 0, 0, 0, 'XXX', 'SET    ']
# [None, 'CRC', 41.75, 31.5, 'O', 0.0, 0.0, 483.4, 1.43, 0.0, 0, -4, 4, 0, 0, 0, 'XXX', 'SET50 / SETCLMV / SETTHSI / SETWB    ']
# [None, 'KSL', 4.4, 3.22, 'O', 0.0, 0.0, 37.54, 1.02, 0.0, 0, -4, 4, 0, 0, 0, 'XXX', 'sSET / SETCLMV    ']
# [None, 'OISHI', 50.5, 41.25, 'O', 0.0, 0.0, 0.94, 0.6, 0.0, 0, -4, 4, 0, 0, 0, 'XXX', 'SET    ']

# %%
for rcd in rcds:
    conlite.execute("""INSERT INTO stocks (id, name, max_price, min_price, status, buy_target, sell_target, volume, beta, cost, qty, buy_spread, sell_spread, available_qty, bl, sh, \
reason, market) \
VALUES( ?, ?, ?, ?, ?, ?, ?, ?, ?,?, ?, ?, ?, ?, ?, ?, ?, ?)""", rcd)

# %% [markdown]
# ### End of Process insert profit records to stocks

# %% [markdown]
# ### Process for stock records that are not in profits table

# %%
sql = '''
SELECT *
FROM stocks
ORDER BY market, name'''
stocks = pd.read_sql(sql, conlite)
stocks.shape
# Out:
# (48, 18)

# %%
sql = '''
SELECT *
FROM profits
ORDER BY name'''
profits = pd.read_sql(sql, conmy)
profits.shape
# Out:
# (21, 23)

# %%
df_merge2 = pd.merge(stocks, profits, on='name', how='outer', indicator=True)
df_merge2.shape
# Out:
# (48, 41)

# %%
names = df_merge2[df_merge2._merge == 'left_only']['name']
names
# Out:
# 0          AH
# 2         ASK
# 3         ASP
# 4     CPNREIT
# 5         DIF
# 6      GVREIT
# 9       JASIF
# 11        MCS
# 12        NER
# 16       SENA
# 18      SYNEX
# 19      TFFIF
# 20        TMT
# 22      WHAIR
# 23      WHART
# 24        BCH
# 27        KCE
# 28        ORI
# 29        PTG
# 31        RCL
# 32     SINGER
# 33        STA
# 34        AWC
# 40        IVL
# 41      JMART
# 45      PTTGC
# 46        SCC
# Name: name, dtype: object

# %%
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'AH', 'ASK', 'ASP', 'CPNREIT', 'DIF', 'GVREIT', 'JASIF', 'MCS', 'NER', 'SENA', 'SYNEX', 'TFFIF', 'TMT', 'WHAIR', 'WHART', 'BCH', 'KCE', 'ORI', 'PTG', 'RCL', 'SINGER', 'STA', 'AWC', 'IVL', 'JMART', 'PTTGC', 'SCC'"

# %%
sql = '''
SELECT *
FROM stocks
WHERE name IN (%s)
ORDER BY market, name'''
sql = sql % in_p
lite_stocks = pd.read_sql(sql, conlite)
lite_stocks[['market','name']]
# Out:
#     market     name
# 0      SET       AH
# 1      SET      ASK
# 2      SET      ASP
# 3      SET  CPNREIT
# 4      SET      DIF
# 5      SET   GVREIT
# 6      SET    JASIF
# 7      SET      MCS
# 8      SET      NER
# 9      SET     SENA
# 10     SET    SYNEX
# 11     SET    TFFIF
# 12     SET      TMT
# 13     SET    WHAIR
# 14     SET    WHART
# 15  SET100      BCH
# 16  SET100      KCE
# 17  SET100      ORI
# 18  SET100      PTG
# 19  SET100      RCL
# 20  SET100   SINGER
# 21  SET100      STA
# 22   SET50      AWC
# 23   SET50      IVL
# 24   SET50    JMART
# 25   SET50    PTTGC
# 26   SET50      SCC

# %%
sql = '''
SELECT name
FROM buy
ORDER BY name'''
stock_buy = pd.read_sql(sql, const)
stock_buy
# Out:
#        name
# 0        AH
# 1    AIMIRT
# 2       ASK
# 3       ASP
# 4       AWC
# 5       BCH
# 6   CPNREIT
# 7       DIF
# 8    GVREIT
# 9       IVL
# 10    JASIF
# 11    JMART
# 12      JMT
# 13      KCE
# 14      MCS
# 15      NER
# 16      ORI
# 17      PTG
# 18    PTTGC
# 19      RCL
# 20      SCC
# 21     SENA
# 22   SINGER
# 23      STA
# 24    SYNEX
# 25    TFFIF
# 26      TMT
# 27    WHAIR
# 28    WHART

# %%
df_merge3 = pd.merge(lite_stocks, stock_buy, on='name', how='outer', indicator=True)
df_merge3
# Out:
#       id     name  max_price  min_price status  buy_target  sell_target  \
# 0    0.0       AH        0.0        0.0      B       31.00        37.25
# 1    2.0      ASK        0.0        0.0      I        0.00         0.00
# 2    3.0      ASP        0.0        0.0      I        0.00         0.00
# 3    6.0  CPNREIT        0.0        0.0      S        0.00        13.20
# 4    7.0      DIF        0.0        0.0      B        9.20         0.00
# 5    8.0   GVREIT        0.0        0.0      I        7.00         0.00
# 6   10.0    JASIF        0.0        0.0      B        6.50         0.00
# 7   14.0      MCS        0.0        0.0      B        6.00         0.00
# 8   15.0      NER        0.0        0.0      B        4.58         0.00
# 9   21.0     SENA        0.0        0.0      B        2.56         0.00
# 10  24.0    SYNEX        0.0        0.0      B       10.00         0.00
# 11  25.0    TFFIF        0.0        0.0      I        0.00         7.75
# 12  26.0      TMT        0.0        0.0      B        6.30         0.00
# 13  27.0    WHAIR        0.0        0.0      B        6.70         0.00
# 14  28.0    WHART        0.0        0.0      I        0.00        11.00
# 15   5.0      BCH        0.0        0.0      I        0.00         0.00
# 16  13.0      KCE        0.0        0.0      I        0.00         0.00
# 17  16.0      ORI        0.0        0.0      B        9.50         0.00
# 18  17.0      PTG        0.0        0.0      I        0.00        12.10
# 19  19.0      RCL        0.0        0.0      I        0.00         0.00
# 20  22.0   SINGER        0.0        0.0      B        7.10         0.00
# 21  23.0      STA        0.0        0.0      B       12.70         0.00
# 22   4.0      AWC        0.0        0.0      B        3.66         0.00
# 23   9.0      IVL        0.0        0.0      I        0.00         0.00
# 24  11.0    JMART        0.0        0.0      I        0.00        20.60
# 25  18.0    PTTGC        0.0        0.0      B       34.50         0.00
# 26  20.0      SCC        0.0        0.0      I        0.00         0.00
# 27   NaN   AIMIRT        NaN        NaN    NaN         NaN          NaN
# 28   NaN      JMT        NaN        NaN    NaN         NaN          NaN
#
#     volume  beta    cost      qty  buy_spread  sell_spread  available_qty  \
# 0      0.0   0.0   37.00    600.0        -4.0          4.0         1200.0
# 1      0.0   0.0   31.00      0.0        -4.0          4.0         4500.0
# 2      0.0   0.0    3.80      0.0        -4.0          4.0        30000.0
# 3      0.0   0.0   17.55   5000.0        -4.0          4.0        60000.0
# 4      0.0   0.0   14.70   3000.0        -4.0          4.0        30000.0
# 5      0.0   0.0    8.70   6000.0        -4.0          4.0        36000.0
# 6      0.0   0.0   10.00   4000.0        -4.0          4.0       130000.0
# 7      0.0   0.0   15.10   4000.0        -4.0          4.0        78000.0
# 8      0.0   0.0    7.45   5000.0        -4.0          4.0        27000.0
# 9      0.0   0.0    4.48   7000.0        -4.0          4.0       105000.0
# 10     0.0   0.0   28.70   2000.0        -4.0          4.0        15000.0
# 11     0.0   0.0    7.50  20000.0        -4.0          4.0        20000.0
# 12     0.0   0.0   10.20   3000.0        -4.0          4.0        36000.0
# 13     0.0   0.0    8.70   3000.0        -4.0          4.0        50000.0
# 14     0.0   0.0   11.70  10000.0        -4.0          4.0        30000.0
# 15     0.0   0.0   21.46      0.0        -4.0          4.0        15000.0
# 16     0.0   0.0   77.25      0.0        -4.0          4.0        10000.0
# 17     0.0   0.0   11.00   2000.0        -4.0          4.0        45000.0
# 18     0.0   0.0   11.40   3600.0        -4.0          4.0         3600.0
# 19     0.0   0.0   38.75      0.0        -4.0          4.0        27000.0
# 20     0.0   0.0   24.80   3000.0        -4.0          4.0         6000.0
# 21     0.0   0.0   40.00   2500.0        -4.0          4.0         5000.0
# 22     0.0   0.0    4.96   4000.0        -4.0          4.0         9000.0
# 23     0.0   0.0   40.00      0.0        -4.0          4.0         7200.0
# 24     0.0   0.0   32.00   1200.0        -4.0          4.0         7200.0
# 25     0.0   0.0   64.75    600.0        -4.0          4.0         6000.0
# 26     0.0   0.0  405.00      0.0        -4.0          4.0          600.0
# 27     NaN   NaN     NaN      NaN         NaN          NaN            NaN
# 28     NaN   NaN     NaN      NaN         NaN          NaN            NaN
#
#      bl   sh   reason  market      _merge
# 0   0.0  0.0  RD15pct     SET        both
# 1   0.0  0.0      XXX     SET        both
# 2   0.0  0.0      XXX     SET        both
# 3   0.0  0.0      XXX     SET        both
# 4   0.0  0.0  RD35pct     SET        both
# 5   0.0  0.0  RD20pct     SET        both
# 6   0.0  0.0  RD35pct     SET        both
# 7   0.0  0.0  RD60pct     SET        both
# 8   0.0  0.0  RD40pct     SET        both
# 9   0.0  0.0  RD45pct     SET        both
# 10  0.0  0.0  RD65pct     SET        both
# 11  0.0  0.0      XXX     SET        both
# 12  0.0  0.0  RD40pct     SET        both
# 13  0.0  0.0  RD25pct     SET        both
# 14  0.0  0.0      XXX     SET        both
# 15  0.0  0.0      XXX  SET100        both
# 16  0.0  0.0      XXX  SET100        both
# 17  0.0  0.0  RD15pct  SET100        both
# 18  0.0  0.0     5pct  SET100        both
# 19  0.0  0.0      XXX  SET100        both
# 20  0.0  0.0  RD70pct  SET100        both
# 21  0.0  0.0  RD70pct  SET100        both
# 22  0.0  0.0  RD25pct   SET50        both
# 23  0.0  0.0      XXX   SET50        both
# 24  0.0  0.0     5pct   SET50        both
# 25  0.0  0.0      RD4   SET50        both
# 26  0.0  0.0      XXX   SET50        both
# 27  NaN  NaN      NaN     NaN  right_only
# 28  NaN  NaN      NaN     NaN  right_only

# %%
names = df_merge3[df_merge3._merge == 'left_only']['name']
names
# Out:
# Series([], Name: name, dtype: object)

# %%
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# ''

# %%
sqlDel = """
DELETE FROM stocks
WHERE name IN (%s)"""
sqlDel = sqlDel % in_p
print(sqlDel)
# Out:
# DELETE FROM stocks
# WHERE name IN ()

# %%
rp = conlite.execute(sqlDel)
rp.rowcount
# Out:
# 0

# %% [markdown]
# ### End of Process to delete stock record that are not in profits and avalable_qty = 0

# %%
sql = '''
SELECT *
FROM dividend
'''
dividend = pd.read_sql(sql, const)
dividend.drop(['PRICE', 'PERCENT'], axis=1, inplace=True)
dividend.columns = dividend.columns.str.lower()
dividend['shares'] = dividend['shares'].astype('int64')
dividend['xdate'] = pd.to_datetime(dividend['xdate'])
dividend['paiddate'] = pd.to_datetime(dividend['paiddate'])
dividend.dtypes
# Out:
# name                object
# q4                 float64
# q3                 float64
# q2                 float64
# q1                 float64
# dividend           float64
# shares               int64
# xdate       datetime64[ns]
# paiddate    datetime64[ns]
# kind                object
# actual               int64
# dtype: object

# %%
dividend.sort_values(['xdate'],ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_76b2e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >q4</th>
#       <th class="col_heading level0 col2" >q3</th>
#       <th class="col_heading level0 col3" >q2</th>
#       <th class="col_heading level0 col4" >q1</th>
#       <th class="col_heading level0 col5" >dividend</th>
#       <th class="col_heading level0 col6" >shares</th>
#       <th class="col_heading level0 col7" >xdate</th>
#       <th class="col_heading level0 col8" >paiddate</th>
#       <th class="col_heading level0 col9" >kind</th>
#       <th class="col_heading level0 col10" >actual</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76b2e_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_76b2e_row0_col0" class="data row0 col0" >HTC</td>
#       <td id="T_76b2e_row0_col1" class="data row0 col1" >1.120000</td>
#       <td id="T_76b2e_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_76b2e_row0_col3" class="data row0 col3" >0.830000</td>
#       <td id="T_76b2e_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_76b2e_row0_col5" class="data row0 col5" >1.950000</td>
#       <td id="T_76b2e_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_76b2e_row0_col7" class="data row0 col7" >2021-09-23 00:00:00</td>
#       <td id="T_76b2e_row0_col8" class="data row0 col8" >2021-09-23 00:00:00</td>
#       <td id="T_76b2e_row0_col9" class="data row0 col9" ></td>
#       <td id="T_76b2e_row0_col10" class="data row0 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_76b2e_level0_row1" class="row_heading level0 row1" >67</th>
#       <td id="T_76b2e_row1_col0" class="data row1 col0" >LPF</td>
#       <td id="T_76b2e_row1_col1" class="data row1 col1" >0.171900</td>
#       <td id="T_76b2e_row1_col2" class="data row1 col2" >0.189400</td>
#       <td id="T_76b2e_row1_col3" class="data row1 col3" >0.179300</td>
#       <td id="T_76b2e_row1_col4" class="data row1 col4" >0.187800</td>
#       <td id="T_76b2e_row1_col5" class="data row1 col5" >0.728400</td>
#       <td id="T_76b2e_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_76b2e_row1_col7" class="data row1 col7" >2022-01-28 00:00:00</td>
#       <td id="T_76b2e_row1_col8" class="data row1 col8" >2022-02-15 00:00:00</td>
#       <td id="T_76b2e_row1_col9" class="data row1 col9" ></td>
#       <td id="T_76b2e_row1_col10" class="data row1 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_76b2e_level0_row2" class="row_heading level0 row2" >32</th>
#       <td id="T_76b2e_row2_col0" class="data row2 col0" >GLOBAL</td>
#       <td id="T_76b2e_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_76b2e_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_76b2e_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_76b2e_row2_col4" class="data row2 col4" >0.000000</td>
#       <td id="T_76b2e_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_76b2e_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_76b2e_row2_col7" class="data row2 col7" >2022-02-02 00:00:00</td>
#       <td id="T_76b2e_row2_col8" class="data row2 col8" >2022-02-02 00:00:00</td>
#       <td id="T_76b2e_row2_col9" class="data row2 col9" ></td>
#       <td id="T_76b2e_row2_col10" class="data row2 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_76b2e_level0_row3" class="row_heading level0 row3" >70</th>
#       <td id="T_76b2e_row3_col0" class="data row3 col0" >IP</td>
#       <td id="T_76b2e_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_76b2e_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_76b2e_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_76b2e_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_76b2e_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_76b2e_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_76b2e_row3_col7" class="data row3 col7" >2022-02-02 00:00:00</td>
#       <td id="T_76b2e_row3_col8" class="data row3 col8" >2022-02-02 00:00:00</td>
#       <td id="T_76b2e_row3_col9" class="data row3 col9" ></td>
#       <td id="T_76b2e_row3_col10" class="data row3 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_76b2e_level0_row4" class="row_heading level0 row4" >76</th>
#       <td id="T_76b2e_row4_col0" class="data row4 col0" >DOHOME</td>
#       <td id="T_76b2e_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_76b2e_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_76b2e_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_76b2e_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_76b2e_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_76b2e_row4_col6" class="data row4 col6" >7200</td>
#       <td id="T_76b2e_row4_col7" class="data row4 col7" >2022-02-02 00:00:00</td>
#       <td id="T_76b2e_row4_col8" class="data row4 col8" >2022-02-02 00:00:00</td>
#       <td id="T_76b2e_row4_col9" class="data row4 col9" ></td>
#       <td id="T_76b2e_row4_col10" class="data row4 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_76b2e_level0_row5" class="row_heading level0 row5" >79</th>
#       <td id="T_76b2e_row5_col0" class="data row5 col0" >STARK</td>
#       <td id="T_76b2e_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_76b2e_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_76b2e_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_76b2e_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_76b2e_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_76b2e_row5_col6" class="data row5 col6" >0</td>
#       <td id="T_76b2e_row5_col7" class="data row5 col7" >2022-02-02 00:00:00</td>
#       <td id="T_76b2e_row5_col8" class="data row5 col8" >2022-02-02 00:00:00</td>
#       <td id="T_76b2e_row5_col9" class="data row5 col9" ></td>
#       <td id="T_76b2e_row5_col10" class="data row5 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_76b2e_level0_row6" class="row_heading level0 row6" >80</th>
#       <td id="T_76b2e_row6_col0" class="data row6 col0" >PTTEP</td>
#       <td id="T_76b2e_row6_col1" class="data row6 col1" >3.000000</td>
#       <td id="T_76b2e_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_76b2e_row6_col3" class="data row6 col3" >2.000000</td>
#       <td id="T_76b2e_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_76b2e_row6_col5" class="data row6 col5" >5.000000</td>
#       <td id="T_76b2e_row6_col6" class="data row6 col6" >0</td>
#       <td id="T_76b2e_row6_col7" class="data row6 col7" >2022-02-10 00:00:00</td>
#       <td id="T_76b2e_row6_col8" class="data row6 col8" >2022-04-18 00:00:00</td>
#       <td id="T_76b2e_row6_col9" class="data row6 col9" ></td>
#       <td id="T_76b2e_row6_col10" class="data row6 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_76b2e_level0_row7" class="row_heading level0 row7" >77</th>
#       <td id="T_76b2e_row7_col0" class="data row7 col0" >SCB</td>
#       <td id="T_76b2e_row7_col1" class="data row7 col1" >2.630000</td>
#       <td id="T_76b2e_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_76b2e_row7_col3" class="data row7 col3" >1.430000</td>
#       <td id="T_76b2e_row7_col4" class="data row7 col4" >0.000000</td>
#       <td id="T_76b2e_row7_col5" class="data row7 col5" >4.060000</td>
#       <td id="T_76b2e_row7_col6" class="data row7 col6" >0</td>
#       <td id="T_76b2e_row7_col7" class="data row7 col7" >2022-02-14 00:00:00</td>
#       <td id="T_76b2e_row7_col8" class="data row7 col8" >2022-04-22 00:00:00</td>
#       <td id="T_76b2e_row7_col9" class="data row7 col9" ></td>
#       <td id="T_76b2e_row7_col10" class="data row7 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_76b2e_level0_row8" class="row_heading level0 row8" >41</th>
#       <td id="T_76b2e_row8_col0" class="data row8 col0" >ADVANC</td>
#       <td id="T_76b2e_row8_col1" class="data row8 col1" >4.240000</td>
#       <td id="T_76b2e_row8_col2" class="da

# %%
df_merge = pd.merge(stocks, dividend, on='name', how='outer', indicator=True)
left_mask= df_merge._merge == 'left_only'
df_merge[left_mask]
#no_dividend.sort_values(['xdate'],ascending=[True])
# Out:
#         id    name  max_price  min_price status  buy_target  sell_target  \
# 0   9011.0     AIT       9.80       4.12      O         0.0         0.00
# 5   9709.0   COTTO       3.18       1.55      O         0.0         0.00
# 8   9713.0   FORTH      53.00       7.70      O         0.0         0.00
# 9   9188.0     GGC      14.40       9.60      O         0.0         0.00
# 19  9449.0     SIS      48.75      25.75      O        30.5         0.00
# 20  9455.0    SMPC      14.20      10.00      O        14.0         0.00
# 22  9714.0     SSP      14.27       9.10      O         0.0         0.00
# 28  9053.0    BCPG      15.40      11.10      O         0.0         0.00
# 29  9074.0     BPP      20.30      15.30      O         0.0         0.00
# 31  9165.0    ESSO       8.90       7.00      O         0.0         0.00
# 35  9702.0     RBF      24.50      14.70      O        14.3         0.00
# 37   620.0  SINGER      56.75      32.43      X         0.0        52.75
# 38  9470.0    SPRC      11.50       7.75      O         0.0         0.00
# 44  9061.0      BH     175.00     116.50      O         0.0         0.00
# 56  9555.0     TOP      61.50      42.50      O         0.0         0.00
# 57  9541.0     TTB       1.50       0.95      O         0.0         0.00
#
#        volume  beta   cost  ...  q3  q2  q1  dividend  shares  xdate paiddate  \
# 0      140.03  1.00   0.00  ... NaN NaN NaN       NaN     NaN    NaT      NaT
# 5       10.15  0.87   0.00  ... NaN NaN NaN       NaN     NaN    NaT      NaT
# 8   188882.96  0.25   0.00  ... NaN NaN NaN       NaN     NaN    NaT      NaT
# 9        9.31  0.96   0.00  ... NaN NaN NaN       NaN     NaN    NaT      NaT
# 19      33.27  1.75   0.00  ... NaN NaN NaN       NaN     NaN    NaT      NaT
# 20      14.45  0.66   0.00  ... NaN NaN NaN       NaN     NaN    NaT      NaT
# 22   35776.45  0.24   0.00  ... NaN NaN NaN       NaN     NaN    NaT      NaT
# 28     157.15  0.95   0.00  ... NaN NaN NaN       NaN     NaN    NaT      NaT
# 29      28.02  0.83   0.00  ... NaN NaN NaN       NaN     NaN    NaT      NaT
# 31     173.92  1.03   0.00  ... NaN NaN NaN       NaN     NaN    NaT      NaT
# 35     154.65  1.17   0.00  ... NaN NaN NaN       NaN     NaN    NaT      NaT
# 37     222.36  1.11  42.25  ... NaN NaN NaN       NaN     NaN    NaT      NaT
# 38     376.23  1.05   0.00  ... NaN NaN NaN       NaN     NaN    NaT      NaT
# 44     480.52  0.43   0.00  ... NaN NaN NaN       NaN     NaN    NaT      NaT
# 56     817.89  1.22   0.00  ... NaN NaN NaN       NaN     NaN    NaT      NaT
# 57     708.25  1.40   0.00  ... NaN NaN NaN       NaN     NaN    NaT      NaT
#
#    kind  actual     _merge
# 0   NaN     NaN  left_only
# 5   NaN     NaN  left_only
# 8   NaN     NaN  left_only
# 9   NaN     NaN  left_only
# 19  NaN     NaN  left_only
# 20  NaN     NaN  left_only
# 22  NaN     NaN  left_only
# 28  NaN     NaN  left_only
# 29  NaN     NaN  left_only
# 31  NaN     NaN  left_only
# 35  NaN     NaN  left_only
# 37  NaN     NaN  left_only
# 38  NaN     NaN  left_only
# 44  NaN     NaN  left_only
# 56  NaN     NaN  left_only
# 57  NaN     NaN  left_only
#
# [16 rows x 29 columns]

# %% [markdown]
# ### End of Process

# %% [markdown]
# ### Consensus table

# %%
# %pwd
# Out:
# 'C:\\Users\\User\\OneDrive\\A7\\Database'

# %%
os.chdir("C:\\users\\user\\onedrive\\a7")
# %pwd
# Out:
# 'C:\\users\\user\\onedrive\\a7'

# %% [markdown]
# ### Create consensus-new.csv

# %%
# !ruby ruby\\crt-consensus-new.rb
# Out:
# Start at: Saturday, Jun 17 11:16 PM
# Name,Target,Max,Min,Buy,Hold,Sell
# ACE        3.60   3.60   3.60  0  0  0   1
# ADVANC   243.14 257.00 225.00 14  0  0   2
# AEONTS   218.70 248.00 200.00  8  2  0   3
# AH        46.00  54.10  39.13  9  0  0   4
# AIMIRT    14.50  14.50  14.50  1  0  0   5
# AJ        11.80  11.80  11.80  1  0  0   6
# AMATA     26.61  30.00  22.00 13  1  0   7
# ANAN       1.25   1.32   1.10  1  3  1   8
# AOT       81.64  86.00  72.00 13  1  0   9
# AP        14.39  15.50  12.20 15  1  0  10
# ASIAN     10.81  12.00   9.92  1  3  0  11
# ASK       40.00  44.00  37.00  3  0  0  12
# ASP        2.80   2.80   2.80  0  0  0  13
# ASW        9.77  10.30   9.40  3  0  0  14
# AWC        6.13   6.80   5.50  3  3  0  15
# BA        16.88  20.00  14.20  6  1  0  16
# BAM       15.21  18.00  12.00  5  3  0  17
# BANPU      9.47  11.40   8.80  2  6  1  18
# BAY       34.50  37.00  32.00  1  1  0  19
# BBL      186.43 200.00 155.00 14  1  0  20
# BCH       20.88  26.50  16.50 10  4  2  21
# BCP       41.03  50.00  34.50 13  2  0  22
# BCPG      14.50  17.00  10.40  7  2  0  23
# BDMS      34.40  37.40  31.00 16  2  0  24
# BE8       65.08  91.00  49.00  2  1  0  25
# BEC        8.10  10.00   5.90  3  2  3  26
# BEM       11.10  14.00   9.50  9  2  0  27
# BGC        9.88  10.30   9.45  1  1  0  28
# BGRIM     46.31  50.00  42.00 14  1  0  29
# BH       251.69 280.00 200.00  6  7  0  30
# BJC       43.57  46.00  40.50 11  1  0  31
# BLA       40.00  40.00  40.00  1  0  0  32
# BLAND      1.11   1.11   1.11  1  0  0  33
# BPP       16.68  18.20  14.60  3  2  0  34
# BTS       10.06  13.60   8.80  7  2  0  35
# BTSGIF     5.49   6.45   4.82  3  1  0  36
# CBG       70.71  86.00  59.00  1 11  2  37
# CENTEL    58.71  67.00  50.00  7  5  0  38
# CHG        3.73   4.50   3.00  7  8  2  39
# CK        26.91  33.34  24.50 11  0  0  40
# CKP        5.07   6.25   4.00  6  2  0  41
# COM7      37.88  45.00  33.00 11  1  0  42
# COTTO      2.24   2.24   2.24  0  0  0  43
# CPALL     74.00  78.00  70.00 16  1  0  44
# CPF       23.63  28.00  20.00  8 10  0  45
# CPN       80.95  84.00  78.00 10  0  0  46
# CPNREIT   14.30  15.70  12.90  1  1  0  47
# CRC       51.60  55.00  49.00 12  1  0  48
# DCC        2.44   2.60   2.24  0  5  0  49
# DELTA    232.47 750.00  52.50  0  1  0  50
# DIF       15.02  19.00  13.60  3  1  1  51
# DOHOME    13.74  17.70  11.00  2  7  2  52
# DRT        8.32   8.50   8.05  1  2  0  53
# EA        84.19 108.00  64.00  6  3  0  54
# ECL        2.15   2.15   2.15  1  0  0  55
# EGCO     205.43 249.00 166.00  5  2  0  56
# EPG        8.52  10.30   7.50  2  3  0  57
# ESSO      10.00  10.50   9.50  2  1  0  58
# FORTH     37.75  37.75  37.75  1  0  0  59
# FTREIT    12.10  12.30  11.90  2  0  0  60
# GFPT      13.26  15.90  10.56 10  5  0  61
# GGC       12.73  13.40  12.00  0  2  0  62
# GLOBAL    19.46  21.50  18.00  4  7  0  63
# GPSC      76.38  88.00  69.00 12  4  0  64
# GULF      59.42  68.00  48.00 11  2  0  65
# GUNKUL     5.31   6.80   4.35  5  1  0  66
# HANA      41.82  51.00  35.00  4  3  4  67
# HMPRO     16.87  18.50  14.70 12  2  0  68
# HTC       45.00  48.00  41.50  3  1  0  69
# ICHI      16.02  17.20  15.00  5  1  0  70
# III       17.05  20.00  14.40  6  0  0  71
# ILM       23.33  24.80  22.10  4  0  0  72
# IMH       19.05  19.10  19.00  2  0  0  73
# IMPACT    14.70  14.70  14.70  1  0  0  74
# INTUCH    83.83  97.00  68.00  5  0  0  75
# IP        18.10  20.10  16.10  4  0  0  76
# IRPC       2.80   3.70   2.00  6 10  1  77
# IVL       41.90  54.00  35.00 11  4  0  78
# JASIF      7.70   9.00   6.20  1  4  0  79
# JMART     24.00  26.00  22.00  0  0  0  80
# JMT       51.67  66.00  38.00  5  1  0  81
# KBANK    162.50 178.00 140.00 13  1  0  82
# KCE       40.12  61.00  32.00  2  5  6  83
# KEX       11.58  16.50   9.10  0  2  0  84
# KKP       79.73  90.00  72.00  8  2  1  85
# KSL        4.77   5.30   4.20  3  0  0  86
# KTB       21.70  24.75  19.40 14  0  0  87
# KTC       65.44  75.00  52.00  6  2  1  88
# LALIN      9.33  11.30   6.50  2  1  2  89
# LANNA     16.00  16.00  16.00  1  0  0  90
# LH        10.67  11.50   8.90 11  3  0  91
# LPF       14.90  15.00  14.80  2  0  0  92
# LPH        6.30   6.30   6.30  1  0  0  93
# LPN        3.84   4.20   3.40  0  2  0  94
# M         55.69  64.00  51.40  6  4  0  95
# MAJOR     20.62  23.20  17.50 10  1  0  96
# MAKRO     43.71  49.00  37.50  8  3  1  97
# MC        14.59  17.10  13.50  7  0  0  98
# MCS       12.20  12.20  12.20  0  0  0  99
# MEGA      52.03  65.00  43.00  6  1  0 100
# MINT      40.57  43.50  37.00 14  0  0 101
# MTC       38.88  49.00  28.00  4  6  3 102
# NER        5.86   7.10   5.00  4  2  1 103
# NOBLE      5.15   6.05   4.24  2  1  1 104
# ONEE       6.12   7.00   4.75  7  3  0 105
# OR        26.17  33.50  21.50 10  2  1 106
# ORI       13.79  15.10  12.50  9  0  0 107
# OSP       30.99  36.00  25.00  8  6  1 108
# PLANB      9.27  10.70   7.77  5  6  0 109
# PRM        9.54  11.00   8.30  6  0  0 110
# PSH       11.23  13.50   8.00  1  4  5 111
# PSL       15.60  19.00  14.00  4  1  0 112
# PTG       16.69  19.50  15.00  9  1  0 113
# PTT       38.95  46.00  28.00 13  1  1 114
# PTTEP    170.72 200.00 160.00 12  6  0 115
# PTTGC     47.73  62.00  37.00  7  8  1 116
# QH         2.49   2.90   2.00  4  7  0 117
# RATCH     47.50  52.50  38.00  5  2  0 118
# RBF       12.86  13.80  11.60  3  2  0 119
# RCL       18.00  18.00  18.00  0  0  0 120
# RJH       30.15  33.00  26.60  0  0  0 121
# ROJNA      7.46   8.50   6.70  3  1  0 122
# RS        15.33  17.90  11.30  1  4  2 123
# SAPPE     84.10  97.00  73.00  9  2  0 124
# SAT       22.81  24.00  21.00  7  4  1 125
# SAWAD     59.46  70.00  42.00  6  4  3 126
# SC         4.98   5.22   4.50  9  0  0 127
# SCB      135.67 160.00 122.00 12  0  0 128
# SCC      351.38 385.00 300.00  8  5  0 129
# SCCC     152.50 180.00 124.00  1  3  0 130
# SCGP      51.79  65.00  33.00  9  4  1 131
# SENA       3.64   4.10   3.23  1  1  1 132
# SINGER     8.87  11.60   6.00  0  0  0 133
# SIRI       2.18   2.32   1.93 11  2  0 134
# SIS       25.75  26.50  25.00  1  1  0 135
# SKR       16.40  16.40  16.40  1  0  0 136
# SMPC      10.50  10.50  10.50  0  0  0 137
# SNC       12.78  16.50   9.85  0  0  0 138
# SPALI     26.57  29.50  21.30 12  4  0 139
# SPRC      11.50  12.50   9.80 11  4  0 140
# SSP       10.88  14.00   9.00  3  2  0 141
# STA       21.76  25.00  20.00  2  3  0 142
# STANLY   236.92 245.00 216.00  4  1  0 143
# STEC      14.52  18.02  11.30  6  3  0 144
# STGT      10.50  11.00  10.00  0  0  0 145
# SVI        9.03  10.50   8.00  1  4  1 146
# SYNEX     16.44  20.34  11.50  4  2  1 147
# TASCO     22.28  26.00  20.60  2  6  0 148
# TCAP      50.43  55.00  45.00  3  4  0 149
# TFFIF      9.55   9.70   9.40  2  0  0 150
# TFG        5.48   6.00   4.80  3  2  0 151
# THANI      4.52   4.90   3.95  5  2  0 152
# THG       48.30  56.00  45.00  0  0  0 153
# TIDLOR    29.66  34.25  25.00 12  3  0 154
# TIPH      74.00  75.00  73.00  2  0  0 155
# TISCO    107.73 125.00  90.25  7  7  0 156
# TKN       11.70  11.70  11.70  1  0  0 157
# TKS       13.70  13.70  13.70  1  0  0 158
# TMT        8.15   8.70   7.60  0  1  0 159
# TOA       40.20  41.00  40.00  5  0  0 160
# TOP       62.50  78.00  52.50 16  2  0 161
# TPIPL      2.34   2.44   2.24  1  1  0 162
# TPIPP      3.75   4.00   3.50  1  1  0 163
# TQM       39.80  48.00  29.00  4  1  0 164
# TRUE       8.89  10.00   7.60  5  2  0 165
# TSE        3.18   3.28   3.10  3  0  0 166
# TTA        8.85   9.00   8.70  2  0  0 167
# TTB        1.62   1.84   1.50  9  3  0 168
# TTW       10.05  12.10   8.00  1  0  0 169
# TU        17.85  22.00  13.50 13  3  0 170
# TVO       24.42  28.00  21.00  0  4  0 171
# UTP       13.50  13.50  13.50  1  0  0 172
# VGI        3.69   5.50   2.90  2  7  1 173
# VIBHA      2.95   2.95   2.95  1  0  0 174
# WHA        4.80   5.05   4.00  9  2  0 175
# WHAIR      9.20   9.20   9.20  1  0  0 176
# WHART     12.75  13.00  12.50  2  0  0 177
# WHAUP      5.25   5.50   5.00  2  0  0 178
# WICE       9.17  11.00   7.90  1  2  0 179
# WORK      19.40  20.80  18.00  1  1  0 180
# End at: Saturday, Jun 17 11:23 PM

# %%
os.chdir("C:\\users\\user\\onedrive\\a7\\Database")
# %pwd
# Out:
# 'C:\\users\\user\\onedrive\\a7\\Database'

# %% [markdown]
# ### Convert csv to dataframe

# %%
	data_path = "../data/"
	file_name   = 'consensus-new.csv'
	input_file = data_path + file_name
	df = pd.read_csv(input_file, sep=',', index_col=None)
	df
# Out:
#        Name  Target    Max     Min  Buy  Hold  Sell
# 0       ACE    3.60    3.6    3.60    0     0     0
# 1    ADVANC  243.14  257.0  225.00   14     0     0
# 2    AEONTS  218.70  248.0  200.00    8     2     0
# 3        AH   46.00   54.1   39.13    9     0     0
# 4    AIMIRT   14.50   14.5   14.50    1     0     0
# ..      ...     ...    ...     ...  ...   ...   ...
# 175   WHAIR    9.20    9.2    9.20    1     0     0
# 176   WHART   12.75   13.0   12.50    2     0     0
# 177   WHAUP    5.25    5.5    5.00    2     0     0
# 178    WICE    9.17   11.0    7.90    1     2     0
# 179    WORK   19.40   20.8   18.00    1     1     0
#
# [180 rows x 7 columns]

# %%
# Convert column names to lowercase
df.columns = df.columns.str.lower()

# %%
#df.rename(columns={'target':'price'},inplace=True)

# %%
df.query('name == "BCH"')
# Out:
#    name  target   max   min  buy  hold  sell
# 20  BCH   20.88  26.5  16.5   10     4     2

# %%
sqlDel = """
DELETE FROM consensus"""
rp = conlite.execute(sqlDel)
rp.rowcount
# Out:
# 186

# %%
# Write dataframe to consensus table
df.to_sql('consensus', conlite, if_exists='append', index=False)

# %%
sql = '''
SELECT * FROM consensus ORDER BY name'''
css = pd.read_sql(sql, conlite)
css.shape
# Out:
# (180, 8)

# %%
css.query('name == "KTC"')
# Out:
#     id name  target   max   min  buy  hold  sell
# 87  88  KTC   65.44  75.0  52.0    6     2     1

# %% [markdown]
# ### End of Consensus table

# %%
sql = '''
SELECT *
FROM profits
ORDER BY name'''
df_prf = pd.read_sql(sql, conmy)
df_prf.shape

# %%
sql = '''
SELECT *
FROM stocks
ORDER BY market, name'''
df_stk = pd.read_sql(sql, conlite)
df_stk.shape

# %%
df_merge = pd.merge(df_prf,df_stk,on='name',how='outer',indicator=True)
df_merge.shape

# %%
left_mask= df_merge._merge == 'left_only'
df_merge[left_mask]

# %%
right_mask= df_merge._merge == 'right_only'
df_merge[right_mask]

# %%
both_mask= df_merge._merge == 'both'
df_merge[both_mask]

# %%
sql = '''
SELECT * FROM SALES ORDER BY name'''
sales = pd.read_sql(sql, conlite)
sales.shape[0]

# %%
sql = '''
DELETE FROM sales
WHERE name = "TCAP"'''
rp = conlite.execute(sql)
rp.rowcount

# %% [markdown]
# ### Temp process

# %%
sql = """
SELECT market,name,buy_target,qty
FROM stocks
WHERE buy_target = 0 AND status IN ('B','O')
ORDER BY market, name"""
df_stocks = pd.read_sql(sql, conlite)
df_stocks
# Out:
#     market     name  buy_target  qty
# 0      SET    CPNCG           0    0
# 1      SET  CPNREIT           0    0
# 2      SET      JWD           0    0
# 3      SET    LANNA           0    0
# 4      SET      PTL           0    0
# 5      SET    TFFIF           0    0
# 6      SET      VNG           0    0
# 7   SET100    AMATA           0    0
# 8   SET100      BAM           0    0
# 9   SET100      BCP           0    0
# 10  SET100    STARK           0    0
# 11   SET50      BLA           0    0
# 12   SET50    JMART           0    0
# 13   SET50      PTT           0    0

# %% [markdown]
# ### Process to set target price

# %% [markdown]
# #### 1) Set50 records

# %%
pd.read_sql_query('SELECT * FROM stocks WHERE market = "SET50" AND status = "O" ORDER BY name', conlite)
# Out:
#      id   name  max_price  min_price status  buy_target  sell_target  \
# 0  9712  BANPU      14.90       9.65      O       11.50            0
# 1  9722    BLA      48.00      26.00      O       37.00            0
# 2  9231    IVL      52.00      36.00      O       42.00            0
# 3  9727  JMART      64.00      30.50      O       43.00            0
# 4  9733    PTT      41.25      32.75      O       34.00            0
# 5  9717    TTB       0.00       0.00      O        0.95            0
#
#        volume  beta  cost    qty  buy_spread  sell_spread  available_qty  bl  \
# 0  1316230.44  1.52   0.0  12000          -4            4              0   0
# 1      285.38  0.88   0.0   4000          -4            4              0   0
# 2     1112.71  1.41  48.5   3000         -11           11              0   0
# 3      521.57  1.65   0.0   3000          -4            4              0   0
# 4     2188.39  1.00   0.0   4500          -4            4              0   0
# 5        0.00  0.00   0.0  90000          -4            4              0   0
#
#    sh reason market
# 0   0     1L  SET50
# 1   0    XXX  SET50
# 2   0   13WL  SET50
# 3   0    XXX  SET50
# 4   0    XXX  SET50
# 5   0   52WL  SET50

# %%
name = 'PTT'
limit = 20 # 1 month of data
sql = """
SELECT P.*
FROM price P
WHERE P.name = '%s'
ORDER BY date DESC
LIMIT %s"""
sql = sql % (name, limit)
df = pd.read_sql(sql, const)
df.describe().round(2)
# Out:
#        price   maxp   minp          qty   opnp
# count  20.00  20.00  20.00        20.00  20.00
# mean   34.95  35.14  34.42  47847446.95  34.71
# std     1.02   0.98   0.93  19277106.16   0.99
# min    33.50  34.00  33.00  19667139.00  33.25
# 25%    34.25  34.50  33.94  31321828.00  34.19
# 50%    34.62  34.75  34.25  46988327.50  34.38
# 75%    35.31  35.50  34.81  59450079.50  35.25
# max    37.00  37.00  36.25  88922626.00  37.00

# %% [markdown]
# #### 2) Set100 records

# %%
pd.read_sql_query('SELECT * FROM stocks WHERE market = "SET100" AND status = "O" ORDER BY name', conlite)
# Out:
#      id   name  max_price  min_price status  buy_target  sell_target  volume  \
# 0  9719  AMATA      23.00       17.1      O          17            0  169.77
# 1  9720    BAM      22.30       15.9      O          16            0  405.08
# 2  9721    BCP      35.25       23.3      O          29            0  264.08
# 3  9736  STARK       5.45        3.9      O           4            0  134.56
#
#    beta  cost    qty  buy_spread  sell_spread  available_qty  bl  sh reason  \
# 0  1.56     0   6000          -4            4              0   0   0    XXX
# 1  1.30     0   6000          -4            4              0   0   0    XXX
# 2  0.94     0   3000          -4            4              0   0   0    XXX
# 3  0.90     0  25000          -4            4              0   0   0    XXX
#
#    market
# 0  SET100
# 1  SET100
# 2  SET100
# 3  SET100

# %%
name = 'STARK'
limit = 60 # 3 month of data
sql = """
SELECT P.*
FROM price P
WHERE P.name = '%s'
ORDER BY date DESC
LIMIT %s"""
sql = sql % (name, limit)
df = pd.read_sql(sql, const)
df.describe().round(2)
# Out:
#        price   maxp   minp           qty   opnp
# count  60.00  60.00  60.00  6.000000e+01  60.00
# mean    4.42   4.50   4.37  2.817365e+07   4.44
# std     0.27   0.28   0.27  3.506276e+07   0.28
# min     4.00   4.14   3.90  3.313251e+06   4.02
# 25%     4.22   4.30   4.18  9.217222e+06   4.22
# 50%     4.34   4.41   4.31  1.462364e+07   4.35
# 75%     4.57   4.67   4.51  2.773165e+07   4.58
# max     5.05   5.10   4.92  1.688560e+08   5.05

# %% [markdown]
# #### 3) Set records

# %%
pd.read_sql_query('SELECT * FROM stocks WHERE market = "SET" AND status = "O" ORDER BY name', conlite)
# Out:
#      id     name  max_price  min_price status  buy_target  sell_target  \
# 0  9724    CPNCG      12.80      10.40      O        0.00            0
# 1  9725  CPNREIT      22.40      17.90      O        0.00            0
# 2  9729      JWD      24.40      12.50      O        0.00            0
# 3  9730    LANNA      29.00      15.00      O        0.00            0
# 4  9732      PTL      30.50      20.60      O        0.00            0
# 5  9714      SSP      14.27       9.10      O        8.75            0
# 6  9739    TFFIF       8.50       7.00      O        0.00            0
# 7  9740      VNG      10.10       7.05      O        0.00            0
#
#      volume  beta  cost    qty  buy_spread  sell_spread  available_qty  bl  \
# 0      3.15  0.49     0      0          -4            4              0   0
# 1     21.29  0.47     0      0          -4            4              0   0
# 2     96.10  1.45     0      0          -4            4              0   0
# 3    111.34  0.86     0      0          -4            4              0   0
# 4     53.78  0.81     0      0          -4            4              0   0
# 5  35776.45  0.24     0  10000          -9            6              0   0
# 6     24.39  0.41     0      0          -4            4              0   0
# 7     17.16  0.73     0      0          -4            4              0   0
#
#    sh reason market
# 0   0    XXX    SET
# 1   0    XXX    SET
# 2   0    XXX    SET
# 3   0    XXX    SET
# 4   0    XXX    SET
# 5   0   52WL    SET
# 6   0    XXX    SET
# 7   0    XXX    SET

# %%
name = 'VNG'
limit = 120 # 6 month of data
sql = """
SELECT P.*
FROM price P
WHERE P.name = '%s'
ORDER BY date DESC
LIMIT %s"""
sql = sql % (name, limit)
df = pd.read_sql(sql, const)
df.describe().round(2)
# Out:
#         price    maxp    minp          qty    opnp
# count  120.00  120.00  120.00       120.00  120.00
# mean     7.66    7.79    7.58   2248783.37    7.69
# std      0.37    0.39    0.35   2150419.52    0.37
# min      7.10    7.20    7.10    125400.00    7.20
# 25%      7.35    7.45    7.30    707225.75    7.40
# 50%      7.55    7.70    7.45   1490555.00    7.57
# 75%      7.95    8.15    7.85   2832852.25    8.00
# max      8.55    8.75    8.45  10934861.00    8.55
