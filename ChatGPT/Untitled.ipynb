# %%
# Fetch Everyday News
import newspaper as np
news_paper = np.build("http://cnn.com")
for news in news_paper.articles:
    news.download()
    news.parse()
    print("URL: ", news.url)
    print("Title: ", news.title)
    print("News: ", news.text)
# Out:
# URL:  http://cnn.com/business/media
# Title:  CNN Business
# News:  1. How relevant is this ad to you?
#
# Video player was slow to load content Video content never loaded Ad froze or did not finish loading Video content did not start after ad Audio on ad was too loud Other issues
# URL:  http://cnn.com/travel/news
# Title:  Travel News - CNN
# News:  Sand surfing the tallest sand dune in North America, diving into Caribbean blue waters and rock climbing an entire city of rocks. Meet the adventurous side of Idaho.
# URL:  https://commercial.cnn.com/latest-news/press/dbs-and-cnns-campaign-exploring-digitalization-and-sustainability/
# Title:  DBS and CNN’s campaign exploring digitalization and sustainability
# ...
