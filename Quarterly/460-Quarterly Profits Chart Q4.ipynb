# %%
ticker = 'SC'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3")
conlt = engine.connect()
engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

year = 2022
quarter = 4
strqtr = 'Q' + str(quarter)

# %%
sql = '''
SELECT * 
FROM epss
WHERE name = '%s'
AND year >= %s-1
ORDER BY year, quarter
'''
sql = sql % (ticker,year)
print(sql)
# Out:
# SELECT *
# FROM epss
# WHERE name = 'SC'
# AND year >= 2022-1
# ORDER BY year, quarter

# %%
rp = conlt.execute(sql)
profit = pd.DataFrame(rp.fetchall())
profit.columns = rp.keys()

with plt.style.context('my_custom_style'):
    fig_name = ticker+'-qtr'+'.png'
    fig_path = '../FIG/profits/'+fig_name    

    ax = profit.plot.bar(x='quarter', y=['q_amt'])
    ax.set_title(ticker)
    ax.set_ylabel("Profit Amount")
    plt.savefig(fig_path)
    plt.show()

# %%
sql = '''
SELECT q_amt 
FROM epss
WHERE name = '%s'
AND year = %s-1 
ORDER BY year, quarter
'''
sql = sql % (ticker,year)
print(sql)
# Out:
# SELECT q_amt
# FROM epss
# WHERE name = 'SC'
# AND year = 2022-1
# ORDER BY year, quarter

# %%
data_last_year = pd.read_sql(sql, conlt)
data_last_year
# Out:
#     q_amt
# 0  416812
# 1  520000
# 2  544638
# 3  580678

# %%
profit_last_year = data_last_year.values
profit_last_year
# Out:
# array([[416812],
#        [520000],
#        [544638],
#        [580678]], dtype=int64)

# %%
sql = '''
SELECT q_amt 
FROM epss
WHERE name = '%s'
AND year = %s
ORDER BY year, quarter
'''
sql = sql % (ticker,year)
print(sql)
# Out:
# SELECT q_amt
# FROM epss
# WHERE name = 'SC'
# AND year = 2022
# ORDER BY year, quarter

# %%
data_this_year = pd.read_sql(sql, conlt)
data_this_year
# Out:
#     q_amt
# 0  387683
# 1  581073
# 2  652224
# 3  935034

# %%
profit_this_year = data_this_year.values
profit_this_year
# Out:
# array([[387683],
#        [581073],
#        [652224],
#        [935034]], dtype=int64)

# %%
# from python data analytics
with plt.style.context('my_custom_style'):
    fig_name = ticker+'-'+str(year)+'-'+str(quarter)+'-Q'+'.png'
    fig_path = '../FIG/profits/'+fig_name    
    
    index = np.arange(4)
    bw = 0.4
    
    plt.title(ticker, fontsize=40)
    plt.ylabel("Profit Amount", fontsize=20)   
    
    plt.bar(index + 0.0, profit_last_year.reshape(profit_last_year.shape[0]), bw, color='y')
    plt.bar(index + bw,   profit_this_year.reshape(profit_this_year.shape[0]), bw, color='g')    

    plt.xticks(index+1*bw, ['2022-Q1','2022-Q2','2022-Q3','2022-Q4'])

    plt.savefig(fig_path)
    plt.show()

# %%
sql = '''
SELECT *
FROM yr_profits
WHERE name = '%s' AND quarter = '%s'
'''
sql = sql % (ticker,strqtr)
print(sql)
# Out:
# SELECT *
# FROM yr_profits
# WHERE name = 'SC' AND quarter = 'Q4'

# %%
yr_profits = pd.read_sql(sql, conlt)
yr_profits
# Out:
#       id name  year quarter  latest_amt  previous_amt  inc_amt    inc_pct  \
# 0  10435   SC  2016      Q4     1968213       1895280    72933   3.848139
# 1  15842   SC  2017      Q4     1258576       1968213  -709637 -36.054888
# 2  35579   SC  2018      Q4     1781743       1258576   523167  41.568169
# 3  56441   SC  2019      Q4     2026424       1781743   244681  13.732676
# 4  80036   SC  2020      Q4     1897935       2026424  -128489  -6.340677
# 5  92068   SC  2021      Q4     2062128       1897935   164193   8.650000
# 6  93091   SC  2022      Q4     2556014       2062128   493886  23.950000
#
#    ticker_id
# 0        425
# 1        425
# 2        425
# 3        425
# 4        425
# 5        425
# 6        425

# %%
with plt.style.context('my_custom_style'):
    fig_name = ticker+'-'+str(year)+'-'+str(quarter)+'-Y'+'.png'
    fig_path = '../fig/profits/'+fig_name
    ax = yr_profits.plot.bar(x='year', y=['previous_amt','latest_amt','inc_amt'])
    ax.set_title(ticker,fontsize=40)
    ax.set_ylabel("Profit Amount",fontsize=20)
    plt.savefig(fig_path)
    plt.show()

# %%
sql = """
SELECT * 
FROM tickers
WHERE name = '%s'
"""
sql = sql % ticker
df_tmp = pd.read_sql(sql, conpg)
df_tmp
# Out:
#     id name                                    full_name  \
# 0  431   SC  SC ASSET CORPORATION PUBLIC COMPANY LIMITED
#
#                     sector             subsector          market  \
# 0  Property & Construction  Property Development  sSET / SETTHSI
#
#            website                 created_at                 updated_at
# 0  www.scasset.com 2018-04-22 04:29:38.757367 2018-07-04 15:30:19.772060
