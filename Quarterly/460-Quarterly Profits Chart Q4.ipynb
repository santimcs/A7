# %%
ticker = 'ASK'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3")
conlt = engine.connect()
engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

year = 2022
quarter = 4
strqtr = 'Q' + str(quarter)

# %%
sql = '''
SELECT * 
FROM epss
WHERE name = '%s'
AND year >= %s-1
ORDER BY year, quarter
'''
sql = sql % (ticker,year)
print(sql)
# Out:
# SELECT *
# FROM epss
# WHERE name = 'ASK'
# AND year >= 2022-1
# ORDER BY year, quarter

# %%
rp = conlt.execute(sql)
profit = pd.DataFrame(rp.fetchall())
profit.columns = rp.keys()

with plt.style.context('my_custom_style'):
    fig_name = ticker+'-qtr'+'.png'
    fig_path = '../FIG/profits/'+fig_name    

    ax = profit.plot.bar(x='quarter', y=['q_amt'])
    ax.set_title(ticker)
    ax.set_ylabel("Profit Amount")
    plt.savefig(fig_path)
    plt.show()

# %%
sql = '''
SELECT q_amt 
FROM epss
WHERE name = '%s'
AND year = %s-1 
ORDER BY year, quarter
'''
sql = sql % (ticker,year)
print(sql)
# Out:
# SELECT q_amt
# FROM epss
# WHERE name = 'ASK'
# AND year = 2022-1
# ORDER BY year, quarter

# %%
data_last_year = pd.read_sql(sql, conlt)
data_last_year
# Out:
#     q_amt
# 0  276197
# 1  269084
# 2  314336
# 3  343187

# %%
profit_last_year = data_last_year.values
profit_last_year
# Out:
# array([[276197],
#        [269084],
#        [314336],
#        [343187]], dtype=int64)

# %%
sql = '''
SELECT q_amt 
FROM epss
WHERE name = '%s'
AND year = %s
ORDER BY year, quarter
'''
sql = sql % (ticker,year)
print(sql)
# Out:
# SELECT q_amt
# FROM epss
# WHERE name = 'ASK'
# AND year = 2022
# ORDER BY year, quarter

# %%
data_this_year = pd.read_sql(sql, conlt)
data_this_year
# Out:
#     q_amt
# 0  351037
# 1  359015
# 2  391437
# 3  410651

# %%
profit_this_year = data_this_year.values
profit_this_year
# Out:
# array([[351037],
#        [359015],
#        [391437],
#        [410651]], dtype=int64)

# %%
# from python data analytics
with plt.style.context('my_custom_style'):
    fig_name = ticker+'-'+str(year)+'-'+str(quarter)+'-Q'+'.png'
    fig_path = '../FIG/profits/'+fig_name    
    
    index = np.arange(4)
    bw = 0.4
    
    plt.title(ticker, fontsize=40)
    plt.ylabel("Profit Amount", fontsize=20)   
    
    plt.bar(index + 0.0, profit_last_year.reshape(profit_last_year.shape[0]), bw, color='y')
    plt.bar(index + bw,   profit_this_year.reshape(profit_this_year.shape[0]), bw, color='g')    

    plt.xticks(index+1*bw, ['2022-Q1','2022-Q2','2022-Q3','2022-Q4'])

    plt.savefig(fig_path)
    plt.show()

# %%
sql = '''
SELECT *
FROM yr_profits
WHERE name = '%s' AND quarter = '%s'
'''
sql = sql % (ticker,strqtr)
print(sql)
# Out:
# SELECT *
# FROM yr_profits
# WHERE name = 'ASK' AND quarter = 'Q4'

# %%
yr_profits = pd.read_sql(sql, conlt)
yr_profits
# Out:
#       id name  year quarter  latest_amt  previous_amt  inc_amt    inc_pct  \
# 0  10320  ASK  2016      Q4      706684        680613    26071   3.830517
# 1  15492  ASK  2017      Q4      745043        706684    38359   5.428027
# 2  35287  ASK  2018      Q4      811289        745043    66246   8.891567
# 3  56129  ASK  2019      Q4      869534        811289    58245   7.179316
# 4  79834  ASK  2020      Q4      883064        869534    13530   1.556006
# 5  91926  ASK  2021      Q4     1202804        883064   319740  36.210000
# 6  93005  ASK  2022      Q4     1512140       1202804   309336  25.720000
#
#    ticker_id
# 0         38
# 1         38
# 2         38
# 3         38
# 4         38
# 5         38
# 6         38

# %%
with plt.style.context('my_custom_style'):
    fig_name = ticker+'-'+str(year)+'-'+str(quarter)+'-Y'+'.png'
    fig_path = '../fig/profits/'+fig_name
    ax = yr_profits.plot.bar(x='year', y=['previous_amt','latest_amt','inc_amt'])
    ax.set_title(ticker,fontsize=40)
    ax.set_ylabel("Profit Amount",fontsize=20)
    plt.savefig(fig_path)
    plt.show()

# %%
sql = """
SELECT * 
FROM tickers
WHERE name = '%s'
"""
sql = sql % ticker
df_tmp = pd.read_sql(sql, conpg)
df_tmp
# Out:
#    id name                                    full_name      sector  \
# 0  42  ASK  ASIA SERMKIJ LEASING PUBLIC COMPANY LIMITED  Financials
#
#               subsector market        website                 created_at  \
# 0  Finance & Securities    SET  www.ask.co.th 2018-04-22 04:29:36.368184
#
#                   updated_at
# 0 2022-01-15 03:54:48.237063
