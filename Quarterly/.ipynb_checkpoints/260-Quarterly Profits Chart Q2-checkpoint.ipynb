# %%
ticker = 'FPT'
year = 2023
quarter = 2
strqtr = 'Q' + str(quarter)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('sqlite:///c:\\ruby\\portlt\\db\\development.sqlite3')
conlt = engine.connect()
engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()
engine = create_engine(
    "postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development"
)
conpg = engine.connect()

format_dict = {'latest_amt':'{:,}','previous_amt':'{:,}','q_amt':'{:,}',
               'inc_amt':'{:,}','inc_pct':'{:.2f}'}

# %%
sql = '''
SELECT * 
FROM epss
WHERE name = '%s'
AND ((year = %s-2 AND quarter >= %s+1) OR (year >= %s-1))
ORDER BY year, quarter
'''
sql = sql % (ticker,year,quarter,year)
print(sql)
# Out:
# SELECT *
# FROM epss
# WHERE name = 'FPT'
# AND ((year = 2023-2 AND quarter >= 2+1) OR (year >= 2023-1))
# ORDER BY year, quarter

# %%
rp = conlt.execute(sql)
profit = pd.DataFrame(rp.fetchall())
profit.columns = rp.keys()

with plt.style.context('my_custom_style'):
    fig_name = ticker+'-qtr'+'.png'
    fig_path = '../FIG/profits/'+fig_name    

    ax = profit.plot.bar(x='quarter', y=['q_amt'])
    ax.set_title(ticker)
    ax.set_ylabel("Profit Amount")
    plt.savefig(fig_path)
    plt.show()

# %% [markdown]
# ### Create previous year data

# %%
sql = '''
SELECT q_amt 
FROM epss
WHERE name = '%s'
AND ((year = %s-2 AND quarter >= %s+1) OR (year = %s-1 AND quarter <= %s))
ORDER BY year, quarter
'''
sql = sql % (ticker,year,quarter,year,quarter)
print(sql)
# Out:
# SELECT q_amt
# FROM epss
# WHERE name = 'FPT'
# AND ((year = 2023-2 AND quarter >= 2+1) OR (year = 2023-1 AND quarter <= 2))
# ORDER BY year, quarter

# %%
data_last_year = pd.read_sql(sql, conlt)
data_last_year.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_89abe_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >q_amt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89abe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_89abe_row0_col0" class="data row0 col0" >463,360</td>
#     </tr>
#     <tr>
#       <th id="T_89abe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_89abe_row1_col0" class="data row1 col0" >157,952</td>
#     </tr>
#     <tr>
#       <th id="T_89abe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_89abe_row2_col0" class="data row2 col0" >750,118</td>
#     </tr>
#     <tr>
#       <th id="T_89abe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_89abe_row3_col0" class="data row3 col0" >312,654</td>
#     </tr>
#   </tbody>
# </table>

# %%
profit_last_year = data_last_year.values
profit_last_year
# Out:
# array([[463360],
#        [157952],
#        [750118],
#        [312654]], dtype=int64)

# %% [markdown]
# ### Create current year data

# %%
sql = '''
SELECT q_amt 
FROM epss
WHERE name = '%s'
AND ((year = %s-1 AND quarter >= %s+1) OR (year = %s))
ORDER BY year, quarter
'''
sql = sql % (ticker,year,quarter,year)
print(sql)
# Out:
# SELECT q_amt
# FROM epss
# WHERE name = 'FPT'
# AND ((year = 2023-1 AND quarter >= 2+1) OR (year = 2023))
# ORDER BY year, quarter

# %%
data_this_year = pd.read_sql(sql, conlt)
data_this_year.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_49f37_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >q_amt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49f37_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_49f37_row0_col0" class="data row0 col0" >680,405</td>
#     </tr>
#     <tr>
#       <th id="T_49f37_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_49f37_row1_col0" class="data row1 col0" >721,288</td>
#     </tr>
#     <tr>
#       <th id="T_49f37_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_49f37_row2_col0" class="data row2 col0" >314,905</td>
#     </tr>
#     <tr>
#       <th id="T_49f37_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_49f37_row3_col0" class="data row3 col0" >316,979</td>
#     </tr>
#   </tbody>
# </table>

# %%
profit_this_year = data_this_year.values
profit_this_year
# Out:
# array([[680405],
#        [721288],
#        [314905],
#        [316979]], dtype=int64)

# %%
# from python data analytics
with plt.style.context('my_custom_style'):
    fig_name = ticker+'-'+str(year)+'-'+str(quarter)+'-Q'+'.png'
    fig_path = '../FIG/profits/'+fig_name    
    
    index = np.arange(4)
    bw = 0.4
    
    plt.title(ticker, fontsize=40)
    plt.ylabel("Profit Amount", fontsize=20)   
    
    plt.bar(index + 0.0, profit_last_year.reshape(profit_last_year.shape[0]), bw, color='y')
    plt.bar(index + bw,   profit_this_year.reshape(profit_this_year.shape[0]), bw, color='g')   

    plt.xticks(index+1*bw, ['2022-Q3','2022-Q4','2023-Q1','2023-Q2'])

    plt.savefig(fig_path)
    plt.show()

# %%
sql = '''
SELECT *
FROM yr_profits
WHERE name = '%s' AND quarter = 'Q%s'
'''
sql = sql % (ticker,quarter)
print(sql)
# Out:
# SELECT *
# FROM yr_profits
# WHERE name = 'FPT' AND quarter = 'Q2'

# %%
yr_profits = pd.read_sql(sql, conlt)
yr_profits.sort_values(['year'],ascending=[False]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e4f67_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >year</th>
#       <th class="col_heading level0 col3" >quarter</th>
#       <th class="col_heading level0 col4" >latest_amt</th>
#       <th class="col_heading level0 col5" >previous_amt</th>
#       <th class="col_heading level0 col6" >inc_amt</th>
#       <th class="col_heading level0 col7" >inc_pct</th>
#       <th class="col_heading level0 col8" >ticker_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4f67_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_e4f67_row0_col0" class="data row0 col0" >95354</td>
#       <td id="T_e4f67_row0_col1" class="data row0 col1" >FPT</td>
#       <td id="T_e4f67_row0_col2" class="data row0 col2" >2023</td>
#       <td id="T_e4f67_row0_col3" class="data row0 col3" >Q2</td>
#       <td id="T_e4f67_row0_col4" class="data row0 col4" >2,033,577</td>
#       <td id="T_e4f67_row0_col5" class="data row0 col5" >1,684,084</td>
#       <td id="T_e4f67_row0_col6" class="data row0 col6" >349,493</td>
#       <td id="T_e4f67_row0_col7" class="data row0 col7" >20.75</td>
#       <td id="T_e4f67_row0_col8" class="data row0 col8" >746</td>
#     </tr>
#     <tr>
#       <th id="T_e4f67_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_e4f67_row1_col0" class="data row1 col0" >95193</td>
#       <td id="T_e4f67_row1_col1" class="data row1 col1" >FPT</td>
#       <td id="T_e4f67_row1_col2" class="data row1 col2" >2022</td>
#       <td id="T_e4f67_row1_col3" class="data row1 col3" >Q2</td>
#       <td id="T_e4f67_row1_col4" class="data row1 col4" >1,684,084</td>
#       <td id="T_e4f67_row1_col5" class="data row1 col5" >2,635,355</td>
#       <td id="T_e4f67_row1_col6" class="data row1 col6" >-951,271</td>
#       <td id="T_e4f67_row1_col7" class="data row1 col7" >-36.10</td>
#       <td id="T_e4f67_row1_col8" class="data row1 col8" >746</td>
#     </tr>
#   </tbody>
# </table>

# %%
with plt.style.context('my_custom_style'):
    fig_name = ticker+'-'+str(year)+'-'+str(quarter)+'-Y'+'.png'
    fig_path = '../fig/profits/'+fig_name
    ax = yr_profits.plot.bar(x='year', y=['previous_amt','latest_amt','inc_amt'])
    ax.set_title(ticker,fontsize=40)
    ax.set_ylabel("Profit Amount",fontsize=20)
    plt.savefig(fig_path)
    plt.show()

# %% [markdown]
# ### Change grade from quarterly performance

# %%
def update_buy_grade(grade,period,name):
    sql = "UPDATE buy SET grade = '%s', period = %s WHERE name = '%s' AND active=1"
    sql = sql % (grade, period, name)
    rp = const.execute(sql)
    return "Records updated = " + str(rp.rowcount)

# %%
name = 'SCC'
sql = """
SELECT * 
FROM buy 
WHERE name = '%s'
"""
sql = sql % name
df_tmp = pd.read_sql(sql, const)
df_tmp['volume'] = df_tmp.volbuy.astype(int)
cols = 'date volume price active dividend period grade'.split()
df_tmp[cols]
# Out:
#          date  volume  price  active  dividend period grade
# 0  2021-09-20     600  405.0       1       8.0      4    C2

# %%
grade = 'C2'
period = 3
update_buy_grade(grade,period,name)
# Out:
# 'Records updated = 1'

# %%
sql = '''
SELECT * 
FROM tickers
WHERE name = '%s'
'''
sql = sql % ticker
df_tmp = pd.read_sql(sql, conpg)
df_tmp
# Out:
#     id name                                          full_name  \
# 0  722  FPT  FRASERS PROPERTY (THAILAND) PUBLIC COMPANY LIM...
#
#                     sector             subsector market  \
# 0  Property & Construction  Property Development    SET
#
#                              website                 created_at  \
# 0  https://www.frasersproperty.co.th 2022-08-07 08:04:12.049363
#
#                   updated_at
# 0 2022-08-07 08:04:12.049363

# %%
ticker = 'DIF'
