# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from sqlalchemy import create_engine
from datetime import date, timedelta
import calendar

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from itables import show
pd.options.display.max_rows = 31

engine = create_engine("sqlite:///c:\\ruby\\expense\\db\\development.sqlite3")
conn = engine.connect()
today = date.today()
today
# Out:
# datetime.date(2023, 8, 1)

# %%
sql = "SELECT C.id, C.name AS item, G.name AS kind, G.id FROM categories C \
       JOIN groups G ON group_id = G.id"
df_c = pd.read_sql(sql, conn)
df_c.head()
# Out:
#    id              item            kind  id
# 0   1  Books & Software     Edutainment   3
# 1   2               CCF          Luxury   5
# 2   3         Cigarette          Luxury   5
# 3   4              Food            Food   4
# 4   5              Fuel  Transportation  10

# %%
# create a date object
date = pd.to_datetime('2023-07-31')

# find the beginning of the month for the given date
bom = date.to_period('M').start_time
eom = date.to_period('M').end_time
bom = bom.date()
eom = eom.date()
print(f'Month start: {bom}')
print(f'Month end: {eom}')
# Out:
# Month start: 2023-07-01
# Month end: 2023-07-31

# %%
sql = """
SELECT date,amount,C.name AS item, G.name AS kind FROM transactions T 
JOIN categories C ON category_id = C.id 
JOIN groups G ON group_id = G.id 
WHERE date = "%s" 
ORDER BY amount DESC
"""
sql = sql % eom
print(sql)

df = pd.read_sql(sql, conn)
df
# Out:
# SELECT date,amount,C.name AS item, G.name AS kind FROM transactions T
# JOIN categories C ON category_id = C.id
# JOIN groups G ON group_id = G.id
# WHERE date = "2023-07-31"
# ORDER BY amount DESC
#          date  amount            item           kind
# 0  2023-07-31   10000          Parent         Parent
# 1  2023-07-31    1050      MidJourney    Edutainment
# 2  2023-07-31     710         ChatGPT    Edutainment
# 3  2023-07-31     640   Internet Home  Communication
# 4  2023-07-31     420         Netflix    Edutainment
# 5  2023-07-31     320  Telephone Dtac  Communication
# 6  2023-07-31     200            Food           Food
# 7  2023-07-31     170          Google    Edutainment
# 8  2023-07-31     140           Apple    Edutainment

# %%
formatted_amt = '{:,.2f}'.format(df.amount.sum())
print(formatted_amt)
# Out:
# 13,650.00

# %%
sql = """
SELECT date,amount,C.name AS item, G.name AS kind FROM transactions T 
JOIN categories C ON category_id = C.id 
JOIN groups G ON group_id = G.id 
WHERE date = "%s" 
ORDER BY amount DESC
"""
sql = sql % (eom)
print(sql)

df_eom = pd.read_sql(sql, conn)
df_eom
# Out:
# SELECT date,amount,C.name AS item, G.name AS kind FROM transactions T
# JOIN categories C ON category_id = C.id
# JOIN groups G ON group_id = G.id
# WHERE date = "2023-07-31"
# ORDER BY amount DESC
#          date  amount            item           kind
# 0  2023-07-31   10000          Parent         Parent
# 1  2023-07-31    1050      MidJourney    Edutainment
# 2  2023-07-31     710         ChatGPT    Edutainment
# 3  2023-07-31     640   Internet Home  Communication
# 4  2023-07-31     420         Netflix    Edutainment
# 5  2023-07-31     320  Telephone Dtac  Communication
# 6  2023-07-31     200            Food           Food
# 7  2023-07-31     170          Google    Edutainment
# 8  2023-07-31     140           Apple    Edutainment

# %%
sql = """
SELECT date,amount,C.name AS item, G.name AS kind FROM transactions T 
JOIN categories C ON category_id = C.id 
JOIN groups G ON group_id = G.id 
WHERE date BETWEEN "%s" AND "%s" 
ORDER BY date
"""
sql = sql % (bom, eom)
print(sql)

df_t = pd.read_sql(sql, conn)
df_t.tail()
# Out:
# SELECT date,amount,C.name AS item, G.name AS kind FROM transactions T
# JOIN categories C ON category_id = C.id
# JOIN groups G ON group_id = G.id
# WHERE date BETWEEN "2023-07-01" AND "2023-07-31"
# ORDER BY date
#           date  amount            item           kind
# 24  2023-07-31     320  Telephone Dtac  Communication
# 25  2023-07-31     170          Google    Edutainment
# 26  2023-07-31     140           Apple    Edutainment
# 27  2023-07-31     710         ChatGPT    Edutainment
# 28  2023-07-31    1050      MidJourney    Edutainment

# %%
grouped = df_t.groupby("item")
grouped['amount'].sum()
# Out:
# item
# Apple               140
# ChatGPT             710
# Food               1780
# Fuel               1340
# Google              170
# Internet Home       640
# Medicine           5660
# MidJourney         1050
# Mother            67000
# Netflix             420
# Parent            10000
# Pets              27900
# Plum              23650
# Telephone Dtac      320
# Name: amount, dtype: int64

# %%
grouped = df_t.groupby("kind")
grouped['amount'].sum()
# Out:
# kind
# Communication       960
# Edutainment        2490
# Food               1780
# Medicine           5660
# Parent            77000
# Pets              27900
# Shelter           23650
# Transportation     1340
# Name: amount, dtype: int64

# %%
expense = grouped.amount.sum()
sum(expense)
# Out:
# 140780

# %%
fig_path = "../fig/Expense-2307.png"
with plt.style.context("my_custom_style"):
    plt.figure(figsize=(12, 12))
    ax = expense.plot.pie(
        colors=["green", "red", "orange", "cyan", "yellow", "blue", "gold"],
        startangle=90,
        autopct="%1.1f%%",
    )
    plt.savefig(fig_path)

# %%
expense.to_csv("../data/expense-2307.csv")

# %%
sql = """
SELECT date,amount,C.name AS item, G.name AS kind FROM transactions T 
JOIN categories C ON category_id = C.id 
JOIN groups G ON group_id = G.id 
WHERE date = "%s" 
ORDER BY date
"""
sql = sql % (eom)
print(sql)
# Out:
# SELECT date,amount,C.name AS item, G.name AS kind FROM transactions T
# JOIN categories C ON category_id = C.id
# JOIN groups G ON group_id = G.id
# WHERE date = "2023-07-31"
# ORDER BY date

# %%
df_tmp = pd.read_sql(sql, conn)
show(df_tmp[['date','amount','item','kind']])
# Out:
# <div><table id="df9a3ce4-9026-4cbb-ab40-a18ab4047011" class="display"><thead>
#     <tr style="text-align: right;">
#
#       <th>date</th>
#       <th>amount</th>
#       <th>item</th>
#       <th>kind</th>
#     </tr>
#   </thead></table>
# <script type="text/javascript">
# require(["datatables"], function (datatables) {
#     $(document).ready(function () {
#         var dt_args = {"columnDefs": [{"width": "70px", "targets": "_all"}], "paging": false, "data": [["2023-07-31", 200, "Food", "Food"], ["2023-07-31", 10000, "Parent", "Parent"], ["2023-07-31", 640, "Internet Home", "Communication"], ["2023-07-31", 420, "Netflix", "Edutainment"], ["2023-07-31", 320, "Telephone Dtac", "Communication"], ["2023-07-31", 170, "Google", "Edutainment"], ["2023-07-31", 140, "Apple", "Edutainment"], ["2023-07-31", 710, "ChatGPT", "Edutainment"], ["2023-07-31", 1050, "MidJourney", "Edutainment"]]};
#         dt_args = eval_functions(dt_args);
#         table = $('#df9a3ce4-9026-4cbb-ab40-a18ab4047011').DataTable(dt_args);
#     });
# })
# </script>
# </div>

# %%
df_tmp.to_csv("../data/expense-eom.csv")

# %%
sql = "SELECT * FROM groups"
groups = pd.read_sql(sql, conn)
groups.dtypes
# Out:
# id             int64
# name          object
# created_at    object
# updated_at    object
# factor4       object
# dtype: object

# %%
groups
# Out:
#     id            name                  created_at  \
# 0    1         Apparel  2016-01-01 13:38:53.119230
# 1    2   Communication  2016-01-01 13:38:53.199234
# 2    3     Edutainment  2016-01-01 13:38:53.289240
# 3    4            Food  2016-01-01 13:38:53.356243
# 4    5          Luxury  2016-01-01 13:38:53.422247
# 5    6        Medicine  2016-01-01 13:38:53.498252
# 6    7          Others  2016-01-01 13:38:53.564255
# 7    8          Parent  2016-01-01 13:38:53.622259
# 8    9         Shelter  2016-01-01 13:38:53.689263
# 9   10  Transportation  2016-01-01 13:38:53.764267
# 10  11            Pets         2020-01-02 16:09:09
# 11  12          Movies         2021-09-30 15:09:14
#
#                     updated_at factor4
# 0   2016-01-01 13:38:53.119230       2
# 1   2016-01-01 13:38:53.199234       5
# 2   2016-01-01 13:38:53.289240       6
# 3   2016-01-01 13:38:53.356243       1
# 4   2016-01-01 13:38:53.422247       6
# 5   2016-01-01 13:38:53.498252       4
# 6   2016-01-01 13:38:53.564255       6
# 7   2016-01-01 13:38:53.622259       6
# 8   2016-01-01 13:38:53.689263       3
# 9   2016-01-01 13:38:53.764267       5
# 10         2020-01-02 16:09:09       6
# 11         2021-09-30 15:09:14       7

# %%
sql = "SELECT * FROM categories"
categories = pd.read_sql(sql, conn)
categories.dtypes
# Out:
# id             int64
# sequence       int64
# name          object
# default        int64
# group_id       int64
# created_at    object
# updated_at    object
# dtype: object

# %%
categories
# Out:
#     id  sequence                name  default  group_id  \
# 0    1         4    Books & Software        0         3
# 1    2        19                 CCF      600         5
# 2    3         2           Cigarette        0         5
# 3    4         1                Food        0         4
# 4    5         3                Fuel        0        10
# ..  ..       ...                 ...      ...       ...
# 36  37        74  Yearly Pluralsight     3300         3
# 37  38        75      Yearly Dropbox     4450         3
# 38  39        76             Netflix      420         3
# 39  40        77             ChatGPT      690         3
# 40  41        78          MidJourney      350         3
#
#                     created_at                  updated_at
# 0   2016-01-01 14:34:11.909054  2016-01-01 14:34:11.909054
# 1   2016-01-01 14:34:11.976058  2016-01-01 14:34:11.976058
# 2   2016-01-01 14:34:12.067063  2016-01-01 14:34:12.067063
# 3   2016-01-01 14:34:12.148068  2016-01-01 14:34:12.148068
# 4   2016-01-01 14:34:12.209071  2016-01-01 14:34:12.209071
# ..                         ...                         ...
# 36         2021-12-30 15:45:55         2021-12-30 15:45:55
# 37         2022-01-16 15:44:51         2022-01-16 15:44:51
# 38         2022-06-30 15:12:52         2022-06-30 15:12:52
# 39         2023-03-31 16:02:59         2023-03-31 16:02:59
# 40         2023-03-31 16:03:46         2023-03-31 16:03:46
#
# [41 rows x 7 columns]

# %%
sql = "SELECT * FROM transactions"
transactions = pd.read_sql(sql, conn)
transactions.dtypes
# Out:
# id              int64
# date           object
# category_id     int64
# amount          int64
# created_at     object
# updated_at     object
# dtype: object

# %%
transactions.tail()
# Out:
#         id        date  category_id  amount                  created_at  \
# 2600  2633  2023-07-31           16     320  2023-08-01 14:41:46.692896
# 2601  2634  2023-07-31           32     170  2023-08-01 14:42:29.378825
# 2602  2635  2023-07-31           30     140  2023-08-01 14:42:44.454296
# 2603  2636  2023-07-31           40     710  2023-08-01 14:43:05.500752
# 2604  2637  2023-07-31           41    1050  2023-08-01 14:43:27.369349
#
#                       updated_at
# 2600  2023-08-01 14:41:46.692896
# 2601  2023-08-01 14:42:29.378825
# 2602  2023-08-01 14:56:25.527156
# 2603  2023-08-01 14:43:05.500752
# 2604  2023-08-01 14:43:27.369349
