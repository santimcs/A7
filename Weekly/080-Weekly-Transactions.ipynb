# %%
import calendar
import pandas as pd
from datetime import date, timedelta
from sqlalchemy import create_engine
from pandas.tseries.offsets import BDay

engine = create_engine('mysql+pymysql://root:@localhost:3306/portfolio_development')
conpf = engine.connect()

engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()

engine = create_engine("sqlite:///c:\\ruby\\portmy\\db\\development.sqlite3")
conmy = engine.connect()

engine = create_engine("mysql+pymysql://root:@localhost:3306/stock")
const = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
box_path = "\\Users\\User\\Dropbox\\"

format_dict = {
    'qty':'{:,}','available_qty':'{:,}','volbuy':'{:,}',
    'price':'{:.2f}','buy_price':'{:.2f}','sell_price':'{:.2f}','diff':'{:.2f}','cost':'{:.2f}',
    'buy_target':'{:.2f}','sell_target':'{:.2f}',
    'amount':'{:,.2f}','gross':'{:,.2f}','profit':'{:,.2f}',
    'buy_amt':'{:,.2f}','sell_amt':'{:,.2f}','pct':'{:,.2f}%'
}
cols = 'trade name qty price reason market active'.split()

today = date.today()
today
# Out:
# datetime.date(2023, 6, 12)

# %%
#today = date(2023, 5, 1)
today
# Out:
# datetime.date(2023, 6, 12)

# %% [markdown]
# ### Yesterday must be last business day

# %%
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(1)
yesterday = today - num_business_days
#yesterday = yesterday.date()
print(f'today: {today}')
print(f'yesterday: {yesterday}')
# Out:
# today: 2023-06-12
# yesterday: 2023-06-09 00:00:00

# %%
# find the beginning of the week for the given yesterday
week_start = yesterday.to_period('W').start_time
week_end = yesterday.to_period('W').end_time
week_start = week_start.date()
week_end = week_end.date()
print(f'week start: {week_start}')
print(f'week end: {week_end}')
# Out:
# week start: 2023-06-05
# week end: 2023-06-11

# %% [markdown]
# ### Restart and Run All Cells

# %%
sql = '''
SELECT name, buys.date AS buy_date, sells.date AS sell_date,
sells.price AS sell_price, buys.price AS buy_price, 
(sells.price - buys.price) AS diff, qty, 
(sells.price * qty) AS sell_amt, (buys.price * qty) AS buy_amt,
(sells.price - buys.price) * qty AS gross, 
ROUND((sells.price - buys.price)/buys.price*100,2) AS pct, profit
FROM sells JOIN buys ON sells.buy_id = buys.id
JOIN stocks ON buys.stock_id = stocks.id
WHERE sells.date BETWEEN '%s' AND '%s'
ORDER BY name, sells.date'''
sql = sql % (week_start, week_end)
print(sql)
# Out:
# SELECT name, buys.date AS buy_date, sells.date AS sell_date,
# sells.price AS sell_price, buys.price AS buy_price,
# (sells.price - buys.price) AS diff, qty,
# (sells.price * qty) AS sell_amt, (buys.price * qty) AS buy_amt,
# (sells.price - buys.price) * qty AS gross,
# ROUND((sells.price - buys.price)/buys.price*100,2) AS pct, profit
# FROM sells JOIN buys ON sells.buy_id = buys.id
# JOIN stocks ON buys.stock_id = stocks.id
# WHERE sells.date BETWEEN '2023-06-05' AND '2023-06-11'
# ORDER BY name, sells.date

# %%
sells_df = pd.read_sql(sql, conpf)
sells_df.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_eefba_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >buy_date</th>
#       <th class="col_heading level0 col2" >sell_date</th>
#       <th class="col_heading level0 col3" >sell_price</th>
#       <th class="col_heading level0 col4" >buy_price</th>
#       <th class="col_heading level0 col5" >diff</th>
#       <th class="col_heading level0 col6" >qty</th>
#       <th class="col_heading level0 col7" >sell_amt</th>
#       <th class="col_heading level0 col8" >buy_amt</th>
#       <th class="col_heading level0 col9" >gross</th>
#       <th class="col_heading level0 col10" >pct</th>
#       <th class="col_heading level0 col11" >profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eefba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eefba_row0_col0" class="data row0 col0" >EA</td>
#       <td id="T_eefba_row0_col1" class="data row0 col1" >2023-06-01</td>
#       <td id="T_eefba_row0_col2" class="data row0 col2" >2023-06-08</td>
#       <td id="T_eefba_row0_col3" class="data row0 col3" >64.00</td>
#       <td id="T_eefba_row0_col4" class="data row0 col4" >61.00</td>
#       <td id="T_eefba_row0_col5" class="data row0 col5" >3.00</td>
#       <td id="T_eefba_row0_col6" class="data row0 col6" >400</td>
#       <td id="T_eefba_row0_col7" class="data row0 col7" >25,600.00</td>
#       <td id="T_eefba_row0_col8" class="data row0 col8" >24,400.00</td>
#       <td id="T_eefba_row0_col9" class="data row0 col9" >1,200.00</td>
#       <td id="T_eefba_row0_col10" class="data row0 col10" >4.92%</td>
#       <td id="T_eefba_row0_col11" class="data row0 col11" >1,089.25</td>
#     </tr>
#     <tr>
#       <th id="T_eefba_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eefba_row1_col0" class="data row1 col0" >JMT</td>
#       <td id="T_eefba_row1_col1" class="data row1 col1" >2023-06-06</td>
#       <td id="T_eefba_row1_col2" class="data row1 col2" >2023-06-09</td>
#       <td id="T_eefba_row1_col3" class="data row1 col3" >41.75</td>
#       <td id="T_eefba_row1_col4" class="data row1 col4" >39.50</td>
#       <td id="T_eefba_row1_col5" class="data row1 col5" >2.25</td>
#       <td id="T_eefba_row1_col6" class="data row1 col6" >600</td>
#       <td id="T_eefba_row1_col7" class="data row1 col7" >25,050.00</td>
#       <td id="T_eefba_row1_col8" class="data row1 col8" >23,700.00</td>
#       <td id="T_eefba_row1_col9" class="data row1 col9" >1,350.00</td>
#       <td id="T_eefba_row1_col10" class="data row1 col10" >5.70%</td>
#       <td id="T_eefba_row1_col11" class="data row1 col11" >1,242.03</td>
#     </tr>
#     <tr>
#       <th id="T_eefba_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eefba_row2_col0" class="data row2 col0" >KTC</td>
#       <td id="T_eefba_row2_col1" class="data row2 col1" >2023-06-07</td>
#       <td id="T_eefba_row2_col2" class="data row2 col2" >2023-06-08</td>
#       <td id="T_eefba_row2_col3" class="data row2 col3" >52.50</td>
#       <td id="T_eefba_row2_col4" class="data row2 col4" >50.00</td>
#       <td id="T_eefba_row2_col5" class="data row2 col5" >2.50</td>
#       <td id="T_eefba_row2_col6" class="data row2 col6" >400</td>
#       <td id="T_eefba_row2_col7" class="data row2 col7" >21,000.00</td>
#       <td id="T_eefba_row2_col8" class="data row2 col8" >20,000.00</td>
#       <td id="T_eefba_row2_col9" class="data row2 col9" >1,000.00</td>
#       <td id="T_eefba_row2_col10" class="data row2 col10" >5.00%</td>
#       <td id="T_eefba_row2_col11" class="data row2 col11" >909.19</td>
#     </tr>
#     <tr>
#       <th id="T_eefba_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eefba_row3_col0" class="data row3 col0" >ORI</td>
#       <td id="T_eefba_row3_col1" class="data row3 col1" >2023-05-17</td>
#       <td id="T_eefba_row3_col2" class="data row3 col2" >2023-06-09</td>
#       <td id="T_eefba_row3_col3" class="data row3 col3" >11.20</td>
#       <td id="T_eefba_row3_col4" class="data row3 col4" >10.20</td>
#       <td id="T_eefba_row3_col5" class="data row3 col5" >1.00</td>
#       <td id="T_eefba_row3_col6" class="data row3 col6" >3,000</td>
#       <td id="T_eefba_row3_col7" class="data row3 col7" >33,600.00</td>
#       <td id="T_eefba_row3_col8" class="data row3 col8" >30,600.00</td>
#       <td id="T_eefba_row3_col9" class="data row3 col9" >3,000.00</td>
#       <td id="T_eefba_row3_col10" class="data row3 col10" >9.80%</td>
#       <td id="T_eefba_row3_col11" class="data row3 col11" >2,857.81</td>
#     </tr>
#   </tbody>
# </table>

# %%
sells_grp = sells_df.groupby(['name'])[['qty','sell_amt','buy_amt','gross','profit']].sum()
#sells_grp.style.format(format_dict)
sells_grp
# Out:
#        qty  sell_amt  buy_amt   gross   profit
# name
# EA     400   25600.0  24400.0  1200.0  1089.25
# JMT    600   25050.0  23700.0  1350.0  1242.03
# KTC    400   21000.0  20000.0  1000.0   909.19
# ORI   3000   33600.0  30600.0  3000.0  2857.81

# %%
sells_df[['sell_amt','buy_amt','gross','profit']].sum()
# Out:
# sell_amt    105250.00
# buy_amt      98700.00
# gross         6550.00
# profit        6098.28
# dtype: float64

# %%
sql = '''
SELECT name, buys.date AS buy_date, buys.price AS buy_price, 
qty, (buys.price * qty) AS buy_amt 
FROM buys
JOIN stocks ON buys.stock_id = stocks.id
WHERE buys.date BETWEEN '%s' AND '%s'
ORDER BY name, buys.date'''
sql = sql % (week_start, week_end)
print(sql)
# Out:
# SELECT name, buys.date AS buy_date, buys.price AS buy_price,
# qty, (buys.price * qty) AS buy_amt
# FROM buys
# JOIN stocks ON buys.stock_id = stocks.id
# WHERE buys.date BETWEEN '2023-06-05' AND '2023-06-11'
# ORDER BY name, buys.date

# %%
buys_df = pd.read_sql(sql, conpf)
buys_df.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_54b7b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >buy_date</th>
#       <th class="col_heading level0 col2" >buy_price</th>
#       <th class="col_heading level0 col3" >qty</th>
#       <th class="col_heading level0 col4" >buy_amt</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54b7b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_54b7b_row0_col0" class="data row0 col0" >AH</td>
#       <td id="T_54b7b_row0_col1" class="data row0 col1" >2023-06-08</td>
#       <td id="T_54b7b_row0_col2" class="data row0 col2" >37.00</td>
#       <td id="T_54b7b_row0_col3" class="data row0 col3" >1,200</td>
#       <td id="T_54b7b_row0_col4" class="data row0 col4" >44,400.00</td>
#     </tr>
#     <tr>
#       <th id="T_54b7b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_54b7b_row1_col0" class="data row1 col0" >JMT</td>
#       <td id="T_54b7b_row1_col1" class="data row1 col1" >2023-06-06</td>
#       <td id="T_54b7b_row1_col2" class="data row1 col2" >39.50</td>
#       <td id="T_54b7b_row1_col3" class="data row1 col3" >600</td>
#       <td id="T_54b7b_row1_col4" class="data row1 col4" >23,700.00</td>
#     </tr>
#     <tr>
#       <th id="T_54b7b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_54b7b_row2_col0" class="data row2 col0" >KTC</td>
#       <td id="T_54b7b_row2_col1" class="data row2 col1" >2023-06-07</td>
#       <td id="T_54b7b_row2_col2" class="data row2 col2" >50.00</td>
#       <td id="T_54b7b_row2_col3" class="data row2 col3" >400</td>
#       <td id="T_54b7b_row2_col4" class="data row2 col4" >20,000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
buys_df[['buy_amt']].sum()
# Out:
# buy_amt    88100.0
# dtype: float64

# %%
sells_df[['buy_amt']].sum()
# Out:
# buy_amt    98700.0
# dtype: float64

# %%
diff_amt = buys_df[['buy_amt']].sum() - sells_df[['buy_amt']].sum()
diff_amt
# Out:
# buy_amt   -10600.0
# dtype: float64

# %%
sql = '''
SELECT name, available_qty, cost, status
FROM stocks
'''
stocks_df = pd.read_sql(sql, conlite)
stocks_df.set_index('name', inplace=True)
stocks_df.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3e589_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >available_qty</th>
#       <th class="col_heading level0 col1" >cost</th>
#       <th class="col_heading level0 col2" >status</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e589_level0_row0" class="row_heading level0 row0" >MCS</th>
#       <td id="T_3e589_row0_col0" class="data row0 col0" >78,000</td>
#       <td id="T_3e589_row0_col1" class="data row0 col1" >15.10</td>
#       <td id="T_3e589_row0_col2" class="data row0 col2" >B</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row1" class="row_heading level0 row1" >PTTGC</th>
#       <td id="T_3e589_row1_col0" class="data row1 col0" >6,000</td>
#       <td id="T_3e589_row1_col1" class="data row1 col1" >61.25</td>
#       <td id="T_3e589_row1_col2" class="data row1 col2" >S</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row2" class="row_heading level0 row2" >JASIF</th>
#       <td id="T_3e589_row2_col0" class="data row2 col0" >130,000</td>
#       <td id="T_3e589_row2_col1" class="data row2 col1" >10.00</td>
#       <td id="T_3e589_row2_col2" class="data row2 col2" >S</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row3" class="row_heading level0 row3" >DIF</th>
#       <td id="T_3e589_row3_col0" class="data row3 col0" >30,000</td>
#       <td id="T_3e589_row3_col1" class="data row3 col1" >14.70</td>
#       <td id="T_3e589_row3_col2" class="data row3 col2" >U</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row4" class="row_heading level0 row4" >WHAIR</th>
#       <td id="T_3e589_row4_col0" class="data row4 col0" >50,000</td>
#       <td id="T_3e589_row4_col1" class="data row4 col1" >8.70</td>
#       <td id="T_3e589_row4_col2" class="data row4 col2" >T</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row5" class="row_heading level0 row5" >STA</th>
#       <td id="T_3e589_row5_col0" class="data row5 col0" >5,000</td>
#       <td id="T_3e589_row5_col1" class="data row5 col1" >40.00</td>
#       <td id="T_3e589_row5_col2" class="data row5 col2" >B</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row6" class="row_heading level0 row6" >SCC</th>
#       <td id="T_3e589_row6_col0" class="data row6 col0" >600</td>
#       <td id="T_3e589_row6_col1" class="data row6 col1" >405.00</td>
#       <td id="T_3e589_row6_col2" class="data row6 col2" >U</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row7" class="row_heading level0 row7" >NER</th>
#       <td id="T_3e589_row7_col0" class="data row7 col0" >32,000</td>
#       <td id="T_3e589_row7_col1" class="data row7 col1" >7.00</td>
#       <td id="T_3e589_row7_col2" class="data row7 col2" >S</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row8" class="row_heading level0 row8" >SYNEX</th>
#       <td id="T_3e589_row8_col0" class="data row8 col0" >15,000</td>
#       <td id="T_3e589_row8_col1" class="data row8 col1" >28.70</td>
#       <td id="T_3e589_row8_col2" class="data row8 col2" >B</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row9" class="row_heading level0 row9" >BCH</th>
#       <td id="T_3e589_row9_col0" class="data row9 col0" >15,000</td>
#       <td id="T_3e589_row9_col1" class="data row9 col1" >21.46</td>
#       <td id="T_3e589_row9_col2" class="data row9 col2" >I</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row10" class="row_heading level0 row10" >KCE</th>
#       <td id="T_3e589_row10_col0" class="data row10 col0" >10,000</td>
#       <td id="T_3e589_row10_col1" class="data row10 col1" >77.25</td>
#       <td id="T_3e589_row10_col2" class="data row10 col2" >U</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row11" class="row_heading level0 row11" >TMT</th>
#       <td id="T_3e589_row11_col0" class="data row11 col0" >36,000</td>
#       <td id="T_3e589_row11_col1" class="data row11 col1" >10.20</td>
#       <td id="T_3e589_row11_col2" class="data row11 col2" >B</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row12" class="row_heading level0 row12" >RCL</th>
#       <td id="T_3e589_row12_col0" class="data row12 col0" >27,000</td>
#       <td id="T_3e589_row12_col1" class="data row12 col1" >38.75</td>
#       <td id="T_3e589_row12_col2" class="data row12 col2" >T</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row13" class="row_heading level0 row13" >WHART</th>
#       <td id="T_3e589_row13_col0" class="data row13 col0" >30,000</td>
#       <td id="T_3e589_row13_col1" class="data row13 col1" >11.70</td>
#       <td id="T_3e589_row13_col2" class="data row13 col2" >T</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row14" class="row_heading level0 row14" >ASP</th>
#       <td id="T_3e589_row14_col0" class="data row14 col0" >30,000</td>
#       <td id="T_3e589_row14_col1" class="data row14 col1" >3.80</td>
#       <td id="T_3e589_row14_col2" class="data row14 col2" >T</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row15" class="row_heading level0 row15" >SENA</th>
#       <td id="T_3e589_row15_col0" class="data row15 col0" >105,000</td>
#       <td id="T_3e589_row15_col1" class="data row15 col1" >4.48</td>
#       <td id="T_3e589_row15_col2" class="data row15 col2" >I</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row16" class="row_heading level0 row16" >ORI</th>
#       <td id="T_3e589_row16_col0" class="data row16 col0" >45,000</td>
#       <td id="T_3e589_row16_col1" class="data row16 col1" >11.00</td>
#       <td id="T_3e589_row16_col2" class="data row16 col2" >O</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row17" class="row_heading level0 row17" >ASK</th>
#       <td id="T_3e589_row17_col0" class="data row17 col0" >4,500</td>
#       <td id="T_3e589_row17_col1" class="data row17 col1" >31.00</td>
#       <td id="T_3e589_row17_col2" class="data row17 col2" >T</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row18" class="row_heading level0 row18" >BH</th>
#       <td id="T_3e589_row18_col0" class="data row18 col0" >0</td>
#       <td id="T_3e589_row18_col1" class="data row18 col1" >210.00</td>
#       <td id="T_3e589_row18_col2" class="data row18 col2" >O</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row19" class="row_heading level0 row19" >IVL</th>
#       <td id="T_3e589_row19_col0" class="data row19 col0" >7,200</td>
#       <td id="T_3e589_row19_col1" class="data row19 col1" >40.00</td>
#       <td id="T_3e589_row19_col2" class="data row19 col2" >B</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row20" class="row_heading level0 row20" >BANPU</th>
#       <td id="T_3e589_row20_col0" class="data row20 col0" >30,000</td>
#       <td id="T_3e589_row20_col1" class="data row20 col1" >11.50</td>
#       <td id="T_3e589_row20_col2" class="data row20 col2" >B</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row21" class="row_heading level0 row21" >TTB</th>
#       <td id="T_3e589_row21_col0" class="data row21 col0" >0</td>
#       <td id="T_3e589_row21_col1" class="data row21 col1" >0.00</td>
#       <td id="T_3e589_row21_col2" class="data row21 col2" >O</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row22" class="row_heading level0 row22" >TASCO</th>
#       <td id="T_3e589_row22_col0" class="data row22 col0" >0</td>
#       <td id="T_3e589_row22_col1" class="data row22 col1" >155.00</td>
#       <td id="T_3e589_row22_col2" class="data row22 col2" >O</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row23" class="row_heading level0 row23" >CKP</th>
#       <td id="T_3e589_row23_col0" class="data row23 col0" >0</td>
#       <td id="T_3e589_row23_col1" class="data row23 col1" >0.00</td>
#       <td id="T_3e589_row23_col2" class="data row23 col2" >X</td>
#     </tr>
#     <tr>
#       <th id="T_3e589_level0_row24" class="row_heading level0 row24" >GVREIT</th>
#       <td id="T_3e589_row24_col0" class="data row24 col0" >30,000</td>
#       <td id="T_3e589_row24_col1" class="data row24 col1" >8.90</td>
#       <td id="T_3e589_row24_col2

# %%
df_merge = pd.merge(sells_grp,stocks_df,on='name',how='inner')
df_merge.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_53f43_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >qty</th>
#       <th class="col_heading level0 col1" >sell_amt</th>
#       <th class="col_heading level0 col2" >buy_amt</th>
#       <th class="col_heading level0 col3" >gross</th>
#       <th class="col_heading level0 col4" >profit</th>
#       <th class="col_heading level0 col5" >available_qty</th>
#       <th class="col_heading level0 col6" >cost</th>
#       <th class="col_heading level0 col7" >status</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53f43_level0_row0" class="row_heading level0 row0" >EA</th>
#       <td id="T_53f43_row0_col0" class="data row0 col0" >400</td>
#       <td id="T_53f43_row0_col1" class="data row0 col1" >25,600.00</td>
#       <td id="T_53f43_row0_col2" class="data row0 col2" >24,400.00</td>
#       <td id="T_53f43_row0_col3" class="data row0 col3" >1,200.00</td>
#       <td id="T_53f43_row0_col4" class="data row0 col4" >1,089.25</td>
#       <td id="T_53f43_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_53f43_row0_col6" class="data row0 col6" >61.00</td>
#       <td id="T_53f43_row0_col7" class="data row0 col7" >O</td>
#     </tr>
#     <tr>
#       <th id="T_53f43_level0_row1" class="row_heading level0 row1" >JMT</th>
#       <td id="T_53f43_row1_col0" class="data row1 col0" >600</td>
#       <td id="T_53f43_row1_col1" class="data row1 col1" >25,050.00</td>
#       <td id="T_53f43_row1_col2" class="data row1 col2" >23,700.00</td>
#       <td id="T_53f43_row1_col3" class="data row1 col3" >1,350.00</td>
#       <td id="T_53f43_row1_col4" class="data row1 col4" >1,242.03</td>
#       <td id="T_53f43_row1_col5" class="data row1 col5" >4,200</td>
#       <td id="T_53f43_row1_col6" class="data row1 col6" >55.50</td>
#       <td id="T_53f43_row1_col7" class="data row1 col7" >O</td>
#     </tr>
#     <tr>
#       <th id="T_53f43_level0_row2" class="row_heading level0 row2" >KTC</th>
#       <td id="T_53f43_row2_col0" class="data row2 col0" >400</td>
#       <td id="T_53f43_row2_col1" class="data row2 col1" >21,000.00</td>
#       <td id="T_53f43_row2_col2" class="data row2 col2" >20,000.00</td>
#       <td id="T_53f43_row2_col3" class="data row2 col3" >1,000.00</td>
#       <td id="T_53f43_row2_col4" class="data row2 col4" >909.19</td>
#       <td id="T_53f43_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_53f43_row2_col6" class="data row2 col6" >50.00</td>
#       <td id="T_53f43_row2_col7" class="data row2 col7" >O</td>
#     </tr>
#     <tr>
#       <th id="T_53f43_level0_row3" class="row_heading level0 row3" >ORI</th>
#       <td id="T_53f43_row3_col0" class="data row3 col0" >3,000</td>
#       <td id="T_53f43_row3_col1" class="data row3 col1" >33,600.00</td>
#       <td id="T_53f43_row3_col2" class="data row3 col2" >30,600.00</td>
#       <td id="T_53f43_row3_col3" class="data row3 col3" >3,000.00</td>
#       <td id="T_53f43_row3_col4" class="data row3 col4" >2,857.81</td>
#       <td id="T_53f43_row3_col5" class="data row3 col5" >45,000</td>
#       <td id="T_53f43_row3_col6" class="data row3 col6" >11.00</td>
#       <td id="T_53f43_row3_col7" class="data row3 col7" >O</td>
#     </tr>
#   </tbody>
# </table>

# %%
sql = '''
SELECT name, SUM(volbuy) AS volbuy, price
FROM buy
WHERE active = 1
GROUP BY name
ORDER BY name'''
buy_df = pd.read_sql(sql, const)
buy_df.volbuy = buy_df.volbuy.astype(int)
buy_df.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_adf98_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >volbuy</th>
#       <th class="col_heading level0 col2" >price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_adf98_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_adf98_row0_col0" class="data row0 col0" >AH</td>
#       <td id="T_adf98_row0_col1" class="data row0 col1" >1,200</td>
#       <td id="T_adf98_row0_col2" class="data row0 col2" >37.00</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_adf98_row1_col0" class="data row1 col0" >ASK</td>
#       <td id="T_adf98_row1_col1" class="data row1 col1" >4,500</td>
#       <td id="T_adf98_row1_col2" class="data row1 col2" >31.00</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_adf98_row2_col0" class="data row2 col0" >ASP</td>
#       <td id="T_adf98_row2_col1" class="data row2 col1" >30,000</td>
#       <td id="T_adf98_row2_col2" class="data row2 col2" >3.80</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_adf98_row3_col0" class="data row3 col0" >BANPU</td>
#       <td id="T_adf98_row3_col1" class="data row3 col1" >30,000</td>
#       <td id="T_adf98_row3_col2" class="data row3 col2" >11.50</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_adf98_row4_col0" class="data row4 col0" >BCH</td>
#       <td id="T_adf98_row4_col1" class="data row4 col1" >15,000</td>
#       <td id="T_adf98_row4_col2" class="data row4 col2" >21.46</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_adf98_row5_col0" class="data row5 col0" >CPNREIT</td>
#       <td id="T_adf98_row5_col1" class="data row5 col1" >60,000</td>
#       <td id="T_adf98_row5_col2" class="data row5 col2" >17.55</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_adf98_row6_col0" class="data row6 col0" >DIF</td>
#       <td id="T_adf98_row6_col1" class="data row6 col1" >30,000</td>
#       <td id="T_adf98_row6_col2" class="data row6 col2" >14.70</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_adf98_row7_col0" class="data row7 col0" >GVREIT</td>
#       <td id="T_adf98_row7_col1" class="data row7 col1" >30,000</td>
#       <td id="T_adf98_row7_col2" class="data row7 col2" >8.90</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_adf98_row8_col0" class="data row8 col0" >IVL</td>
#       <td id="T_adf98_row8_col1" class="data row8 col1" >7,200</td>
#       <td id="T_adf98_row8_col2" class="data row8 col2" >40.00</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_adf98_row9_col0" class="data row9 col0" >JASIF</td>
#       <td id="T_adf98_row9_col1" class="data row9 col1" >130,000</td>
#       <td id="T_adf98_row9_col2" class="data row9 col2" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_adf98_row10_col0" class="data row10 col0" >JMART</td>
#       <td id="T_adf98_row10_col1" class="data row10 col1" >6,000</td>
#       <td id="T_adf98_row10_col2" class="data row10 col2" >34.50</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_adf98_row11_col0" class="data row11 col0" >JMT</td>
#       <td id="T_adf98_row11_col1" class="data row11 col1" >4,200</td>
#       <td id="T_adf98_row11_col2" class="data row11 col2" >55.50</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_adf98_row12_col0" class="data row12 col0" >KCE</td>
#       <td id="T_adf98_row12_col1" class="data row12 col1" >10,000</td>
#       <td id="T_adf98_row12_col2" class="data row12 col2" >77.25</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_adf98_row13_col0" class="data row13 col0" >MCS</td>
#       <td id="T_adf98_row13_col1" class="data row13 col1" >78,000</td>
#       <td id="T_adf98_row13_col2" class="data row13 col2" >15.10</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_adf98_row14_col0" class="data row14 col0" >NER</td>
#       <td id="T_adf98_row14_col1" class="data row14 col1" >32,000</td>
#       <td id="T_adf98_row14_col2" class="data row14 col2" >7.00</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_adf98_row15_col0" class="data row15 col0" >ORI</td>
#       <td id="T_adf98_row15_col1" class="data row15 col1" >45,000</td>
#       <td id="T_adf98_row15_col2" class="data row15 col2" >11.00</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_adf98_row16_col0" class="data row16 col0" >PTTGC</td>
#       <td id="T_adf98_row16_col1" class="data row16 col1" >6,000</td>
#       <td id="T_adf98_row16_col2" class="data row16 col2" >64.75</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_adf98_row17_col0" class="data row17 col0" >RCL</td>
#       <td id="T_adf98_row17_col1" class="data row17 col1" >27,000</td>
#       <td id="T_adf98_row17_col2" class="data row17 col2" >38.75</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_adf98_row18_col0" class="data row18 col0" >SCC</td>
#       <td id="T_adf98_row18_col1" class="data row18 col1" >600</td>
#       <td id="T_adf98_row18_col2" class="data row18 col2" >405.00</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_adf98_row19_col0" class="data row19 col0" >SENA</td>
#       <td id="T_adf98_row19_col1" class="data row19 col1" >105,000</td>
#       <td id="T_adf98_row19_col2" class="data row19 col2" >4.48</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_adf98_row20_col0" class="data row20 col0" >SINGER</td>
#       <td id="T_adf98_row20_col1" class="data row20 col1" >6,000</td>
#       <td id="T_adf98_row20_col2" class="data row20 col2" >24.80</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_adf98_row21_col0" class="data row21 col0" >STA</td>
#       <td id="T_adf98_row21_col1" class="data row21 col1" >5,000</td>
#       <td id="T_adf98_row21_col2" class="data row21 col2" >40.00</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_adf98_row22_col0" class="data row22 col0" >SYNEX</td>
#       <td id="T_adf98_row22_col1" class="data row22 col1" >15,000</td>
#       <td id="T_adf98_row22_col2" class="data row22 col2" >28.70</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_adf98_row23_col0" class="data row23 col0" >TFFIF</td>
#       <td id="T_adf98_row23_col1" class="data row23 col1" >20,000</td>
#       <td id="T_adf98_row23_col2" class="data row23 col2" >7.65</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_adf98_row24_col0" class="data row24 col0" >TMT</td>
#       <td id="T_adf98_row24_col1" class="data row24 col1" >36,000</td>
#       <td id="T_adf98_row24_col2" class="data row24 col2" >10.20</td>
#     </tr>
#     <tr>
#       <th id="T_adf98_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_adf98_row25_col0"

# %%
df_merge2 = pd.merge(buy_df,stocks_df,on='name',how='inner')
df_merge2.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9282a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >volbuy</th>
#       <th class="col_heading level0 col2" >price</th>
#       <th class="col_heading level0 col3" >available_qty</th>
#       <th class="col_heading level0 col4" >cost</th>
#       <th class="col_heading level0 col5" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9282a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9282a_row0_col0" class="data row0 col0" >AH</td>
#       <td id="T_9282a_row0_col1" class="data row0 col1" >1,200</td>
#       <td id="T_9282a_row0_col2" class="data row0 col2" >37.00</td>
#       <td id="T_9282a_row0_col3" class="data row0 col3" >1,200</td>
#       <td id="T_9282a_row0_col4" class="data row0 col4" >37.00</td>
#       <td id="T_9282a_row0_col5" class="data row0 col5" >I</td>
#     </tr>
#     <tr>
#       <th id="T_9282a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9282a_row1_col0" class="data row1 col0" >ASK</td>
#       <td id="T_9282a_row1_col1" class="data row1 col1" >4,500</td>
#       <td id="T_9282a_row1_col2" class="data row1 col2" >31.00</td>
#       <td id="T_9282a_row1_col3" class="data row1 col3" >4,500</td>
#       <td id="T_9282a_row1_col4" class="data row1 col4" >31.00</td>
#       <td id="T_9282a_row1_col5" class="data row1 col5" >T</td>
#     </tr>
#     <tr>
#       <th id="T_9282a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9282a_row2_col0" class="data row2 col0" >ASP</td>
#       <td id="T_9282a_row2_col1" class="data row2 col1" >30,000</td>
#       <td id="T_9282a_row2_col2" class="data row2 col2" >3.80</td>
#       <td id="T_9282a_row2_col3" class="data row2 col3" >30,000</td>
#       <td id="T_9282a_row2_col4" class="data row2 col4" >3.80</td>
#       <td id="T_9282a_row2_col5" class="data row2 col5" >T</td>
#     </tr>
#     <tr>
#       <th id="T_9282a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9282a_row3_col0" class="data row3 col0" >BANPU</td>
#       <td id="T_9282a_row3_col1" class="data row3 col1" >30,000</td>
#       <td id="T_9282a_row3_col2" class="data row3 col2" >11.50</td>
#       <td id="T_9282a_row3_col3" class="data row3 col3" >30,000</td>
#       <td id="T_9282a_row3_col4" class="data row3 col4" >11.50</td>
#       <td id="T_9282a_row3_col5" class="data row3 col5" >B</td>
#     </tr>
#     <tr>
#       <th id="T_9282a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9282a_row4_col0" class="data row4 col0" >BCH</td>
#       <td id="T_9282a_row4_col1" class="data row4 col1" >15,000</td>
#       <td id="T_9282a_row4_col2" class="data row4 col2" >21.46</td>
#       <td id="T_9282a_row4_col3" class="data row4 col3" >15,000</td>
#       <td id="T_9282a_row4_col4" class="data row4 col4" >21.46</td>
#       <td id="T_9282a_row4_col5" class="data row4 col5" >I</td>
#     </tr>
#     <tr>
#       <th id="T_9282a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9282a_row5_col0" class="data row5 col0" >CPNREIT</td>
#       <td id="T_9282a_row5_col1" class="data row5 col1" >60,000</td>
#       <td id="T_9282a_row5_col2" class="data row5 col2" >17.55</td>
#       <td id="T_9282a_row5_col3" class="data row5 col3" >60,000</td>
#       <td id="T_9282a_row5_col4" class="data row5 col4" >17.55</td>
#       <td id="T_9282a_row5_col5" class="data row5 col5" >I</td>
#     </tr>
#     <tr>
#       <th id="T_9282a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9282a_row6_col0" class="data row6 col0" >DIF</td>
#       <td id="T_9282a_row6_col1" class="data row6 col1" >30,000</td>
#       <td id="T_9282a_row6_col2" class="data row6 col2" >14.70</td>
#       <td id="T_9282a_row6_col3" class="data row6 col3" >30,000</td>
#       <td id="T_9282a_row6_col4" class="data row6 col4" >14.70</td>
#       <td id="T_9282a_row6_col5" class="data row6 col5" >U</td>
#     </tr>
#     <tr>
#       <th id="T_9282a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9282a_row7_col0" class="data row7 col0" >GVREIT</td>
#       <td id="T_9282a_row7_col1" class="data row7 col1" >30,000</td>
#       <td id="T_9282a_row7_col2" class="data row7 col2" >8.90</td>
#       <td id="T_9282a_row7_col3" class="data row7 col3" >30,000</td>
#       <td id="T_9282a_row7_col4" class="data row7 col4" >8.90</td>
#       <td id="T_9282a_row7_col5" class="data row7 col5" >I</td>
#     </tr>
#     <tr>
#       <th id="T_9282a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9282a_row8_col0" class="data row8 col0" >IVL</td>
#       <td id="T_9282a_row8_col1" class="data row8 col1" >7,200</td>
#       <td id="T_9282a_row8_col2" class="data row8 col2" >40.00</td>
#       <td id="T_9282a_row8_col3" class="data row8 col3" >7,200</td>
#       <td id="T_9282a_row8_col4" class="data row8 col4" >40.00</td>
#       <td id="T_9282a_row8_col5" class="data row8 col5" >B</td>
#     </tr>
#     <tr>
#       <th id="T_9282a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9282a_row9_col0" class="data row9 col0" >JASIF</td>
#       <td id="T_9282a_row9_col1" class="data row9 col1" >130,000</td>
#       <td id="T_9282a_row9_col2" class="data row9 col2" >10.00</td>
#       <td id="T_9282a_row9_col3" class="data row9 col3" >130,000</td>
#       <td id="T_9282a_row9_col4" class="data row9 col4" >10.00</td>
#       <td id="T_9282a_row9_col5" class="data row9 col5" >S</td>
#     </tr>
#     <tr>
#       <th id="T_9282a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9282a_row10_col0" class="data row10 col0" >JMART</td>
#       <td id="T_9282a_row10_col1" class="data row10 col1" >6,000</td>
#       <td id="T_9282a_row10_col2" class="data row10 col2" >34.50</td>
#       <td id="T_9282a_row10_col3" class="data row10 col3" >6,000</td>
#       <td id="T_9282a_row10_col4" class="data row10 col4" >34.50</td>
#       <td id="T_9282a_row10_col5" class="data row10 col5" >B</td>
#     </tr>
#     <tr>
#       <th id="T_9282a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9282a_row11_col0" class="data row11 col0" >JMT</td>
#       <td id="T_9282a_row11_col1" class="data row11 col1" >4,200</td>
#       <td id="T_9282a_row11_col2" class="data row11 col2" >55.50</td>
#       <td id="T_9282a_row11_col3" class="data row11 col3" >4,200</td>
#       <td id="T_9282a_row11_col4" class="data row11 col4" >55.50</td>
#       <td id="T_9282a_row11_col5" class="data row11 col5" >O</td>
#     </tr>
#     <tr>
#       <th id="T_9282a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9282a_row12_col0" class="data row12 col0" >KCE</td>
#       <td id="T_9282a_row12_col1" class="data row12 col1" >10,000</td>
#       <td id="T_9282a_row12_col2" class="data row12 col2" >77.25</td>
#       <td id="T_9282a_row12_col3" class="data row12 col3" >10,000</td>
#       <td id="T_9282a_row12_col4" class="data row12 col4" >77.25</td>
#       <td id="T_9282a_row12_col5" class="data row12 col5" >U</td>
#     </tr>
#     <tr>
#       <th id="T_9282a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9282a_row13_col0" class="data row13 col0" >MCS</td>
#       <td id="T_9282a_row13_col1" class="data row13 col1" >78,000</td>
#       <td id="T_9282a_row13_col2" class="data row13 col2" >15.10</td>
#       <td id="T_9282a_row13_col3" class="data row13 col3" >78,000</td>
#       <td id="T_9282a_row13_col4" class="data row13 col4" >15.10</td>
#       <td id="T_9282a_row13_col5" class="data row13 col5" >B</td>
#     </tr>
#     <tr>
#       <th id="T_9282a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9282a_row14_col0" class="data row14 col0" >NER</td>
#       <td id="T_9282a_row14_col1" class="data row14 col1" >32,000</td>
#       <td id="T_9282a_row14_col2" class="data row14 col2" >7.00</td>
#       <td id="T_9282a_row14_col3" class="data row14 col3" >32,000</td>
#       <td id="T_9282a_row14_col4" class="data row14 col4" >7.00</td>
#       <td id="T_9282a_row14_col5" class="data row14

# %%
mask1 = df_merge2.volbuy != df_merge2.available_qty
mask2 = df_merge2.price != df_merge2.cost
df_merge2[mask1 | mask2].style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c640b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >volbuy</th>
#       <th class="col_heading level0 col2" >price</th>
#       <th class="col_heading level0 col3" >available_qty</th>
#       <th class="col_heading level0 col4" >cost</th>
#       <th class="col_heading level0 col5" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c640b_level0_row0" class="row_heading level0 row0" >16</th>
#       <td id="T_c640b_row0_col0" class="data row0 col0" >PTTGC</td>
#       <td id="T_c640b_row0_col1" class="data row0 col1" >6,000</td>
#       <td id="T_c640b_row0_col2" class="data row0 col2" >64.75</td>
#       <td id="T_c640b_row0_col3" class="data row0 col3" >6,000</td>
#       <td id="T_c640b_row0_col4" class="data row0 col4" >61.25</td>
#       <td id="T_c640b_row0_col5" class="data row0 col5" >S</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### New process

# %%
sql = '''
SELECT trade, O.name, O.qty, price, S.qty, buy_target
FROM orders O
JOIN stocks S
ON O.name = S.name
WHERE trade = "B" AND price <> buy_target
'''
orders_df = pd.read_sql(sql, conlite)
orders_df.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d6b45_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >trade</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >qty</th>
#       <th class="col_heading level0 col3" >price</th>
#       <th class="col_heading level0 col4" >qty</th>
#       <th class="col_heading level0 col5" >buy_target</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
sql = '''
SELECT trade, O.name, O.qty, price, S.qty, sell_target
FROM orders O
JOIN stocks S
ON O.name = S.name
WHERE trade = "S" AND price <> sell_target
'''
orders_df = pd.read_sql(sql, conlite)
orders_df.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e7ac5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >trade</th>
#       <th class="col_heading level0 col1" >name</th>
#       <th class="col_heading level0 col2" >qty</th>
#       <th class="col_heading level0 col3" >price</th>
#       <th class="col_heading level0 col4" >qty</th>
#       <th class="col_heading level0 col5" >sell_target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7ac5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e7ac5_row0_col0" class="data row0 col0" >S</td>
#       <td id="T_e7ac5_row0_col1" class="data row0 col1" >AH</td>
#       <td id="T_e7ac5_row0_col2" class="data row0 col2" >1,200</td>
#       <td id="T_e7ac5_row0_col3" class="data row0 col3" >39.25</td>
#       <td id="T_e7ac5_row0_col4" class="data row0 col4" >1,200</td>
#       <td id="T_e7ac5_row0_col5" class="data row0 col5" >39.00</td>
#     </tr>
#     <tr>
#       <th id="T_e7ac5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e7ac5_row1_col0" class="data row1 col0" >S</td>
#       <td id="T_e7ac5_row1_col1" class="data row1 col1" >NER</td>
#       <td id="T_e7ac5_row1_col2" class="data row1 col2" >5,000</td>
#       <td id="T_e7ac5_row1_col3" class="data row1 col3" >4.80</td>
#       <td id="T_e7ac5_row1_col4" class="data row1 col4" >5,000</td>
#       <td id="T_e7ac5_row1_col5" class="data row1 col5" >4.84</td>
#     </tr>
#   </tbody>
# </table>
