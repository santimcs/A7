# %% [markdown]
# ### portmy database: profits, stocks tables
# ### portpg database: consensus, tickers tables
# ### csv files: consensus-ORD.csv

# %%
import pandas as pd
import numpy as np
from datetime import date, timedelta
from sqlalchemy import create_engine
from pandas.tseries.offsets import BDay

engine = create_engine("sqlite:///c:\\ruby\\portmy\\db\\development.sqlite3")
conmy = engine.connect()
engine = create_engine("postgresql+psycopg2://postgres:admin@localhost:5432/portpg_development")
conpg = engine.connect()
engine = create_engine("sqlite:///c:\\ruby\\port_lite\\db\\development.sqlite3")
conlite = engine.connect()
engine = create_engine('mysql+pymysql://root:@localhost:3306/stock')
const = engine.connect()

data_path = "../data/"
csv_path = "\\Users\\User\\iCloudDrive\\"
one_path = "\\Users\\User\\OneDrive\\Documents\\Data\\"
osd_path = "\\Users\\User\\OneDrive\\Documents\\obsidian-git-sync\\Data\\"

# Define a formatting function to format integers with zero decimal places and floats with two decimal places
def format_cell(x):
    if isinstance(x, int):
        return "{:,.0f}".format(x)
    elif isinstance(x, float):
        return "{:.2f}".format(x)
    else:
        return x

pd.options.display.max_rows = 20
#pd.options.display.float_format = '{:.2f}'.format

today = date.today()
today
# Out:
# datetime.date(2023, 6, 10)

# %% [markdown]
# ### Process after last business day, yesterday must be last business day

# %%
# convert the timedelta object to a BusinessDay object
num_business_days = BDay(1)
yesterday = today - num_business_days
print(f'today: {today}')
print(f'yesterday: {yesterday}')
# Out:
# today: 2023-06-10
# yesterday: 2023-06-09 00:00:00

# %%
# find the beginning of the week for the given yesterday
week_start = yesterday.to_period('W').start_time
week_end = yesterday.to_period('W').end_time
week_start = week_start.date()
week_end = week_end.date()
print(f'week start: {week_start}')
print(f'week end: {week_end}')
# Out:
# week start: 2023-06-05
# week end: 2023-06-11

# %%
yesterday = yesterday.date()
week_start, yesterday
# Out:
# (datetime.date(2023, 6, 5), datetime.date(2023, 6, 9))

# %% [markdown]
# ### Restart and Run All Cells

# %%
cols = 'quarter price target_price upside buy hold sell yield max_price min_price pe pbv dly_vol beta'.split()
colt = 'name price target_price upside buy hold sell market sector subsector dly_vol beta yield'.split()
colu = 'price target_price upside buy hold sell mrkt yield'.split()

# %%
format_dict = {
    'latest_amt_y':'{:,}','previous_amt_y':'{:,}','inc_amt_y':'{:,}',   
    'latest_amt_q':'{:,}','previous_amt_q':'{:,}','inc_amt_q':'{:,}',    
    'q_amt_c':'{:,}','y_amt': '{:,}','inc_amt_py':'{:,}', 
    'q_amt_p': '{:,}','inc_amt_pq':'{:,}', 
    'inc_pct_y': '{:.2f}%','inc_pct_q': '{:.2f}%',
    'inc_pct_py': '{:.2f}%','inc_pct_pq': '{:.2f}%',
    'mean_pct': '{:.2f}%','std_pct': '{:.2f}%','upside': '{:.2f}%', 
    
    'price':'{:.2f}','target_price':'{:.2f}','diff':'{:.2f}',
    'eps_a':'{:.2f}','eps_b':'{:.2f}',                
    'pe':'{:.2f}','pbv':'{:.2f}',
    'yield':'{:.2f}%',
    
    'price':'{:.2f}','max_price':'{:.2f}','min_price':'{:.2f}',                
    'pe':'{:.2f}','pbv':'{:.2f}',
    'paid_up':'{:,.2f}','market_cap':'{:,.2f}',   
    'daily_volume':'{:,.2f}','beta':'{:,.2f}', 
    'dly_vol':'{:,.2f}',    
}

# %%
sql = """
SELECT * FROM profits 
ORDER BY id DESC 
"""
tmp = pd.read_sql(sql, conmy)
tmp
# Out:
#       id   name  year  quarter  kind  latest_amt_y  previous_amt_y  inc_amt_y  \
# 0   2600    AWC  2023        1     1       4630796         2100590    2530206
# 1   2599  TFFIF  2023        2     1       1996055         1209444     786611
# 2   2598  OISHI  2023        2     1       1187041          834166     352875
# 3   2597    FPT  2023        2     1       2033577         1684084     349493
# 4   2596     EA  2023        1     1       8557738         6054527    2503211
# ..   ...    ...   ...      ...   ...           ...             ...        ...
# 15  2585   LHFG  2023        1     1       1736882         1334969     401913
# 16  2584    BBL  2023        1     1      32316817        26702007    5614810
# 17  2583    KTB  2023        1     1      34983988        24790196   10193792
# 18  2582    KTC  2023        1     1       7203836         5992158    1211678
# 19  2581    TTB  2023        1     1      15294801        10886994    4407807
#
#     inc_pct_y  latest_amt_q  ...   q_amt_c    y_amt  inc_amt_py  inc_pct_py  \
# 0      120.45       4630796  ...   1422041   645106      776935  120.435246
# 1       65.04       1996055  ...    472071   397594       74477   18.731923
# 2       42.30       1187041  ...    325685   264766       60919   23.008619
# 3       20.75       2033577  ...    316979   312654        4325    1.383318
# 4       41.34       8557738  ...   2319761  1366310      953451   69.782919
# ..        ...           ...  ...       ...      ...         ...         ...
# 15      30.11       1736882  ...    669868   511741      158127   30.899811
# 16      21.03      32316817  ...  10129289  7118064     3011225   42.303989
# 17      41.12      34983988  ...  10066596  8780344     1286252   14.649221
# 18      20.22       7203836  ...   1871710  1747272      124438    7.121845
# 19      40.49      15294801  ...   4294515  3194904     1099611   34.417654
#
#     q_amt_p  inc_amt_pq  inc_pct_pq  ticker_id   mean_pct    std_pct
# 0   1405856       16185    1.151256        699  65.549126  63.858830
# 1    472036          35    0.007415        686  21.914834  29.861353
# 2    316960        8725    2.752713        338  18.367833  18.312317
# 3    314905        2074    0.658611        745   5.750482  10.011356
# 4   2172251      147510    6.790652        148  32.613393  29.025750
# ..      ...         ...         ...        ...        ...        ...
# 15   344754      325114   94.303184        268  41.333249  36.611253
# 16  7569465     2559824   33.817767         50  26.857939  14.092700
# 17  8109182     1957414   24.138242        258  20.931866  15.812750
# 18  1665855      205855   12.357318        259  10.364791   7.866690
# 19  3847324      447191   11.623430        541  23.570271  16.298783
#
# [20 rows x 23 columns]

# %%
names = tmp['name'].values.tolist()
names
# Out:
# ['AWC',
#  'TFFIF',
#  'OISHI',
#  'FPT',
#  'EA',
#  'LANNA',
#  'TASCO',
#  'BDMS',
#  'BEM',
#  'AH',
#  'PTG',
#  'ICHI',
#  'PTTEP',
#  'BH',
#  'KKP',
#  'LHFG',
#  'BBL',
#  'KTB',
#  'KTC',
#  'TTB']

# %%
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'AWC', 'TFFIF', 'OISHI', 'FPT', 'EA', 'LANNA', 'TASCO', 'BDMS', 'BEM', 'AH', 'PTG', 'ICHI', 'PTTEP', 'BH', 'KKP', 'LHFG', 'BBL', 'KTB', 'KTC', 'TTB'"

# %%
sql = '''
SELECT * FROM stocks 
WHERE name IN (%s)
'''
sql = sql % in_p
print(sql)

tmp = pd.read_sql(sql, conlite)
tmp.shape
# Out:
# SELECT * FROM stocks
# WHERE name IN ('AWC', 'TFFIF', 'OISHI', 'FPT', 'EA', 'LANNA', 'TASCO', 'BDMS', 'BEM', 'AH', 'PTG', 'ICHI', 'PTTEP', 'BH', 'KKP', 'LHFG', 'BBL', 'KTB', 'KTC', 'TTB')
# (20, 18)

# %%
sql = '''
SELECT * FROM tickers 
WHERE name IN (%s)
'''
sql = sql % in_p
print(sql)

tmp = pd.read_sql(sql, conmy)
tmp.shape
# Out:
# SELECT * FROM tickers
# WHERE name IN ('AWC', 'TFFIF', 'OISHI', 'FPT', 'EA', 'LANNA', 'TASCO', 'BDMS', 'BEM', 'AH', 'PTG', 'ICHI', 'PTTEP', 'BH', 'KKP', 'LHFG', 'BBL', 'KTB', 'KTC', 'TTB')
# (20, 9)

# %%
sql = '''
SELECT name, kind, year, quarter
FROM profits
ORDER BY name'''
#WHERE quarter = 4
my_profits = pd.read_sql(sql, conmy)
my_profits
# Out:
#      name  kind  year  quarter
# 0      AH     1  2023        1
# 1     AWC     1  2023        1
# 2     BBL     1  2023        1
# 3    BDMS     1  2023        1
# 4     BEM     1  2023        1
# ..    ...   ...   ...      ...
# 15    PTG     1  2023        1
# 16  PTTEP     1  2023        1
# 17  TASCO     1  2023        1
# 18  TFFIF     1  2023        2
# 19    TTB     1  2023        1
#
# [20 rows x 4 columns]

# %%
#sql = """
SELECT name, price, target_price, 
buy, hold, sell, yield, 
date(updated_at), ('%s'::date - date(updated_at)::date) AS days
FROM consensus
WHERE price > 0 AND target_price > 0
"""
sql = sql % (today)
print(sql)
#sql = sql % (today, today)
#AND ('%s'::date - date(updated_at)::date) < 15
consensus = pd.read_sql(sql, conpg)
consensus.set_index('name', inplace=True)
consensus['diff'] = consensus['target_price'] - consensus['price']
consensus['upside'] = round(consensus['diff']/consensus['price']*100,2)
consensus.shape
# Out:
# SELECT name, price, target_price,
# buy, hold, sell, yield,
# date(updated_at), ('2023-05-29'::date - date(updated_at)::date) AS days
# FROM consensus
# WHERE price > 0 AND target_price > 0
# (210, 10)

# %% [markdown]
# ### ruby ruby\crt-consensus-new.rb

# %%
sql = """
SELECT name, target_price
FROM consensus_new
"""
#sql = sql % (today)
print(sql)
#sql = sql % (today, today)
#AND ('%s'::date - date(updated_at)::date) < 15
consensus = pd.read_sql(sql, conpg)
#consensus.set_index('name', inplace=True)
#consensus['diff'] = consensus['target_price'] - consensus['price']
#consensus['upside'] = round(consensus['diff']/consensus['price']*100,2)
consensus.shape
# Out:
# SELECT name, target_price
# FROM consensus_new
# (214, 2)

# %%
data_path = "../data/"
file_name   = 'consensus-new.csv'
input_file = data_path + file_name
consensus = pd.read_csv(input_file, sep=',', index_col=None)
consensus = consensus.rename(columns=str.lower)
consensus
# Out:
#        name  target    max     min  buy  hold  sell
# 0       ACE    3.60    3.6    3.60    0     0     0
# 1    ADVANC  243.14  257.0  225.00   14     0     0
# 2    AEONTS  218.70  248.0  200.00    9     1     0
# 3        AH   46.00   54.1   39.13    9     0     0
# 4        AJ   11.80   11.8   11.80    1     0     0
# ..      ...     ...    ...     ...  ...   ...   ...
# 177   WHAIR    9.20    9.2    9.20    1     0     0
# 178   WHART   12.75   13.0   12.50    2     0     0
# 179   WHAUP    5.25    5.5    5.00    2     0     0
# 180    WICE    9.17   11.0    7.90    1     2     0
# 181    WORK   19.40   20.8   18.00    1     1     0
#
# [182 rows x 7 columns]

# %%
#consensus.loc['TSTH',['target','upside']] = [1.52,1]

# %%
my_profits.columns
# Out:
# Index(['name', 'kind', 'year', 'quarter'], dtype='object')

# %%
prf_css = pd.merge(my_profits, consensus, on='name', how='inner')
prf_css.sample(5).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e6995_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >kind</th>
#       <th class="col_heading level0 col2" >year</th>
#       <th class="col_heading level0 col3" >quarter</th>
#       <th class="col_heading level0 col4" >target</th>
#       <th class="col_heading level0 col5" >max</th>
#       <th class="col_heading level0 col6" >min</th>
#       <th class="col_heading level0 col7" >buy</th>
#       <th class="col_heading level0 col8" >hold</th>
#       <th class="col_heading level0 col9" >sell</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6995_level0_row0" class="row_heading level0 row0" >10</th>
#       <td id="T_e6995_row0_col0" class="data row0 col0" >KTC</td>
#       <td id="T_e6995_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_e6995_row0_col2" class="data row0 col2" >2023</td>
#       <td id="T_e6995_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_e6995_row0_col4" class="data row0 col4" >65.440000</td>
#       <td id="T_e6995_row0_col5" class="data row0 col5" >75.000000</td>
#       <td id="T_e6995_row0_col6" class="data row0 col6" >52.000000</td>
#       <td id="T_e6995_row0_col7" class="data row0 col7" >6</td>
#       <td id="T_e6995_row0_col8" class="data row0 col8" >2</td>
#       <td id="T_e6995_row0_col9" class="data row0 col9" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e6995_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_e6995_row1_col0" class="data row1 col0" >AH</td>
#       <td id="T_e6995_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_e6995_row1_col2" class="data row1 col2" >2023</td>
#       <td id="T_e6995_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_e6995_row1_col4" class="data row1 col4" >46.000000</td>
#       <td id="T_e6995_row1_col5" class="data row1 col5" >54.100000</td>
#       <td id="T_e6995_row1_col6" class="data row1 col6" >39.130000</td>
#       <td id="T_e6995_row1_col7" class="data row1 col7" >9</td>
#       <td id="T_e6995_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_e6995_row1_col9" class="data row1 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e6995_level0_row2" class="row_heading level0 row2" >9</th>
#       <td id="T_e6995_row2_col0" class="data row2 col0" >KTB</td>
#       <td id="T_e6995_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_e6995_row2_col2" class="data row2 col2" >2023</td>
#       <td id="T_e6995_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_e6995_row2_col4" class="data row2 col4" >21.520000</td>
#       <td id="T_e6995_row2_col5" class="data row2 col5" >24.750000</td>
#       <td id="T_e6995_row2_col6" class="data row2 col6" >19.000000</td>
#       <td id="T_e6995_row2_col7" class="data row2 col7" >15</td>
#       <td id="T_e6995_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_e6995_row2_col9" class="data row2 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e6995_level0_row3" class="row_heading level0 row3" >16</th>
#       <td id="T_e6995_row3_col0" class="data row3 col0" >TTB</td>
#       <td id="T_e6995_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_e6995_row3_col2" class="data row3 col2" >2023</td>
#       <td id="T_e6995_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_e6995_row3_col4" class="data row3 col4" >1.620000</td>
#       <td id="T_e6995_row3_col5" class="data row3 col5" >1.840000</td>
#       <td id="T_e6995_row3_col6" class="data row3 col6" >1.500000</td>
#       <td id="T_e6995_row3_col7" class="data row3 col7" >9</td>
#       <td id="T_e6995_row3_col8" class="data row3 col8" >3</td>
#       <td id="T_e6995_row3_col9" class="data row3 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e6995_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_e6995_row4_col0" class="data row4 col0" >BH</td>
#       <td id="T_e6995_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_e6995_row4_col2" class="data row4 col2" >2023</td>
#       <td id="T_e6995_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_e6995_row4_col4" class="data row4 col4" >251.690000</td>
#       <td id="T_e6995_row4_col5" class="data row4 col5" >280.000000</td>
#       <td id="T_e6995_row4_col6" class="data row4 col6" >200.000000</td>
#       <td id="T_e6995_row4_col7" class="data row4 col7" >6</td>
#       <td id="T_e6995_row4_col8" class="data row4 col8" >7</td>
#       <td id="T_e6995_row4_col9" class="data row4 col9" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
#prf_css.days.value_counts(normalize=True).to_frame().style.format('{:.2%}')

# %%
names = prf_css['name']
names
# Out:
# 0        AH
# 1       AWC
# 2       BBL
# 3      BDMS
# 4       BEM
#       ...
# 12      PTG
# 13    PTTEP
# 14    TASCO
# 15    TFFIF
# 16      TTB
# Name: name, Length: 17, dtype: object

# %%
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'AH', 'AWC', 'BBL', 'BDMS', 'BEM', 'BH', 'EA', 'ICHI', 'KKP', 'KTB', 'KTC', 'LANNA', 'PTG', 'PTTEP', 'TASCO', 'TFFIF', 'TTB'"

# %%
#rp = conpg.execute(sqlDel)
#rp.rowcount

# %% [markdown]
# ### If there are deleted records, must rerun from select consensus

# %% [markdown]
# ### Profits w/o consensus

# %%
df_tmp = pd.merge(my_profits, consensus, on='name', how='outer',indicator=True)
prf_wo_css = df_tmp['_merge'] == 'left_only'
df_tmp[prf_wo_css]
# Out:
#      name  kind    year  quarter  target  max  min  buy  hold  sell     _merge
# 7     FPT   1.0  2023.0      2.0     NaN  NaN  NaN  NaN   NaN   NaN  left_only
# 13   LHFG   1.0  2023.0      1.0     NaN  NaN  NaN  NaN   NaN   NaN  left_only
# 14  OISHI   1.0  2023.0      2.0     NaN  NaN  NaN  NaN   NaN   NaN  left_only

# %%
names = df_tmp[prf_wo_css]['name']
names
# Out:
# 7       FPT
# 13     LHFG
# 14    OISHI
# Name: name, dtype: object

# %%
in_p = ", ".join(map(lambda name: "'%s'" % name, names))
in_p
# Out:
# "'FPT', 'LHFG', 'OISHI'"

# %%
sqlDel = '''
DELETE FROM profits
WHERE name IN (%s)
'''
sqlDel = sqlDel % in_p
print(sqlDel)
# Out:
# DELETE FROM profits
# WHERE name IN ('FPT', 'LHFG', 'OISHI')

# %%
rp = conmy.execute(sqlDel)
rp.rowcount
# Out:
# 0

# %% [markdown]
# ### If there are deleted records, must rerun from select profits

# %% [markdown]
# ### Start of Gain Percentage Calculation

# %%
sql = '''
SELECT name, max_price, min_price, pe, pbv, daily_volume AS dly_vol, beta, market
FROM stocks
'''
my_stocks = pd.read_sql(sql, conmy)
my_stocks.sample(10)
# Out:
#        name  max_price  min_price      pe   pbv  dly_vol  beta  \
# 107      MC      11.90       8.70   16.17  2.47    14.20  0.63
# 238     ILM      25.00      15.00   15.23  1.74    14.27  1.39
# 93    LALIN      11.80       8.35    6.45  1.00     2.46  0.84
# 12       BA      14.80       8.40  999.99  1.82    64.57  1.28
# 20     BDMS      32.00      22.10   39.31  5.54  1026.53  0.42
# 177  TLOGIS      12.00      10.00  999.99  1.00     2.92  0.04
# 247     KEX      27.25      17.30  999.99  4.45    48.69  1.02
# 193   UNIPF      10.20       9.30  999.99  0.95     0.43  0.08
# 67   GLOBAL      23.70      16.80   26.82  4.65   405.68  1.02
# 158     STA      32.50      17.70    6.29  0.67   121.31  1.25
#
#                                     market
# 107                               sSET
# 238                               sSET
# 93                                sSET
# 12                                 SET
# 20   SET50 / SETCLMV / SETTHSI / SETWB
# 177                                SET
# 247           SET100 / SETTHSI / SETWB
# 193                                SET
# 67   SET50 / SETCLMV / SETTHSI / SETWB
# 158           SET100 / SETTHSI / SETWB

# %%
filters = [
   (my_stocks.market.str.contains('SET50')),
   (my_stocks.market.str.contains('SET100')),
   (my_stocks.market.str.contains('mai'))]
values = ['SET50','SET100','mai']
my_stocks["mrkt"] = np.select(filters, values, default='SET999')

# %%
my_stocks["mrkt"].value_counts()
# Out:
# SET999    148
# SET50      50
# SET100     46
# mai         9
# Name: mrkt, dtype: int64

# %%
prf_css_stk = pd.merge(prf_css, my_stocks, on='name', how='inner')
prf_css_stk.set_index('name', inplace=True)
prf_css_stk.shape
# Out:
# (17, 17)

# %%
set50 = prf_css_stk.mrkt.str.contains('SET50')
flt_set50 = prf_css_stk[set50]
flt_set50.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c8b84_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >kind</th>
#       <th class="col_heading level0 col1" >year</th>
#       <th class="col_heading level0 col2" >quarter</th>
#       <th class="col_heading level0 col3" >target</th>
#       <th class="col_heading level0 col4" >max</th>
#       <th class="col_heading level0 col5" >min</th>
#       <th class="col_heading level0 col6" >buy</th>
#       <th class="col_heading level0 col7" >hold</th>
#       <th class="col_heading level0 col8" >sell</th>
#       <th class="col_heading level0 col9" >max_price</th>
#       <th class="col_heading level0 col10" >min_price</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >dly_vol</th>
#       <th class="col_heading level0 col14" >beta</th>
#       <th class="col_heading level0 col15" >market</th>
#       <th class="col_heading level0 col16" >mrkt</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8b84_level0_row0" class="row_heading level0 row0" >AWC</th>
#       <td id="T_c8b84_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_c8b84_row0_col1" class="data row0 col1" >2023</td>
#       <td id="T_c8b84_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_
row1_col8" class="data row1 col8" >0</td>
#       <td id="T_e0bd3_row1_col9" class="data row1 col9" >16.40</td>
#       <td id="T_e0bd3_row1_col10" class="data row1 col10" >12.90</td>
#       <td id="T_e0bd3_row1_col11" class="data row1 col11" >26.07</td>
#       <td id="T_e0bd3_row1_col12" class="data row1 col12" >2.59</td>
#       <td id="T_e0bd3_row1_col13" class="data row1 col13" >187.88</td>
#       <td id="T_e0bd3_row1_col14" class="data row1 col14" >1.24</td>
#       <td id="T_e0bd3_row1_col15" class="data row1 col15" >SET100 / SETTHSI    </td>
#       <td id="T_e0bd3_row1_col16" class="data row1 col16" >SET100</td>
#     </tr>
#   </tbody>
# </table>

# %%
set999 = prf_css_stk.mrkt.str.contains('SET999')
flt_set999 = prf_css_stk[set999]
flt_set999.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ed473_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >kind</th>
#       <th class="col_heading level0 col1" >year</th>
#       <th class="col_heading level0 col2" >quarter</th>
#       <th class="col_heading level0 col3" >target</th>
#       <th class="col_heading level0 col4" >max</th>
#       <th class="col_heading level0 col5" >min</th>
#       <th class="col_heading level0 col6" >buy</th>
#       <th class="col_heading level0 col7" >hold</th>
#       <th class="col_heading level0 col8" >sell</th>
#       <th class="col_heading level0 col9" >max_price</th>
#       <th class="col_heading level0 col10" >min_price</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >dly_vol</th>
#       <th class="col_heading level0 col14" >beta</th>
#       <th class="col_heading level0 col15" >market</th>
#       <th class="col_heading level0 col16" >mrkt</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed473_level0_row0" class="row_heading level0 row0" >AH</th>
#       <td id="T_ed473_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ed473_row0_col1" class="data row0 col1" >2023</td>
#       <td id="T_ed473_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_ed473_row0_col3" class="data row0 col3" >46.000000</td>
#       <td id="T_ed473_row0_col4" class="data row0 col4" >54.100000</td>
#       <td id="T_ed473_row0_col5" class="data row0 col5" >39.130000</td>
#       <td id="T_ed473_row0_col6" class="data row0 col6" >9</td>
#       <td id="T_ed473_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_ed473_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_ed473_row0_col9" class="data row0 col9" >35.75</td>
#       <td id="T_ed473_row0_col10" class="data row0 col10" >19.40</td>
#       <td id="T_ed473_row0_col11" class="data row0 col11" >7.48</td>
#       <td id="T_ed473_row0_col12" class="data row0 col12" >1.21</td>
#       <td id="T_ed473_row0_col13" class="data row0 col13" >70.31</td>
#       <td id="T_ed473_row0_col14" class="data row0 col14" >1.51</td>
#       <td id="T_ed473_row0_col15" class="data row0 col15" >sSET / SETTHSI    </td>
#       <td id="T_ed473_row0_col16" class="data row0 col16" >SET999</td>
#     </tr>
#     <tr>
#       <th id="T_ed473_level0_row1" class="row_heading level0 row1" >ICHI</th>
#       <td id="T_ed473_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_ed473_row1_col1" class="data row1 col1" >2023</td>
#       <td id="T_ed473_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_ed473_row1_col3" class="data row1 col3" >16.020000</td>
#       <td id="T_ed473_row1_col4" class="data row1 col4" >17.200000</td>
#       <td id="T_ed473_row1_col5" class="data row1 col5" >15.000000</td>
#       <td id="T_ed473_row1_col6" class="data row1 col6" >6</td>
#       <td id="T_ed473_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_ed473_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_ed473_row1_col9" class="data row1 col9" >12.40</td>
#       <td id="T_ed473_row1_col10" class="data row1 col10" >7.20</td>
#       <td id="T_ed473_row1_col11" class="data row1 col11" >27.06</td>
#       <td id="T_ed473_row1_col12" class="data row1 col12" >2.63</td>
#       <td id="T_ed473_row1_col13" class="data row1 col13" >60.25</td>
#       <td id="T_ed473_row1_col14" class="data row1 col14" >1.71</td>
#       <td id="T_ed473_row1_col15" class="data row1 col15" >sSET / SETCLMV / SETTHSI    </td>
#       <td id="T_ed473_row1_col16" class="data row1 col16" >SET999</td>
#     </tr>
#     <tr>
#       <th id="T_ed473_level0_row2" class="row_heading level0 row2" >LANNA</th>
#       <td id="T_ed473_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_ed473_row2_col1" class="data row2 col1" >2023</td>
#       <td id="T_ed473_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_ed473_row2_col3" class="data row2 col3" >16.000000</td>
#       <td id="T_ed473_row2_col4" class="data row2 col4" >16.000000</td>
#       <td id="T_ed473_row2_col5" class="data row2 col5" >16.000000</td>
#       <td id="T_ed473_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_ed473_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_ed473_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_ed473_row2_col9" class="data row2 col9" >24.60</td>
#       <td id="T_ed473_row2_col10" class="data row2 col10" >16.10</td>
#       <td id="T_ed473_row2_col11" class="data row2 col11" >2.98</td>
#       <td id="T_ed473_row2_col12" class="data row2 col12" >1.16</td>
#       <td id="T_ed473_row2_col13" class="data row2 col13" >30.91</td>
#       <td id="T_ed473_row2_col14" class="data row2 col14" >0.65</td>
#       <td id="T_ed473_row2_col15" class="data row2 col15" >sSET    </td>
#       <td id="T_ed473_row2_col16" class="data row2 col16" >SET999</td>
#     </tr>
#     <tr>
#       <th id="T
b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >kind</th>
#       <th class="col_heading level0 col1" >year</th>
#       <th class="col_heading level0 col2" >quarter</th>
#       <th class="col_heading level0 col3" >target</th>
#       <th class="col_heading level0 col4" >max</th>
#       <th class="col_heading level0 col5" >min</th>
#       <th class="col_heading level0 col6" >buy</th>
#       <th class="col_heading level0 col7" >hold</th>
#       <th class="col_heading level0 col8" >sell</th>
#       <th class="col_heading level0 col9" >max_price</th>
#       <th class="col_heading level0 col10" >min_price</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >dly_vol</th>
#       <th class="col_heading level0 col14" >beta</th>
#       <th class="col_heading level0 col15" >market</th>
#       <th class="col_heading level0 col16" >mrkt</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
flt_all = pd.concat([flt_set50,flt_set100,flt_set999,flt_mai])
flt_all.sort_values(['name'],ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0173b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >kind</th>
#       <th class="col_heading level0 col1" >year</th>
#       <th class="col_heading level0 col2" >quarter</th>
#       <th class="col_heading level0 col3" >target</th>
#       <th class="col_heading level0 col4" >max</th>
#       <th class="col_heading level0 col5" >min</th>
#       <th class="col_heading level0 col6" >buy</th>
#       <th class="col_heading level0 col7" >hold</th>
#       <th class="col_heading level0 col8" >sell</th>
#       <th class="col_heading level0 col9" >max_price</th>
#       <th class="col_heading level0 col10" >min_price</th>
#       <th class="col_heading level0 col11" >pe</th>
#       <th class="col_heading level0 col12" >pbv</th>
#       <th class="col_heading level0 col13" >dly_vol</th>
#       <th class="col_heading level0 col14" >beta</th>
#       <th class="col_heading level0 col15" >market</th>
#       <th class="col_heading level0 col16" >mrkt</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0173b_level0_row0" class="row_heading level0 row0" >AH</th>
#       <td id="T_0173b_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_0173b_row0_col1" class="data row0 col1" >2023</td>
#       <td id="T_0173b_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_0173b_row0_col3" class="data row0 col3" >46.000000</td>
#       <td id="T_0173b_row0_col4" class="data row0 col4" >54.100000</td>
#       <td id="T_0173b_row0_col5" class="data row0 col5" >39.130000</td>
#       <td id="T_0173b_row0_col6" class="data row0 col6" >9</td>
#       <td id="T_0173b_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_0173b_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_0173b_row0_col9" class="data row0 col9" >35.75</td>
#       <td id="T_0173b_row0_col10" class="data row0 col10" >19.40</td>
#       <td id="T_0173b_row0_col11" class="data row0 col11" >7.48</td>
#       <td id="T_0173b_row0_col12" class="data row0 col12" >1.21</td>
#       <td id="T_0173b_row0_col13" class="data row0 col13" >70.31</td>
#       <td id="T_0173b_row0_col14" class="data row0 col14" >1.51</td>
#       <td id="T_0173b_row0_col15" class="data row0 col15" >sSET / SETTHSI    </td>
#       <td id="T_0173b_row0_col16" class="data row0 col16" >SET999</td>
#     </tr>
#     <tr>
#       <th id="T_0173b_level0_row1" class="row_heading level0 row1" >AWC</th>
#       <td id="T_0173b_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_0173b_row1_col1" class="data row1 col1" >2023</td>
#       <td id="T_0173b_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_0173b_row1_col3" class="data row1 col3" >6.130000</td>
#       <td id="T_0173b_row1_col4" class="data row1 col4" >6.800000</td>
#       <td id="T_0173b_row1_col5" class="data row1 col5" >5.500000</td>
#       <td id="T_0173b_row1_col6" class="data row1 col6" >3</td>
#       <td id="T_0173b_row1_col7" class="data row1 col7" >3</td>
#       <td id="T_0173b_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_0173b_row1_col9" class="data row1 col9" >6.55</td>
#       <td id="T_0173b_row1_col10" class="data row1 col10" >4.56</td>
#       <td id="T_0173b_row1_col11" class="data row1 col11" >56.69</td>
#       <td id="T_0173b_row1_col12" class="data row1 col12" >2.38</td>
#       <td id="T_0173b_row1_col13" class="data row1 col13" >316.90</td>
#       <td id="T_0173b_row1_col14" class="data row1 col14" >1.13</td>
#       <td id="T_0173b_row1_col15" class="data row1 col15" >SET50 / SETTHSI    </td>
#       <td id="T_0173b_row1_col16" class="data row1 col16" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_0173b_level0_row2" class="row_heading level0 row2" >BBL</th>
#       <td id="T_0173b_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_0173b_row2_col1" class="data row2 col1" >2023</td>
#       <td id="T_0173b_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_0173b_row2_col3" class="data row2 col3" >185.770000</td>
#       <td id="T_0173b_row2_col4" class="data row2 col4" >200.000000</td>
#       <td id="T_0173b_row2_col5" class="data row2 col5" >155.000000</td>
#       <td id="T_0173b_row2_col6" class="data row2 col6" >14</td>
#       <td id="T_0173b_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_0173b_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_0173b_row2_col9" class="data row2 col9" >163.00</td>
#       <td id="T_0173b_row2_col10" class="data row2 col10" >124.50</td>
#       <td id="T_0173b_row2_col11" class="data row2 col11" >10.95</td>
#       <td id="T_0173b_row2_col12" class="data row2 col12" >0.60</td>
#       <td id="T_0173b_row2_col13" class="data row2 col13" >2,107.11</td>
#       <td id="T_0173b_row2_col14" class="data row2 col14" >0.86</td>
#       <td id="T_0173b_row2_col15" class="data row2 col15" >SET50 / SETCLMV / SETHD / SETTHSI    </td>
#       <td id="T_0173b_row2_col16" class="data row2 col16" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_0173b_level0_row3" class="row_heading level0 row3" >BDMS</th>
#       <td id="T_0173b_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_0173b_row3_col1" class="data row3 col1" >2023</td>
#       <td id="T_0173b_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_0173b_row3_col3" class="data row3 col3" >34.400000</td>
#       <td id="T_0173b_row3_col4" class="data row3 col4" >37.400000</td>
#       <td id="T_0173b_row3_col5" class="data row3 col5" >31.000000</td>
#       <td id="T_0173b_row3_col6" class="data row3 col6" >16</td>
#       <td id="T
row1_col16" class="data row1 col16" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_2a411_level0_row2" class="row_heading level0 row2" >BBL</th>
#       <td id="T_2a411_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_2a411_row2_col1" class="data row2 col1" >2023</td>
#       <td id="T_2a411_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_2a411_row2_col3" class="data row2 col3" >185.770000</td>
#       <td id="T_2a411_row2_col4" class="data row2 col4" >200.000000</td>
#       <td id="T_2a411_row2_col5" class="data row2 col5" >155.000000</td>
#       <td id="T_2a411_row2_col6" class="data row2 col6" >14</td>
#       <td id="T_2a411_row2_col7" class="data row2 col7" >1</td>
#       <td id="T_2a411_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_2a411_row2_col9" class="data row2 col9" >163.00</td>
#       <td id="T_2a411_row2_col10" class="data row2 col10" >124.50</td>
#       <td id="T_2a411_row2_col11" class="data row2 col11" >10.95</td>
#       <td id="T_2a411_row2_col12" class="data row2 col12" >0.60</td>
#       <td id="T_2a411_row2_col13" class="data row2 col13" >2,107.11</td>
#       <td id="T_2a411_row2_col14" class="data row2 col14" >0.86</td>
#       <td id="T_2a411_row2_col15" class="data row2 col15" >SET50 / SETCLMV / SETHD / SETTHSI    </td>
#       <td id="T_2a411_row2_col16" class="data row2 col16" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_2a411_level0_row3" class="row_heading level0 row3" >BDMS</th>
#       <td id="T_2a411_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_2a411_row3_col1" class="data row3 col1" >2023</td>
#       <td id="T_2a411_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_2a411_row3_col3" class="data row3 col3" >34.400000</td>
#       <td id="T_2a411_row3_col4" class="data row3 col4" >37.400000</td>
#       <td id="T_2a411_row3_col5" class="data row3 col5" >31.000000</td>
#       <td id="T_2a411_row3_col6" class="data row3 col6" >16</td>
#       <td id="T_2a411_row3_col7" class="data row3 col7" >2</td>
#       <td id="T_2a411_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_2a411_row3_col9" class="data row3 col9" >32.00</td>
#       <td id="T_2a411_row3_col10" class="data row3 col10" >22.10</td>
#       <td id="T_2a411_row3_col11" class="data row3 col11" >39.31</td>
#       <td id="T_2a411_row3_col12" class="data row3 col12" >5.54</td>
#       <td id="T_2a411_row3_col13" class="data row3 col13" >1,026.53</td>
#       <td id="T_2a411_row3_col14" class="data row3 col14" >0.42</td>
#       <td id="T_2a411_row3_col15" class="data row3 col15" >SET50 / SETCLMV / SETTHSI / SETWB    </td>
#       <td id="T_2a411_row3_col16" class="data row3 col16" >SET50</td>
#     </tr>
#     <tr>
#       <th id="T_2a411_level0_row4" class="row_heading level0 row4" >BEM</th>
#       <td id="T_2a411_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_2a411_row4_col1" class="data row4 col1" >2023</td>
#       <td id="T_2a411_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_2a411_row4_col3" class="data row4 col3" >11.100000</td>
#       <td id="T_2a411_row4_col4" class="data row4 col4" >14.000000</td>
#       <td id="T_2a411_row4_col5" class="data row4 col5" >9.500000</td>
#       <td id="T_2a411_row4_col6" class="data row4 col6" >9</td>
#       <td id="T_2a411_row4_col7" class="data row4 col7" >2</td>
#       <td id="T_2a411_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_2a411_row4_col9" class="data row4 col9" >10.10</td>
#       <td id="T_2a411_row4_col10" class="data row4 col10" >7.90</td>
#       <td id="T_2a411_row4_col11" class="data row4 col11" >67.20</td>
#       <td id="T_2a411_row4_col12" class="data row4 col12" >3.97</td>
#       <td id="T_2a411_row4_col13" class="data row4 col13"

# %%
'candidates to buy = ' + str(flt_all.shape[0]) + ' stocks'
# Out:
# 'candidates to buy = 17 stocks'

# %%
sql = '''
SELECT name, sector, subsector
FROM tickers'''
pg_tickers = pd.read_sql(sql, conpg)
pg_tickers.shape[0]
# Out:
# 403

# %%
final = pd.merge(flt_all, pg_tickers, on='name', how='inner')
final.reset_index()
final.sort_values(['name'],ascending=[True]).to_json("C:/ClearStep/dist/consensus.json", orient="table")

# %% [markdown]
# ### Final result to update to port_lite stocks

# %%
final.sort_values(['name'],ascending=[True]).style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4f129_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >kind</th>
#       <th class="col_heading level0 col2" >year</th>
#       <th class="col_heading level0 col3" >quarter</th>
#       <th class="col_heading level0 col4" >target</th>
#       <th class="col_heading level0 col5" >max</th>
#       <th class="col_heading level0 col6" >min</th>
#       <th class="col_heading level0 col7" >buy</th>
#       <th class="col_heading level0 col8" >hold</th>
#       <th class="col_heading level0 col9" >sell</th>
#       <th class="col_heading level0 col10" >max_price</th>
#       <th class="col_heading level0 col11" >min_price</th>
#       <th class="col_heading level0 col12" >pe</th>
#       <th class="col_heading level0 col13" >pbv</th>
#       <th class="col_heading level0 col14" >dly_vol</th>
#       <th class="col_heading level0 col15" >beta</th>
#       <th class="col_heading level0 col16" >market</th>
#       <th class="col_heading level0 col17" >mrkt</th>
#       <th class="col_heading level0 col18" >sector</th>
#       <th class="col_heading level0 col19" >subsector</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f129_level0_row0" class="row_heading level0 row0" >12</th>
#       <td id="T_4f129_row0_col0" class="data row0 col0" >AH</td>
#       <td id="T_4f129_row0_col1" class="data row0 col1" >1</td>
#       <td id="T_4f129_row0_col2" class="data row0 col2" >2023</td>
#       <td id="T_4f129_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_4f129_row0_col4" class="data row0 col4" >46.000000</td>
#       <td id="T_4f129_row0_col5" class="data row0 col5" >54.100000</td>
#       <td id="T_4f129_row0_col6" class="data row0 col6" >39.130000</td>
#       <td id="T_4f129_row0_col7" class="data row0 col7" >9</td>
#       <td id="T_4f129_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_4f129_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_4f129_row0_col10" class="data row0 col10" >35.75</td>
#       <td id="T_4f129_row0_col11" class="data row0 col11" >19.40</td>
#       <td id="T_4f129_row0_col12" class="data row0 col12" >7.48</td>
#       <td id="T_4f129_row0_col13" class="data row0 col13" >1.21</td>
#       <td id="T_4f129_row0_col14" class="data row0 col14" >70.31</td>
#       <td id="T_4f129_row0_col15" class="data row0 col15" >1.51</td>
#       <td id="T_4f129_row0_col16" class="data row0 col16" >sSET / SETTHSI    </td>
#       <td id="T_4f129_row0_col17" class="data row0 col17" >SET999</td>
#       <td id="T_4f129_row0_col18" class="data row0 col18" >Industrials</td>
#       <td id="T_4f129_row0_col19" class="data row0 col19" >Automotive</td>
#     </tr>
#     <tr>
#       <th id="T_4f129_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_4f129_row1_col0" class="data row1 col0" >AWC</td>
#       <td id="T_4f129_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_4f129_row1_col2" class="data row1 col2" >2023</td>
#       <td id="T_4f129_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_4f129_row1_col4" class="data row1 col4" >6.130000</td>
#       <td id="T_4f129_row1_col5" class="data row1 col5" >6.800000</td>
#       <td id="T_4f129_row1_col6" class="data row1 col6" >5.500000</td>
#       <td id="T_4f129_row1_col7" class="data row1 col7" >3</td>
#       <td id="T_4f129_row1_col8" class="data row1 col8" >3</td>
#       <td id="T_4f129_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_4f129_row1_col10" class="data row1 col10" >6.55</td>
#       <td id="T_4f129_row1_col11" class="data row1 col11" >4.56</td>
#       <td id="T_4f129_row1_col12" class="data row1 col12" >56.69</td>
#       <td id="T_4f129_row1_col13" class="data row1 col13" >2.38</td>
#       <td id="T_4f129_row1_col14" class="data row1 col14" >316.90</td>
#       <td id="T_4f129_row1_col15" class="data row1 col15" >1.13</td>
#       <td id="T_4f129_row1_col16" class="data row1 col16" >SET50 / SETTHSI    </td>
#       <td id="T_4f129_row1_col17" class="data row1 col17" >SET50</td>
#       <td id="T_4f129_row1_col18" class="data row1 col18" >Property & Construction</td>
#       <td id="T_4f129_row1_col19" class="data row1 col19" >Property Development</td>
#     </tr>
#     <tr>
#       <th id="T_4f129_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T
row4_col8" class="data row4 col8" >2</td>
#       <td id="T_4f129_row4_col9" class="data row4 col9" >0

# %%
final.shape
# Out:
# (17, 20)

# %% [markdown]
# ### Matching check with Buy table in MySql database to filter only records not yet in stocks

# %%
sql = """
SELECT name
FROM buy
WHERE active = 1"""
buy_df = pd.read_sql(sql, const)
buy_df.shape
# Out:
# (27, 1)

# %%
final_buy = pd.merge(my_profits, buy_df, on='name', how='outer', indicator=True)
final_buy.shape
# Out:
# (45, 5)

# %%
final_buy.dtypes
# Out:
# name         object
# kind        float64
# year        float64
# quarter     float64
# _merge     category
# dtype: object

# %%
not_in_port = final_buy.loc[
    final_buy['_merge'] == 'left_only']
not_in_port
# Out:
#      name  kind    year  quarter     _merge
# 1     AWC   1.0  2023.0      1.0  left_only
# 2     BBL   1.0  2023.0      1.0  left_only
# 3    BDMS   1.0  2023.0      1.0  left_only
# 4     BEM   1.0  2023.0      1.0  left_only
# 5      BH   1.0  2023.0      1.0  left_only
# ..    ...   ...     ...      ...        ...
# 14  OISHI   1.0  2023.0      2.0  left_only
# 15    PTG   1.0  2023.0      1.0  left_only
# 16  PTTEP   1.0  2023.0      1.0  left_only
# 17  TASCO   1.0  2023.0      1.0  left_only
# 19    TTB   1.0  2023.0      1.0  left_only
#
# [18 rows x 5 columns]

# %%
not_in_port.dtypes
# Out:
# name         object
# kind        float64
# year        float64
# quarter     float64
# _merge     category
# dtype: object

# %%
not_in_port2 = not_in_port.copy()
not_in_port2
# Out:
#      name  kind    year  quarter     _merge
# 1     AWC   1.0  2023.0      1.0  left_only
# 2     BBL   1.0  2023.0      1.0  left_only
# 3    BDMS   1.0  2023.0      1.0  left_only
# 4     BEM   1.0  2023.0      1.0  left_only
# 5      BH   1.0  2023.0      1.0  left_only
# ..    ...   ...     ...      ...        ...
# 14  OISHI   1.0  2023.0      2.0  left_only
# 15    PTG   1.0  2023.0      1.0  left_only
# 16  PTTEP   1.0  2023.0      1.0  left_only
# 17  TASCO   1.0  2023.0      1.0  left_only
# 19    TTB   1.0  2023.0      1.0  left_only
#
# [18 rows x 5 columns]

# %%
file_name = 'consensus-ORD.csv'
data_file = data_path + file_name
output_file = csv_path + file_name
osd_file = osd_path + file_name
one_file = one_path + file_name

not_in_port.sort_values(['name'],ascending=[True]).to_csv(output_file, index=False)
not_in_port.sort_values(['name'],ascending=[True]).to_csv(data_file, index=False)
not_in_port.sort_values(['name'],ascending=[True]).to_csv(osd_file, index=False)
not_in_port.sort_values(['name'],ascending=[True]).to_csv(one_file, index=False)

# %%
not_in_port2.dtypes
# Out:
# name         object
# kind        float64
# year        float64
# quarter     float64
# _merge     category
# dtype: object

# %%
not_in_port2.drop(columns=['_merge'],inplace=True)

# %%
sql = """
SELECT *
FROM stocks"""
stocks = pd.read_sql(sql, conlite)
stocks.shape
# Out:
# (80, 18)

# %%
df_merge4 = pd.merge(not_in_port2, stocks, on='name', how='outer', indicator=True)
df_merge4.shape
# Out:
# (80, 22)

# %%
df_merge4[df_merge4['_merge'] == 'left_only'].sort_values('name',ascending=True)
# Out:
# Empty DataFrame
# Columns: [name, kind, year, quarter, id, max_price, min_price, status, buy_target, sell_target, volume, beta, cost, qty, buy_spread, sell_spread, available_qty, bl, sh, reason, market, _merge]
# Index: []
#
# [0 rows x 22 columns]
