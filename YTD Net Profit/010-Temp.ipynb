# %% [markdown]
# ### Restart and run all

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from sqlalchemy import create_engine
from datetime import date, timedelta
import calendar

engine = create_engine("sqlite:///c:\\ruby\\expense\\db\\development.sqlite3")
connection = engine.connect()

format_dict = {'amount':'{:,}','y_amt':'{:,}','yoy_gain':'{:,}',
               'q_amt_c':'{:,}','q_amt_p':'{:,}',
               'aq_amt':'{:,}','ay_amt':'{:,}','acc_gain':'{:,}',
               'latest_amt':'{:,}','previous_amt':'{:,}','inc_amt':'{:,}',
               'latest_amt_q':'{:,}','previous_amt_q':'{:,}','inc_amt_q':'{:,}',
               'latest_amt_y':'{:,}','previous_amt_y':'{:,}','inc_amt_y':'{:,}',
               'inc_pct':'{:.2f}','inc_pct_q':'{:.2f}','inc_pct_y':'{:.2f}'}
year = '2023'
today = date.today()
today
# Out:
# datetime.date(2023, 1, 13)

# %%
sql = """
SELECT date, amount, C.name AS item, G.name AS kind, strftime("%m", date) as Month 
FROM transactions T 
JOIN categories C ON category_id = C.id 
JOIN groups G ON group_id = G.id 
WHERE strftime('%Y', date) = '%s'
"""
sql = sql % year
print(sql)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15968/3455222274.py in <module>
#       6 WHERE strftime('%Y', date) = '%s'
#       7 """
# ----> 8 sql = sql % year
#       9 print(sql)
#
# ValueError: unsupported format character 'm' (0x6d) at index 65

# %%
df_t = pd.read_sql(sql, connection)
df_t.style.format(format_dict)
# Out:
# <style type="text/css">
# </style>
# <table id="T_e2533_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >date</th>
#       <th class="col_heading level0 col1" >amount</th>
#       <th class="col_heading level0 col2" >item</th>
#       <th class="col_heading level0 col3" >kind</th>
#       <th class="col_heading level0 col4" >Month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2533_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e2533_row0_col0" class="data row0 col0" >2023-01-04</td>
#       <td id="T_e2533_row0_col1" class="data row0 col1" >5,670</td>
#       <td id="T_e2533_row0_col2" class="data row0 col2" >Pets</td>
#       <td id="T_e2533_row0_col3" class="data row0 col3" >Pets</td>
#       <td id="T_e2533_row0_col4" class="data row0 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_e2533_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e2533_row1_col0" class="data row1 col0" >2023-01-04</td>
#       <td id="T_e2533_row1_col1" class="data row1 col1" >10,960</td>
#       <td id="T_e2533_row1_col2" class="data row1 col2" >Medicine</td>
#       <td id="T_e2533_row1_col3" class="data row1 col3" >Medicine</td>
#       <td id="T_e2533_row1_col4" class="data row1 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_e2533_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e2533_row2_col0" class="data row2 col0" >2023-01-02</td>
#       <td id="T_e2533_row2_col1" class="data row2 col1" >1,670</td>
#       <td id="T_e2533_row2_col2" class="data row2 col2" >Food</td>
#       <td id="T_e2533_row2_col3" class="data row2 col3" >Food</td>
#       <td id="T_e2533_row2_col4" class="data row2 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_e2533_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e2533_row3_col0" class="data row3 col0" >2023-01-04</td>
#       <td id="T_e2533_row3_col1" class="data row3 col1" >280</td>
#       <td id="T_e2533_row3_col2" class="data row3 col2" >Food</td>
#       <td id="T_e2533_row3_col3" class="data row3 col3" >Food</td>
#       <td id="T_e2533_row3_col4" class="data row3 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_e2533_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e2533_row4_col0" class="data row4 col0" >2023-01-03</td>
#       <td id="T_e2533_row4_col1" class="data row4 col1" >100</td>
#       <td id="T_e2533_row4_col2" class="data row4 col2" >Food</td>
#       <td id="T_e2533_row4_col3" class="data row4 col3" >Food</td>
#       <td id="T_e2533_row4_col4" class="data row4 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_e2533_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e2533_row5_col0" class="data row5 col0" >2023-01-01</td>
#       <td id="T_e2533_row5_col1" class="data row5 col1" >1,200</td>
#       <td id="T_e2533_row5_col2" class="data row5 col2" >Fuel</td>
#       <td id="T_e2533_row5_col3" class="data row5 col3" >Transportation</td>
#       <td id="T_e2533_row5_col4" class="data row5 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_e2533_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e2533_row6_col0" class="data row6 col0" >2023-01-01</td>
#       <td id="T_e2533_row6_col1" class="data row6 col1" >120</td>
#       <td id="T_e2533_row6_col2" class="data row6 col2" >Food</td>
#       <td id="T_e2533_row6_col3" class="data row6 col3" >Food</td>
#       <td id="T_e2533_row6_col4" class="data row6 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_e2533_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e2533_row7_col0" class="data row7 col0" >2023-01-05</td>
#       <td id="T_e2533_row7_col1" class="data row7 col1" >920</td>
#       <td id="T_e2533_row7_col2" class="data row7 col2" >Pets</td>
#       <td id="T_e2533_row7_col3" class="data row7 col3" >Pets</td>
#       <td id="T_e2533_row7_col4" class="data row7 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_e2533_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e2533_row8_col0" class="data row8 col0" >2023-01-04</td>
#       <td id="T_e2533_row8_col1" class="data row8 col1" >100</td>
#       <td id="T_e2533_row8_col2" class="data row8 col2" >Merit Making</td>
#       <td id="T_e2533_row8_col3" class="data row8 col3" >Others</td>
#       <td id="T_e2533_row8_col4" class="data row8 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_e2533_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e2533_row9_col0" class="data row9 col0" >2023-01-09</td>
#       <td id="T_e2533_row9_col1" class="data row9 col1" >3,590</td>
#       <td id="T_e2533_row9_col2" class="data row9 col2" >Plum</td>
#       <td id="T_e2533_row9_col3" class="data row9 col3" >Shelter</td>
#       <td id="T_e2533_row9_col4" class="data row9 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_e2533_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e2533_row10_col0" class="data row10 col0" >2023-01-05</td>
#       <td id="T_e2533_row10_col1" class="data row10 col1" >10,100</td>
#       <td id="T_e2533_row10_col2" class="data row10 col2" >Plum</td>
#       <td id="T_e2533_row10_col3" class="data row10 col3" >Shelter</td>
#       <td id="T_e2533_row10_col4" class="data row10 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_e2533_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e2533_row11_col0" class="data row11 col0" >2023-01-12</td>
#       <td id="T_e2533_row11_col1" class="data row11 col1" >3,770</td>
#       <td id="T_e2533_row11_col2" class="data row11 col2" >Pets</td>
#       <td id="T_e2533_row11_col3" class="data row11 col3" >Pets</td>
#       <td id="T_e2533_row11_col4" class="data row11 col4" >01</td>
#     </tr>
#     <tr>
#       <th id="T_e2533_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e2533_row12_col0" class="data row12 col0" >2023-01-13</td>
#       <td id="T_e2533_row12_col1" class="data row12 col1" >790</td>
#       <td id="T_e2533_row12_col2" class="data row12 col2" >Pets</td>
#       <td id="T_e2533_row12_col3" class="data row12 col3" >Pets</td>
#       <td id="T_e2533_row12_col4" class="data row12 col4" >01</td>
#     </tr>
#   </tbody>
# </table>

# %%
grouped = df_t.groupby("item")
grouped.sum().style.format(format_dict)

# %%
grouped = df_t.groupby("kind")
grouped.sum().style.format(format_dict)

# %%
monthly = df_t.groupby("Month")
monthly.sum().style.format(format_dict)

# %%
expense = grouped.amount.sum()
sum(expense)
